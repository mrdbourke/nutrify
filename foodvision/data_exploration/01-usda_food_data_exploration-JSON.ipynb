# %% [markdown]
# # Exploring the data downloaded from USDA FoodData Central
#
# See the download here: https://fdc.nal.usda.gov/download-datasets.html
#
# This notework works with the JSON version of the data.

# %%
# Append the upper level directory to sys
import os
import sys
sys.path.append("..")

import pandas as pd
import numpy as np

from pathlib import Path

import torch

from utils.misc import sort_dict_by_values

# Get config
from configs.default_config import config

args = config

# Connect to GCP
from utils.gcp_utils import set_gcp_credentials, test_gcp_connection
set_gcp_credentials(path_to_key="../utils/google-storage-key.json")
test_gcp_connection()

import wandb

# Initialize a new run
from utils.wandb_utils import wandb_load_artifact, wandb_download_and_load_labels

notes = f"autolabel new images"

run = wandb.init(project=args.wandb_project, 
                 job_type=args.wandb_job_type,
                 tags=['auto_label_new_images'],
                 notes=notes)

annotations, class_names, class_dict, reverse_class_dict, labels_path = wandb_download_and_load_labels(wandb_run=run,
wandb_labels_artifact_name=args.wandb_labels_artifact)

len(annotations.label.unique())
# Out:
# [INFO] GCP credentials set!
# [INFO] GCP connection successful! Access to GCP for saving/loading data and models available.
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: mrdbourke. Use `wandb login --relogin` to force relogin
# wandb version 0.14.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/home/daniel/code/nutrify/foodvision/data_exploration/wandb/run-20230412_144620-3fx8g75b</code>
# Syncing run <strong><a href="https://wandb.ai/mrdbourke/test_wandb_artifacts_by_reference/runs/3fx8g75b" target="_blank">pious-valley-648</a></strong> to <a href="https://wandb.ai/mrdbourke/test_wandb_artifacts_by_reference" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# [INFO] Labels directory: ./artifacts/food_vision_labels:v77
# [INFO] Labels path: artifacts/food_vision_labels:v77/annotations.csv
# [INFO] Working with: 331 classes
# 331

# %%
import gspread
import pandas as pd

# Open the sheet with Google Sheets
gc = gspread.oauth()

# See the link here: https://docs.google.com/spreadsheets/d/1fgNtqfuaBSbPBPQfyzYAmRb1UUHdsRphoAqXHfP-dD0/edit?usp=sharing 
sheet = gc.open("nutrify-name-to-fdc-id")
worksheet = sheet.sheet1
rows = worksheet.get_all_records()
nutrify_to_fdcid = pd.DataFrame(rows)

# Replace all blank rows in fdc_id with NaN
nutrify_to_fdcid['fdc_id'] = nutrify_to_fdcid['fdc_id'].replace('', None)

# Go through class_names and add classes that don't appear in the nutrify_to_fdcid dataframe to the Google Sheet
classes_added_to_sheet = []
for class_name in class_names:
    if class_name not in nutrify_to_fdcid['class_name'].values:
        print(f"Adding row for: {class_name}")
        classes_added_to_sheet.append(class_name)
        worksheet.append_row([0, class_name, None])
if len(classes_added_to_sheet) == 0:
    print(f"Looks like all the classes are already in the Google Sheet! Onwards!")
else:
    print(f"Added {len(classes_added_to_sheet)} classes to the Google Sheet! See:\n{classes_added_to_sheet}")

# Get the latest version of the sheet
# See the link here: https://docs.google.com/spreadsheets/d/1fgNtqfuaBSbPBPQfyzYAmRb1UUHdsRphoAqXHfP-dD0/edit?usp=sharing 
sheet = gc.open("nutrify-name-to-fdc-id")
worksheet = sheet.sheet1
rows = worksheet.get_all_records()
nutrify_to_fdcid = pd.DataFrame(rows)

# Replace all blank rows in fdc_id with NaN
nutrify_to_fdcid['fdc_id'] = nutrify_to_fdcid['fdc_id'].replace('', None)

# Delete duplicates
nutrify_to_fdcid = nutrify_to_fdcid.drop_duplicates(subset=['class_name'])
nutrify_to_fdcid.head()
# Out:
# Looks like all the classes are already in the Google Sheet! Onwards!
#    number     class_name   fdc_id
# 0       0        achacha     None
# 1       1  almond_butter  2262074
# 2       2        almonds  2346393
# 3       3  apple_custard   168175
# 4       4    apple_green  1750342

# %%
# How many rows have an FDC ID?
rows_with_fdcid = nutrify_to_fdcid[nutrify_to_fdcid["fdc_id"].notna()]
rows_without_fdcid = nutrify_to_fdcid[nutrify_to_fdcid["fdc_id"].isna()]

print(f"Rows with FDC ID: {len(rows_with_fdcid)}")
print(f"Rows without FDC ID: {len(rows_without_fdcid)}")
# nutrify_to_fdcid.isna()
# Out:
# Rows with FDC ID: 280
# Rows without FDC ID: 51

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from tqdm.auto import tqdm

from pathlib import Path

# %% [markdown]
# ## Get FDC Data
#
# Download data from here: https://fdc.nal.usda.gov/download-datasets.html

# %%
targ_dir = "data/2022/JSON"

# Get all the files in the directory
data_files = sorted(list(Path(targ_dir).glob("*.json")))
data_files

# Combine them into one big JSON?
data = {}
for file in tqdm(data_files):
    with open(file) as f:
        data = {**data, **json.load(f)}

dataset_names = list(data.keys())
print(f"Dataset names: {dataset_names}")

print(f"Length of Foundation Foods: {len(data['FoundationFoods'])}")
print(f"Length of Legacy Foods: {len(data['SRLegacyFoods'])}")
print(f"Length of Survey Foods: {len(data['SurveyFoods'])}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Dataset names: ['FoundationFoods', 'SRLegacyFoods', 'SurveyFoods']
# Length of Foundation Foods: 210
# Length of Legacy Foods: 7793
# Length of Survey Foods: 5624

# %%
# nutrify_to_fdcid_keys = [int(key) for key in fdcid_to_nutrify_name.keys() if key is not None]
nutrify_to_fdcid_keys = nutrify_to_fdcid["fdc_id"].dropna().tolist()
print(nutrify_to_fdcid_keys[:10])

# Create list of nutrify food items
nutrify_food_items = []
all_nutrients = []

# Get a list of all descriptions and map to FDC ID
fdcid_to_description_list = []

# Get a list of all FDC IDs (to make sure the Nutrify FDC IDs are correct FDC IDs)
fdcid_list = []

for dataset_name in dataset_names:
    for item in data[dataset_name]:
        fdcid = item["fdcId"]
        description = item["description"]
        fdcid_to_description_dict = {}
        fdcid_to_description_dict["fdcid"] = fdcid
        fdcid_to_description_dict["description"] = description
        fdcid_to_description_list.append(fdcid_to_description_dict)

        fdcid_list.append(fdcid)
        # fdcid_to_description_list.append((fdcid, description))

        if item["fdcId"] in nutrify_to_fdcid_keys:
            nutrify_food_items.append(item)
            for nutrient in item["foodNutrients"]:
                all_nutrients.append(nutrient["nutrient"]["name"])

# Make sure all nutrify_to_fdcid_keys are in the fdcid_list
for fdcid in nutrify_to_fdcid_keys:
    if fdcid not in fdcid_list:
        print(f"Nutrify FDC ID {fdcid} is not in the FDC ID list! Please update before continuing.")
        # Find the row it belongs to
        row = nutrify_to_fdcid[nutrify_to_fdcid["fdc_id"] == fdcid]
        print(f"Key {fdcid} belongs to row: {row}")
        
# Sort and set the all_nutrients
all_nutrients = sorted(list(set(all_nutrients)))
print(f"Number of Nutrify foods that line up with FDC IDs: {len(nutrify_food_items)}")
print(f"Number of unique nutrients: {len(all_nutrients)}")
# Out:
# [2262074, 2346393, 168175, 1750342, 1750339, 171697, 169205, 168389, 171705, 749420]
# Number of Nutrify foods that line up with FDC IDs: 279
# Number of unique nutrients: 236

# %%
fdcid_to_description_df = pd.DataFrame(fdcid_to_description_list)

# Drop duplicates based on FDC ID
fdcid_to_description_df = fdcid_to_description_df.drop_duplicates(subset=["fdcid"])

# Drop duplicates based on description
fdcid_to_description_df = fdcid_to_description_df.drop_duplicates(subset=["description"])
len(fdcid_to_description_df)
# Out:
# 13475

# %%
# TODO: sort all nutrients into different categories, e.g. minerals, vitamins, macronutrients, etc.
# See here for a list of essential nutrients: https://www.britannica.com/science/human-nutrition/Essential-nutrients 
all_nutrients
# Out:
# [' Ergosta-5,7-dienol',
#  ' Ergosta-7,22-dienol',
#  '10-Formyl folic acid (10HCOFA)',
#  '25-hydroxycholecalciferol',
#  '5-Formyltetrahydrofolic acid (5-HCOH4',
#  '5-methyl tetrahydrofolate (5-MTHF)',
#  'Alanine',
#  'Alcohol, ethyl',
#  'Arginine',
#  'Ash',
#  'Aspartic acid',
#  'Beta-glucan',
#  'Beta-sitostanol',
#  'Beta-sitosterol',
#  'Betaine',
#  'Biotin',
#  'Boron, B',
#  'Brassicasterol',
#  'Caffeine',
#  'Calcium, Ca',
#  'Campestanol',
#  'Campesterol',
#  'Carbohydrate, by difference',
#  'Carbohydrate, by summation',
#  'Carotene, alpha',
#  'Carotene, beta',
#  'Carotene, gamma',
#  'Cholesterol',
#  'Choline, free',
#  'Choline, from glycerophosphocholine',
#  'Choline, from phosphocholine',
#  'Choline, from phosphotidyl choline',
#  'Choline, from sphingomyelin',
#  'Choline, total',
#  'Citric acid',
#  'Cobalt, Co',
#  'Copper, Cu',
#  'Cryptoxanthin, alpha',
#  'Cryptoxanthin, beta',
#  'Cysteine',
#  'Cystine',
#  'Daidzein',
#  'Daidzin',
#  'Delta-5-avenasterol',
#  'Delta-7-Stigmastenol',
#  'Energy',
#  'Energy (Atwater General Factors)',
#  'Energy (Atwater Specific Factors)',
#  'Ergosta-7-enol',
#  'Ergosterol',
#  'Ergothioneine',
#  'Fatty acids, total monounsaturated',
#  'Fatty acids, total polyunsaturated',
#  'Fatty acids, total saturated',
#  'Fatty acids, total trans',
#  'Fatty acids, total trans-dienoic',
#  'Fatty acids, total trans-monoenoic',
#  'Fatty acids, total trans-polyenoic',
#  'Fiber, insoluble',
#  'Fiber, soluble',
#  'Fiber, total dietary',
#  'Fluoride, F',
#  'Folate, DFE',
#  'Folate, food',
#  'Folate, total',
#  'Folic acid',
#  'Fructose',
#  'Galactose',
#  'Genistein',
#  'Genistin',
#  'Glucose',
#  'Glutamic acid',
#  'Glycine',
#  'Glycitin',
#  'High Molecular Weight Dietary Fiber (HMWDF)',
#  'Histidine',
#  'Hydroxyproline',
#  'Iodine, I',
#  'Iron, Fe',
#  'Isoleucine',
#  'Lactose',
#  'Leucine',
#  'Low Molecular Weight Dietary Fiber (LMWDF)',
#  'Lutein',
#  'Lutein + zeaxanthin',
#  'Lycopene',
#  'Lysine',
#  'MUFA 12:1',
#  'MUFA 14:1',
#  'MUFA 14:1 c',
#  'MUFA 15:1',
#  'MUFA 16:1',
#  'MUFA 16:1 c',
#  'MUFA 17:1',
#  'MUFA 17:1 c',
#  'MUFA 18:1',
#  'MUFA 18:1 c',
#  'MUFA 20:1',
#  'MUFA 20:1 c',
#  'MUFA 22:1',
#  'MUFA 22:1 c',
#  'MUFA 22:1 n-11',
#  'MUFA 22:1 n-9',
#  'MUFA 24:1 c',
#  'Magnesium, Mg',
#  'Malic acid',
#  'Maltose',
#  'Manganese, Mn',
#  'Methionine',
#  'Molybdenum, Mo',
#  'Niacin',
#  'Nickel, Ni',
#  'Nitrogen',
#  'Oxalic acid',
#  'PUFA 18:2',
#  'PUFA 18:2 CLAs',
#  'PUFA 18:2 c',
#  'PUFA 18:2 n-6 c,c',
#  'PUFA 18:3',
#  'PUFA 18:3 c',
#  'PUFA 18:3 n-3 c,c,c (ALA)',
#  'PUFA 18:3 n-6 c,c,c',
#  'PUFA 18:3i',
#  'PUFA 18:4',
#  'PUFA 20:2 c',
#  'PUFA 20:2 n-6 c,c',
#  'PUFA 20:3',
#  'PUFA 20:3 c',
#  'PUFA 20:3 n-3',
#  'PUFA 20:3 n-6',
#  'PUFA 20:3 n-9',
#  'PUFA 20:4',
#  'PUFA 20:4 n-6',
#  'PUFA 20:4c',
#  'PUFA 20:5 n-3 (EPA)',
#  'PUFA 20:5c',
#  'PUFA 22:2',
#  'PUFA 22:3',
#  'PUFA 22:4',
#  'PUFA 22:5 c',
#  'PUFA 22:5 n-3 (DPA)',
#  'PUFA 22:6 c',
#  'PUFA 22:6 n-3 (DHA)',
#  'PUFA 2:5 n-3 (EPA)',
#  'Pantothenic acid',
#  'Phenylalanine',
#  'Phosphorus, P',
#  'Phytoene',
#  'Phytofluene',
#  'Phytosterols',
#  'Phytosterols, other',
#  'Potassium, K',
#  'Proline',
#  'Protein',
#  'Pyruvic acid',
#  'Quinic acid',
#  'Retinol',
#  'Riboflavin',
#  'SFA 10:0',
#  'SFA 11:0',
#  'SFA 12:0',
#  'SFA 13:0',
#  'SFA 14:0',
#  'SFA 15:0',
#  'SFA 16:0',
#  'SFA 17:0',
#  'SFA 18:0',
#  'SFA 20:0',
#  'SFA 21:0',
#  'SFA 22:0',
#  'SFA 23:0',
#  'SFA 24:0',
#  'SFA 4:0',
#  'SFA 5:0',
#  'SFA 6:0',
#  'SFA 7:0',
#  'SFA 8:0',
#  'SFA 9:0',
#  'Selenium, Se',
#  'Serine',
#  'Sodium, Na',
#  'Starch',
#  'Stigmasterol',
#  'Sucrose',
#  'Sugars, Total',
#  'Sugars, total including NLEA',
#  'Sulfur, S',
#  'TFA 14:1 t',
#  'TFA 16:1 t',
#  'TFA 18:1 t',
#  'TFA 18:2 t not further defined',
#  'TFA 18:2 t,t',
#  'TFA 18:3 t',
#  'TFA 20:1 t',
#  'TFA 22:1 t',
#  'Theobromine',
#  'Thiamin',
#  'Threonine',
#  'Tocopherol, beta',
#  'Tocopherol, delta',
#  'Tocopherol, gamma',
#  'Tocotrienol, alpha',
#  'Tocotrienol, beta',
#  'Tocotrienol, delta',
#  'Tocotrienol, gamma',
#  'Total dietary fiber (AOAC 2011.25)',
#  'Total fat (NLEA)',
#  'Total lipid (fat)',
#  'Tryptophan',
#  'Tyrosine',
#  'Valine',
#  'Vitamin A',
#  'Vitamin A, IU',
#  'Vitamin A, RAE',
#  'Vitamin B-12',
#  'Vitamin B-12, added',
#  'Vitamin B-6',
#  'Vitamin C, total ascorbic acid',
#  'Vitamin D (D2 + D3)',
#  'Vitamin D (D2 + D3), International Units',
#  'Vitamin D2 (ergocalciferol)',
#  'Vitamin D3 (cholecalciferol)',
#  'Vitamin D4',
#  'Vitamin E (alpha-tocopherol)',
#  'Vitamin E, added',
#  'Vitamin K (Dihydrophylloquinone)',
#  'Vitamin K (Menaquinone-4)',
#  'Vitamin K (phylloquinone)',
#  'Water',
#  'Zeaxanthin',
#  'Zinc, Zn',
#  'cis-Lutein/Zeaxanthin',
#  'cis-Lycopene',
#  'cis-beta-Carotene',
#  'trans-Lycopene',
#  'trans-beta-Carotene']

# %%
import random
nutrify_food_items[random.randint(0, len(nutrify_food_items))].keys()
# Out:
# dict_keys(['foodClass', 'description', 'foodNutrients', 'foodAttributes', 'foodCode', 'startDate', 'endDate', 'wweiaFoodCategory', 'foodPortions', 'publicationDate', 'inputFoods', 'fdcId', 'dataType'])

# %%
target_key = "foodNutrients"
target_food = nutrify_food_items[random.randint(0, len(nutrify_food_items))]

print(f"Target key: {target_key}")
print(f"Target food: {target_food['description']}")
print(f"Target food fdc id: {target_food['fdcId']}")
print(f"Target food data type: {target_food['dataType']}")
print(f"Target food with key:\n{target_food[target_key][0].keys()}")
# Out:
# Target key: foodNutrients
# Target food: Beans, Dry, Black (0% moisture)
# Target food fdc id: 747444
# Target food data type: Foundation
# Target food with key:
# dict_keys(['type', 'id', 'nutrient', 'dataPoints', 'foodNutrientDerivation', 'max', 'min', 'median', 'amount'])

# %% [markdown]
# Details about the keys:
# - `fdcId`: Unique identifier for a food item
# - `description`: Description of the food item
# - `wweiaFoodCategory`:
# ```
# {'wweiaFoodCategoryCode': 2643393,
#  'wweiaFoodCategoryDescription': 'Poultry mixed dishes'}
# ```
# * `foodPortions`: The amount of a certain food you'd have in a portion, e.g. 1 cup of corn (the default is 100g but some foods also have information per serving)
# * `dataType`: Where the data comes from, e.g. `Foundation` or `SR Legacy` or `Survey (FNDDS)`
# * `foodNutrients`: The nutrients of the food (macronutrients, micronutrients, etc.)
# * `foodClass`: Similar to the `dataType` but shows simpler category e.g. `Survey`

# %%
# Get a list of macronutrients
macronutrients = ["Protein", 
                  "Total lipid (fat)", 
                  "Carbohydrate, by difference",
                  "Alcohol, ethyl"]

macronutrients_to_key = {"Protein": "protein",
                          "Total lipid (fat)": "fat",
                          "Carbohydrate, by difference": "carbohydrate",
                          "Alcohol, ethyl": "alcohol"}

# Create a dictionary mapping macronutrients to their energy density (kcal/g)
energy_dict = {"protein": 4,
               "fat": 9,
               "carbohydrate": 4,
               "alcohol": 7}

## Create a list of micronutrients to get started (see: https://www.hsph.harvard.edu/nutritionsource/vitamins/)
# Create a list of minerals (from FDC)
minerals = [
    "Calcium, Ca",
    "Copper, Cu",
    "Fluoride, F",
    "Iodine, I", 
    "Iron, Fe",
    "Magnesium, Mg",
    "Manganese, Mn",
    "Molybdenum, Mo",
    "Nickel, Ni",
    "Phosphorus, P",
    "Potassium, K",
    "Selenium, Se",
    "Sodium, Na",
    "Zinc, Zn",
]

# Create a list of vitamins (from FDC)
vitamins = [
    "Vitamin A", # IU = international units = 0.3 mcg retinol activity equivalents (RAE)
    "Thiamin", # vitamin B1
    "Riboflavin", # vitamin B2
    "Niacin", # vitamin B3
    "Pantothenic acid", # vitamin B5
    "Vitamin B-6", # (pyridoxal, pyridoxine, pyridoxamine)
    "Biotin", # vitamin B7
    "Folate, total", # vitamin B9, folic acid
    "Vitamin B-12", # cobalamin
    "Vitamin C, total ascorbic acid", # ascorbic acid
    "Choline, total", # choline
    "Vitamin D (D2 + D3)", # calciferol
    "Vitamin E (alpha-tocopherol)", # alpha-tocopherol
    "Vitamin K (phylloquinone)", # phylloquinone
]

# Create a list of other
other_food_nutrients = [
    "Caffeine",
    "Citric acid"
]

# Oils (e.g. olive oil) have a different layout to other kinds of foods, as they are mostly fats rather than 
# carbohydrates and protein.
lipids = {"Fatty acids, total saturated": "SFA",
          "Fatty acids, total monounsaturated": "MUFA",
          "Fatty acids, total polyunsaturated": "PUFA"} 

lipids_to_key = {"Fatty acids, total saturated": "saturated_fat",
                 "Fatty acids, total monounsaturated": "monounsaturated_fat",
                 "Fatty acids, total polyunsaturated": "polyunsaturated_fat"}


# Get oil names from Foundation Foods (can make this more general later, e.g. semantic search across the whole database)
foundation_food_oil_types = ["Oil, canola", "Oil, coconut", "Oil, corn", "Oil, peanut", "Oil, safflower", "Oil, soybean", "Oil, sunflower", "Oil, olive, extra light", "Oil, olive, extra virgin"]
oil_items = [item for item in data["FoundationFoods"] if item["description"] in foundation_food_oil_types]
oil_names = [item["description"] for item in oil_items]
print(oil_names)
# Out:
# ['Oil, coconut', 'Oil, canola', 'Oil, corn', 'Oil, soybean', 'Oil, olive, extra virgin', 'Oil, peanut', 'Oil, sunflower', 'Oil, safflower', 'Oil, olive, extra light']

# %%
import random
target_item = nutrify_food_items[random.randint(0, len(nutrify_food_items))]
print(target_item["fdcId"])
print(target_item["description"])

for item in target_item["foodNutrients"]:
    if item["nutrient"]["name"] in macronutrients:
        print(item["nutrient"]["name"])

target_item
# Out:
# 2342931
# Soybean soup, miso broth
# Protein
# Total lipid (fat)
# Carbohydrate, by difference
# Alcohol, ethyl
# {'foodClass': 'Survey',
#  'description': 'Soybean soup, miso broth',
#  'foodNutrients': [{'type': 'FoodNutrient',
#    'id': 28681639,
#    'nutrient': {'id': 1003,
#     'number': '203',
#     'name': 'Protein',
#     'rank': 600,
#     'unitName': 'g'},
#    'amount': 2.5},
#   {'type': 'FoodNutrient',
#    'id': 28681640,
#    'nutrient': {'id': 1004,
#     'number': '204',
#     'name': 'Total lipid (fat)',
#     'rank': 800,
#     'unitName': 'g'},
#    'amount': 1.56},
#   {'type': 'FoodNutrient',
#    'id': 28681641,
#    'nutrient': {'id': 1005,
#     'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'rank': 1110,
#     'unitName': 'g'},
#    'amount': 2.27},
#   {'type': 'FoodNutrient',
#    'id': 28681642,
#    'nutrient': {'id': 1008,
#     'number': '208',
#     'name': 'Energy',
#     'rank': 300,
#     'unitName': 'kcal'},
#    'amount': 32.0},
#   {'type': 'FoodNutrient',
#    'id': 28681643,
#    'nutrient': {'id': 1018,
#     'number': '221',
#     'name': 'Alcohol, ethyl',
#     'rank': 18200,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681644,
#    'nutrient': {'id': 1051,
#     'number': '255',
#     'name': 'Water',
#     'rank': 100,
#     'unitName': 'g'},
#    'amount': 91.8},
#   {'type': 'FoodNutrient',
#    'id': 28681645,
#    'nutrient': {'id': 1057,
#     'number': '262',
#     'name': 'Caffeine',
#     'rank': 18300,
#     'unitName': 'mg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681646,
#    'nutrient': {'id': 1058,
#     'number': '263',
#     'name': 'Theobromine',
#     'rank': 18400,
#     'unitName': 'mg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681647,
#    'nutrient': {'id': 2000,
#     'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'rank': 1510,
#     'unitName': 'g'},
#    'amount': 0.83},
#   {'type': 'FoodNutrient',
#    'id': 28681648,
#    'nutrient': {'id': 1079,
#     'number': '291',
#     'name': 'Fiber, total dietary',
#     'rank': 1200,
#     'unitName': 'g'},
#    'amount': 0.4},
#   {'type': 'FoodNutrient',
#    'id': 28681649,
#    'nutrient': {'id': 1087,
#     'number': '301',
#     'name': 'Calcium, Ca',
#     'rank': 5300,
#     'unitName': 'mg'},
#    'amount': 16.0},
#   {'type': 'FoodNutrient',
#    'id': 28681650,
#    'nutrient': {'id': 1089,
#     'number': '303',
#     'name': 'Iron, Fe',
#     'rank': 5400,
#     'unitName': 'mg'},
#    'amount': 0.32},
#   {'type': 'FoodNutrient',
#    'id': 28681651,
#    'nutrient': {'id': 1090,
#     'number': '304',
#     'name': 'Magnesium, Mg',
#     'rank': 5500,
#     'unitName': 'mg'},
#    'amount': 8.0},
#   {'type': 'FoodNutrient',
#    'id': 28681652,
#    'nutrient': {'id': 1091,
#     'number': '305',
#     'name': 'Phosphorus, P',
#     'rank': 5600,
#     'unitName': 'mg'},
#    'amount': 30.0},
#   {'type': 'FoodNutrient',
#    'id': 28681653,
#    'nutrient': {'id': 1092,
#     'number': '306',
#     'name': 'Potassium, K',
#     'rank': 5700,
#     'unitName': 'mg'},
#    'amount': 57.0},
#   {'type': 'FoodNutrient',
#    'id': 28681654,
#    'nutrient': {'id': 1093,
#     'number': '307',
#     'name': 'Sodium, Na',
#     'rank': 5800,
#     'unitName': 'mg'},
#    'amount': 613},
#   {'type': 'FoodNutrient',
#    'id': 28681655,
#    'nutrient': {'id': 1095,
#     'number': '309',
#     'name': 'Zinc, Zn',
#     'rank': 5900,
#     'unitName': 'mg'},
#    'amount': 0.3},
#   {'type': 'FoodNutrient',
#    'id': 28681656,
#    'nutrient': {'id': 1098,
#     'number': '312',
#     'name': 'Copper, Cu',
#     'rank': 6000,
#     'unitName': 'mg'},
#    'amount': 0.05},
#   {'type': 'FoodNutrient',
#    'id': 28681657,
#    'nutrient': {'id': 1103,
#     'number': '317',
#     'name': 'Selenium, Se',
#     'rank': 6200,
#     'unitName': 'µg'},
#    'amount': 3.0},
#   {'type': 'FoodNutrient',
#    'id': 28681658,
#    'nutrient': {'id': 1105,
#     'number': '319',
#     'name': 'Retinol',
#     'rank': 7430,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681659,
#    'nutrient': {'id': 1106,
#     'number': '320',
#     'name': 'Vitamin A, RAE',
#     'rank': 7420,
#     'unitName': 'µg'},
#    'amount': 1.0},
#   {'type': 'FoodNutrient',
#    'id': 28681660,
#    'nutrient': {'id': 1107,
#     'number': '321',
#     'name': 'Carotene, beta',
#     'rank': 7440,
#     'unitName': 'µg'},
#    'amount': 5.0},
#   {'type': 'FoodNutrient',
#    'id': 28681661,
#    'nutrient': {'id': 1108,
#     'number': '322',
#     'name': 'Carotene, alpha',
#     'rank': 7450,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681662,
#    'nutrient': {'id': 1109,
#     'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'rank': 7905,
#     'unitName': 'mg'},
#    'amount': 0.21},
#   {'type': 'FoodNutrient',
#    'id': 28681663,
#    'nutrient': {'id': 1114,
#     'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'rank': 8700,
#     'unitName': 'µg'},
#    'amount': 0.1},
#   {'type': 'FoodNutrient',
#    'id': 28681664,
#    'nutrient': {'id': 1120,
#     'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'rank': 7460,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681665,
#    'nutrient': {'id': 1122,
#     'number': '337',
#     'name': 'Lycopene',
#     'rank': 7530,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681666,
#    'nutrient': {'id': 1123,
#     'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'rank': 7560,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681667,
#    'nutrient': {'id': 1162,
#     'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'rank': 6300,
#     'unitName': 'mg'},
#    'amount': 0.1},
#   {'type': 'FoodNutrient',
#    'id': 28681668,
#    'nutrient': {'id': 1165,
#     'number': '404',
#     'name': 'Thiamin',
#     'rank': 6400,
#     'unitName': 'mg'},
#    'amount': 0.029},
#   {'type': 'FoodNutrient',
#    'id': 28681669,
#    'nutrient': {'id': 1166,
#     'number': '405',
#     'name': 'Riboflavin',
#     'rank': 6500,
#     'unitName': 'mg'},
#    'amount': 0.075},
#   {'type': 'FoodNutrient',
#    'id': 28681670,
#    'nutrient': {'id': 1167,
#     'number': '406',
#     'name': 'Niacin',
#     'rank': 6600,
#     'unitName': 'mg'},
#    'amount': 0.429},
#   {'type': 'FoodNutrient',
#    'id': 28681671,
#    'nutrient': {'id': 1175,
#     'number': '415',
#     'name': 'Vitamin B-6',
#     'rank': 6800,
#     'unitName': 'mg'},
#    'amount': 0.028},
#   {'type': 'FoodNutrient',
#    'id': 28681672,
#    'nutrient': {'id': 1177,
#     'number': '417',
#     'name': 'Folate, total',
#     'rank': 6900,
#     'unitName': 'µg'},
#    'amount': 6.0},
#   {'type': 'FoodNutrient',
#    'id': 28681673,
#    'nutrient': {'id': 1178,
#     'number': '418',
#     'name': 'Vitamin B-12',
#     'rank': 7300,
#     'unitName': 'µg'},
#    'amount': 0.13},
#   {'type': 'FoodNutrient',
#    'id': 28681674,
#    'nutrient': {'id': 1180,
#     'number': '421',
#     'name': 'Choline, total',
#     'rank': 7220,
#     'unitName': 'mg'},
#    'amount': 10.7},
#   {'type': 'FoodNutrient',
#    'id': 28681675,
#    'nutrient': {'id': 1185,
#     'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'rank': 8800,
#     'unitName': 'µg'},
#    'amount': 3.3},
#   {'type': 'FoodNutrient',
#    'id': 28681676,
#    'nutrient': {'id': 1186,
#     'number': '431',
#     'name': 'Folic acid',
#     'rank': 7000,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681677,
#    'nutrient': {'id': 1187,
#     'number': '432',
#     'name': 'Folate, food',
#     'rank': 7100,
#     'unitName': 'µg'},
#    'amount': 6.0},
#   {'type': 'FoodNutrient',
#    'id': 28681678,
#    'nutrient': {'id': 1190,
#     'number': '435',
#     'name': 'Folate, DFE',
#     'rank': 7200,
#     'unitName': 'µg'},
#    'amount': 6.0},
#   {'type': 'FoodNutrient',
#    'id': 28681679,
#    'nutrient': {'id': 1242,
#     'number': '573',
#     'name': 'Vitamin E, added',
#     'rank': 7920,
#     'unitName': 'mg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681680,
#    'nutrient': {'id': 1246,
#     'number': '578',
#     'name': 'Vitamin B-12, added',
#     'rank': 7340,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681681,
#    'nutrient': {'id': 1253,
#     'number': '601',
#     'name': 'Cholesterol',
#     'rank': 15700,
#     'unitName': 'mg'},
#    'amount': 4.0},
#   {'type': 'FoodNutrient',
#    'id': 28681682,
#    'nutrient': {'id': 1258,
#     'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'rank': 9700,
#     'unitName': 'g'},
#    'amount': 0.218},
#   {'type': 'FoodNutrient',
#    'id': 28681683,
#    'nutrient': {'id': 1259,
#     'number': '607',
#     'name': 'SFA 4:0',
#     'rank': 9800,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681684,
#    'nutrient': {'id': 1260,
#     'number': '608',
#     'name': 'SFA 6:0',
#     'rank': 9900,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681685,
#    'nutrient': {'id': 1261,
#     'number': '609',
#     'name': 'SFA 8:0',
#     'rank': 10000,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681686,
#    'nutrient': {'id': 1262,
#     'number': '610',
#     'name': 'SFA 10:0',
#     'rank': 10100,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681687,
#    'nutrient': {'id': 1263,
#     'number': '611',
#     'name': 'SFA 12:0',
#     'rank': 10300,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681688,
#    'nutrient': {'id': 1264,
#     'number': '612',
#     'name': 'SFA 14:0',
#     'rank': 10500,
#     'unitName': 'g'},
#    'amount': 0.002},
#   {'type': 'FoodNutrient',
#    'id': 28681689,
#    'nutrient': {'id': 1265,
#     'number': '613',
#     'name': 'SFA 16:0',
#     'rank': 10700,
#     'unitName': 'g'},
#    'amount': 0.157},
#   {'type': 'FoodNutrient',
#    'id': 28681690,
#    'nutrient': {'id': 1266,
#     'number': '614',
#     'name': 'SFA 18:0',
#     'rank': 10900,
#     'unitName': 'g'},
#    'amount': 0.047},
#   {'type': 'FoodNutrient',
#    'id': 28681691,
#    'nutrient': {'id': 1268,
#     'number': '617',
#     'name': 'MUFA 18:1',
#     'rank': 12100,
#     'unitName': 'g'},
#    'amount': 0.435},
#   {'type': 'FoodNutrient',
#    'id': 28681692,
#    'nutrient': {'id': 1269,
#     'number': '618',
#     'name': 'PUFA 18:2',
#     'rank': 13100,
#     'unitName': 'g'},
#    'amount': 0.537},
#   {'type': 'FoodNutrient',
#    'id': 28681693,
#    'nutrient': {'id': 1270,
#     'number': '619',
#     'name': 'PUFA 18:3',
#     'rank': 13900,
#     'unitName': 'g'},
#    'amount': 0.074},
#   {'type': 'FoodNutrient',
#    'id': 28681694,
#    'nutrient': {'id': 1271,
#     'number': '620',
#     'name': 'PUFA 20:4',
#     'rank': 14700,
#     'unitName': 'g'},
#    'amount': 0.001},
#   {'type': 'FoodNutrient',
#    'id': 28681695,
#    'nutrient': {'id': 1272,
#     'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'rank': 15300,
#     'unitName': 'g'},
#    'amount': 0.005},
#   {'type': 'FoodNutrient',
#    'id': 28681696,
#    'nutrient': {'id': 1275,
#     'number': '626',
#     'name': 'MUFA 16:1',
#     'rank': 11700,
#     'unitName': 'g'},
#    'amount': 0.006},
#   {'type': 'FoodNutrient',
#    'id': 28681697,
#    'nutrient': {'id': 1276,
#     'number': '627',
#     'name': 'PUFA 18:4',
#     'rank': 14250,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681698,
#    'nutrient': {'id': 1277,
#     'number': '628',
#     'name': 'MUFA 20:1',
#     'rank': 12400,
#     'unitName': 'g'},
#    'amount': 0.008},
#   {'type': 'FoodNutrient',
#    'id': 28681699,
#    'nutrient': {'id': 1278,
#     'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'rank': 15000,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681700,
#    'nutrient': {'id': 1279,
#     'number': '630',
#     'name': 'MUFA 22:1',
#     'rank': 12500,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681701,
#    'nutrient': {'id': 1280,
#     'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'rank': 15200,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28681702,
#    'nutrient': {'id': 1292,
#     'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'rank': 11400,
#     'unitName': 'g'},
#    'amount': 0.453},
#   {'type': 'FoodNutrient',
#    'id': 28681703,
#    'nutrient': {'id': 1293,
#     'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'rank': 12900,
#     'unitName': 'g'},
#    'amount': 0.622}],
#  'foodAttributes': [{'id': 2645533,
#    'name': 'WWEIA Category description',
#    'value': 'Soups',
#    'foodAttributeType': {'id': 999,
#     'name': 'Attribute',
#     'description': 'Generic attributes'}},
#   {'id': 2645532,
#    'name': 'WWEIA Category number',
#    'value': '3802',
#    'foodAttributeType': {'id': 999,
#     'name': 'Attribute',
#     'description': 'Generic attributes'}},
#   {'id': 2655958,
#    'value': 'tofu soup',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 2},
#   {'id': 2655957,
#    'value': 'bean curd soup',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 1},
#   {'id': 2664656,
#    'value': 'Moisture change: 0%',
#    'foodAttributeType': {'id': 1002,
#     'name': 'Adjustments',
#     'description': 'Adjustments made to foods, including moisture changes'}}],
#  'foodCode': '41601070',
#  'startDate': '1/1/2019',
#  'endDate': '12/31/2020',
#  'wweiaFoodCategory': {'wweiaFoodCategoryCode': 2645533,
#   'wweiaFoodCategoryDescription': 'Soups'},
#  'foodPortions': [{'id': 275777,
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'},
#    'modifier': '90000',
#    'gramWeight': 300,
#    'sequenceNumber': 2,
#    'portionDescription': 'Quantity not specified'},
#   {'id': 275776,
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'},
#    'modifier': '10205',
#    'gramWeight': 240,
#    'sequenceNumber': 1,
#    'portionDescription': '1 cup'}],
#  'publicationDate': '10/28/2022',
#  'inputFoods': [{'id': 112511,
#    'unit': 'WO',
#    'portionDescription': 'NONE',
#    'portionCode': '0',
#    'foodDescription': 'Tofu, soft, prepared with calcium sulfate and magnesium chloride (nigari)',
#    'sequenceNumber': 7,
#    'ingredientDescription': 'Tofu, soft, prepared with calcium sulfate and magnesium chloride (nigari)',
#    'ingredientWeight': 56.7,
#    'amount': 2,
#    'ingredientCode': 16127},
#   {'id': 112505,
#    'unit': 'C',
#    'portionDescription': '1 cup',
#    'portionCode': '10205',
#    'foodDescription': 'Soup, chicken broth, ready-to-serve',
#    'sequenceNumber': 1,
#    'ingredientDescription': 'Soup, chicken broth, ready-to-serve',
#    'ingredientWeight': 960,
#    'amount': 4,
#    'ingredientCode': 6194},
#   {'id': 112507,
#    'unit': '',
#    'portionDescription': '1/8 cup or 2 tablespoons',
#    'portionCode': '63260',
#    'foodDescription': 'Seaweed, kelp, raw',
#    'sequenceNumber': 3,
#    'ingredientDescription': 'Seaweed, kelp, raw',
#    'ingredientWeight': 10,
#    'amount': 1,
#    'ingredientCode': 11445},
#   {'id': 112506,
#    'unit': 'C',
#    'portionDescription': '1 cup',
#    'portionCode': '10205',
#    'foodDescription': 'Miso',
#    'sequenceNumber': 2,
#    'ingredientDescription': 'Miso',
#    'ingredientWeight': 68.75,
#    'amount': 0.25,
#    'ingredientCode': 16112},
#   {'id': 112508,
#    'unit': 'GM',
#    'portionDescription': 'NONE',
#    'portionCode': '0',
#    'foodDescription': 'Mushroom, Asian, cooked, from dried',
#    'sequenceNumber': 4,
#    'ingredientDescription': 'Mushroom, Asian, cooked, from dried',
#    'ingredientWeight': 36,
#    'amount': 36,
#    'ingredientCode': 75219100},
#   {'id': 112509,
#    'unit': 'GM',
#    'portionDescription': 'NONE',
#    'portionCode': '0',
#    'foodDescription': 'Fish, cod, Atlantic, dried and salted',
#    'sequenceNumber': 5,
#    'ingredientDescription': 'Fish, cod, Atlantic, dried and salted',
#    'ingredientWeight': 14,
#    'amount': 14,
#    'ingredientCode': 15018},
#   {'id': 112510,
#    'unit': 'TS',
#    'portionDescription': '1 cup',
#    'portionCode': '10205',
#    'foodDescription': 'Vegetable oil, NFS',
#    'sequenceNumber': 6,
#    'ingredientDescription': 'Vegetable oil, NFS',
#    'ingredientWeight': 9.333,
#    'amount': 2,
#    'ingredientCode': 82101000}],
#  'fdcId': 2342931,
#  'dataType': 'Survey (FNDDS)'}

# %%
import json

json.dump(target_item, open("target_item.json", "w"), indent=4)

# %%
for i, item in enumerate(nutrify_food_items):
    if item["fdcId"] == 748608: # Olive oil, see: https://fdc.nal.usda.gov/fdc-app.html#/food-details/748608/nutrients
        print(i)
        print(item)
# Out:
# 25
# {'foodClass': 'FinalFood', 'description': 'Oil, olive, extra virgin', 'foodNutrients': [{'type': 'FoodNutrient', 'id': 8529145, 'nutrient': {'id': 1264, 'number': '612', 'name': 'SFA 14:0', 'rank': 10500, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.021, 'min': 0.009, 'median': 0.012, 'amount': 0.013}, {'type': 'FoodNutrient', 'id': 8529146, 'nutrient': {'id': 1265, 'number': '613', 'name': 'SFA 16:0', 'rank': 10700, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 15.8, 'min': 9.48, 'median': 12, 'amount': 12.1}, {'type': 'FoodNutrient', 'id': 8529147, 'nutrient': {'id': 1266, 'number': '614', 'name': 'SFA 18:0', 'rank': 10900, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 3.16, 'min': 1.87, 'median': 2.62, 'amount': 2.59}, {'type': 'FoodNutrient', 'id': 8529148, 'nutrient': {'id': 1267, 'number': '615', 'name': 'SFA 20:0', 'rank': 11100, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.472, 'min': 0.379, 'median': 0.406, 'amount': 0.411}, {'type': 'FoodNutrient', 'id': 8529149, 'nutrient': {'id': 1273, 'number': '624', 'name': 'SFA 22:0', 'rank': 11200, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.147, 'min': 0.102, 'median': 0.116, 'amount': 0.118}, {'type': 'FoodNutrient', 'id': 8529150, 'nutrient': {'id': 1299, 'number': '652', 'name': 'SFA 15:0', 'rank': 10600, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.012, 'min': 0.004, 'median': 0.006, 'amount': 0.006}, {'type': 'FoodNutrient', 'id': 8529151, 'nutrient': {'id': 1300, 'number': '653', 'name': 'SFA 17:0', 'rank': 10800, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.148, 'min': 0.038, 'median': 0.078, 'amount': 0.081}, {'type': 'FoodNutrient', 'id': 8529152, 'nutrient': {'id': 1301, 'number': '654', 'name': 'SFA 24:0', 'rank': 11300, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.075, 'min': 0.049, 'median': 0.062, 'amount': 0.062}, {'type': 'FoodNutrient', 'id': 8529153, 'nutrient': {'id': 1314, 'number': '673', 'name': 'MUFA 16:1 c', 'rank': 11800, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 1.96, 'min': 0.593, 'median': 0.96, 'amount': 1.03}, {'type': 'FoodNutrient', 'id': 8529154, 'nutrient': {'id': 1315, 'number': '674', 'name': 'MUFA 18:1 c', 'rank': 12200, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 73.2, 'min': 56.9, 'median': 68.6, 'amount': 67.8}, {'type': 'FoodNutrient', 'id': 8529155, 'nu ...

# %%
# Get info for Olive oil
nutrify_food_items[25]

# Get info for Yoghurt
# nutrify_food_items[47]
# Out:
# {'foodClass': 'FinalFood',
#  'description': 'Oil, olive, extra virgin',
#  'foodNutrients': [{'type': 'FoodNutrient',
#    'id': 8529145,
#    'nutrient': {'id': 1264,
#     'number': '612',
#     'name': 'SFA 14:0',
#     'rank': 10500,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.021,
#    'min': 0.009,
#    'median': 0.012,
#    'amount': 0.013},
#   {'type': 'FoodNutrient',
#    'id': 8529146,
#    'nutrient': {'id': 1265,
#     'number': '613',
#     'name': 'SFA 16:0',
#     'rank': 10700,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 15.8,
#    'min': 9.48,
#    'median': 12,
#    'amount': 12.1},
#   {'type': 'FoodNutrient',
#    'id': 8529147,
#    'nutrient': {'id': 1266,
#     'number': '614',
#     'name': 'SFA 18:0',
#     'rank': 10900,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 3.16,
#    'min': 1.87,
#    'median': 2.62,
#    'amount': 2.59},
#   {'type': 'FoodNutrient',
#    'id': 8529148,
#    'nutrient': {'id': 1267,
#     'number': '615',
#     'name': 'SFA 20:0',
#     'rank': 11100,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.472,
#    'min': 0.379,
#    'median': 0.406,
#    'amount': 0.411},
#   {'type': 'FoodNutrient',
#    'id': 8529149,
#    'nutrient': {'id': 1273,
#     'number': '624',
#     'name': 'SFA 22:0',
#     'rank': 11200,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.147,
#    'min': 0.102,
#    'median': 0.116,
#    'amount': 0.118},
#   {'type': 'FoodNutrient',
#    'id': 8529150,
#    'nutrient': {'id': 1299,
#     'number': '652',
#     'name': 'SFA 15:0',
#     'rank': 10600,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.012,
#    'min': 0.004,
#    'median': 0.006,
#    'amount': 0.006},
#   {'type': 'FoodNutrient',
#    'id': 8529151,
#    'nutrient': {'id': 1300,
#     'number': '653',
#     'name': 'SFA 17:0',
#     'rank': 10800,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.148,
#    'min': 0.038,
#    'median': 0.078,
#    'amount': 0.081},
#   {'type': 'FoodNutrient',
#    'id': 8529152,
#    'nutrient': {'id': 1301,
#     'number': '654',
#     'name': 'SFA 24:0',
#     'rank': 11300,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.075,
#    'min': 0.049,
#    'median': 0.062,
#    'amount': 0.062},
#   {'type': 'FoodNutrient',
#    'id': 8529153,
#    'nutrient': {'id': 1314,
#     'number': '673',
#     'name': 'MUFA 16:1 c',
#     'rank': 11800,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 1.96,
#    'min': 0.593,
#    'median': 0.96,
#    'amount': 1.03},
#   {'type': 'FoodNutrient',
#    'id': 8529154,
#    'nutrient': {'id': 1315,
#     'number': '674',
#     'name': 'MUFA 18:1 c',
#     'rank': 12200,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 73.2,
#    'min': 56.9,
#    'median': 68.6,
#    'amount': 67.8},
#   {'type': 'FoodNutrient',
#    'id': 8529155,
#    'nutrient': {'id': 1316,
#     'number': '675',
#     'name': 'PUFA 18:2 n-6 c,c',
#     'rank': 13200,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 14.8,
#    'min': 5.14,
#    'median': 7.68,
#    'amount': 8.4},
#   {'type': 'FoodNutrient',
#    'id': 8529156,
#    'nutrient': {'id': 2006,
#     'number': '681',
#     'name': 'SFA 21:0',
#     'rank': 11150,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.02,
#    'min': 0.008,
#    'median': 0.014,
#    'amount': 0.014},
#   {'type': 'FoodNutrient',
#    'id': 8529157,
#    'nutrient': {'id': 1406,
#     'number': '853',
#     'name': 'PUFA 20:4 n-6',
#     'rank': 14600,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0,
#    'min': 0,
#    'median': 0,
#    'amount': 0},
#   {'type': 'FoodNutrient',
#    'id': 8529158,
#    'nutrient': {'id': 1258,
#     'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'rank': 9700,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 18.8,
#    'min': 13.1,
#    'median': 15.3,
#    'amount': 15.4},
#   {'type': 'FoodNutrient',
#    'id': 8529159,
#    'nutrient': {'id': 1292,
#     'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'rank': 11400,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 74.2,
#    'min': 59.2,
#    'median': 70,
#    'amount': 69.2},
#   {'type': 'FoodNutrient',
#    'id': 8529160,
#    'nutrient': {'id': 2016,
#     'number': '831',
#     'name': 'PUFA 18:2 c',
#     'rank': 13150,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'code': 'AS',
#     'description': 'Summed',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'amount': 8.4},
#   {'type': 'FoodNutrient',
#    'id': 8529161,
#    'nutrient': {'id': 2020,
#     'number': '835',
#     'name': 'PUFA 20:3 c',
#     'rank': 14450,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'code': 'AS',
#     'description': 'Summed',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'amount': 0},
#   {'type': 'FoodNutrient',
#    'id': 8529162,
#    'nutrient': {'id': 1293,
#     'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'rank': 12900,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 15.5,
#    'min': 5.81,
#    'median': 8.35,
#    'amount': 9.07},
#   {'type': 'FoodNutrient',
#    'id': 8529163,
#    'nutrient': {'id': 1085,
#     'number': '298',
#     'name': 'Total fat (NLEA)',
#     'rank': 900,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'code': 'AS',
#     'description': 'Summed',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'amount': 93.7},
#   {'type': 'FoodNutrient',
#    'id': 8529164,
#    'nutrient': {'id': 1288,
#     'number': '641',
#     'name': 'Beta-sitosterol',
#     'rank': 16200,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 167,
#    'min': 90.1,
#    'median': 126,
#    'amount': 126},
#   {'type': 'FoodNutrient',
#    'id': 8529165,
#    'nutrient': {'id': 1287,
#     'number': '640',
#     'name': 'Brassicasterol',
#     'rank': 16100,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0,
#    'min': 0,
#    'median': 0,
#    'amount': 0},
#   {'type': 'FoodNutrient',
#    'id': 8529166,
#    'nutrient': {'id': 1289,
#     'number': '642',
#     'name': 'Campestanol',
#     'rank': 16221,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0,
#    'min': 0,
#    'median': 0,
#    'amount': 0},
#   {'type': 'FoodNutrient',
#    'id': 8529167,
#    'nutrient': {'id': 1286,
#     'number': '639',
#     'name': 'Campesterol',
#     'rank': 16000,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 8.09,
#    'min': 3.69,
#    'median': 5.64,
#    'amount': 5.68},
#   {'type': 'FoodNutrient',
#    'id': 8529168,
#    'nutrient': {'id': 1296,
#     'number': '649',
#     'name': 'Delta-5-avenasterol',
#     'rank': 16224,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 36.2,
#    'min': 16.7,
#    'median': 22.6,
#    'amount': 23.1},
#   {'type': 'FoodNutrient',
#    'id': 8529169,
#    'nutrient': {'id': 1298,
#     'number': '651',
#     'name': 'Phytosterols, other',
#     'rank': 16227,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 51.3,
#    'min': 16.9,
#    'median': 25,
#    'amount': 26.9},
#   {'type': 'FoodNutrient',
#    'id': 8529170,
#    'nutrient': {'id': 1294,
#     'number': '647',
#     'name': 'Beta-sitostanol',
#     'rank': 16222,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 4.14,
#    'min': 1.73,
#    'median': 2.52,
#    'amount': 2.55},
#   {'type': 'FoodNutrient',
#    'id': 8529171,
#    'nutrient': {'id': 1285,
#     'number': '638',
#     'name': 'Stigmasterol',
#     'rank': 15900,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 1.88,
#    'min': 0.636,
#    'median': 1,
#    'amount': 1.02},
#   {'type': 'FoodNutrient',
#    'id': 8529172,
#    'nutrient': {'id': 2012,
#     'number': '829',
#     'name': 'MUFA 20:1 c',
#     'rank': 12401,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.333,
#    'min': 0.208,
#    'median': 0.278,
#    'amount': 0.276},
#   {'type': 'FoodNutrient',
#    'id': 8529173,
#    'nutrient': {'id': 1404,
#     'number': '851',
#     'name': 'PUFA 18:3 n-3 c,c,c (ALA)',
#     'rank': 14000,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.72,
#    'min': 0.506,
#    'median': 0.661,
#    'amount': 0.651},
#   {'type': 'FoodNutrient',
#    'id': 8529174,
#    'nutrient': {'id': 2018,
#     'number': '833',
#     'name': 'PUFA 18:3 c',
#     'rank': 13910,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'code': 'AS',
#     'description': 'Summed',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'amount': 0.651}],
#  'foodAttributes': [],
#  'nutrientConversionFactors': [],
#  'isHistoricalReference': False,
#  'ndbNumber': 4063,
#  'fdcId': 748608,
#  'dataType': 'Foundation',
#  'foodCategory': {'description': 'Fats and Oils'},
#  'inputFoods': [{'id': 46664,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748474,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46650,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748379,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46676,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748552,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46673,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748532,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46683,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748602,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46680,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748581,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46656,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748417,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46679,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748575,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46674,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748538,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46649,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748373,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46666,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748487,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46658,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748431,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46671,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748518,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46653,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748398,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46659,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748438,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46677,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748559,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46678,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748565,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46672,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748525,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46652,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748391,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46662,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748460,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46651,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748385,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46670,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748511,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46675,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748545,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46660,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748445,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46682,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748596,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46648,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748367,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46655,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748411,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46663,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748467,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46668,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748499,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46657,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748424,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46654,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748405,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46669,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748505,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46667,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748493,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46661,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748453,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46681,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748589,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46665,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748481,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}}],
#  'foodPortions': [{'id': 192355,
#    'value': 100,
#    'measureUnit': {'id': 1004, 'name': 'milliliter', 'abbreviation': 'ml'},
#    'modifier': '',
#    'gramWeight': 90.7,
#    'sequenceNumber': 1,
#    'minYearAcquired': 2019,
#    'amount': 100}],
#  'publicationDate': '12/16/2019'}

# %%
source_url_base = "https://fdc.nal.usda.gov/fdc-app.html#/food-details/{}/nutrients"

nutrify_food_items_nutrients = []
for item in tqdm(nutrify_food_items):
    calories_string = "total_energy_calories"

    item_dict = {}
    item_dict["fdcId"] = item["fdcId"]
    # print(f"On item: {item['fdcId']}")
    item_dict["description"] = item["description"]
    item_dict["default_size"] = 100
    item_dict["unit"] = "g"
    item_dict[calories_string] = 0

    # Get the macronutrients + water + micronutrients
    item_macronutrients = {}

    # Create empty lists for various minerals and vitamins
    mineral_list = []
    vitamin_list = []
    other_nutrient_list = []

    # Setup micronutrients dictionary
    item_dict["micronutrients"] = {"vitamins": "",
                                   "minerals": ""}

    # Setup other nutrients dictionary
    item_other_nutrients = {} 
    
    for nutrient in item["foodNutrients"]:

        nutrient_name = nutrient["nutrient"]["name"]

        # Get the macronutrients
        if nutrient_name in macronutrients:
            macronutrient_name = macronutrients_to_key[nutrient_name]
            item_macronutrients[macronutrient_name] = nutrient["amount"]
            item_dict["macronutrients"] = item_macronutrients
        
        # Get the water
        if nutrient_name == "Water":
            item_dict["Water"] = nutrient["amount"]

        # Get the vitamin micronutrients
        if nutrient_name in vitamins:
            item_vitamin_micronutrients = {}
            vitamin_name = nutrient["nutrient"]["name"]
            # print(f"On vitamin name: {vitamin_name}")
            try:
                vitamin_amount = nutrient["amount"]
                vitamin_unit = nutrient["nutrient"]["unitName"]
            except:
                print(f"Could not get amount for vitamin: {vitamin_name}")
                if nutrient_name == "Vitamin A": # replace for Retinol
                    vitamin_amount = [nutrient["amount"] for nutrient in item["foodNutrients"] if nutrient["nutrient"]["name"] == "Retinol"][0]
                    vitamin_unit = [nutrient["nutrient"]["unitName"] for nutrient in item["foodNutrients"] if nutrient["nutrient"]["name"] == "Retinol"][0]
                    
            item_vitamin_micronutrients["name"] = vitamin_name
            item_vitamin_micronutrients["amount"] = vitamin_amount
            item_vitamin_micronutrients["unit"] = vitamin_unit

            vitamin_list.append(item_vitamin_micronutrients)
            # print(len(vitamin_list))
        
        # Get the mineral micronutrients
        if nutrient_name in minerals:
            item_mineral_micronutrients = {}
            mineral_name = nutrient["nutrient"]["name"]
            # print(f"On mineral name: {mineral_name}")
            try:
                mineral_amount = nutrient["amount"]
                mineral_unit = nutrient["nutrient"]["unitName"]
            except:
                print(f"Could not get amount for mineral: {mineral_name}")
            
            item_mineral_micronutrients["name"] = mineral_name
            item_mineral_micronutrients["amount"] = mineral_amount
            item_mineral_micronutrients["unit"] = mineral_unit

            mineral_list.append(item_mineral_micronutrients)
            # print(len(mineral_list))
        
        # Get the other nutrients
        if nutrient_name in other_food_nutrients:
            item_other_nutrients = {}
            other_nutrient_name = nutrient["nutrient"]["name"]
            # print(f"On other nutrient name: {other_nutrient_name}")
            try:
                other_nutrient_amount = nutrient["amount"]
                other_nutrient_unit = nutrient["nutrient"]["unitName"]
            except:
                print(f"Could not get amount for other nutrient: {other_nutrient_name}")

            item_other_nutrients["name"] = other_nutrient_name
            item_other_nutrients["amount"] = other_nutrient_amount
            item_other_nutrients["unit"] = other_nutrient_unit

            other_nutrient_list.append(item_other_nutrients)
            # print(len(other_nutrient_list))
            

    item_dict["micronutrients"]["vitamins"] = vitamin_list
    item_dict["micronutrients"]["minerals"] = mineral_list
    item_dict["other_nutrients"] = other_nutrient_list
    
    # Handle oils
    if item["description"] in oil_names:
        for nutrient in item["foodNutrients"]:
            if nutrient["nutrient"]["name"] in lipids:
                target_lipid_name = lipids_to_key[nutrient["nutrient"]["name"]]
                item_macronutrients[target_lipid_name] = nutrient["amount"]
                item_dict["lipids"] = item_macronutrients
        lipid_items = item_dict["lipids"].keys()
        for lipid in lipid_items:
            item_dict[calories_string] += round(item_dict["lipids"][lipid] * energy_dict["fat"]) # all lipids are fat

    # Calculate the total energy (this will fail on items like Table Salt + Olive Oil, their values in the FDC are different to others, see: 746775 and https://fdc.nal.usda.gov/fdc-app.html#/food-details/748608/nutrients)
    for nutrient in macronutrients:
        try:
            target_macronutrient = macronutrients_to_key[nutrient]
            if target_macronutrient in item_dict["macronutrients"]:
                item_dict[calories_string] += round(item_dict["macronutrients"][target_macronutrient] * energy_dict[target_macronutrient])
        except Exception as e:
            print(e)
            print(item_dict)
    
    # Add the source url
    item_dict["fdc_source_url"] = source_url_base.format(item["fdcId"])
    
    nutrify_food_items_nutrients.append(item_dict)
# Out:
#   0%|          | 0/279 [00:00<?, ?it/s]
# 'macronutrients'
# {'fdcId': 746775, 'description': 'Salt, table, iodized', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 0, 'micronutrients': {'vitamins': [], 'minerals': [{'name': 'Iron, Fe', 'amount': 0, 'unit': 'mg'}, {'name': 'Magnesium, Mg', 'amount': 0, 'unit': 'mg'}, {'name': 'Phosphorus, P', 'amount': 0, 'unit': 'mg'}, {'name': 'Sodium, Na', 'amount': 38700, 'unit': 'mg'}, {'name': 'Copper, Cu', 'amount': 0, 'unit': 'mg'}, {'name': 'Manganese, Mn', 'amount': 0.032, 'unit': 'mg'}, {'name': 'Calcium, Ca', 'amount': 50, 'unit': 'mg'}, {'name': 'Potassium, K', 'amount': 2, 'unit': 'mg'}, {'name': 'Zinc, Zn', 'amount': 0, 'unit': 'mg'}, {'name': 'Iodine, I', 'amount': 5080, 'unit': 'µg'}]}, 'Water': 0.42, 'other_nutrients': []}
# 'macronutrients'
# {'fdcId': 746775, 'description': 'Salt, table, iodized', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 0, 'micronutrients': {'vitamins': [], 'minerals': [{'name': 'Iron, Fe', 'amount': 0, 'unit': 'mg'}, {'name': 'Magnesium, Mg', 'amount': 0, 'unit': 'mg'}, {'name': 'Phosphorus, P', 'amount': 0, 'unit': 'mg'}, {'name': 'Sodium, Na', 'amount': 38700, 'unit': 'mg'}, {'name': 'Copper, Cu', 'amount': 0, 'unit': 'mg'}, {'name': 'Manganese, Mn', 'amount': 0.032, 'unit': 'mg'}, {'name': 'Calcium, Ca', 'amount': 50, 'unit': 'mg'}, {'name': 'Potassium, K', 'amount': 2, 'unit': 'mg'}, {'name': 'Zinc, Zn', 'amount': 0, 'unit': 'mg'}, {'name': 'Iodine, I', 'amount': 5080, 'unit': 'µg'}]}, 'Water': 0.42, 'other_nutrients': []}
# 'macronutrients'
# {'fdcId': 746775, 'description': 'Salt, table, iodized', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 0, 'micronutrients': {'vitamins': [], 'minerals': [{'name': 'Iron, Fe', 'amount': 0, 'unit': 'mg'}, {'name': 'Magnesium, Mg', 'amount': 0, 'unit': 'mg'}, {'name': 'Phosphorus, P', 'amount': 0, 'unit': 'mg'}, {'name': 'Sodium, Na', 'amount': 38700, 'unit': 'mg'}, {'name': 'Copper, Cu', 'amount': 0, 'unit': 'mg'}, {'name': 'Manganese, Mn', 'amount': 0.032, 'unit': 'mg'}, {'name': 'Calcium, Ca', 'amount': 50, 'unit': 'mg'}, {'name': 'Potassium, K', 'amount': 2, 'unit': 'mg'}, {'name': 'Zinc, Zn', 'amount': 0, 'unit': 'mg'}, {'name': 'Iodine, I', 'amount': 5080, 'unit': 'µg'}]}, 'Water': 0.42, 'other_nutrients': []}
# 'macronutrients'
# {'fdcId': 746775, 'description': 'Salt, table, iodized', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 0, 'micronutrients': {'vitamins': [], 'minerals': [{'name': 'Iron, Fe', 'amount': 0, 'unit': 'mg'}, {'name': 'Magnesium, Mg', 'amount': 0, 'unit': 'mg'}, {'name': 'Phosphorus, P', 'amount': 0, 'unit': 'mg'}, {'name': 'Sodium, Na', 'amount': 38700, 'unit': 'mg'}, {'name': 'Copper, Cu', 'amount': 0, 'unit': 'mg'}, {'name': 'Manganese, Mn', 'amount': 0.032, 'unit': 'mg'}, {'name': 'Calcium, Ca', 'amount': 50, 'unit': 'mg'}, {'name': 'Potassium, K', 'amount': 2, 'unit': 'mg'}, {'name': 'Zinc, Zn', 'amount': 0, 'unit': 'mg'}, {'name': 'Iodine, I', 'amount': 5080, 'unit': 'µg'}]}, 'Water': 0.42, 'other_nutrients': []}
# 'macronutrients'
# {'fdcId': 748608, 'description': 'Oil, olive, extra virgin', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 844, 'micronutrients': {'vitamins': [], 'minerals': []}, 'other_nutrients': [], 'lipids': {'saturated_fat': 15.4, 'monounsaturated_fat': 69.2, 'polyunsaturated_fat': 9.07}}
# 'macronutrients'
# {'fdcId': 748608, 'description': 'Oil, olive, extra virgin', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 844, 'micronutrients': {'vitamins': [], 'minerals': []}, 'other_nutrients': [], 'lipids': {'saturated_fat': 15.4, 'monounsaturated_fat': 69.2, 'polyunsaturated_fat': 9.07}}
# 'macronutrients'
# {'fdcId': 748608, 'description': 'Oil, olive, extra virgin', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 844, 'micronutrients': {'vitamins': [], 'minerals': []}, 'other_nutrients': [], 'lipids': {'saturated_fat': 15.4, 'monounsaturated_fat': 69.2, 'polyunsaturated_fat': 9.07}}
# 'macronutrients'
# {'fdcId': 748608, 'description': 'Oil, olive, extra virgin', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 844, 'micronutrients': {'vitamins': [], 'minerals': []}, 'other_nutrients': [], 'lipids': {'saturated_fat': 15.4, 'monounsaturated_fat': 69.2, 'polyunsaturated_fat': 9.07}}
# Could not get amount for vitamin: Vitamin A
# Could not get amount for vitamin: Vitamin A

# %%
nutrify_food_items_nutrients[random.randint(0, len(nutrify_food_items_nutrients))]
# Out:
# {'fdcId': 2342418,
#  'description': 'Cuban sandwich',
#  'default_size': 100,
#  'unit': 'g',
#  'total_energy_calories': 225,
#  'micronutrients': {'vitamins': [{'name': 'Vitamin E (alpha-tocopherol)',
#     'amount': 0.3,
#     'unit': 'mg'},
#    {'name': 'Vitamin D (D2 + D3)', 'amount': 0.4, 'unit': 'µg'},
#    {'name': 'Vitamin C, total ascorbic acid', 'amount': 0.6, 'unit': 'mg'},
#    {'name': 'Thiamin', 'amount': 0.365, 'unit': 'mg'},
#    {'name': 'Riboflavin', 'amount': 0.279, 'unit': 'mg'},
#    {'name': 'Niacin', 'amount': 3.29, 'unit': 'mg'},
#    {'name': 'Vitamin B-6', 'amount': 0.21, 'unit': 'mg'},
#    {'name': 'Folate, total', 'amount': 32.0, 'unit': 'µg'},
#    {'name': 'Vitamin B-12', 'amount': 0.68, 'unit': 'µg'},
#    {'name': 'Choline, total', 'amount': 45.5, 'unit': 'mg'},
#    {'name': 'Vitamin K (phylloquinone)', 'amount': 3.9, 'unit': 'µg'}],
#   'minerals': [{'name': 'Calcium, Ca', 'amount': 159, 'unit': 'mg'},
#    {'name': 'Iron, Fe', 'amount': 1.75, 'unit': 'mg'},
#    {'name': 'Magnesium, Mg', 'amount': 22.0, 'unit': 'mg'},
#    {'name': 'Phosphorus, P', 'amount': 197, 'unit': 'mg'},
#    {'name': 'Potassium, K', 'amount': 212, 'unit': 'mg'},
#    {'name': 'Sodium, Na', 'amount': 575, 'unit': 'mg'},
#    {'name': 'Zinc, Zn', 'amount': 2.35, 'unit': 'mg'},
#    {'name': 'Copper, Cu', 'amount': 0.088, 'unit': 'mg'},
#    {'name': 'Selenium, Se', 'amount': 29.6, 'unit': 'µg'}]},
#  'macronutrients': {'protein': 15.9,
#   'fat': 10.7,
#   'carbohydrate': 16.3,
#   'alcohol': 0.0},
#  'Water': 54.4,
#  'other_nutrients': [{'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}],
#  'fdc_source_url': 'https://fdc.nal.usda.gov/fdc-app.html#/food-details/2342418/nutrients'}

# %%
len(nutrify_food_items_nutrients)
# Out:
# 279

# %%
# Save to JSON
with open("nutrify_foodvision_items_nutrients.json", "w") as f:
    json.dump(nutrify_food_items_nutrients, f)

# %%
# Upload to Google Storage
# !gsutil cp nutrify_foodvision_items_nutrients.json gs://food_vision_bucket_with_object_versioning/nutrition_information/nutrify_foodvision_items_nutrients.json
# Out:
# Copying file://nutrify_foodvision_items_nutrients.json [Content-Type=application/json]...
# - [1 files][407.7 KiB/407.7 KiB]
# Operation completed over 1 objects/407.7 KiB.

# %%
# TODO: 
# back the nutrition information up to Google Storage ✅
    # could also track this as an Artifact in Weights & Biases? 
# Merge the Nutrition information with the Nutrify Food Item names ✅
# For foods without an FDC ID - could match the closest food item based on the name and then use the nutrition information from that food item
    # Could do the same with every other food, e.g. encode the text and show links to the closest food items (e.g. apple_red -> red delicious apple + more, apple_green -> granny smith apple + more, etc.)
    # Could just do something with ChatGPT in terms of similar foods, just generate similar foods and show the closest ones (e.g. what types of red apple are there, then provide the closest ones)
    # This would be the same with text-based foods as well, just include the most similar foods based on the text lookup (e.g. canola oil -> canola oil + more, olive oil -> olive oil + more, etc.)

# %% [markdown]
# ## Find a match for foods with no exact match

# %%
# TODO: 
# UPTOHERE
# Find classes which don't have nutrients
# Display options for the *most* similar items
    # E.g. if someone types in "Cheese, blue" and there is no exact match, display the closest matches
    # Could also just do this for the existing foods (find the most similar foods via name)

# %%
# Which rows don't have FDC IDs?
nutrify_to_fdcid[nutrify_to_fdcid["fdc_id"].isna()]
# Out:
#      number            class_name fdc_id
# 0         0               achacha   None
# 11       11  bacon_and_egg_burger   None
# 15       15          banana_bread   None
# 22       22            beef_diced   None
# 23       23            beef_kebab   None
# 30       30               biltong   None
# 31       31          black_pepper   None
# 48       48     cape_gooseberries   None
# 54       54         carrot_purple   None
# 68       68      chicken_stir_fry   None
# 73       73           chimichurri   None
# 78       78              choy_sum   None
# 89       89       crumbed_chicken   None
# 93       93          curry_leaves   None
# 102     102          endive_curly   None
# 106     106           finger_lime   None
# 116     116         garlic_chives   None
# 121     121          grapes_black   None
# 127     127                 gyoza   None
# 134     134                   ice   None
# 139     139                jujube   None
# 141     141       karaage_chicken   None
# 143     143            kiwi_berry   None
# 148     148            lemongrass   None
# 155     155           lime_leaves   None
# 162     162            mangosteen   None
# 164     164              marjoram   None
# 168     168           melon_candy   None
# 169     169            melon_dino   None
# 170     170            melon_long   None
# 171     171         melon_spanish   None
# 179     179         mushroom_flat   None
# 186     186   mushroom_white_cups   None
# 204     204                papple   None
# 209     209                pawpaw   None
# 215     215          pear_prickly   None
# 225     225            plum_sugar   None
# 234     234           potato_bake   None
# 237     237        potato_kipfler   None
# 239     239   potato_purple_sweet   None
# 242     242     potato_royal_blue   None
# 243     243        potato_scallop   None
# 246     246    potato_white_sweet   None
# 255     255              rambutan   None
# 266     266              rosellas   None
# 278     278          sausage_roll   None
# 298     298             tamarillo   None
# 307     307        tomato_chutney   None
# 325     325           lime_kaffir   None
# 327     327   potato_purple_congo   None
# 328     328           snake_gourd   None

# %%
# Create a function to similarity match the class names (e.g. code which string is most like another string)
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import dot_score
model = SentenceTransformer("all-MiniLM-L6-v2")

def embed_list_of_classes(class_names: list, model: SentenceTransformer):
    """
    Embeds a list of class names.
    """

    # Map the class_name to the embedding
    class_name_to_embedding = {class_name: embedding for class_name, embedding in zip(class_names, model.encode(class_names))}

    return class_name_to_embedding

# Create a function to similarity match the class names (e.g. code which string is most like another string)
def find_most_similar_class_name(target_class_name, class_name_embedding_dict, num_similar=3):
    """
    Finds the most similar class name to the class_name provided.
    """
    # Get the embedding of the target_class_name
    target_class_name_embedding = model.encode([target_class_name])[0]

    # Create a dictionary of the class_name and the dot score between the target_class_name and the class_name
    class_name_embedding_dict = {class_name: dot_score(embedding, target_class_name_embedding) for class_name, embedding in class_name_embedding_dict.items()}

    # Sort the dictionary by the dot score
    most_similar_class_names = {k: v[0].item() for k, v in sorted(class_name_embedding_dict.items(), key=lambda item: item[1], reverse=True)}

    # Only return the top num_similar
    # most_similar_class_names = list(most_similar_class_names.items())[:num_similar]

    return most_similar_class_names

# %%
# Get a list of the unique descriptions
unique_descriptions = fdcid_to_description_df["description"].unique().tolist()
len(unique_descriptions)
# Out:
# 13475

# %%
# Create an embedding of all the unique descriptions
class_name_embedding_dict_unique_descriptions = embed_list_of_classes(unique_descriptions, model)

# %%
food_item_without_fdcid = rows_without_fdcid.class_name.to_list()
food_item_without_fdcid[:5]
# Out:
# ['achacha', 'bacon_and_egg_burger', 'banana_bread', 'beef_diced', 'beef_kebab']

# %%
# target_food_item = random.choice(food_item_without_fdcid)
target_food_item = "red apple"
print(f"Showing the most similar class names to: {target_food_item}")
most_similar_class_names = find_most_similar_class_name(target_food_item, class_name_embedding_dict_unique_descriptions, num_similar=10)
most_similar_class_names
# Out:
# Showing the most similar class names to: red apple
# {'Apples, red delicious, with skin, raw': 0.7135860919952393,
#  'Rose-apples, raw': 0.6315896511077881,
#  'Apple, dried': 0.6260167360305786,
#  'Crisp, apple': 0.6217784881591797,
#  'Apple, raw': 0.6178090572357178,
#  'Applesauce, regular': 0.6107631921768188,
#  'Apple, candied': 0.5980645418167114,
#  'Apple, baked': 0.5918879508972168,
#  'Applesauce, flavored': 0.5883489847183228,
#  'Pie, apple': 0.5762279629707336,
#  'Pears, raw, red anjou': 0.5739957690238953,
#  "Apples, raw, red delicious, with skin (Includes foods for USDA's Food Distribution Program)": 0.5658494830131531,
#  'Apple cider': 0.5499900579452515,
#  'Applesauce, unsweetened': 0.5496532917022705,
#  'Apple juice, 100%': 0.5481484532356262,
#  'Babyfood, juice, apple - cherry': 0.5468789935112,
#  'Apples, raw, golden delicious, with skin': 0.5462113618850708,
#  'Apples, raw, without skin': 0.5439801812171936,
#  'Baby Toddler juice, apple': 0.5428827404975891,
#  'Babyfood, juice, apple': 0.5408956408500671,
#  'Babyfood, juice, orange and apple': 0.5367645025253296,
#  'Babyfood, fruit, applesauce, junior': 0.5351508855819702,
#  'Apples, gala, with skin, raw': 0.5331279039382935,
#  'Babyfood, fruit, apple and raspberry, junior': 0.5305817127227783,
#  'Apples, granny smith, with skin, raw': 0.5299031734466553,
#  'Orange, raw': 0.5276337265968323,
#  'Apples, raw, without skin, cooked, microwave': 0.5246798396110535,
#  'Apples, raw, without skin, cooked, boiled': 0.5220211744308472,
#  'Strudel, apple': 0.519320547580719,
#  'Babyfood, fruit, apple and blueberry, junior': 0.518286943435669,
#  'Fruit butters, apple': 0.5167291164398193,
#  'Apple juice beverage, 40-50% juice, light': 0.5137234926223755,
#  'Vinegar, red wine': 0.513099193572998,
#  'Apples, dried, sulfured, uncooked': 0.5129543542861938,
#  'Apples, fuji, with skin, raw': 0.509431004524231,
#  'Babyfood, fruit, applesauce, strained': 0.5087912082672119,
#  'Babyfood, apple-banana juice': 0.5052187442779541,
#  'Apples, canned, sweetened, sliced, drained, heated': 0.5047768950462341,
#  'Babyfood, juice, apple and peach': 0.5043784379959106,
#  'Tomatoes, red, ripe, cooked': 0.5030605792999268,
#  'Candied fruit': 0.5014867782592773,
#  'Babyfood, fruit, applesauce with banana, junior': 0.5014485716819763,
#  'Babyfood, juice, orange and apple and banana': 0.498360812664032,
#  'Salsa, red': 0.49799633026123047,
#  'Babyfood, fruit, applesauce and pineapple, junior': 0.49467235803604126,
#  'Sugar-apples, (sweetsop), raw': 0.49337875843048096,
#  'Cake or cupcake, apple': 0.49293869733810425,
#  'Apples, dehydrated (low moisture), sulfured, uncooked': 0.4925893545150757,
#  'Pepper, sweet, red, raw': 0.4918000400066376,
#  'Fruit flavored drink': 0.49038001894950867,
#  'Babyfood, juice, apple and grape': 0.48900118470191956,
#  'Babyfood, fruit, applesauce and cherries, junior': 0.4883256256580353,
#  'Fruit juice drink, light': 0.4880844056606293,
#  'Peaches, yellow, raw': 0.48737528920173645,
#  'Cobbler, apple': 0.4873660206794739,
#  'Babyfood, fruit, applesauce and apricots, junior': 0.4871629476547241,
#  'Babyfood, juice, apple-sweet potato': 0.4865259528160095,
#  'Pear, raw': 0.48575982451438904,
#  'Wheat, soft red winter': 0.4855791926383972,
#  'Cherries, sweet, dark red, raw': 0.4842705726623535,
#  'Desserts, apple crisp, prepared-from-recipe': 0.48409366607666016,
#  'Onions, red, raw': 0.48203808069229126,
#  'Raspberries, frozen, red, sweetened': 0.4808357357978821,
#  'Applesauce, unsweetened, with added vitamin C': 0.4784545600414276,
#  'Orange Blossom': 0.478313684463501,
#  'Wheat, hard red winter': 0.4781777858734131,
#  'Apples, honeycrisp, with skin, raw': 0.4771101474761963,
#  'Applesauce, canned, sweetened, with salt': 0.47619032859802246,
#  'Wine, table, red': 0.4761573076248169,
#  'Peach, raw': 0.47605064511299133,
#  'Grapes, red, seedless, raw': 0.4759693145751953,
#  'Alcoholic beverage, wine, table, red': 0.4755839705467224,
#  'Fruit juice drink': 0.4755663275718689,
#  'Croissants, apple': 0.47540438175201416,
#  'Fruit punch, made with fruit juice and soda': 0.47469907999038696,
#  'Babyfood, dessert, dutch apple, junior': 0.4742310345172882,
#  'Babyfood, juice, apple and prune': 0.4738743305206299,
#  'Beverages, cranberry-apple juice drink, bottled': 0.4737975001335144,
#  "Apples, raw, with skin (Includes foods for USDA's Food Distribution Program)": 0.47363007068634033,
#  'Raspberries, frozen, red, unsweetened': 0.47175973653793335,
#  'Cookie, applesauce': 0.4713085889816284,
#  'Fruit punch, alcoholic': 0.46972936391830444,
#  'Babyfood, fruit, applesauce and apricots, strained': 0.46931132674217224,
#  'Fruit, NFS': 0.4691523611545563,
#  'Cherries, sour, red, raw': 0.4685128629207611,
#  'Applesauce, canned, sweetened, without salt': 0.466216117143631,
#  "Apples, raw, gala, with skin (Includes foods for USDA's Food Distribution Program)": 0.4661562442779541,
#  'Potatoes, red, without skin, raw': 0.46558958292007446,
#  'Babyfood, fruit, apple and blueberry, strained': 0.4654332399368286,
#  "APPLEBEE'S, chili": 0.46475571393966675,
#  'Grapefruit juice, pink or red, with added calcium': 0.4617216885089874,
#  'Tomatoes, red, ripe, cooked, stewed': 0.4611382484436035,
#  'Mammy-apple, (mamey), raw': 0.46074509620666504,
#  'Water beverage, fruit flavored': 0.4585181474685669,
#  'Babyfood, fruit, apple and raspberry, strained': 0.4584570527076721,
#  'Grapefruit, raw, pink and red, California and Arizona': 0.45817774534225464,
#  'Babyfood, fruit, applesauce and pineapple, strained': 0.45803457498550415,
#  'Apples, dried, sulfured, stewed, with added sugar': 0.45703747868537903,
#  'Orange, canned, juice pack': 0.4557141363620758,
#  "Apples, raw, fuji, with skin (Includes foods for USDA's Food Distribution Program)": 0.4556584358215332,
#  'Babyfood, banana apple dessert, strained': 0.45541056990623474,
#  'Pie, apple, fast food': 0.4552958607673645,
#  'Crisp, peach': 0.45476117730140686,
#  "APPLEBEE'S, chicken tenders platter": 0.45469844341278076,
#  'Babyfood, juice, orange': 0.4546918272972107,
#  'Bread, fruit': 0.4541611969470978,
#  'Apple juice, canned or bottled, unsweetened, with added ascorbic acid, calcium, and potassium': 0.45365840196609497,
#  'Babyfood, dessert, dutch apple, strained': 0.45323652029037476,
#  'Babyfood, apples with ham, strained': 0.4532254934310913,
#  'Tomatoes, red, ripe, cooked, with salt': 0.4528864324092865,
#  'Orange peel, raw': 0.45281273126602173,
#  'Apples, dehydrated (low moisture), sulfured, stewed': 0.45268893241882324,
#  'Babyfood, fruit, applesauce and cherries, strained': 0.4525672495365143,
#  'Pumpkin, raw': 0.45248663425445557,
#  'Potato, hash brown, from fast food': 0.4520055055618286,
#  'Sangria, red': 0.45196008682250977,
#  'Apple juice, 100%, with calcium added': 0.45137834548950195,
#  'Salsa, red, homemade': 0.4513610005378723,
#  'Sugar, brown': 0.4510052800178528,
#  'Peach, frozen': 0.4508167505264282,
#  'Tomatoes, red, ripe, canned, stewed': 0.4506273865699768,
#  'Potatoes, red, flesh and skin, baked': 0.45036226511001587,
#  'Peppers, red, cooked': 0.44966351985931396,
#  "APPLEBEE'S, fish, hand battered": 0.4489864706993103,
#  'Tomatoes, canned, red, ripe, diced': 0.4484039843082428,
#  'Fruit juice, NFS': 0.4481586515903473,
#  'Potato, hash brown, from fresh': 0.4478946924209595,
#  'Apples, dried, sulfured, stewed, without added sugar': 0.4472799003124237,
#  'Dragon fruit': 0.445809006690979,
#  "APPLEBEE'S, 9 oz house sirloin steak": 0.4454428553581238,
#  'Fruit smoothie, light': 0.44543367624282837,
#  "Apples, raw, granny smith, with skin (Includes foods for USDA's Food Distribution Program)": 0.44525960087776184,
#  'Grapefruit, raw, pink and red, Florida': 0.44485825300216675,
#  'Green banana, fried': 0.44479066133499146,
#  'Apple pie filling': 0.44477617740631104,
#  'Passion-fruit juice, yellow, raw': 0.44464820623397827,
#  'Pear nectar': 0.44431406259536743,
#  'Apple juice, with added vitamin C, from concentrate, shelf stable': 0.4439597427845001,
#  'Banana, raw': 0.4438750147819519,
#  'Cheesecake, fruit': 0.4428090453147888,
#  'Tomatoes, red, ripe, canned, packed in tomato juice': 0.44075047969818115,
#  'Pie, strawberry': 0.44071561098098755,
#  'Scone, with fruit': 0.440609335899353,
#  'Blueberry juice': 0.4406015872955322,
#  'Red pepper, cooked, as ingredient': 0.44050830602645874,
#  'Babyfood, juice, pear': 0.4402252435684204,
#  'Pie, Dutch Apple, Commercially Prepared': 0.44002455472946167,
#  'Pear, dried': 0.439995139837265,
#  "Custard-apple, (bullock's-heart), raw": 0.4394412338733673,
#  'Fruit butter': 0.4394184648990631,
#  'Peach, dried': 0.4392821788787842,
#  'Babyfood, juice, orange and banana': 0.439211905002594,
#  'Pears, raw': 0.4390512704849243,
#  'Fruit syrup': 0.43880629539489746,
#  'Cereal, other, fruit flavored': 0.4384896457195282,
#  'Fruit, pickled': 0.4375234842300415,
#  'Toaster pastries, fruit (includes apple, blueberry, cherry, strawberry)': 0.4372507631778717,
#  'Babyfood, juice, apple, with calcium': 0.4371098279953003,
#  'Kiwifruit, green, raw': 0.43649861216545105,
#  'Pear, Asian, raw': 0.43649137020111084,
#  'Topping, fruit': 0.43635687232017517,
#  'Babyfood, fruit, bananas with apples and pears, strained': 0.43621504306793213,
#  'Babyfood, fruit and vegetable, apple and sweet potato': 0.43614065647125244,
#  'Potatoes, red, flesh and skin, raw': 0.4360995292663574,
#  'Empanada, fruit': 0.43603408336639404,
#  'Candy, fruit leather': 0.4358643889427185,
#  'Baby Toddler apples, Stage 1': 0.4358096718788147,
#  'Ruby Red grapefruit juice blend (grapefruit, grape, apple), OCEAN SPRAY, bottled, with added vitamin C': 0.43569415807724,
#  'Applesauce, canned, unsweetened, with added ascorbic acid': 0.4352560043334961,
#  'Pie, apple, prepared from recipe': 0.43497785925865173,
#  'Passion fruit, raw': 0.43465858697891235,
#  'Babyfood, fruit, peaches, junior': 0.4345947504043579,
#  'Macadamia nuts': 0.43287575244903564,
#  'Apple juice, frozen concentrate, unsweetened, diluted with 3 volume water, with added ascorbic acid': 0.4318980574607849,
#  'Lentils, pink or red, raw': 0.4318501651287079,
#  'Babyfood, rice and apples, dry': 0.4312319755554199,
#  'Wheat, hard red spring': 0.4305591583251953,
#  'Pancakes, fruit': 0.4300925135612488,
#  'Babyfood, dessert, fruit pudding, orange, strained': 0.42901191115379333,
#  'Apple juice, canned or bottled, unsweetened, with added ascorbic acid': 0.4287096858024597,
#  'Pie, peach': 0.4286550283432007,
#  'Peach nectar': 0.4285319745540619,
#  'Cereal, fruit crispy': 0.42828965187072754,
#  'Oranges, raw, with peel': 0.4275144040584564,
#  'Syrup, fruit flavored': 0.42721453309059143,
#  'Potato, hash brown, from restaurant': 0.4265124499797821,
#  'Babyfood, apples, dices, toddler': 0.4263893663883209,
#  'Pumpkin, cooked': 0.4262712299823761,
#  'Babyfood, juice, orange and pineapple': 0.42615196108818054,
#  'Blackberries, raw': 0.42565539479255676,
#  'Pear, canned, juice pack': 0.4254555404186249,
#  'Banana, fried': 0.4252307415008545,
#  'Beverages, Apple juice drink, light, fortified with vitamin C': 0.42483484745025635,
#  'Grapefruit, raw, pink and red, all areas': 0.42472150921821594,
#  'Kiwi fruit, raw': 0.42460501194000244,
#  'Fruit, chocolate covered': 0.4244304299354553,
#  "Apples, frozen, unsweetened, unheated (Includes foods for USDA's Food Distribution Program)": 0.4243711233139038,
#  'Fruit flavored drink, powdered, reconstituted': 0.4242975413799286,
#  "Apples, frozen, unsweetened, heated (Includes foods for USDA's Food Distribution Program)": 0.42417019605636597,
#  "APPLEBEE'S, coleslaw": 0.4231295585632324,
#  'Sherbet, orange': 0.4228552579879761,
#  'Watermelon, raw': 0.4222239851951599,
#  'Persimmon, raw': 0.42214882373809814,
#  'Blueberries, raw': 0.4217539429664612,
#  'Potato, hash brown, from school lunch': 0.4217227101325989,
#  'Peach, canned, juice pack': 0.4216901659965515,
#  'Peas, green, raw': 0.42120638489723206,
#  'Potato, hash brown, from fast food, with cheese': 0.42088350653648376,
#  'Baby Toddler apples, Stage 2': 0.42043399810791016,
#  'Potato, hash brown, ready-to-heat': 0.42009708285331726,
#  'Cabbage, red, raw': 0.4199189841747284,
#  'Pineapple, raw': 0.41985681653022766,
#  'Fruit juice drink (Sunny D)': 0.4197373390197754,
#  'Grapefruit juice, pink, raw': 0.4197114109992981,
#  'Cranberry-orange relish, canned': 0.41960757970809937,
#  'Babyfood, fruit, banana and strawberry, junior': 0.4193265438079834,
#  'Muffin, fruit': 0.4187231659889221,
#  'Pie, blueberry': 0.4180338382720947,
#  'Orange juice beverage, 40-50% juice, light': 0.4179132580757141,
#  'Babyfood, fruit, pears and pineapple, junior': 0.41770654916763306,
#  'Peppers, sweet, red, raw': 0.41767141222953796,
#  "McDONALD'S, Strawberry Sundae": 0.4175635278224945,
#  "Applesauce, canned, unsweetened, without added ascorbic acid (Includes foods for USDA's Food Distribution Program)": 0.41751956939697266,
#  'Strawberry juice, 100%': 0.4165017008781433,
#  'Babyfood, juice, orange and apricot': 0.4160737693309784,
#  'Fruit punch, made with soda, fruit juice, and sherbet or ice cream': 0.41569074988365173,
#  'Cheese, blue': 0.41542524099349976,
#  'Beverages, OCEAN SPRAY, Cranberry-Apple Juice Drink, bottled': 0.415243923664093,
#  'Soup, fruit': 0.41521546244621277,
#  'Babyfood, fruit, peaches, strained': 0.41470736265182495,
#  'Alcoholic Beverage, wine, table, red, Gamay': 0.4143790900707245,
#  'Peaches, frozen, sliced, sweetened': 0.4141560196876526,
#  'Apple juice, canned or bottled, unsweetened, without added ascorbic acid': 0.41405051946640015,
#  'Cereal, fruit rings': 0.41330817341804504,
#  'Babyfood, fruit, pears, junior': 0.41318079829216003,
#  'Babyfood, apple yogurt dessert, strained': 0.4131535291671753,
#  'Toaster pastries, fruit, toasted (include apple, blueberry, cherry, strawberry)': 0.4122712314128876,
#  "APPLEBEE'S, mozzarella sticks": 0.4114810824394226,
#  'Passion-fruit juice, purple, raw': 0.4114726781845093,
#  'Alcoholic Beverage, wine, table, red, Petite Sirah': 0.4110572636127472,
#  'Blueberries, frozen': 0.41102245450019836,
#  'Currants, red and white, raw': 0.41102224588394165,
#  "McDONALD'S, Hash Brown": 0.410134881734848,
#  'Tea, ginger': 0.4100065529346466,
#  'Orange chicken': 0.4095964729785919,
#  'Soft drink, ginger ale': 0.40944361686706543,
#  'Babyfood, cereal, high protein, with apple and orange, prepared with whole milk': 0.4092579483985901,
#  'Beverages, Orange juice drink': 0.40925133228302,
#  'Apple juice, frozen concentrate, unsweetened, diluted with 3 volume water without added ascorbic acid': 0.4091406464576721,
#  'Sugars, brown': 0.4090825617313385,
#  'Toaster Pastries, fruit, frosted (include apples, blueberry, cherry, strawberry)': 0.4090011417865753,
#  'Crisp, cherry': 0.4082116484642029,
#  'Beans, Dry, Medium Red (0% moisture)': 0.40811222791671753,
#  'Pumpkin, canned, cooked': 0.40784522891044617,
#  'Ginger root, raw': 0.4077966511249542,
#  'Ginger root, pickled': 0.4071693420410156,
#  'Oranges, raw, all commercial varieties': 0.4068980813026428,
#  'Babyfood, juice, orange-carrot': 0.406785249710083,
#  'Grapefruit, raw, pink and red and white, all areas': 0.4066779315471649,
#  'Potato, hash brown, from fresh, with cheese': 0.40660497546195984,
#  'Apricots, raw': 0.4065796732902527,
#  'Juice, apple, grape and pear blend, with added ascorbic acid and calcium': 0.406534343957901,
#  'Alcoholic Beverage, wine, table, red, Zinfandel': 0.4065023958683014,
#  'Fruit juice drink (Capri Sun)': 0.40649688243865967,
#  'Babyfood, cereal, mixed, with applesauce and bananas, strained': 0.40649116039276123,
#  'Apple juice, frozen concentrate, unsweetened, undiluted, with added ascorbic acid': 0.4061697721481323,
#  'Babyfood, cereal, high protein, with apple and orange, dry': 0.4061114490032196,
#  'Waffle, fruit': 0.40589600801467896,
#  'Lemonade, fruit juice drink, light': 0.4057934880256653,
#  'Alcoholic Beverage, wine, table, red, Syrah': 0.4055703580379486,
#  'Babyfood, dessert, peach yogurt': 0.4049508273601532,
#  'Hard cider': 0.4041176438331604,
#  'Mango, raw': 0.4040200114250183,
#  'Cake, fruit cake': 0.40382176637649536,
#  'Avocado, raw': 0.403746634721756,
#  'Alcoholic Beverage, wine, table, red, Burgundy': 0.40352895855903625,
#  'Candy, fruit flavored pieces': 0.40344423055648804,
#  'Alcoholic Beverage, wine, table, red, Barbera': 0.4034135341644287,
#  'Beverages, OCEAN SPRAY, Ruby Red cranberry': 0.4032612144947052,
#  'Apple juice, frozen concentrate, unsweetened, undiluted, without added ascorbic acid': 0.40318426489830017,
#  'Olives, green': 0.402999609708786,
#  'Cabbage, red, cooked': 0.4027048945426941,
#  'Lettuce, leaf, red, raw': 0.40264803171157837,
#  'Persimmons, japanese, raw': 0.402597039937973,
#  'Carrots, raw, salad with apples': 0.4021926522254944,
#  'Babyfood, GERBER, Banana with orange medley': 0.4020577371120453,
#  "APPLEBEE'S, french fries": 0.4019559621810913,
#  'Orange juice, canned, unsweetened': 0.4014703035354614,
#  'Pie, berry': 0.4013592302799225,
#  'Babyfood, fruit supreme dessert': 0.4012302756309509,
#  'Tomatoes, red, ripe, canned, packed in tomato juice, no salt added': 0.4011276960372925,
#  'Crepe, fruit filled': 0.4010241627693176,
#  'Babyfood, juice, prune and orange': 0.4009815752506256,
#  'Babyfood, dessert, fruit pudding, pineapple, strained': 0.4003504812717438,
#  'Energy drink (Red Bull)': 0.40027809143066406,
#  "McDONALD'S, Fruit 'n Yogurt Parfait": 0.4001207649707794,
#  "APPLEBEE'S, chicken tenders, from kids' menu": 0.400087833404541,
#  'Lemonade, fruit juice drink': 0.39984673261642456,
#  'Blackberry juice, 100%': 0.3997932970523834,
#  'Fruit juice drink, with high vitamin C, light': 0.3996196389198303,
#  'Pie, apple, commercially prepared, enriched flour': 0.3995337188243866,
#  'Fruit flavored drink, powdered, reconstituted, diet': 0.3994971811771393,
#  'Babyfood, juice, mixed fruit': 0.3992682695388794,
#  'Pie, cherry': 0.39912545680999756,
#  'Potato, hash brown, ready-to-heat, with cheese': 0.3987486660480499,
#  "Beverages, The COCA-COLA company, Hi-C Flashin' Fruit Punch": 0.39872071146965027,
#  'Green peas, raw': 0.3985869884490967,
#  'Pumpkin seeds, salted': 0.398561954498291,
#  'Beans, Dry, Small Red (0% moisture)': 0.39846062660217285,
#  'Cactus, raw': 0.3984575569629669,
#  'Tomatoes, orange, raw': 0.39843428134918213,
#  'Baby Toddler juice, pear': 0.3984341621398926,
#  'Beverages, cranberry-apple juice drink, low calorie, with vitamin C added': 0.39820539951324463,
#  "Pears, raw, green anjou (Includes foods for USDA's Food Distribution Program)": 0.3981088399887085,
#  'Passion fruit juice, 100%': 0.3980931043624878,
#  'Pineapple, frozen': 0.3978571891784668,
#  'Bluberries, canned': 0.3976757526397705,
#  'Babyfood, dessert, peach melba, junior': 0.3975152373313904,
#  'Beans, Dry, Red (0% moisture)': 0.39747047424316406,
#  'Grapes, red or green (European type, such as Thompson seedless), raw': 0.39747047424316406,
#  'Mango, frozen': 0.3973265290260315,
#  'Blackberries, frozen': 0.39680612087249756,
#  'Banana nectar': 0.39667606353759766,
#  'Pepper, sweet, green, raw': 0.39630407094955444,
#  'Blackberry juice, canned': 0.3962073028087616,
#  'Orange juice, 100%,  freshly squeezed': 0.3959214687347412,
#  'Lemonade, fruit flavored drink': 0.39566802978515625,
#  'Blueberries, dried': 0.39566144347190857,
#  'Alcoholic Beverage, wine, table, red, Claret': 0.3955938518047333,
#  'Prickly pears, raw': 0.3953017592430115,
#  'Apricot nectar': 0.39514726400375366,
#  'Raspberries, canned, red, heavy syrup pack, solids and liquids': 0.3949604332447052,
#  'Pineapple, raw, all varieties': 0.3948984146118164,
#  'Olives, black': 0.3945463299751282,
#  'Pie fillings, apple, canned': 0.3944670557975769,
#  'Potato, hash brown, from restaurant, with cheese': 0.3941572308540344,
#  'Bread, pumpkin': 0.393637090921402,
#  'Bananas, ripe and slightly ripe, raw': 0.39346450567245483,
#  'Pears, asian, raw': 0.3933675289154053,
#  'Fruit nectar, NFS': 0.3932938873767853,
#  'Grapefruit, raw': 0.3932386636734009,
#  'Turnover, fruit': 0.39306703209877014,
#  'Grapes, raw': 0.39299434423446655,
#  'Fruit smoothie, bottled': 0.3928391933441162,
#  'Pepper, banana, raw': 0.3923228979110718,
#  'Cabbage, red, pickled': 0.39228180050849915,
#  'Frozen fruit juice bar': 0.39226245880126953,
#  'Frozen novelties, juice type, orange': 0.3922025263309479,
#  'Orange juice, 100%, frozen, reconstituted': 0.3918861448764801,
#  'Tomatoes, green, raw': 0.3917432427406311,
#  'Fruit flavored drink, powdered, not reconstituted': 0.3916955292224884,
#  'Pink beans, cooked': 0.39167022705078125,
#  'Blueberry syrup': 0.3916163146495819,
#  'Alcoholic Beverage, wine, table, red, Sangiovese': 0.39142346382141113,
#  'Babyfood, GERBER, 3rd Foods, apple, mango and kiwi': 0.3911800980567932,
#  'Soft drink, cola': 0.39070257544517517,
#  'Candy, fruit snacks': 0.3905695676803589,
#  'Macaroni, vegetable, enriched, cooked': 0.3905487656593323,
#  'Fruit flavored drink, diet': 0.39026010036468506,
#  'Fruit mixture, frozen': 0.38998323678970337,
#  'Fruit flavored drink, powdered, not reconstituted, diet': 0.38987651467323303,
#  'Grapes, green, seedless, raw': 0.3898050785064697,
#  'Oranges, raw, navels': 0.3896615505218506,
#  'Beverages, OCEAN SPRAY, White Cranberry Peach': 0.3896600008010864,
#  'Fruit juice, acai blend': 0.3893097937107086,
#  'Croissant, fruit': 0.3886602520942688,
#  'Tomato, green, pickled': 0.3884439766407013,
#  "APPLEBEE'S, crunchy onion rings": 0.3882967233657837,
#  'Fruit flavored drink, with high vitamin C, powdered, reconstituted': 0.3882589340209961,
#  'Beverages, tea, black, ready-to-drink, peach, diet': 0.388224333524704,
#  'Apricot, raw': 0.3881484568119049,
#  'Orange juice, 100%, NFS': 0.388147234916687,
#  'Fruit juice smoothie, NAKED JUICE, BLUE MACHINE': 0.38811004161834717,
#  'Cake, coffeecake, fruit': 0.3877496123313904,
#  'Pumpkin, canned, with salt': 0.38772475719451904,
#  'Cake or cupcake, gingerbread': 0.38772308826446533,
#  'Fruit flavored drink, with high vitamin C': 0.38763314485549927,
#  'Alcoholic Beverage, wine, table, red, Pinot Noir': 0.3875734806060791,
#  'Pie, pumpkin': 0.38744601607322693,
#  'Persimmon, dried': 0.38683801889419556,
#  'Bananas, raw': 0.38651958107948303,
#  'Potatoes, hash brown, frozen, plain, unprepared': 0.3863863945007324,
#  'Grapefruit, raw, white, California': 0.3858858644962311,
#  'Orange, canned, NFS': 0.38562870025634766,
#  'Fruit juice beverage, 40-50% juice, citrus': 0.38549190759658813,
#  'Baby Toddler fruit, NFS': 0.38513651490211487,
#  'Pineapple, dried': 0.38503190875053406,
#  'Babyfood, dinner, apples and chicken, strained': 0.3849433660507202,
#  'Lettuce, red leaf, raw': 0.38479942083358765,
#  'Raspberries, raw': 0.3847982883453369,
#  'Babyfood, dessert, peach melba, strained': 0.3847219944000244,
#  'Fruit smoothie, NFS': 0.3846070170402527,
#  'Pumpkin flowers, raw': 0.38391098380088806,
#  'Orange, canned, in syrup': 0.38355526328086853,
#  'Spices, pepper, red or cayenne': 0.38351553678512573,
#  'Yuca fries': 0.3833925724029541,
#  'Ice creams, strawberry': 0.3833646774291992,
#  'Juice, apple and grape blend, with added ascorbic acid': 0.38331905007362366,
#  'Green beans, raw': 0.3831973075866699,
#  'Crisp, berry': 0.38278618454933167,
#  'Passion fruit nectar': 0.38263005018234253,
#  'Cherry juice, tart': 0.3823941946029663,
#  'Jelly': 0.38215067982673645,
#  'Nuts, macadamia nuts, raw': 0.381914347410202,
#  'Pumpkin leaves, raw': 0.3818919062614441,
#  'Strawberries, raw': 0.3818337321281433,
#  'Babyfood, cereal, rice, with applesauce and bananas, strained': 0.3817991018295288,
#  'Jam or jelly, fruit juice sweetened': 0.38168638944625854,
#  'Winter melon, cooked': 0.38115665316581726,
#  'Pineapple, raw, extra sweet variety': 0.38103967905044556,
#  'Enchilada sauce, red': 0.38101857900619507,
#  'Beverages, Orange juice, light, No pulp': 0.3809938430786133,
#  'Beet juice': 0.3809792101383209,
#  'Beans, snap, green, raw': 0.3808872103691101,
#  'Banana pudding': 0.3806178867816925,
#  'Grape juice drink, light': 0.3804863691329956,
#  'Persimmons, native, raw': 0.38040444254875183,
#  'Tomatoes, red, ripe, canned, with green chilies': 0.38036221265792847,
#  'Sweet potato, candied': 0.3802630603313446,
#  'Mango, canned': 0.3800368010997772,
#  'Yogurt, Greek, nonfat, Fruit on Bottom, Blackberry, CHOBANI': 0.3799586296081543,
#  'Melon balls, frozen': 0.37991905212402344,
#  'Ice cream sundae, fruit topping': 0.3797897696495056,
#  'Grapefruit juice, white, raw': 0.3797461688518524,
#  'Cake or cupcake, red velvet': 0.3796519637107849,
#  'Babyfood, fruit, pears, strained': 0.37964487075805664,
#  'Beans, kidney, california red, mature seeds, raw': 0.3795827627182007,
#  'Roll, sweet, with fruit, frosted': 0.379536509513855,
#  'Beverages, cranberry-apricot juice drink, bottled': 0.37944337725639343,
#  'Biscuit with fruit': 0.3792276978492737,
#  'Pear, canned, in syrup': 0.3791058361530304,
#  'Beverages, Energy drink, RED BULL': 0.3790048360824585,
#  'Soursop, nectar': 0.3789401054382324,
#  'Babyfood, fruit, pears and pineapple, strained': 0.37885981798171997,
#  "Candies, HERSHEY'S POT OF GOLD Almond Bar": 0.37871065735816956,
#  'Pineapple, canned, juice pack': 0.37870991230010986,
#  'Elderberries, raw': 0.37869542837142944,
#  'Beef burgundy': 0.37857547402381897,
#  'Green banana, cooked in salt water': 0.3784194588661194,
#  "APPLEBEE'S, Double Crunch Shrimp": 0.3783044219017029,
#  'Fish, caviar, black and red, granular': 0.3782426714897156,
#  'Apple salad with dressing': 0.37810540199279785,
#  'Grapefruit juice, red, not fortified, not from concentrate, refrigerated': 0.37808799743652344,
#  'Soft drink, fruit flavored, caffeine free': 0.3780084252357483,
#  'Macaroni, vegetable, enriched, dry': 0.37781211733818054,
#  'Vinegar, cider': 0.3777507245540619,
#  'Blueberries, frozen, sweetened': 0.3776249885559082,
#  'Big Mac (McDonalds)': 0.377444863319397,
#  "Orange juice, raw (Includes foods for USDA's Food Distribution Program)": 0.3773317337036133,
#  'Peppers, sweet, red, freeze-dried': 0.37713849544525146,
#  'Whiskey and ginger ale': 0.37694841623306274,
#  'Pineapple juice, 100%': 0.37672746181488037,
#  'Fruit flavored drink, with high vitamin C, powdered, reconstituted, diet': 0.3766185939311981,
#  'Cherries, sour, red, canned, light syrup pack, solids and liquids': 0.37654370069503784,
#  'Honeydew melon, raw': 0.3764529526233673,
#  'Pie, apple, commercially prepared, unenriched flour': 0.3759838044643402,
#  'Watermelon juice, 100%': 0.37542784214019775,
#  'Babyfood, cereal, mixed, with applesauce and bananas, junior, fortified': 0.37540698051452637,
#  'Mango, dried': 0.37522464990615845,
#  'Fritter, fruit': 0.3751516342163086,
#  'Beverages, SNAPPLE, tea, black and green, ready to drink, peach, diet': 0.37505656480789185,
#  'Pumpkin, canned, without salt': 0.374912291765213,
#  'Potatoes, yellow fleshed, hash brown, shredded, salt added in processing, frozen, unprepared': 0.3749008774757385,
#  'Fruit juice smoothie, NAKED JUICE, GREEN MACHINE': 0.3745465874671936,
#  'Yogurt, NS as to type of milk, fruit': 0.3745006024837494,
#  'Onions, green, raw': 0.3744492530822754,
#  'Peppers, sweet, red, frozen, chopped, unprepared': 0.3738599419593811,
#  'Raspberries, frozen': 0.37366849184036255,
#  'Fruit juice blend, 100% juice': 0.373668372631073,
#  'Wine, light': 0.37347447872161865,
#  'Potato chips, ruffled, other flavored': 0.3734513521194458,
#  'Ripe plantain, raw': 0.3729752004146576,
#  'Lime juice, raw': 0.3729548752307892,
#  'Soft drink, fruit flavored, caffeine containing': 0.37292221188545227,
#  'Cocoa, dry powder, unsweetened, processed with alkali': 0.3729018270969391,
#  'Soybeans, green, raw': 0.37254267930984497,
#  'Peppers, bell, red, raw': 0.3724815845489502,
#  'Apricots, frozen, sweetened': 0.3723980784416199,
#  "Cherries, sour, red, frozen, unsweetened (Includes foods for USDA's Food Distribution Program)": 0.37227800488471985,
#  'Sour cream, light': 0.37210527062416077,
#  'Fruit juice drink, diet': 0.37172186374664307,
#  'Babyfood, cereal, oatmeal, with applesauce and bananas, strained': 0.37155723571777344,
#  'Peppers, sweet, red, cooked, boiled, drained, with salt': 0.3714231252670288,
#  'Cranberry juice, unsweetened': 0.3713718056678772,
#  'Alcoholic Beverage, wine, table, red, Lemberger': 0.3712176978588104,
#  'Cherries, raw': 0.37118032574653625,
#  'Babyfood, fruit, apricot with tapioca, junior': 0.3711414337158203,
#  'Potato, hash brown, from dry mix': 0.3709098696708679,
#  'Energy drink, sugar-free (Red Bull)': 0.3706737160682678,
#  'Baby Toddler fruit, with grain': 0.3705506920814514,
#  'Pie, pineapple cream': 0.3700260818004608,
#  "McDONALD'S, BIG MAC": 0.37001609802246094,
#  'Babyfood, cookie, baby, fruit': 0.36991316080093384,
#  'Balsam-pear (bitter gourd), pods, raw': 0.36986565589904785,
#  'Blueberries, dried, sweetened': 0.3697993755340576,
#  'Strawberry milk, whole': 0.36975938081741333,
#  'Lemonade, frozen concentrate, pink': 0.3697150647640228,
#  'Potato chips, other flavored': 0.369634211063385,
#  'Cherries, sweet, raw': 0.36931121349334717,
#  'Peaches, dried, sulfured, uncooked': 0.3692705035209656,
#  'Bread, Boston Brown': 0.3691672682762146,
#  'Fruit juice drink, with high vitamin C': 0.3689129650592804,
#  'Alcoholic Beverage, wine, table, red, Merlot': 0.368762731552124,
#  'Babyfood, dessert, peach cobbler, junior': 0.3686710298061371,
#  "McDONALD'S, BIG MAC (without Big Mac Sauce)": 0.3686393201351166,
#  'Cereal beverage': 0.3684971332550049,
#  'Chayote, fruit, raw': 0.36849555373191833,
#  "McDONALD'S, Hot Caramel Sundae": 0.3684728443622589,
#  'Persimmons, japanese, dried': 0.3682754933834076,
#  'Corn, sweet, yellow, raw': 0.36807137727737427,
#  'Babyfood, dessert, tropical fruit, junior': 0.36795493960380554,
#  'Orange juice, 100%, frozen, not reconstituted': 0.36777353286743164,
#  'Beverages, Fruit flavored drink containing less than 3% fruit juice, with high vitamin C': 0.3673992156982422,
#  'Beverages, orange and apricot juice drink, canned': 0.3671875596046448,
#  'Cherries, sour, red, canned, water pack, solids and liquids': 0.3671478033065796,
#  'Beans, snap, yellow, raw': 0.36697205901145935,
#  'Wine, rice': 0.36686915159225464,
#  'Beverages, yellow green colored citrus soft drink with caffeine': 0.3668225407600403,
#  'Beverages, Kiwi Strawberry Juice Drink': 0.3665962815284729,
#  'Lime, raw': 0.36658787727355957,
#  'Orange Pineapple Juice Blend': 0.36652982234954834,
#  'Beverages, AMBER, hard cider': 0.3665032982826233,
#  'Clementines, raw': 0.3664707541465759,
#  'Fruit cocktail, canned, juice pack': 0.3662186563014984,
#  'Banana chips': 0.36621636152267456,
#  'Wine, dessert, sweet': 0.36599624156951904,
#  'Grape juice, 100%': 0.3659338057041168,
#  'Fruit juice smoothie, BOLTHOUSE FARMS, GREEN GOODNESS': 0.3658783733844757,
#  'Coleslaw, with fruit': 0.3658202886581421,
#  'Pumpkin, cooked, boiled, drained, with salt': 0.36578232049942017,
#  'Clementine, raw': 0.36560744047164917,
#  'Bread, sweet potato': 0.36557820439338684,
#  'Fruit mixture, dried': 0.36553332209587097,
#  'Beverages, carbonated, orange': 0.36508670449256897,
#  'Strawberry drink syrup': 0.36505576968193054,
#  'Babyfood, fruit, papaya and applesauce with tapioca, strained': 0.36504650115966797,
#  'Babyfood, dessert, blueberry yogurt, strained': 0.36504295468330383,
#  'Almonds, flavored': 0.36504101753234863,
#  'Bread, black': 0.3650221526622772,
#  'Strawberries, frozen': 0.3648431897163391,
#  'Potato chips, plain': 0.36482852697372437,
#  'Nectarine, raw': 0.3647497892379761,
#  'Alcoholic beverages, wine, rose': 0.36451098322868347,
#  'Apricot, canned': 0.3644779324531555,
#  'Mango nectar': 0.3644709587097168,
#  'Pie, fried pies, fruit': 0.36446359753608704,
#  'Mushroom, oyster': 0.3642284572124481,
#  'Mangos, raw': 0.3641946017742157,
#  'Oheloberries, raw': 0.3641458749771118,
#  'Soft drink, cola, fruit or vanilla flavored': 0.36413949728012085,
#  'Beans, kidney, california red, mature seeds, cooked, boiled, with salt': 0.36392197012901306,
#  'Tea, iced, bottled, green': 0.3638977110385895,
#  'Gravy, brown, dry': 0.36370038986206055,
#  'Peppers, hot chili, red, raw': 0.36362820863723755,
#  'Yogurt, NS as to type of milk, flavors other than fruit': 0.3635038137435913,
#  'Beans, kidney, royal red, mature seeds, raw': 0.36349496245384216,
#  'Cookie, gingersnaps': 0.36349111795425415,
#  'Baby Toddler fruit, with yogurt': 0.3632906675338745,
#  'Toppings, strawberry': 0.3630283772945404,
#  'Fruit juice smoothie, NAKED JUICE, strawberry banana': 0.3630262017250061,
#  'Pie, sweet potato': 0.3628607988357544,
#  'Fruit flavored drink, with high vitamin C, powdered, not reconstituted': 0.36281949281692505,
#  'Pancakes, fruit, frozen': 0.3625209927558899,
#  'Peppers, sweet, red, cooked, boiled, drained, without salt': 0.3624400496482849,
#  'Beverages, pineapple and orange juice drink, canned': 0.36242181062698364,
#  'Potatoes, hash brown, frozen, with butter sauce, unprepared': 0.36234810948371887,
#  "Cereal, K's, flavored": 0.3623196482658386,
#  'Peaches, dehydrated (low-moisture), sulfured, uncooked': 0.36225956678390503,
#  'Fruit juice blend, citrus, 100% juice': 0.362226277589798,
#  'Strudel, peach': 0.36208584904670715,
#  'Melons, honeydew, raw': 0.36204928159713745,
#  'Fried green tomatoes': 0.3620445132255554,
#  'Cherries, sour, red, canned, heavy syrup pack, solids and liquids': 0.361879825592041,
#  'Vinegar': 0.3618754744529724,
#  'Cranberries, raw': 0.36176806688308716,
#  'Tea, iced, bottled, black': 0.36171919107437134,
#  'Peppers, sweet, red, sauteed': 0.36171674728393555,
#  'Fried green beans': 0.3615258038043976,
#  'Beverages, V8 V-FUSION Juices, Peach Mango': 0.3614543676376343,
#  'Ham, prosciutto': 0.3614140748977661,
#  'Snacks, fruit leather, pieces': 0.36107951402664185,
#  'Berries, NFS': 0.3609957695007324,
#  'Beverages, Fruit punch drink, frozen concentrate': 0.3603633642196655,
#  'Cereal, bran flakes, flavored': 0.36021220684051514,
#  'Candies, MARS SNACKFOOD US, COCOAVIA Blueberry and Almond Chocolate Bar': 0.360104501247406,
#  'SILK Peach soy yogurt': 0.35987621545791626,
#  'Cherries, sour, red, canned, extra heavy syrup pack, solids and liquids': 0.3598378896713257,
#  'Tomatoes, yellow, raw': 0.3595098853111267,
#  'Potato sticks, flavored': 0.3594711720943451,
#  'Potatoes, gold, without skin, raw': 0.3594048321247101,
#  'Fish, salmon, pink, raw': 0.3588799834251404,
#  'Beans, kidney, red, mature seeds, raw': 0.3585757613182068,
#  'Potatoes, hash brown, refrigerated, unprepared': 0.3584870994091034,
#  'Tomatoes, red, ripe, raw, year round average': 0.3582409918308258,
#  'Fried summer squash, yellow or green': 0.3580704927444458,
#  'Pumpkin, flowers, cooked, boiled, drained, with salt': 0.35800039768218994,
#  'Babyfood, fruit, bananas with tapioca, junior': 0.35778677463531494,
#  'Beverages, OCEAN SPRAY, White Cranberry Strawberry Flavored Juice Drink': 0.3577274978160858,
#  'Orange juice, 100%, with calcium added, frozen, reconstituted': 0.35761091113090515,
#  'Babyfood, fruit, bananas and pineapple with tapioca, junior': 0.3575688600540161,
#  'Potato patty': 0.3575509190559387,
#  "APPLEBEE'S, KRAFT, Macaroni & Cheese, from kid's menu": 0.3575287461280823,
#  'Beer': 0.35748928785324097,
#  'Bread, white': 0.35734909772872925,
#  'Passion-fruit, (granadilla), purple, raw': 0.35717153549194336,
#  'Cookies, gingersnaps': 0.35696539282798767,
#  'Peppers, sweet, red, frozen, chopped, boiled, drained, with salt': 0.35686755180358887,
#  "McDONALD'S, Hot Fudge Sundae": 0.35625433921813965,
#  'Tangerine juice, raw': 0.3561818599700928,
#  'Ham': 0.35611093044281006,
#  'Beverages, OCEAN SPRAY, Light Cranberry and Raspberry Flavored Juice': 0.3560936152935028,
#  'CHICK-FIL-A, hash browns': 0.35600775480270386,
#  'Nectarines, raw': 0.35591673851013184,
#  'Fruit juice smoothie, BOLTHOUSE FARMS, strawberry banana': 0.35589316487312317,
#  'Grapefruit, raw, white, Florida': 0.3558884561061859,
#  'Babyfood, beverage, GERBER, GRADUATES, FRUIT SPLASHERS': 0.35586774349212646,
#  'Peach, canned, in syrup': 0.3558650314807892,
#  'Bread, potato': 0.3556860089302063,
#  'Beverages, V8 V-FUSION Juices, Strawberry Banana': 0.35568344593048096,
#  'Beef, ground, raw': 0.3555593192577362,
#  'Babyfood, juice, fruit punch, with calcium': 0.35555005073547363,
#  'Fruit juice smoothie, ODWALLA, strawberry banana': 0.35553714632987976,
#  'Blackberries, frozen, unsweetened': 0.35552310943603516,
#  'Babyfood, dessert, peach cobbler, strained': 0.3554413914680481,
#  'Pears, dried, sulfured, uncooked': 0.355404794216156,
#  'Beans, kidney, california red, mature seeds, cooked, boiled, without salt': 0.35517120361328125,
#  'Green peas, cooked, from restaurant': 0.3551686704158783,
#  'Melon, banana (Navajo)': 0.3551492989063263,
#  'Beverages, fruit punch juice drink, frozen concentrate': 0.35511142015457153,
#  'Cocoa, dry powder, hi-fat or breakfast, processed with alkali': 0.3550088703632355,
#  'Apricot, dried': 0.3549894690513611,
#  'Pumpkin, cooked, boiled, drained, without salt': 0.35493066906929016,
#  'Gourd, white-flowered (calabash), raw': 0.354844331741333,
#  'Peas, green, cooked, boiled, drained, with salt': 0.3547489047050476,
#  'Yogurt, fruit variety, nonfat': 0.35443106293678284,
#  'Baby Toddler juice, mixed fruit': 0.354428768157959,
#  'Onions, green, cooked': 0.354282945394516,
#  'Tangerine, raw': 0.35412299633026123,
#  'Beverages, Fruit punch drink, with added nutrients, canned': 0.35409748554229736,
#  'Yogurt, liquid': 0.3540254235267639,
#  'Beverages, V8 SPLASH Juice Drinks, Mango Peach': 0.3540014624595642,
#  'Bitter melon, cooked': 0.35395777225494385,
#  'Coconut, fresh': 0.35389411449432373,
#  'Beef, ground': 0.35376492142677307,
#  'Cereals ready-to-eat, MALT-O-MEAL, Apple ZINGS': 0.35374611616134644,
#  'Carrot juice, 100%': 0.35364168882369995,
#  'Flavored rice, brown and wild': 0.35360482335090637,
#  'Strawberry milk, NFS': 0.35356706380844116,
#  'Lobster': 0.3535577952861786,
#  'Candies, MARS SNACKFOOD US, STARBURST Fruit Chews, Original fruits': 0.353401780128479,
#  'Beverages, Cocoa mix, powder': 0.3533775210380554,
#  'Tomato juice, 100%': 0.35329902172088623,
#  'Babyfood, finger snacks, GERBER, GRADUATES, PUFFS, apple and cinnamon': 0.3532555401325226,
#  'Babyfood, tropical fruit medley': 0.35313770174980164,
#  'Fruit juice drink, with high vitamin C, plus added calcium': 0.3531208634376526,
#  'Cocoa, dry powder, unsweetened': 0.35305824875831604,
#  'Peppers, sweet, red, frozen, chopped, boiled, drained, without salt': 0.35302603244781494,
#  'Fruit juice drink, citrus, carbonated': 0.3529050648212433,
#  'Potato chips, ruffled, sour cream and onion flavored': 0.3528349697589874,
#  'Poke greens, cooked': 0.35276663303375244,
#  'Olives, pickled, canned or bottled, green': 0.35275545716285706,
#  'Beans, kidney, royal red, mature seeds, cooked, boiled with salt': 0.35265839099884033,
#  'Ham, ground': 0.3526577353477478,
#  'Summer squash, green, raw': 0.3526206612586975,
#  'Pumpkin seeds, unsalted': 0.35244280099868774,
#  'Potato, hash brown, NFS': 0.3523094058036804,
#  'Waffle, fruit, frozen': 0.35222065448760986,
#  'Peas, green, frozen, cooked, boiled, drained, with salt': 0.3521435856819153,
#  'Yardlong bean, raw': 0.35206902027130127,
#  'Fruit juice drink, added calcium (Sunny D)': 0.3520492613315582,
#  'Potato chowder': 0.351859450340271,
#  'Lemon, raw': 0.3517836928367615,
#  'Corn, sweet, white, raw': 0.3517150282859802,
#  'Bagel, with fruit other than raisins': 0.35169070959091187,
#  'Burrito, beef, cheese': 0.3516569137573242,
#  'Peppers, green, cooked': 0.3516436815261841,
#  'Onions, yellow, raw': 0.3516432046890259,
#  'Dark chocolate candy': 0.3514294922351837,
#  'Gelatin dessert with fruit': 0.351339191198349,
#  'Fruit juice drink, noncitrus, carbonated': 0.3512094020843506,
#  'Beer, light': 0.35118693113327026,
#  'Vegetable and fruit juice drink, with high vitamin C, light': 0.3511473536491394,
#  'Ice cream, fried': 0.3507953882217407,
#  'Babyfood, fruit, apricot with tapioca, strained': 0.35070669651031494,
#  'Potatoes, hash brown, home-prepared': 0.35067492723464966,
#  'Fast foods, sundae, strawberry': 0.35043567419052124,
#  'Baby Toddler yogurt, with fruit': 0.350376158952713,
#  'Snack cake, white': 0.35037142038345337,
#  'Orange juice, 100%, canned, bottled or in a carton': 0.3503158986568451,
#  'Hot chocolate / Cocoa, ready to drink': 0.35030585527420044,
#  'Pear, canned, NFS': 0.3502918481826782,
#  'Peppers, sweet, red, canned, solids and liquids': 0.3501858711242676,
#  'Cake or cupcake, strawberry': 0.35003662109375,
#  'Blackeyed peas, from frozen': 0.34971997141838074,
#  'Cereal or granola bar (KIND Fruit and Nut Bar)': 0.34962865710258484,
#  'Roll, sweet, with fruit, frosted, diet': 0.3495510220527649,
#  'Brandy and cola': 0.3495368957519531,
#  'Sweet potatoes, orange flesh, without skin, raw': 0.34951967000961304,
#  'Mango, dried, sweetened': 0.3489559590816498,
#  'Orange-grapefruit juice, canned or bottled, unsweetened': 0.3487910330295563,
#  'Fried rice, Puerto Rican style': 0.34849750995635986,
#  'Tea, hot, leaf, green': 0.3482789397239685,
#  'Fish, salmon, sockeye (red), raw (Alaska Native)': 0.34807223081588745,
#  'Guava nectar': 0.3479282855987549,
#  'Egg burrito, with ham': 0.3479158282279968,
#  'Alcoholic beverage, wine, dessert, sweet': 0.34785982966423035,
#  'Cranberries, dried': 0.34779834747314453,
#  'Yogurt, Greek, NS as to type of milk, fruit': 0.3477722704410553,
#  'Grapefruit juice, white, canned, sweetened': 0.34774327278137207,
#  'Bread, pita with fruit': 0.3476989269256592,
#  'Potato chips, ruffled, plain': 0.34752410650253296,
#  'Peas, green, cooked, boiled, drained, without salt': 0.34728217124938965,
#  'Cereal, rice crispy, flavored': 0.34715136885643005,
#  'Fruit flavored drink, with high vitamin C, diet': 0.347046822309494,
#  'Almonds, salted': 0.3470432162284851,
#  'Turtle, green, raw': 0.34702783823013306,
#  'Cranberry juice drink, with high vitamin C, light': 0.34702780842781067,
#  'Peas, green, frozen, cooked, boiled, drained, without salt': 0.34686172008514404,
#  'Alcoholic beverage, wine, light': 0.3468262255191803,
#  'Green beans, pickled': 0.34676867723464966,
#  'Pecans, salted': 0.34672731161117554,
#  'Rice dessert or salad with fruit': 0.3466976284980774,
#  'Pears, raw, bartlett': 0.3466198444366455,
#  'Beef, oxtails': 0.3465203642845154,
#  'Sherbet, all flavors': 0.34626805782318115,
#  'Peppers, sweet, green, raw': 0.3462553918361664,
#  'Strawberries, canned': 0.3462251126766205,
#  'Milk, chocolate beverage, hot cocoa, homemade': 0.3461833596229553,
#  'Rusty Nail': 0.3461259603500366,
#  'Tea, hot, leaf, black': 0.3460543751716614,
#  "Candies, REESE'S NUTRAGEOUS Candy Bar": 0.34598517417907715,
#  'Beans, kidney, red, mature seeds, cooked, boiled, with salt': 0.34596121311187744,
#  'Fruit juice smoothie, NAKED JUICE, MIGHTY MANGO': 0.3457995057106018,
#  'Fish, roughy, orange, raw': 0.345703125,
#  'Tea, iced, brewed, green, unsweetened': 0.34570273756980896,
#  'Chocolate syrup, light': 0.34566354751586914,
#  'Zucchini, pickled': 0.3453875780105591,
#  'Beans, snap, green, microwaved': 0.34532493352890015,
#  'Pineapple, frozen, chunks, sweetened': 0.34494245052337646,
#  'Strawberries, frozen, sweetened, sliced': 0.34486523270606995,
#  'Crabapples, raw': 0.3447483479976654,
#  'Beans, snap, green, frozen, all styles, microwaved': 0.3444819152355194,
#  'Beans, kidney, royal red, mature seeds, cooked, boiled, without salt': 0.3443990647792816,
#  'Pecans, honey roasted': 0.34422898292541504,
#  'Beverages, fruit punch-flavor drink, powder, without added sodium, prepared with water': 0.34421733021736145,
#  'Mushroom, king oyster': 0.3441731929779053,
#  'Cassava, raw': 0.3441241383552551,
#  'Pancakes, pumpkin': 0.3436136245727539,
#  'Barley, pearled, raw': 0.3435719609260559,
#  'Pineapple, raw, traditional varieties': 0.34335586428642273,
#  'Pastry, fruit-filled': 0.34328967332839966,
#  'Oscar Mayer, Ham (chopped with natural juice)': 0.3432880640029907,
#  'Yogurt, Greek, strawberry, DANNON OIKOS': 0.34297460317611694,
#  'Beverages, orange-flavor drink, breakfast type, powder': 0.3428877592086792,
#  'Alcoholic beverage, beer, light': 0.34261128306388855,
#  'Fruit juice drink, reduced sugar (Sunny D)': 0.34259581565856934,
#  'Babyfood, dessert, banana pudding, strained': 0.3425780236721039,
#  'Beet greens, raw': 0.3425767123699188,
#  'Corn grain, yellow': 0.34236183762550354,
#  'Potato chips, popped, flavored': 0.3423491418361664,
#  'Icing, white': 0.3422182500362396,
#  'Beets, raw': 0.3421632945537567,
#  'Potato, scalloped, from fresh': 0.34206336736679077,
#  'Tea, iced, bottled, green, unsweetened': 0.3418946862220764,
#  'Alcoholic Beverage, wine, table, red, Mouvedre': 0.34186166524887085,
#  'Avocados, raw, all commercial varieties': 0.34181642532348633,
#  'Burrito, beef and bean, frozen': 0.34169235825538635,
#  'Hominy, canned, yellow': 0.34151795506477356,
#  'Sweet potato, cooked, baked in skin, flesh, with salt': 0.3414408564567566,
#  'Egg burrito': 0.3414241373538971,
#  'Wine, table, rose': 0.34137797355651855,
#  'Fruit cocktail, canned, NFS': 0.3413441479206085,
#  'Yogurt, Greek, NS as to type of milk, flavors other than fruit': 0.3413350582122803,
#  'Candies, soft fruit and nut squares': 0.3410326838493347,
#  'Alcoholic Beverage, wine, table, red, Carignane': 0.3408416509628296,
#  'Tangerine juice, 100%': 0.3408288359642029,
#  'Water, tonic': 0.3408276438713074,
#  'Potato chips, ruffled, cheese flavored': 0.34066396951675415,
#  'Peppers, sweet, yellow, raw': 0.34061580896377563,
#  'Candies, MARS SNACKFOOD US, STARBURST Fruit Chews, Fruit and Creme': 0.34021157026290894,
#  'Nuts, acorns, raw': 0.3401278257369995,
#  'Snack, Mixed Berry Bar': 0.34010207653045654,
#  'Candy, caramel': 0.34007641673088074,
#  'Cake, strawberry shortcake': 0.3400028944015503,
#  'Babyfood, snack, GERBER GRADUATE FRUIT  STRIPS, Real Fruit Bars': 0.3400007486343384,
#  'Salmon, red (sockeye), filets with skin, smoked (Alaska Native)': 0.3398835361003876,
#  'Tea, iced, instant, green, unsweetened': 0.33986103534698486,
#  "Cereal or granola bar (Kellogg's Nutri-Grain Fruit and Nut Bar)": 0.33969980478286743,
#  'Corn, raw': 0.33960261940956116,
#  'Beverages, tea, green, ready-to-drink, sweetened': 0.3395483195781708,
#  'Gooseberries, raw': 0.3393489122390747,
#  'Barley, pearled, cooked': 0.33930981159210205,
#  'Pudding, rice': 0.33914434909820557,
#  "Oranges, raw, navels (Includes foods for USDA's Food Distribution Program)": 0.3391385078430176,
#  'Yogurt, Greek, nonfat, Fruit on Bottom, Strawberry, CHOBANI': 0.33907991647720337,
#  'Tomatoes, raw': 0.33902156352996826,
#  'Fig, raw': 0.33890730142593384,
#  'Grapes, american type (slip skin), raw': 0.3388883173465729,
#  'Asparagus, raw': 0.33884158730506897,
#  'Orange juice, 100%, with calcium added, canned, bottled or in a carton': 0.3388024568557739,
#  'Babyfood, dessert, banana yogurt, strained': 0.33864331245422363,
#  'Muffin, pumpkin': 0.3385336399078369,
#  'Water, with corn syrup and/or sugar and low calorie sweetener, fruit flavored': 0.3384718596935272,
#  'Soft drink, pepper type': 0.3384248912334442,
#  'Squash, winter, acorn, cooked, baked, with salt': 0.33842024207115173,
#  'Summer squash, yellow, raw': 0.3383963704109192,
#  'Guavas, strawberry, raw': 0.3381066918373108,
#  'Pan Dulce, with fruit, no frosting': 0.3380727767944336,
#  'Beverages, cranberry-grape juice drink, bottled': 0.3380352556705475,
#  'Tea, iced, brewed, black, unsweetened': 0.33801111578941345,
#  'Soy milk, light': 0.3379931151866913,
#  'Beans, kidney, red, mature seeds, canned, solids and liquids': 0.33794277906417847,
#  'Ice cream sandwich, made with light ice cream, vanilla': 0.3378499746322632,
#  'Beef, pot roast': 0.3378424346446991,
#  'Beef, ground, patty': 0.33775824308395386,
#  'Ice cream soda, chocolate': 0.3375081419944763,
#  'Guava, raw': 0.3373495936393738,
#  'Tangerines, (mandarin oranges), raw': 0.33721479773521423,
#  'Pot pie, beef': 0.3371831178665161,
#  'Candies, MARS SNACKFOOD US, COCOAVIA Chocolate Bar': 0.33712828159332275,
#  'Pineapple, canned, NFS': 0.3370550870895386,
#  'Toppings, pineapple': 0.33683714270591736,
#  'Cherries, frozen': 0.3368259072303772,
#  'Beans, pink, mature seeds, raw': 0.3368237614631653,
#  'Green bean casserole': 0.33674100041389465,
#  'Beverages, Orange-flavor drink, breakfast type, with pulp, frozen concentrate.': 0.3367305397987366,
#  'Beans, Dry, Light Red Kidney (0% moisture)': 0.3367030918598175,
#  'Babyfood, fruit, tutti frutti, junior': 0.3366820812225342,
#  'Winter squash, raw': 0.3366408944129944,
#  'Fruit cocktail, (peach and pineapple and pear and grape and cherry), canned, extra light syrup, solids and liquids': 0.3366298973560333,
#  'Oil, cocoa butter': 0.33661216497421265,
#  'Soft drink, cola, chocolate flavored': 0.3365391492843628,
#  'Baby Toddler juice, fruit and vegetable': 0.3364453911781311,
#  "Cocoa, dry powder, unsweetened, HERSHEY'S European Style Cocoa": 0.33637094497680664,
#  'Bread, zucchini': 0.3363616466522217,
#  'Beef, roast': 0.3362888693809509,
#  'Soft drink, fruit flavored, diet, caffeine free': 0.33625519275665283,
#  'Potato from Puerto Rican beef stew, with gravy': 0.3362058997154236,
#  'Gnocchi, potato': 0.33617550134658813,
#  'Fruit cocktail, (peach and pineapple and pear and grape and cherry), canned, light syrup, solids and liquids': 0.33600789308547974,
#  'Yogurt, whole milk, fruit': 0.33584392070770264,
#  'Bologna sandwich on white': 0.33576732873916626,
#  'Candy, mint': 0.335729718208313,
#  'Burrito, cheese only': 0.3356538414955139,
#  'Plantains, yellow, fried, Latino restaurant': 0.3356007933616638,
#  'Babyfood, fruit, tutti frutti, strained': 0.3355904221534729,
#  'Ginger root, pickled, canned, with artificial sweetener': 0.33551788330078125,
#  'Pears, canned, juice pack, solids and liquids': 0.33545932173728943,
#  'Babyfood, mixed fruit juice with low fat yogurt': 0.3353898525238037,
#  'Burrito, beef, with rice, cheese': 0.33538883924484253,
#  'Beans, snap, yellow, frozen, all styles, unprepared': 0.3353831470012665,
#  'Beverages, V8 SPLASH Juice Drinks, Orange Pineapple': 0.3352678716182709,
#  'Tomatoes, grape, raw': 0.33520206809043884,
#  'Candies, MARS SNACKFOOD US, COCOAVIA Crispy Chocolate Bar': 0.3351406455039978,
#  'Pepper, hot, pickled': 0.33505362272262573,
#  'Potato, home fries, from fresh': 0.3350033760070801,
#  'Beans, kidney, red, mature seeds, cooked, boiled, without salt': 0.334949791431427,
#  'Grapefruit, canned': 0.3348221778869629,
#  'Tea, iced, bottled, black, unsweetened': 0.3346930742263794,
#  'Blackeyed peas, from canned': 0.33466002345085144,
#  'Plantains, green, fried': 0.3346080183982849,
#  'Balsam-pear (bitter gourd), pods, cooked, boiled, drained, with salt': 0.3345654606819153,
#  'Carrot juice, canned': 0.33456218242645264,
#  'Babyfood, banana with mixed berries, strained': 0.33451706171035767,
#  'Melons, cantaloupe, raw': 0.33447813987731934,
#  'Mango nectar, canned': 0.33444729447364807,
#  'Sweet potato, frozen, cooked, baked, with salt': 0.33430835604667664,
#  'Potato sticks, plain': 0.3342922329902649,
#  'Pie shell, chocolate': 0.33427906036376953,
#  'Cookie, fruit-filled bar': 0.33422815799713135,
#  'Beverages, V8 SPLASH Juice Drinks, Strawberry Banana': 0.33415788412094116,
#  'Beverages, tea, black, ready-to-drink, lemon, sweetened': 0.33415013551712036,
#  'Coffee, pre-lightened': 0.33412572741508484,
#  'Squash, winter, acorn, raw': 0.3340638279914856,
#  'Ice cream sundae cone': 0.3340052664279938,
#  'Pigeon peas (red gram), mature seeds, raw': 0.3338756561279297,
#  'Bread, boston brown, canned': 0.33386296033859253,
#  'Stuffed green pepper, Puerto Rican style': 0.33382847905158997,
#  'Yogurt, Greek, strawberry, lowfat': 0.3337588906288147,
#  'Brandy': 0.3337572515010834,
#  'Babyfood, dessert, cherry vanilla pudding, junior': 0.33374541997909546,
#  'Fruit juice smoothie, BOLTHOUSE FARMS, BERRY BOOST': 0.33369529247283936,
#  'Babyfood, dessert, fruit dessert, without ascorbic acid, junior': 0.3336407542228699,
#  'Oysters, fried': 0.33362776041030884,
#  'Grape juice, purple, with added vitamin C, from concentrate, shelf stable': 0.3336164355278015,
#  'Melba toast': 0.3335481882095337,
#  'Tangerines, (mandarin oranges), canned, juice pack': 0.333355188369751,
#  'Chocolate candy with dried fruit': 0.3331458568572998,
#  'Pineapple, canned, juice pack, drained': 0.33306586742401123,
#  'Muffin, bran with fruit, lowfat': 0.3330056071281433,
#  'Rice, brown, with peas, fat added': 0.3329901695251465,
#  'Gourd, white-flowered (calabash), cooked, boiled, drained, with salt': 0.3329690992832184,
#  'Soursop, raw': 0.33289334177970886,
#  'Tomato aspic': 0.332871675491333,
#  'Beef, roast, hash': 0.3327576816082001,
#  'Pears, canned, light syrup pack, solids and liquids': 0.3327503800392151,
#  'Nuts, chestnuts, japanese, raw': 0.3327091634273529,
#  'Cereal, other, plain': 0.3326761722564697,
#  'Corn grain, white': 0.33265310525894165,
#  'Sweet potato chips': 0.3326098620891571,
#  'Babyfood, juice treats, fruit medley, toddler': 0.3325876295566559,
#  'Pumpkin flowers, cooked, boiled, drained, without salt': 0.33257174491882324,
#  'Blueberries, canned, light syrup, drained': 0.3324916660785675,
#  'Sweet potato, cooked, baked in skin, flesh, without salt': 0.33245840668678284,
#  'Ice cream sandwich': 0.33231496810913086,
#  'Ham, honey, smoked, cooked': 0.33226215839385986,
#  'Cookie, pumpkin': 0.33225345611572266,
#  'Grapefruit juice, white, canned or bottled, unsweetened': 0.3321669101715088,
#  'Yogurt, Greek, whole milk, flavors other than fruit': 0.3321186900138855,
#  'Cheese, Blue or Roquefort': 0.3320424556732178,
#  'Candy, cotton': 0.33178794384002686,
#  'Egg, white, raw, fresh': 0.3317159414291382,
#  'Soft drink, chocolate flavored': 0.3317036032676697,
#  'Pie, fried pies, cherry': 0.331679105758667,
#  'Cobbler, peach': 0.33160918951034546,
#  'Alcoholic beverage, beer, light, higher alcohol': 0.33151620626449585,
#  'Fish, swordfish, raw': 0.33138638734817505,
#  "Cereal, O's, flavored": 0.33124300837516785,
#  'Spices, ginger, ground': 0.33117353916168213,
#  'Nuts, chestnuts, japanese, roasted': 0.33080264925956726,
#  'Babyfood, cereal, whole wheat, with apples, dry fortified': 0.3307079076766968,
#  'Potato from Puerto Rican style stuffed pot roast, with gravy': 0.3306756019592285,
#  'Beverages, fruit punch juice drink, frozen concentrate, prepared with water': 0.33061903715133667,
#  'Black bean sauce': 0.3305028975009918,
#  'Candies, ALMOND JOY Candy Bar': 0.33046603202819824,
#  'Ham sandwich on white': 0.3304465413093567,
#  'Beverages, NESTEA, tea, black, ready-to-drink, lemon': 0.33033668994903564,
#  'Soft drink, fruit flavored, caffeine containing, diet': 0.33008304238319397,
#  'Breadfruit, raw': 0.33003389835357666,
#  'Beverages, Fruit punch drink, frozen concentrate, prepared with water': 0.32986414432525635,
#  'Wheat, hard white': 0.3298611640930176,
#  'Pork, roast': 0.3298289477825165,
#  'Ripe plantain meat pie, Puerto Rican style': 0.32976335287094116,
#  'Limes, raw': 0.32968345284461975,
#  'Cherries, dried': 0.3296319842338562,
#  'Goji berries, dried': 0.3295430839061737,
#  'Beverages, tea, green, ready to drink, unsweetened': 0.3295411765575409,
#  'Barley': 0.32949042320251465,
#  'Tea, iced, instant, black, unsweetened': 0.32945722341537476,
#  'Keikitos (muffins), Latino bakery item': 0.3294152021408081,
#  'Yogurt, soy': 0.3293454647064209,
#  'Egg, white only, raw': 0.3292534351348877,
#  'Peaches, dehydrated (low-moisture), sulfured, stewed': 0.32914331555366516,
#  'Potato pancake': 0.32913970947265625,
#  'Cocoa powder, not reconstituted': 0.3291082978248596,
#  'Beverages, V8 SPLASH Juice Drinks, Fruit Medley': 0.32910555601119995,
#  'Cabbage, red, cooked, boiled, drained, with salt': 0.32907533645629883,
#  'Beans, Dry, Dark Red Kidney (0% moisture)': 0.32903602719306946,
#  'Yogurt, whole milk, flavors other than fruit': 0.32898926734924316,
#  'SILK Black Cherry soy yogurt': 0.32897505164146423,
#  'Bananas, overripe, raw': 0.3287616968154907,
#  "McDONALD'S, Sausage Burrito": 0.32875266671180725,
#  'Ice cream sundae, NFS': 0.3287310004234314,
#  'Beverages, MOTTS, Apple juice light, fortified with vitamin C': 0.3287228047847748,
#  'Gourd, white-flowered (calabash), cooked, boiled, drained, without salt': 0.32871174812316895,
#  'Babyfood, dinner, macaroni and tomato and beef, junior': 0.3287000060081482,
#  'Peaches, canned, juice pack, solids and liquids': 0.3284810185432434,
#  'Macaroni with tuna, Puerto Rican style': 0.32823505997657776,
#  'Gravy, brown instant, dry': 0.3281206786632538,
#  'Alcoholic Beverage, wine, table, red, Cabernet Franc': 0.3280772566795349,
#  'Babyfood, mixed fruit yogurt, strained': 0.32792186737060547,
#  'Oil, avocado': 0.32790684700012207,
#  'Grapefruit, raw, white, all areas': 0.32789838314056396,
#  'Rice, fried, with beef': 0.32789158821105957,
#  'Alcoholic beverage, wine, dessert, dry': 0.32783010601997375,
#  'Rice, white, cooked with fat, Puerto Rican style': 0.3277692198753357,
#  'Babyfood, fruit, bananas with tapioca, strained': 0.32770735025405884,
#  'Cheese, cottage, with fruit': 0.3276892304420471,
#  'Pumpkin seeds, NFS': 0.3276769518852234,
#  'Wheat, soft white': 0.3276726007461548,
#  'Spices, pepper, black': 0.327661395072937,
#  'Pie, blueberry, commercially prepared': 0.3276408910751343,
#  'Beverages, Cranberry juice cocktail': 0.3276359438896179,
#  'Bean chips': 0.3275787830352783,
#  'Onions, white, raw': 0.3275756239891052,
#  "Mushroom, lion's mane": 0.32753893733024597,
#  'Hot chocolate / Cocoa, ready to drink, with whipped cream': 0.3275347948074341,
#  'Black beans, from fast food / restaurant': 0.3274955451488495,
#  'Onions, pearl, cooked': 0.3273756504058838,
#  'Peppers, bell, orange, raw': 0.32729384303092957,
#  'Black beans and brown rice': 0.3272089660167694,
#  'Fruit cocktail, (peach and pineapple and pear and grape and cherry), canned, heavy syrup, solids and liquids': 0.32720041275024414,
#  'Burrito, beef and bean, microwaved': 0.3271888494491577,
#  "Blueberries, frozen, unsweetened (Includes foods for USDA's Food Distribution Program)": 0.3270881772041321,
#  'Balsam-pear (bitter gourd), pods, cooked, boiled, drained, without salt': 0.32705098390579224,
#  'Beverages, Cocoa mix, powder, prepared with water': 0.3269868493080139,
#  'Rice, brown, with gravy, fat added': 0.32690632343292236,
#  'Olives, stuffed': 0.32671964168548584,
#  'Vodka': 0.32663142681121826,
#  'Pie, banana cream': 0.32660049200057983,
#  'Sour cream, regular': 0.3265891373157501,
#  'Cheeseburger (McDonalds)': 0.32646995782852173,
#  'Frijoles rojos volteados (Refried beans, red, canned)': 0.32646405696868896,
#  'Potato chips, ruffled, barbecue flavored': 0.3264494240283966,
#  'Gelatin dessert, sugar free, with fruit': 0.3264489769935608,
#  'Peaches, canned, heavy syrup, drained': 0.32640618085861206,
#  'Pears, canned, heavy syrup, drained': 0.3263687193393707,
#  'Beans, kidney, red, mature seeds, canned, solids and liquid, low sodium': 0.32636746764183044,
#  'Sauce, peppers, hot, chili, mature red, canned': 0.32635146379470825,
#  'Blueberries, canned, heavy syrup, solids and liquids': 0.3262847065925598,
#  ...}

# %%
import openai

openai.api_key_path = "../foodvision/utils/openai_api_key.txt"

def chat_complete(prompt: str, **openai_kwargs) -> str:
    """Generate completion from OpenAI ChatGPT API"""
    default_kwargs = {"model": "gpt-3.5-turbo", "max_tokens": 256, "temperature": 0.2, "top_p": 1}
    openai_kwargs = {**default_kwargs, **openai_kwargs}
    response = openai.ChatCompletion.create(
        **openai_kwargs,
        messages=[
                {"role": "system", "content": "You are a helpful assistant who is very good at designing apps and making them look good."},
                {"role": "user", "content": prompt},
            ]
        )
    return response

base_prompt_for_sorting_food_names = """You are a food scientist and nutritionist very knowledgable on all different kinds of foods.\n
Given the following list of foods and the target text, please sort the list of foods into which ones relate most to the target text.\n
For example, the list ['apples, red delicious, with skin, raw',
 'apples, gala, with skin, raw',
 'apples, honeycrisp, with skin, raw',
 'apples, granny smith, with skin, raw',
 'applesauce, unsweetened, with added vitamin c',
 ...]
and the target text 'apple_red' would be sorted as a JSON dictionary,
 '1': 'apples, red delicious, with skin, raw', 
 '2': 'apples, gala, with skin, raw', 
 '3': 'apples, honeycrisp, with skin, raw', 
 '4': 'apples, granny smith, with skin, raw', 
 '5': 'applesauce, unsweetened, with added vitamin c', 
 ....\n
Please do not include any extra foods or text, only return the list of foods in the target food list.\n
Put a favour on similar types of foods, e.g. if the target text contains "capsicum_green" then "pepper, red" should be higher than "cabbage, green".\n
If the target list of foods to sort has N items, you should return a list of N items.\n
For example, if the target list of foods to sort has 10 items, you should return a list of 10 items.\n
Target text: {target_text}\n
List of foods to sort: {target_food_list}\n
Sorted list of food as properly formatted JSON dictionary:\n
"""

def sort_list_of_foods(base_prompt: str, target_text: str, target_food_list: list) -> list:
    # print(base_prompt)
    target_text_dict = {"target_text": target_text, "target_food_list": target_food_list}
    target_text_prompt = base_prompt.format(**target_text_dict)
    # target_text_prompt = base_prompt.format(target_text, target_food_list)
    # print(target_text_prompt)
    answer = chat_complete(target_text_prompt)
    answer_formatted = str(answer.choices[0].message.content)
    # Remove "\n"
    # print(f"Display name generated: {target_text} -> {answer_formatted}")
    return answer_formatted

# target_text = "capsicum_red"
target_text = random.choice(food_item_without_fdcid)
print(f"Predicting the most similar class names to: {target_text}")

most_similar_class_names = find_most_similar_class_name(target_text, class_name_embedding_dict_unique_descriptions)

# Get the top 10 most similar class names
target_food_list = list(most_similar_class_names.keys())[:10]
print(len(target_food_list))

# Turn target_food_list into a dictionary with keys in order of 1, 2, 3...
target_food_list = {i+1: food_name for i, food_name in enumerate(target_food_list)}
print(target_food_list)
# print(target_food_list)

sorted_list_of_foods = sort_list_of_foods(base_prompt=base_prompt_for_sorting_food_names, target_text=target_text, target_food_list=target_food_list)
sorted_list_of_foods
# Out:
# Predicting the most similar class names to: melon_spanish
# 10
# {1: 'Melon, banana (Navajo)', 2: 'Honeydew melon, raw', 3: 'Melons, honeydew, raw', 4: 'Winter melon, cooked', 5: 'Melons, casaba, raw', 6: 'Bitter melon, cooked', 7: 'Melons, cantaloupe, raw', 8: 'Horned melon (Kiwano)', 9: 'Waxgourd, (chinese preserving melon), raw', 10: 'Waxgourd, (chinese preserving melon), cooked, boiled, drained, with salt'}
# '{\n    "1": "Melons, honeydew, raw",\n    "2": "Honeydew melon, raw",\n    "3": "Melons, cantaloupe, raw",\n    "4": "Melons, casaba, raw",\n    "5": "Horned melon (Kiwano)",\n    "6": "Waxgourd, (chinese preserving melon), raw",\n    "7": "Waxgourd, (chinese preserving melon), cooked, boiled, drained, with salt",\n    "8": "Winter melon, cooked",\n    "9": "Bitter melon, cooked",\n    "10": "Melon, banana (Navajo)"\n}'

# %%
import json
sorted_list_of_foods = json.loads(sorted_list_of_foods)
sorted_list_of_foods
# Out:
# {'1': 'peppers, bell, red, raw',
#  '2': 'cabbage, red, raw',
#  '3': 'cherries, sweet, dark red, raw',
#  '4': 'lettuce, leaf, red, raw',
#  '5': 'onions, red, raw',
#  '6': 'peppers, bell, orange, raw',
#  '7': 'peppers, bell, yellow, raw',
#  '8': 'peppers, bell, green, raw',
#  '9': 'mustard, prepared, yellow',
#  '10': 'beans, dry, medium red (0% moisture)'}
