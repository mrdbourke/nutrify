# %% [markdown]
# # Exploring the data downloaded from USDA FoodData Central
#
# See the download here: https://fdc.nal.usda.gov/download-datasets.html
#
# This notework works with the JSON version of the data.

# %%
import gspread
import pandas as pd

# Open the sheet with Google Sheets
gc = gspread.oauth()

# See the link here: https://docs.google.com/spreadsheets/d/1fgNtqfuaBSbPBPQfyzYAmRb1UUHdsRphoAqXHfP-dD0/edit?usp=sharing 
sheet = gc.open("nutrify-name-to-fdc-id")
worksheet = sheet.sheet1
rows = worksheet.get_all_records()

nutrify_to_fdcid = pd.DataFrame(rows)

# Replace all blank rows in fdc_id with NaN
nutrify_to_fdcid['fdc_id'] = nutrify_to_fdcid['fdc_id'].replace('', None)
nutrify_to_fdcid.head()
# Out:
#    number     class_name   fdc_id
# 0       0        achacha     None
# 1       1  almond_butter  2262074
# 2       2        almonds  2346393
# 3       3  apple_custard   168175
# 4       4    apple_green  1750342

# %%
# How many rows have an FDC ID?
rows_with_fdcid = nutrify_to_fdcid[nutrify_to_fdcid["fdc_id"].notna()]
rows_without_fdcid = nutrify_to_fdcid[nutrify_to_fdcid["fdc_id"].isna()]

print(f"Rows with FDC ID: {len(rows_with_fdcid)}")
print(f"Rows without FDC ID: {len(rows_without_fdcid)}")
# nutrify_to_fdcid.isna()
# Out:
# Rows with FDC ID: 275
# Rows without FDC ID: 48

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from tqdm.auto import tqdm

from pathlib import Path

# %% [markdown]
# ## Get FDC Data
#
# Download data from here: https://fdc.nal.usda.gov/download-datasets.html

# %%
targ_dir = "data/2022/JSON"

# Get all the files in the directory
data_files = sorted(list(Path(targ_dir).glob("*.json")))
data_files

# Combine them into one big JSON?
data = {}
for file in tqdm(data_files):
    with open(file) as f:
        data = {**data, **json.load(f)}

dataset_names = list(data.keys())
print(f"Dataset names: {dataset_names}")

print(f"Length of Foundation Foods: {len(data['FoundationFoods'])}")
print(f"Length of Legacy Foods: {len(data['SRLegacyFoods'])}")
print(f"Length of Survey Foods: {len(data['SurveyFoods'])}")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Dataset names: ['FoundationFoods', 'SRLegacyFoods', 'SurveyFoods']
# Length of Foundation Foods: 210
# Length of Legacy Foods: 7793
# Length of Survey Foods: 5624

# %%
nutrify_to_fdcid["fdc_id"]
# Out:
# 0         None
# 1      2262074
# 2      2346393
# 3       168175
# 4      1750342
#         ...
# 318    2346264
# 319     168572
# 320    2259793
# 321     169291
# 322     171714
# Name: fdc_id, Length: 323, dtype: object

# %%
# nutrify_to_fdcid_keys = [int(key) for key in fdcid_to_nutrify_name.keys() if key is not None]
nutrify_to_fdcid_keys = nutrify_to_fdcid["fdc_id"].dropna().tolist()
print(nutrify_to_fdcid_keys[:10])

# Create list of nutrify food items
nutrify_food_items = []
all_nutrients = []

# Get a list of all descriptions and map to FDC ID
fdcid_to_description_list = []

for dataset_name in dataset_names:
    for item in data[dataset_name]:
        fdcid = item["fdcId"]
        description = item["description"]
        fdcid_to_description_dict = {}
        fdcid_to_description_dict["fdcid"] = fdcid
        fdcid_to_description_dict["description"] = description
        fdcid_to_description_list.append(fdcid_to_description_dict)
        # fdcid_to_description_list.append((fdcid, description))

        if item["fdcId"] in nutrify_to_fdcid_keys:
            nutrify_food_items.append(item)
            for nutrient in item["foodNutrients"]:
                all_nutrients.append(nutrient["nutrient"]["name"])

# Sort and set the all_nutrients
all_nutrients = sorted(list(set(all_nutrients)))
print(f"Number of Nutrify foods that line up with FDC IDs: {len(nutrify_food_items)}")
print(f"Number of unique nutrients: {len(all_nutrients)}")
# Out:
# [2262074, 2346393, 168175, 1750342, 1750339, 171697, 169205, 168389, 171705, 749420]
# Number of Nutrify foods that line up with FDC IDs: 274
# Number of unique nutrients: 236

# %%
len(fdcid_to_description_list)
# Out:
# 13627

# %%
fdcid_to_description_df = pd.DataFrame(fdcid_to_description_list)

# Drop duplicates based on FDC ID
fdcid_to_description_df = fdcid_to_description_df.drop_duplicates(subset=["fdcid"])

# Drop duplicates based on description
fdcid_to_description_df = fdcid_to_description_df.drop_duplicates(subset=["description"])
len(fdcid_to_description_df)
# Out:
# 13475

# %%
# TODO: sort all nutrients into different categories, e.g. minerals, vitamins, macronutrients, etc.
# See here for a list of essential nutrients: https://www.britannica.com/science/human-nutrition/Essential-nutrients 
all_nutrients
# Out:
# [' Ergosta-5,7-dienol',
#  ' Ergosta-7,22-dienol',
#  '10-Formyl folic acid (10HCOFA)',
#  '25-hydroxycholecalciferol',
#  '5-Formyltetrahydrofolic acid (5-HCOH4',
#  '5-methyl tetrahydrofolate (5-MTHF)',
#  'Alanine',
#  'Alcohol, ethyl',
#  'Arginine',
#  'Ash',
#  'Aspartic acid',
#  'Beta-glucan',
#  'Beta-sitostanol',
#  'Beta-sitosterol',
#  'Betaine',
#  'Biotin',
#  'Boron, B',
#  'Brassicasterol',
#  'Caffeine',
#  'Calcium, Ca',
#  'Campestanol',
#  'Campesterol',
#  'Carbohydrate, by difference',
#  'Carbohydrate, by summation',
#  'Carotene, alpha',
#  'Carotene, beta',
#  'Carotene, gamma',
#  'Cholesterol',
#  'Choline, free',
#  'Choline, from glycerophosphocholine',
#  'Choline, from phosphocholine',
#  'Choline, from phosphotidyl choline',
#  'Choline, from sphingomyelin',
#  'Choline, total',
#  'Citric acid',
#  'Cobalt, Co',
#  'Copper, Cu',
#  'Cryptoxanthin, alpha',
#  'Cryptoxanthin, beta',
#  'Cysteine',
#  'Cystine',
#  'Daidzein',
#  'Daidzin',
#  'Delta-5-avenasterol',
#  'Delta-7-Stigmastenol',
#  'Energy',
#  'Energy (Atwater General Factors)',
#  'Energy (Atwater Specific Factors)',
#  'Ergosta-7-enol',
#  'Ergosterol',
#  'Ergothioneine',
#  'Fatty acids, total monounsaturated',
#  'Fatty acids, total polyunsaturated',
#  'Fatty acids, total saturated',
#  'Fatty acids, total trans',
#  'Fatty acids, total trans-dienoic',
#  'Fatty acids, total trans-monoenoic',
#  'Fatty acids, total trans-polyenoic',
#  'Fiber, insoluble',
#  'Fiber, soluble',
#  'Fiber, total dietary',
#  'Fluoride, F',
#  'Folate, DFE',
#  'Folate, food',
#  'Folate, total',
#  'Folic acid',
#  'Fructose',
#  'Galactose',
#  'Genistein',
#  'Genistin',
#  'Glucose',
#  'Glutamic acid',
#  'Glycine',
#  'Glycitin',
#  'High Molecular Weight Dietary Fiber (HMWDF)',
#  'Histidine',
#  'Hydroxyproline',
#  'Iodine, I',
#  'Iron, Fe',
#  'Isoleucine',
#  'Lactose',
#  'Leucine',
#  'Low Molecular Weight Dietary Fiber (LMWDF)',
#  'Lutein',
#  'Lutein + zeaxanthin',
#  'Lycopene',
#  'Lysine',
#  'MUFA 12:1',
#  'MUFA 14:1',
#  'MUFA 14:1 c',
#  'MUFA 15:1',
#  'MUFA 16:1',
#  'MUFA 16:1 c',
#  'MUFA 17:1',
#  'MUFA 17:1 c',
#  'MUFA 18:1',
#  'MUFA 18:1 c',
#  'MUFA 20:1',
#  'MUFA 20:1 c',
#  'MUFA 22:1',
#  'MUFA 22:1 c',
#  'MUFA 22:1 n-11',
#  'MUFA 22:1 n-9',
#  'MUFA 24:1 c',
#  'Magnesium, Mg',
#  'Malic acid',
#  'Maltose',
#  'Manganese, Mn',
#  'Methionine',
#  'Molybdenum, Mo',
#  'Niacin',
#  'Nickel, Ni',
#  'Nitrogen',
#  'Oxalic acid',
#  'PUFA 18:2',
#  'PUFA 18:2 CLAs',
#  'PUFA 18:2 c',
#  'PUFA 18:2 n-6 c,c',
#  'PUFA 18:3',
#  'PUFA 18:3 c',
#  'PUFA 18:3 n-3 c,c,c (ALA)',
#  'PUFA 18:3 n-6 c,c,c',
#  'PUFA 18:3i',
#  'PUFA 18:4',
#  'PUFA 20:2 c',
#  'PUFA 20:2 n-6 c,c',
#  'PUFA 20:3',
#  'PUFA 20:3 c',
#  'PUFA 20:3 n-3',
#  'PUFA 20:3 n-6',
#  'PUFA 20:3 n-9',
#  'PUFA 20:4',
#  'PUFA 20:4 n-6',
#  'PUFA 20:4c',
#  'PUFA 20:5 n-3 (EPA)',
#  'PUFA 20:5c',
#  'PUFA 22:2',
#  'PUFA 22:3',
#  'PUFA 22:4',
#  'PUFA 22:5 c',
#  'PUFA 22:5 n-3 (DPA)',
#  'PUFA 22:6 c',
#  'PUFA 22:6 n-3 (DHA)',
#  'PUFA 2:5 n-3 (EPA)',
#  'Pantothenic acid',
#  'Phenylalanine',
#  'Phosphorus, P',
#  'Phytoene',
#  'Phytofluene',
#  'Phytosterols',
#  'Phytosterols, other',
#  'Potassium, K',
#  'Proline',
#  'Protein',
#  'Pyruvic acid',
#  'Quinic acid',
#  'Retinol',
#  'Riboflavin',
#  'SFA 10:0',
#  'SFA 11:0',
#  'SFA 12:0',
#  'SFA 13:0',
#  'SFA 14:0',
#  'SFA 15:0',
#  'SFA 16:0',
#  'SFA 17:0',
#  'SFA 18:0',
#  'SFA 20:0',
#  'SFA 21:0',
#  'SFA 22:0',
#  'SFA 23:0',
#  'SFA 24:0',
#  'SFA 4:0',
#  'SFA 5:0',
#  'SFA 6:0',
#  'SFA 7:0',
#  'SFA 8:0',
#  'SFA 9:0',
#  'Selenium, Se',
#  'Serine',
#  'Sodium, Na',
#  'Starch',
#  'Stigmasterol',
#  'Sucrose',
#  'Sugars, Total',
#  'Sugars, total including NLEA',
#  'Sulfur, S',
#  'TFA 14:1 t',
#  'TFA 16:1 t',
#  'TFA 18:1 t',
#  'TFA 18:2 t not further defined',
#  'TFA 18:2 t,t',
#  'TFA 18:3 t',
#  'TFA 20:1 t',
#  'TFA 22:1 t',
#  'Theobromine',
#  'Thiamin',
#  'Threonine',
#  'Tocopherol, beta',
#  'Tocopherol, delta',
#  'Tocopherol, gamma',
#  'Tocotrienol, alpha',
#  'Tocotrienol, beta',
#  'Tocotrienol, delta',
#  'Tocotrienol, gamma',
#  'Total dietary fiber (AOAC 2011.25)',
#  'Total fat (NLEA)',
#  'Total lipid (fat)',
#  'Tryptophan',
#  'Tyrosine',
#  'Valine',
#  'Vitamin A',
#  'Vitamin A, IU',
#  'Vitamin A, RAE',
#  'Vitamin B-12',
#  'Vitamin B-12, added',
#  'Vitamin B-6',
#  'Vitamin C, total ascorbic acid',
#  'Vitamin D (D2 + D3)',
#  'Vitamin D (D2 + D3), International Units',
#  'Vitamin D2 (ergocalciferol)',
#  'Vitamin D3 (cholecalciferol)',
#  'Vitamin D4',
#  'Vitamin E (alpha-tocopherol)',
#  'Vitamin E, added',
#  'Vitamin K (Dihydrophylloquinone)',
#  'Vitamin K (Menaquinone-4)',
#  'Vitamin K (phylloquinone)',
#  'Water',
#  'Zeaxanthin',
#  'Zinc, Zn',
#  'cis-Lutein/Zeaxanthin',
#  'cis-Lycopene',
#  'cis-beta-Carotene',
#  'trans-Lycopene',
#  'trans-beta-Carotene']

# %%
import random
nutrify_food_items[random.randint(0, len(nutrify_food_items))].keys()
# Out:
# dict_keys(['foodClass', 'description', 'foodNutrients', 'scientificName', 'foodAttributes', 'nutrientConversionFactors', 'isHistoricalReference', 'ndbNumber', 'foodCategory', 'fdcId', 'dataType', 'inputFoods', 'publicationDate', 'foodPortions'])

# %%
target_key = "foodNutrients"
target_food = nutrify_food_items[random.randint(0, len(nutrify_food_items))]

print(f"Target key: {target_key}")
print(f"Target food: {target_food['description']}")
print(f"Target food fdc id: {target_food['fdcId']}")
print(f"Target food data type: {target_food['dataType']}")
print(f"Target food with key:\n{target_food[target_key][0].keys()}")
# Out:
# Target key: foodNutrients
# Target food: Apples, red delicious, with skin, raw
# Target food fdc id: 1750339
# Target food data type: Foundation
# Target food with key:
# dict_keys(['type', 'id', 'nutrient', 'dataPoints', 'foodNutrientDerivation', 'max', 'min', 'median', 'amount'])

# %% [markdown]
# Details about the keys:
# - `fdcId`: Unique identifier for a food item
# - `description`: Description of the food item
# - `wweiaFoodCategory`:
# ```
# {'wweiaFoodCategoryCode': 2643393,
#  'wweiaFoodCategoryDescription': 'Poultry mixed dishes'}
# ```
# * `foodPortions`: The amount of a certain food you'd have in a portion, e.g. 1 cup of corn (the default is 100g but some foods also have information per serving)
# * `dataType`: Where the data comes from, e.g. `Foundation` or `SR Legacy` or `Survey (FNDDS)`
# * `foodNutrients`: The nutrients of the food (macronutrients, micronutrients, etc.)
# * `foodClass`: Similar to the `dataType` but shows simpler category e.g. `Survey`

# %%
# Get a list of macronutrients
macronutrients = ["Protein", 
                  "Total lipid (fat)", 
                  "Carbohydrate, by difference",
                  "Alcohol, ethyl"]

macronutrients_to_key = {"Protein": "protein",
                          "Total lipid (fat)": "fat",
                          "Carbohydrate, by difference": "carbohydrate",
                          "Alcohol, ethyl": "alcohol"}

# Create a dictionary mapping macronutrients to their energy density (kcal/g)
energy_dict = {"protein": 4,
               "fat": 9,
               "carbohydrate": 4,
               "alcohol": 7}

## Create a list of micronutrients to get started (see: https://www.hsph.harvard.edu/nutritionsource/vitamins/)
# Create a list of minerals (from FDC)
minerals = [
    "Calcium, Ca",
    "Copper, Cu",
    "Fluoride, F",
    "Iodine, I", 
    "Iron, Fe",
    "Magnesium, Mg",
    "Manganese, Mn",
    "Molybdenum, Mo",
    "Nickel, Ni",
    "Phosphorus, P",
    "Potassium, K",
    "Selenium, Se",
    "Sodium, Na",
    "Zinc, Zn",
]

# Create a list of vitamins (from FDC)
vitamins = [
    "Vitamin A", # IU = international units = 0.3 mcg retinol activity equivalents (RAE)
    "Thiamin", # vitamin B1
    "Riboflavin", # vitamin B2
    "Niacin", # vitamin B3
    "Pantothenic acid", # vitamin B5
    "Vitamin B-6", # (pyridoxal, pyridoxine, pyridoxamine)
    "Biotin", # vitamin B7
    "Folate, total", # vitamin B9, folic acid
    "Vitamin B-12", # cobalamin
    "Vitamin C, total ascorbic acid", # ascorbic acid
    "Choline, total", # choline
    "Vitamin D (D2 + D3)", # calciferol
    "Vitamin E (alpha-tocopherol)", # alpha-tocopherol
    "Vitamin K (phylloquinone)", # phylloquinone
]

# Create a list of other
other_food_nutrients = [
    "Caffeine",
    "Citric acid"
]

# Oils (e.g. olive oil) have a different layout to other kinds of foods, as they are mostly fats rather than 
# carbohydrates and protein.
lipids = {"Fatty acids, total saturated": "SFA",
          "Fatty acids, total monounsaturated": "MUFA",
          "Fatty acids, total polyunsaturated": "PUFA"} 

lipids_to_key = {"Fatty acids, total saturated": "saturated_fat",
                 "Fatty acids, total monounsaturated": "monounsaturated_fat",
                 "Fatty acids, total polyunsaturated": "polyunsaturated_fat"}


# Get oil names from Foundation Foods (can make this more general later, e.g. semantic search across the whole database)
foundation_food_oil_types = ["Oil, canola", "Oil, coconut", "Oil, corn", "Oil, peanut", "Oil, safflower", "Oil, soybean", "Oil, sunflower", "Oil, olive, extra light", "Oil, olive, extra virgin"]
oil_items = [item for item in data["FoundationFoods"] if item["description"] in foundation_food_oil_types]
oil_names = [item["description"] for item in oil_items]
print(oil_names)
# Out:
# ['Oil, coconut', 'Oil, canola', 'Oil, corn', 'Oil, soybean', 'Oil, olive, extra virgin', 'Oil, peanut', 'Oil, sunflower', 'Oil, safflower', 'Oil, olive, extra light']

# %%
len(oil_names)
# Out:
# 9

# %%
import random
target_item = nutrify_food_items[random.randint(0, len(nutrify_food_items))]
print(target_item["fdcId"])
print(target_item["description"])

for item in target_item["foodNutrients"]:
    if item["nutrient"]["name"] in macronutrients:
        print(item["nutrient"]["name"])
    # print(item["nutrient"]["name"])

target_item
# Out:
# 2344649
# Soup, mostly noodles
# Protein
# Total lipid (fat)
# Carbohydrate, by difference
# Alcohol, ethyl
# {'foodClass': 'Survey',
#  'description': 'Soup, mostly noodles',
#  'foodNutrients': [{'type': 'FoodNutrient',
#    'id': 28793309,
#    'nutrient': {'id': 1003,
#     'number': '203',
#     'name': 'Protein',
#     'rank': 600,
#     'unitName': 'g'},
#    'amount': 1.55},
#   {'type': 'FoodNutrient',
#    'id': 28793310,
#    'nutrient': {'id': 1004,
#     'number': '204',
#     'name': 'Total lipid (fat)',
#     'rank': 800,
#     'unitName': 'g'},
#    'amount': 2.68},
#   {'type': 'FoodNutrient',
#    'id': 28793311,
#    'nutrient': {'id': 1005,
#     'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'rank': 1110,
#     'unitName': 'g'},
#    'amount': 9.17},
#   {'type': 'FoodNutrient',
#    'id': 28793312,
#    'nutrient': {'id': 1008,
#     'number': '208',
#     'name': 'Energy',
#     'rank': 300,
#     'unitName': 'kcal'},
#    'amount': 67.0},
#   {'type': 'FoodNutrient',
#    'id': 28793313,
#    'nutrient': {'id': 1018,
#     'number': '221',
#     'name': 'Alcohol, ethyl',
#     'rank': 18200,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793314,
#    'nutrient': {'id': 1051,
#     'number': '255',
#     'name': 'Water',
#     'rank': 100,
#     'unitName': 'g'},
#    'amount': 85.7},
#   {'type': 'FoodNutrient',
#    'id': 28793315,
#    'nutrient': {'id': 1057,
#     'number': '262',
#     'name': 'Caffeine',
#     'rank': 18300,
#     'unitName': 'mg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793316,
#    'nutrient': {'id': 1058,
#     'number': '263',
#     'name': 'Theobromine',
#     'rank': 18400,
#     'unitName': 'mg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793317,
#    'nutrient': {'id': 2000,
#     'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'rank': 1510,
#     'unitName': 'g'},
#    'amount': 0.3},
#   {'type': 'FoodNutrient',
#    'id': 28793318,
#    'nutrient': {'id': 1079,
#     'number': '291',
#     'name': 'Fiber, total dietary',
#     'rank': 1200,
#     'unitName': 'g'},
#    'amount': 0.4},
#   {'type': 'FoodNutrient',
#    'id': 28793319,
#    'nutrient': {'id': 1087,
#     'number': '301',
#     'name': 'Calcium, Ca',
#     'rank': 5300,
#     'unitName': 'mg'},
#    'amount': 6.0},
#   {'type': 'FoodNutrient',
#    'id': 28793320,
#    'nutrient': {'id': 1089,
#     'number': '303',
#     'name': 'Iron, Fe',
#     'rank': 5400,
#     'unitName': 'mg'},
#    'amount': 0.62},
#   {'type': 'FoodNutrient',
#    'id': 28793321,
#    'nutrient': {'id': 1090,
#     'number': '304',
#     'name': 'Magnesium, Mg',
#     'rank': 5500,
#     'unitName': 'mg'},
#    'amount': 5.0},
#   {'type': 'FoodNutrient',
#    'id': 28793322,
#    'nutrient': {'id': 1091,
#     'number': '305',
#     'name': 'Phosphorus, P',
#     'rank': 5600,
#     'unitName': 'mg'},
#    'amount': 17.0},
#   {'type': 'FoodNutrient',
#    'id': 28793323,
#    'nutrient': {'id': 1092,
#     'number': '306',
#     'name': 'Potassium, K',
#     'rank': 5700,
#     'unitName': 'mg'},
#    'amount': 28.0},
#   {'type': 'FoodNutrient',
#    'id': 28793324,
#    'nutrient': {'id': 1093,
#     'number': '307',
#     'name': 'Sodium, Na',
#     'rank': 5800,
#     'unitName': 'mg'},
#    'amount': 286},
#   {'type': 'FoodNutrient',
#    'id': 28793325,
#    'nutrient': {'id': 1095,
#     'number': '309',
#     'name': 'Zinc, Zn',
#     'rank': 5900,
#     'unitName': 'mg'},
#    'amount': 0.1},
#   {'type': 'FoodNutrient',
#    'id': 28793326,
#    'nutrient': {'id': 1098,
#     'number': '312',
#     'name': 'Copper, Cu',
#     'rank': 6000,
#     'unitName': 'mg'},
#    'amount': 0.028},
#   {'type': 'FoodNutrient',
#    'id': 28793327,
#    'nutrient': {'id': 1103,
#     'number': '317',
#     'name': 'Selenium, Se',
#     'rank': 6200,
#     'unitName': 'µg'},
#    'amount': 3.5},
#   {'type': 'FoodNutrient',
#    'id': 28793328,
#    'nutrient': {'id': 1105,
#     'number': '319',
#     'name': 'Retinol',
#     'rank': 7430,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793329,
#    'nutrient': {'id': 1106,
#     'number': '320',
#     'name': 'Vitamin A, RAE',
#     'rank': 7420,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793330,
#    'nutrient': {'id': 1107,
#     'number': '321',
#     'name': 'Carotene, beta',
#     'rank': 7440,
#     'unitName': 'µg'},
#    'amount': 1.0},
#   {'type': 'FoodNutrient',
#    'id': 28793331,
#    'nutrient': {'id': 1108,
#     'number': '322',
#     'name': 'Carotene, alpha',
#     'rank': 7450,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793332,
#    'nutrient': {'id': 1109,
#     'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'rank': 7905,
#     'unitName': 'mg'},
#    'amount': 0.37},
#   {'type': 'FoodNutrient',
#    'id': 28793333,
#    'nutrient': {'id': 1114,
#     'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'rank': 8700,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793334,
#    'nutrient': {'id': 1120,
#     'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'rank': 7460,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793335,
#    'nutrient': {'id': 1122,
#     'number': '337',
#     'name': 'Lycopene',
#     'rank': 7530,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793336,
#    'nutrient': {'id': 1123,
#     'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'rank': 7560,
#     'unitName': 'µg'},
#    'amount': 3.0},
#   {'type': 'FoodNutrient',
#    'id': 28793337,
#    'nutrient': {'id': 1162,
#     'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'rank': 6300,
#     'unitName': 'mg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793338,
#    'nutrient': {'id': 1165,
#     'number': '404',
#     'name': 'Thiamin',
#     'rank': 6400,
#     'unitName': 'mg'},
#    'amount': 0.055},
#   {'type': 'FoodNutrient',
#    'id': 28793339,
#    'nutrient': {'id': 1166,
#     'number': '405',
#     'name': 'Riboflavin',
#     'rank': 6500,
#     'unitName': 'mg'},
#    'amount': 0.035},
#   {'type': 'FoodNutrient',
#    'id': 28793340,
#    'nutrient': {'id': 1167,
#     'number': '406',
#     'name': 'Niacin',
#     'rank': 6600,
#     'unitName': 'mg'},
#    'amount': 0.74},
#   {'type': 'FoodNutrient',
#    'id': 28793341,
#    'nutrient': {'id': 1175,
#     'number': '415',
#     'name': 'Vitamin B-6',
#     'rank': 6800,
#     'unitName': 'mg'},
#    'amount': 0.005},
#   {'type': 'FoodNutrient',
#    'id': 28793342,
#    'nutrient': {'id': 1177,
#     'number': '417',
#     'name': 'Folate, total',
#     'rank': 6900,
#     'unitName': 'µg'},
#    'amount': 12.0},
#   {'type': 'FoodNutrient',
#    'id': 28793343,
#    'nutrient': {'id': 1178,
#     'number': '418',
#     'name': 'Vitamin B-12',
#     'rank': 7300,
#     'unitName': 'µg'},
#    'amount': 0.04},
#   {'type': 'FoodNutrient',
#    'id': 28793344,
#    'nutrient': {'id': 1180,
#     'number': '421',
#     'name': 'Choline, total',
#     'rank': 7220,
#     'unitName': 'mg'},
#    'amount': 0.8},
#   {'type': 'FoodNutrient',
#    'id': 28793345,
#    'nutrient': {'id': 1185,
#     'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'rank': 8800,
#     'unitName': 'µg'},
#    'amount': 1.4},
#   {'type': 'FoodNutrient',
#    'id': 28793346,
#    'nutrient': {'id': 1186,
#     'number': '431',
#     'name': 'Folic acid',
#     'rank': 7000,
#     'unitName': 'µg'},
#    'amount': 7.0},
#   {'type': 'FoodNutrient',
#    'id': 28793347,
#    'nutrient': {'id': 1187,
#     'number': '432',
#     'name': 'Folate, food',
#     'rank': 7100,
#     'unitName': 'µg'},
#    'amount': 5.0},
#   {'type': 'FoodNutrient',
#    'id': 28793348,
#    'nutrient': {'id': 1190,
#     'number': '435',
#     'name': 'Folate, DFE',
#     'rank': 7200,
#     'unitName': 'µg'},
#    'amount': 18.0},
#   {'type': 'FoodNutrient',
#    'id': 28793349,
#    'nutrient': {'id': 1242,
#     'number': '573',
#     'name': 'Vitamin E, added',
#     'rank': 7920,
#     'unitName': 'mg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793350,
#    'nutrient': {'id': 1246,
#     'number': '578',
#     'name': 'Vitamin B-12, added',
#     'rank': 7340,
#     'unitName': 'µg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793351,
#    'nutrient': {'id': 1253,
#     'number': '601',
#     'name': 'Cholesterol',
#     'rank': 15700,
#     'unitName': 'mg'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793352,
#    'nutrient': {'id': 1258,
#     'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'rank': 9700,
#     'unitName': 'g'},
#    'amount': 1.24},
#   {'type': 'FoodNutrient',
#    'id': 28793353,
#    'nutrient': {'id': 1259,
#     'number': '607',
#     'name': 'SFA 4:0',
#     'rank': 9800,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793354,
#    'nutrient': {'id': 1260,
#     'number': '608',
#     'name': 'SFA 6:0',
#     'rank': 9900,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793355,
#    'nutrient': {'id': 1261,
#     'number': '609',
#     'name': 'SFA 8:0',
#     'rank': 10000,
#     'unitName': 'g'},
#    'amount': 0.001},
#   {'type': 'FoodNutrient',
#    'id': 28793356,
#    'nutrient': {'id': 1262,
#     'number': '610',
#     'name': 'SFA 10:0',
#     'rank': 10100,
#     'unitName': 'g'},
#    'amount': 0.002},
#   {'type': 'FoodNutrient',
#    'id': 28793357,
#    'nutrient': {'id': 1263,
#     'number': '611',
#     'name': 'SFA 12:0',
#     'rank': 10300,
#     'unitName': 'g'},
#    'amount': 0.008},
#   {'type': 'FoodNutrient',
#    'id': 28793358,
#    'nutrient': {'id': 1264,
#     'number': '612',
#     'name': 'SFA 14:0',
#     'rank': 10500,
#     'unitName': 'g'},
#    'amount': 0.027},
#   {'type': 'FoodNutrient',
#    'id': 28793359,
#    'nutrient': {'id': 1265,
#     'number': '613',
#     'name': 'SFA 16:0',
#     'rank': 10700,
#     'unitName': 'g'},
#    'amount': 1.07},
#   {'type': 'FoodNutrient',
#    'id': 28793360,
#    'nutrient': {'id': 1266,
#     'number': '614',
#     'name': 'SFA 18:0',
#     'rank': 10900,
#     'unitName': 'g'},
#    'amount': 0.108},
#   {'type': 'FoodNutrient',
#    'id': 28793361,
#    'nutrient': {'id': 1268,
#     'number': '617',
#     'name': 'MUFA 18:1',
#     'rank': 12100,
#     'unitName': 'g'},
#    'amount': 0.927},
#   {'type': 'FoodNutrient',
#    'id': 28793362,
#    'nutrient': {'id': 1269,
#     'number': '618',
#     'name': 'PUFA 18:2',
#     'rank': 13100,
#     'unitName': 'g'},
#    'amount': 0.324},
#   {'type': 'FoodNutrient',
#    'id': 28793363,
#    'nutrient': {'id': 1270,
#     'number': '619',
#     'name': 'PUFA 18:3',
#     'rank': 13900,
#     'unitName': 'g'},
#    'amount': 0.009},
#   {'type': 'FoodNutrient',
#    'id': 28793364,
#    'nutrient': {'id': 1271,
#     'number': '620',
#     'name': 'PUFA 20:4',
#     'rank': 14700,
#     'unitName': 'g'},
#    'amount': 0.001},
#   {'type': 'FoodNutrient',
#    'id': 28793365,
#    'nutrient': {'id': 1272,
#     'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'rank': 15300,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793366,
#    'nutrient': {'id': 1275,
#     'number': '626',
#     'name': 'MUFA 16:1',
#     'rank': 11700,
#     'unitName': 'g'},
#    'amount': 0.004},
#   {'type': 'FoodNutrient',
#    'id': 28793367,
#    'nutrient': {'id': 1276,
#     'number': '627',
#     'name': 'PUFA 18:4',
#     'rank': 14250,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793368,
#    'nutrient': {'id': 1277,
#     'number': '628',
#     'name': 'MUFA 20:1',
#     'rank': 12400,
#     'unitName': 'g'},
#    'amount': 0.005},
#   {'type': 'FoodNutrient',
#    'id': 28793369,
#    'nutrient': {'id': 1278,
#     'number': '629',
#     'name': 'PUFA 20:5 n-3 (EPA)',
#     'rank': 15000,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793370,
#    'nutrient': {'id': 1279,
#     'number': '630',
#     'name': 'MUFA 22:1',
#     'rank': 12500,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793371,
#    'nutrient': {'id': 1280,
#     'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'rank': 15200,
#     'unitName': 'g'},
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'id': 28793372,
#    'nutrient': {'id': 1292,
#     'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'rank': 11400,
#     'unitName': 'g'},
#    'amount': 0.937},
#   {'type': 'FoodNutrient',
#    'id': 28793373,
#    'nutrient': {'id': 1293,
#     'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'rank': 12900,
#     'unitName': 'g'},
#    'amount': 0.334}],
#  'foodAttributes': [{'id': 2648969,
#    'name': 'WWEIA Category description',
#    'value': 'Soups',
#    'foodAttributeType': {'id': 999,
#     'name': 'Attribute',
#     'description': 'Generic attributes'}},
#   {'id': 2648968,
#    'name': 'WWEIA Category number',
#    'value': '3802',
#    'foodAttributeType': {'id': 999,
#     'name': 'Attribute',
#     'description': 'Generic attributes'}},
#   {'id': 2659417,
#    'value': 'Maruchan Instant Lunch',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 8},
#   {'id': 2659410,
#    'value': 'spaghetti or noodle soup',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 1},
#   {'id': 2659416,
#    'value': 'Cup Noodles',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 7},
#   {'id': 2659412,
#    'value': 'Asian Noodle Soup',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 3},
#   {'id': 2659415,
#    'value': 'Oodles of Noodles',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 6},
#   {'id': 2659419,
#    'value': 'Souper Meal',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 11},
#   {'id': 2659414,
#    'value': 'saimin soup',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 5},
#   {'id': 2659411,
#    'value': 'Top Ramen',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 2},
#   {'id': 2659418,
#    'value': 'Nissin noodle soups',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 9},
#   {'id': 2659413,
#    'value': 'meat flavors',
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'},
#    'rank': 4},
#   {'id': 2666374,
#    'value': 'Moisture change: 0%',
#    'foodAttributeType': {'id': 1002,
#     'name': 'Adjustments',
#     'description': 'Adjustments made to foods, including moisture changes'}}],
#  'foodCode': '58407030',
#  'startDate': '1/1/2019',
#  'endDate': '12/31/2020',
#  'wweiaFoodCategory': {'wweiaFoodCategoryCode': 2648969,
#   'wweiaFoodCategoryDescription': 'Soups'},
#  'foodPortions': [{'id': 283493,
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'},
#    'modifier': '61555',
#    'gramWeight': 494,
#    'sequenceNumber': 2,
#    'portionDescription': '1 package (3 oz), prepared'},
#   {'id': 283492,
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'},
#    'modifier': '10205',
#    'gramWeight': 233,
#    'sequenceNumber': 1,
#    'portionDescription': '1 cup'},
#   {'id': 283495,
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'},
#    'modifier': '40049',
#    'gramWeight': 164,
#    'sequenceNumber': 4,
#    'portionDescription': '1 oz, dry, yields'},
#   {'id': 283498,
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'},
#    'modifier': '64502',
#    'gramWeight': 656,
#    'sequenceNumber': 7,
#    'portionDescription': '1 microwavable package, prepared'},
#   {'id': 283494,
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'},
#    'modifier': '90000',
#    'gramWeight': 388,
#    'sequenceNumber': 3,
#    'portionDescription': 'Quantity not specified'},
#   {'id': 283497,
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'},
#    'modifier': '64347',
#    'gramWeight': 705,
#    'sequenceNumber': 6,
#    'portionDescription': '1 Souper Meal'},
#   {'id': 283496,
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'},
#    'modifier': '63829',
#    'gramWeight': 370,
#    'sequenceNumber': 5,
#    'portionDescription': '1 cup package (2.25 oz), prepared'}],
#  'publicationDate': '10/28/2022',
#  'inputFoods': [{'id': 118920,
#    'unit': 'C',
#    'portionDescription': '1 cup',
#    'portionCode': '10205',
#    'foodDescription': 'Beverages, water, tap, drinking',
#    'sequenceNumber': 1,
#    'ingredientDescription': 'Beverages, water, tap, drinking',
#    'ingredientWeight': 474,
#    'amount': 2,
#    'ingredientCode': 14411},
#   {'id': 118921,
#    'unit': 'WO',
#    'portionDescription': 'NONE',
#    'portionCode': '0',
#    'foodDescription': 'Soup, ramen noodle, any flavor, dry',
#    'sequenceNumber': 2,
#    'ingredientDescription': 'Soup, ramen noodle, any flavor, dry',
#    'ingredientWeight': 85.05,
#    'amount': 3,
#    'ingredientCode': 6583}],
#  'fdcId': 2344649,
#  'dataType': 'Survey (FNDDS)'}

# %%
import json

json.dump(target_item, open("target_item.json", "w"), indent=4)

# %%
for i, item in enumerate(nutrify_food_items):
    if item["fdcId"] == 748608: # Olive oil, see: https://fdc.nal.usda.gov/fdc-app.html#/food-details/748608/nutrients
        print(i)
        print(item)
# Out:
# 25
# {'foodClass': 'FinalFood', 'description': 'Oil, olive, extra virgin', 'foodNutrients': [{'type': 'FoodNutrient', 'id': 8529145, 'nutrient': {'id': 1264, 'number': '612', 'name': 'SFA 14:0', 'rank': 10500, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.021, 'min': 0.009, 'median': 0.012, 'amount': 0.013}, {'type': 'FoodNutrient', 'id': 8529146, 'nutrient': {'id': 1265, 'number': '613', 'name': 'SFA 16:0', 'rank': 10700, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 15.8, 'min': 9.48, 'median': 12, 'amount': 12.1}, {'type': 'FoodNutrient', 'id': 8529147, 'nutrient': {'id': 1266, 'number': '614', 'name': 'SFA 18:0', 'rank': 10900, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 3.16, 'min': 1.87, 'median': 2.62, 'amount': 2.59}, {'type': 'FoodNutrient', 'id': 8529148, 'nutrient': {'id': 1267, 'number': '615', 'name': 'SFA 20:0', 'rank': 11100, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.472, 'min': 0.379, 'median': 0.406, 'amount': 0.411}, {'type': 'FoodNutrient', 'id': 8529149, 'nutrient': {'id': 1273, 'number': '624', 'name': 'SFA 22:0', 'rank': 11200, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.147, 'min': 0.102, 'median': 0.116, 'amount': 0.118}, {'type': 'FoodNutrient', 'id': 8529150, 'nutrient': {'id': 1299, 'number': '652', 'name': 'SFA 15:0', 'rank': 10600, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.012, 'min': 0.004, 'median': 0.006, 'amount': 0.006}, {'type': 'FoodNutrient', 'id': 8529151, 'nutrient': {'id': 1300, 'number': '653', 'name': 'SFA 17:0', 'rank': 10800, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.148, 'min': 0.038, 'median': 0.078, 'amount': 0.081}, {'type': 'FoodNutrient', 'id': 8529152, 'nutrient': {'id': 1301, 'number': '654', 'name': 'SFA 24:0', 'rank': 11300, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 0.075, 'min': 0.049, 'median': 0.062, 'amount': 0.062}, {'type': 'FoodNutrient', 'id': 8529153, 'nutrient': {'id': 1314, 'number': '673', 'name': 'MUFA 16:1 c', 'rank': 11800, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 1.96, 'min': 0.593, 'median': 0.96, 'amount': 1.03}, {'type': 'FoodNutrient', 'id': 8529154, 'nutrient': {'id': 1315, 'number': '674', 'name': 'MUFA 18:1 c', 'rank': 12200, 'unitName': 'g'}, 'dataPoints': 36, 'foodNutrientDerivation': {'code': 'A', 'description': 'Analytical', 'foodNutrientSource': {'id': 1, 'code': '1', 'description': 'Analytical or derived from analytical'}}, 'max': 73.2, 'min': 56.9, 'median': 68.6, 'amount': 67.8}, {'type': 'FoodNutrient', 'id': 8529155, 'nu ...

# %%
# Get info for Olive oil
nutrify_food_items[25]

# Get info for Yoghurt
# nutrify_food_items[47]
# Out:
# {'foodClass': 'FinalFood',
#  'description': 'Oil, olive, extra virgin',
#  'foodNutrients': [{'type': 'FoodNutrient',
#    'id': 8529145,
#    'nutrient': {'id': 1264,
#     'number': '612',
#     'name': 'SFA 14:0',
#     'rank': 10500,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.021,
#    'min': 0.009,
#    'median': 0.012,
#    'amount': 0.013},
#   {'type': 'FoodNutrient',
#    'id': 8529146,
#    'nutrient': {'id': 1265,
#     'number': '613',
#     'name': 'SFA 16:0',
#     'rank': 10700,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 15.8,
#    'min': 9.48,
#    'median': 12,
#    'amount': 12.1},
#   {'type': 'FoodNutrient',
#    'id': 8529147,
#    'nutrient': {'id': 1266,
#     'number': '614',
#     'name': 'SFA 18:0',
#     'rank': 10900,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 3.16,
#    'min': 1.87,
#    'median': 2.62,
#    'amount': 2.59},
#   {'type': 'FoodNutrient',
#    'id': 8529148,
#    'nutrient': {'id': 1267,
#     'number': '615',
#     'name': 'SFA 20:0',
#     'rank': 11100,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.472,
#    'min': 0.379,
#    'median': 0.406,
#    'amount': 0.411},
#   {'type': 'FoodNutrient',
#    'id': 8529149,
#    'nutrient': {'id': 1273,
#     'number': '624',
#     'name': 'SFA 22:0',
#     'rank': 11200,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.147,
#    'min': 0.102,
#    'median': 0.116,
#    'amount': 0.118},
#   {'type': 'FoodNutrient',
#    'id': 8529150,
#    'nutrient': {'id': 1299,
#     'number': '652',
#     'name': 'SFA 15:0',
#     'rank': 10600,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.012,
#    'min': 0.004,
#    'median': 0.006,
#    'amount': 0.006},
#   {'type': 'FoodNutrient',
#    'id': 8529151,
#    'nutrient': {'id': 1300,
#     'number': '653',
#     'name': 'SFA 17:0',
#     'rank': 10800,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.148,
#    'min': 0.038,
#    'median': 0.078,
#    'amount': 0.081},
#   {'type': 'FoodNutrient',
#    'id': 8529152,
#    'nutrient': {'id': 1301,
#     'number': '654',
#     'name': 'SFA 24:0',
#     'rank': 11300,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.075,
#    'min': 0.049,
#    'median': 0.062,
#    'amount': 0.062},
#   {'type': 'FoodNutrient',
#    'id': 8529153,
#    'nutrient': {'id': 1314,
#     'number': '673',
#     'name': 'MUFA 16:1 c',
#     'rank': 11800,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 1.96,
#    'min': 0.593,
#    'median': 0.96,
#    'amount': 1.03},
#   {'type': 'FoodNutrient',
#    'id': 8529154,
#    'nutrient': {'id': 1315,
#     'number': '674',
#     'name': 'MUFA 18:1 c',
#     'rank': 12200,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 73.2,
#    'min': 56.9,
#    'median': 68.6,
#    'amount': 67.8},
#   {'type': 'FoodNutrient',
#    'id': 8529155,
#    'nutrient': {'id': 1316,
#     'number': '675',
#     'name': 'PUFA 18:2 n-6 c,c',
#     'rank': 13200,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 14.8,
#    'min': 5.14,
#    'median': 7.68,
#    'amount': 8.4},
#   {'type': 'FoodNutrient',
#    'id': 8529156,
#    'nutrient': {'id': 2006,
#     'number': '681',
#     'name': 'SFA 21:0',
#     'rank': 11150,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.02,
#    'min': 0.008,
#    'median': 0.014,
#    'amount': 0.014},
#   {'type': 'FoodNutrient',
#    'id': 8529157,
#    'nutrient': {'id': 1406,
#     'number': '853',
#     'name': 'PUFA 20:4 n-6',
#     'rank': 14600,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0,
#    'min': 0,
#    'median': 0,
#    'amount': 0},
#   {'type': 'FoodNutrient',
#    'id': 8529158,
#    'nutrient': {'id': 1258,
#     'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'rank': 9700,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 18.8,
#    'min': 13.1,
#    'median': 15.3,
#    'amount': 15.4},
#   {'type': 'FoodNutrient',
#    'id': 8529159,
#    'nutrient': {'id': 1292,
#     'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'rank': 11400,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 74.2,
#    'min': 59.2,
#    'median': 70,
#    'amount': 69.2},
#   {'type': 'FoodNutrient',
#    'id': 8529160,
#    'nutrient': {'id': 2016,
#     'number': '831',
#     'name': 'PUFA 18:2 c',
#     'rank': 13150,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'code': 'AS',
#     'description': 'Summed',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'amount': 8.4},
#   {'type': 'FoodNutrient',
#    'id': 8529161,
#    'nutrient': {'id': 2020,
#     'number': '835',
#     'name': 'PUFA 20:3 c',
#     'rank': 14450,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'code': 'AS',
#     'description': 'Summed',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'amount': 0},
#   {'type': 'FoodNutrient',
#    'id': 8529162,
#    'nutrient': {'id': 1293,
#     'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'rank': 12900,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 15.5,
#    'min': 5.81,
#    'median': 8.35,
#    'amount': 9.07},
#   {'type': 'FoodNutrient',
#    'id': 8529163,
#    'nutrient': {'id': 1085,
#     'number': '298',
#     'name': 'Total fat (NLEA)',
#     'rank': 900,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'code': 'AS',
#     'description': 'Summed',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'amount': 93.7},
#   {'type': 'FoodNutrient',
#    'id': 8529164,
#    'nutrient': {'id': 1288,
#     'number': '641',
#     'name': 'Beta-sitosterol',
#     'rank': 16200,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 167,
#    'min': 90.1,
#    'median': 126,
#    'amount': 126},
#   {'type': 'FoodNutrient',
#    'id': 8529165,
#    'nutrient': {'id': 1287,
#     'number': '640',
#     'name': 'Brassicasterol',
#     'rank': 16100,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0,
#    'min': 0,
#    'median': 0,
#    'amount': 0},
#   {'type': 'FoodNutrient',
#    'id': 8529166,
#    'nutrient': {'id': 1289,
#     'number': '642',
#     'name': 'Campestanol',
#     'rank': 16221,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0,
#    'min': 0,
#    'median': 0,
#    'amount': 0},
#   {'type': 'FoodNutrient',
#    'id': 8529167,
#    'nutrient': {'id': 1286,
#     'number': '639',
#     'name': 'Campesterol',
#     'rank': 16000,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 8.09,
#    'min': 3.69,
#    'median': 5.64,
#    'amount': 5.68},
#   {'type': 'FoodNutrient',
#    'id': 8529168,
#    'nutrient': {'id': 1296,
#     'number': '649',
#     'name': 'Delta-5-avenasterol',
#     'rank': 16224,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 36.2,
#    'min': 16.7,
#    'median': 22.6,
#    'amount': 23.1},
#   {'type': 'FoodNutrient',
#    'id': 8529169,
#    'nutrient': {'id': 1298,
#     'number': '651',
#     'name': 'Phytosterols, other',
#     'rank': 16227,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 51.3,
#    'min': 16.9,
#    'median': 25,
#    'amount': 26.9},
#   {'type': 'FoodNutrient',
#    'id': 8529170,
#    'nutrient': {'id': 1294,
#     'number': '647',
#     'name': 'Beta-sitostanol',
#     'rank': 16222,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 4.14,
#    'min': 1.73,
#    'median': 2.52,
#    'amount': 2.55},
#   {'type': 'FoodNutrient',
#    'id': 8529171,
#    'nutrient': {'id': 1285,
#     'number': '638',
#     'name': 'Stigmasterol',
#     'rank': 15900,
#     'unitName': 'mg'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 1.88,
#    'min': 0.636,
#    'median': 1,
#    'amount': 1.02},
#   {'type': 'FoodNutrient',
#    'id': 8529172,
#    'nutrient': {'id': 2012,
#     'number': '829',
#     'name': 'MUFA 20:1 c',
#     'rank': 12401,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.333,
#    'min': 0.208,
#    'median': 0.278,
#    'amount': 0.276},
#   {'type': 'FoodNutrient',
#    'id': 8529173,
#    'nutrient': {'id': 1404,
#     'number': '851',
#     'name': 'PUFA 18:3 n-3 c,c,c (ALA)',
#     'rank': 14000,
#     'unitName': 'g'},
#    'dataPoints': 36,
#    'foodNutrientDerivation': {'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'max': 0.72,
#    'min': 0.506,
#    'median': 0.661,
#    'amount': 0.651},
#   {'type': 'FoodNutrient',
#    'id': 8529174,
#    'nutrient': {'id': 2018,
#     'number': '833',
#     'name': 'PUFA 18:3 c',
#     'rank': 13910,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'code': 'AS',
#     'description': 'Summed',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'amount': 0.651}],
#  'foodAttributes': [],
#  'nutrientConversionFactors': [],
#  'isHistoricalReference': False,
#  'ndbNumber': 4063,
#  'fdcId': 748608,
#  'dataType': 'Foundation',
#  'foodCategory': {'description': 'Fats and Oils'},
#  'inputFoods': [{'id': 46664,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748474,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46650,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748379,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46676,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748552,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46673,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748532,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46683,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748602,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46680,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748581,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46656,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748417,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46679,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748575,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46674,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748538,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46649,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748373,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46666,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748487,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46658,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748431,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46671,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748518,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46653,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748398,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46659,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748438,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46677,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748559,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46678,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748565,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46672,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748525,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46652,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748391,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46662,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748460,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46651,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748385,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46670,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748511,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46675,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748545,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46660,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748445,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46682,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748596,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46648,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748367,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46655,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748411,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46663,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748467,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46668,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748499,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46657,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748424,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46654,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748405,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46669,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748505,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46667,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748493,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46661,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748453,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46681,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748589,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}},
#   {'id': 46665,
#    'foodDescription': 'OLIVE OIL, EXTRA VIRGIN',
#    'inputFood': {'foodClass': 'Composite',
#     'description': 'OLIVE OIL, EXTRA VIRGIN',
#     'fdcId': 748481,
#     'dataType': 'Sample',
#     'foodCategory': {'id': 4, 'code': '0400', 'description': 'Fats and Oils'},
#     'publicationDate': '12/16/2019'}}],
#  'foodPortions': [{'id': 192355,
#    'value': 100,
#    'measureUnit': {'id': 1004, 'name': 'milliliter', 'abbreviation': 'ml'},
#    'modifier': '',
#    'gramWeight': 90.7,
#    'sequenceNumber': 1,
#    'minYearAcquired': 2019,
#    'amount': 100}],
#  'publicationDate': '12/16/2019'}

# %%
source_url_base = "https://fdc.nal.usda.gov/fdc-app.html#/food-details/{}/nutrients"

nutrify_food_items_nutrients = []
for item in tqdm(nutrify_food_items):
    calories_string = "total_energy_calories"

    item_dict = {}
    item_dict["fdcId"] = item["fdcId"]
    print(f"On item: {item['fdcId']}")
    item_dict["description"] = item["description"]
    item_dict["default_size"] = 100
    item_dict["unit"] = "g"
    item_dict[calories_string] = 0

    # Get the macronutrients + water + micronutrients
    item_macronutrients = {}

    # Create empty lists for various minerals and vitamins
    mineral_list = []
    vitamin_list = []
    other_nutrient_list = []

    # Setup micronutrients dictionary
    item_dict["micronutrients"] = {"vitamins": "",
                                   "minerals": ""}

    # Setup other nutrients dictionary
    item_other_nutrients = {} 
    
    for nutrient in item["foodNutrients"]:

        nutrient_name = nutrient["nutrient"]["name"]

        # Get the macronutrients
        if nutrient_name in macronutrients:
            macronutrient_name = macronutrients_to_key[nutrient_name]
            item_macronutrients[macronutrient_name] = nutrient["amount"]
            item_dict["macronutrients"] = item_macronutrients
        
        # Get the water
        if nutrient_name == "Water":
            item_dict["Water"] = nutrient["amount"]

        # Get the vitamin micronutrients
        if nutrient_name in vitamins:
            item_vitamin_micronutrients = {}
            vitamin_name = nutrient["nutrient"]["name"]
            # print(f"On vitamin name: {vitamin_name}")
            try:
                vitamin_amount = nutrient["amount"]
                vitamin_unit = nutrient["nutrient"]["unitName"]
            except:
                print(f"Could not get amount for vitamin: {vitamin_name}")
                if nutrient_name == "Vitamin A": # replace for Retinol
                    vitamin_amount = [nutrient["amount"] for nutrient in item["foodNutrients"] if nutrient["nutrient"]["name"] == "Retinol"][0]
                    vitamin_unit = [nutrient["nutrient"]["unitName"] for nutrient in item["foodNutrients"] if nutrient["nutrient"]["name"] == "Retinol"][0]
                    
            item_vitamin_micronutrients["name"] = vitamin_name
            item_vitamin_micronutrients["amount"] = vitamin_amount
            item_vitamin_micronutrients["unit"] = vitamin_unit

            vitamin_list.append(item_vitamin_micronutrients)
            # print(len(vitamin_list))
        
        # Get the mineral micronutrients
        if nutrient_name in minerals:
            item_mineral_micronutrients = {}
            mineral_name = nutrient["nutrient"]["name"]
            # print(f"On mineral name: {mineral_name}")
            try:
                mineral_amount = nutrient["amount"]
                mineral_unit = nutrient["nutrient"]["unitName"]
            except:
                print(f"Could not get amount for mineral: {mineral_name}")
            
            item_mineral_micronutrients["name"] = mineral_name
            item_mineral_micronutrients["amount"] = mineral_amount
            item_mineral_micronutrients["unit"] = mineral_unit

            mineral_list.append(item_mineral_micronutrients)
            # print(len(mineral_list))
        
        # Get the other nutrients
        if nutrient_name in other_food_nutrients:
            item_other_nutrients = {}
            other_nutrient_name = nutrient["nutrient"]["name"]
            # print(f"On other nutrient name: {other_nutrient_name}")
            try:
                other_nutrient_amount = nutrient["amount"]
                other_nutrient_unit = nutrient["nutrient"]["unitName"]
            except:
                print(f"Could not get amount for other nutrient: {other_nutrient_name}")

            item_other_nutrients["name"] = other_nutrient_name
            item_other_nutrients["amount"] = other_nutrient_amount
            item_other_nutrients["unit"] = other_nutrient_unit

            other_nutrient_list.append(item_other_nutrients)
            # print(len(other_nutrient_list))
            

    item_dict["micronutrients"]["vitamins"] = vitamin_list
    item_dict["micronutrients"]["minerals"] = mineral_list
    item_dict["other_nutrients"] = other_nutrient_list
    
    # Handle oils
    if item["description"] in oil_names:
        for nutrient in item["foodNutrients"]:
            if nutrient["nutrient"]["name"] in lipids:
                target_lipid_name = lipids_to_key[nutrient["nutrient"]["name"]]
                item_macronutrients[target_lipid_name] = nutrient["amount"]
                item_dict["lipids"] = item_macronutrients
        lipid_items = item_dict["lipids"].keys()
        for lipid in lipid_items:
            item_dict[calories_string] += round(item_dict["lipids"][lipid] * energy_dict["fat"]) # all lipids are fat

    # Calculate the total energy (this will fail on items like Table Salt + Olive Oil, their values in the FDC are different to others, see: 746775 and https://fdc.nal.usda.gov/fdc-app.html#/food-details/748608/nutrients)
    for nutrient in macronutrients:
        try:
            target_macronutrient = macronutrients_to_key[nutrient]
            if target_macronutrient in item_dict["macronutrients"]:
                item_dict[calories_string] += round(item_dict["macronutrients"][target_macronutrient] * energy_dict[target_macronutrient])
        except Exception as e:
            print(e)
            print(item_dict)
    
    # Add the source url
    item_dict["fdc_source_url"] = source_url_base.format(item["fdcId"])
    
    nutrify_food_items_nutrients.append(item_dict)
# Out:
#   0%|          | 0/274 [00:00<?, ?it/s]
# On item: 321360
# On item: 323121
# On item: 323505
# On item: 324653
# On item: 325430
# On item: 327046
# On item: 327357
# On item: 328637
# On item: 331897
# On item: 331960
# On item: 332397
# On item: 334194
# On item: 334536
# On item: 335240
# On item: 746762
# On item: 746768
# On item: 746769
# On item: 746771
# On item: 746773
# On item: 746775
# 'macronutrients'
# {'fdcId': 746775, 'description': 'Salt, table, iodized', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 0, 'micronutrients': {'vitamins': [], 'minerals': [{'name': 'Iron, Fe', 'amount': 0, 'unit': 'mg'}, {'name': 'Magnesium, Mg', 'amount': 0, 'unit': 'mg'}, {'name': 'Phosphorus, P', 'amount': 0, 'unit': 'mg'}, {'name': 'Sodium, Na', 'amount': 38700, 'unit': 'mg'}, {'name': 'Copper, Cu', 'amount': 0, 'unit': 'mg'}, {'name': 'Manganese, Mn', 'amount': 0.032, 'unit': 'mg'}, {'name': 'Calcium, Ca', 'amount': 50, 'unit': 'mg'}, {'name': 'Potassium, K', 'amount': 2, 'unit': 'mg'}, {'name': 'Zinc, Zn', 'amount': 0, 'unit': 'mg'}, {'name': 'Iodine, I', 'amount': 5080, 'unit': 'µg'}]}, 'Water': 0.42, 'other_nutrients': []}
# 'macronutrients'
# {'fdcId': 746775, 'description': 'Salt, table, iodized', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 0, 'micronutrients': {'vitamins': [], 'minerals': [{'name': 'Iron, Fe', 'amount': 0, 'unit': 'mg'}, {'name': 'Magnesium, Mg', 'amount': 0, 'unit': 'mg'}, {'name': 'Phosphorus, P', 'amount': 0, 'unit': 'mg'}, {'name': 'Sodium, Na', 'amount': 38700, 'unit': 'mg'}, {'name': 'Copper, Cu', 'amount': 0, 'unit': 'mg'}, {'name': 'Manganese, Mn', 'amount': 0.032, 'unit': 'mg'}, {'name': 'Calcium, Ca', 'amount': 50, 'unit': 'mg'}, {'name': 'Potassium, K', 'amount': 2, 'unit': 'mg'}, {'name': 'Zinc, Zn', 'amount': 0, 'unit': 'mg'}, {'name': 'Iodine, I', 'amount': 5080, 'unit': 'µg'}]}, 'Water': 0.42, 'other_nutrients': []}
# 'macronutrients'
# {'fdcId': 746775, 'description': 'Salt, table, iodized', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 0, 'micronutrients': {'vitamins': [], 'minerals': [{'name': 'Iron, Fe', 'amount': 0, 'unit': 'mg'}, {'name': 'Magnesium, Mg', 'amount': 0, 'unit': 'mg'}, {'name': 'Phosphorus, P', 'amount': 0, 'unit': 'mg'}, {'name': 'Sodium, Na', 'amount': 38700, 'unit': 'mg'}, {'name': 'Copper, Cu', 'amount': 0, 'unit': 'mg'}, {'name': 'Manganese, Mn', 'amount': 0.032, 'unit': 'mg'}, {'name': 'Calcium, Ca', 'amount': 50, 'unit': 'mg'}, {'name': 'Potassium, K', 'amount': 2, 'unit': 'mg'}, {'name': 'Zinc, Zn', 'amount': 0, 'unit': 'mg'}, {'name': 'Iodine, I', 'amount': 5080, 'unit': 'µg'}]}, 'Water': 0.42, 'other_nutrients': []}
# 'macronutrients'
# {'fdcId': 746775, 'description': 'Salt, table, iodized', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 0, 'micronutrients': {'vitamins': [], 'minerals': [{'name': 'Iron, Fe', 'amount': 0, 'unit': 'mg'}, {'name': 'Magnesium, Mg', 'amount': 0, 'unit': 'mg'}, {'name': 'Phosphorus, P', 'amount': 0, 'unit': 'mg'}, {'name': 'Sodium, Na', 'amount': 38700, 'unit': 'mg'}, {'name': 'Copper, Cu', 'amount': 0, 'unit': 'mg'}, {'name': 'Manganese, Mn', 'amount': 0.032, 'unit': 'mg'}, {'name': 'Calcium, Ca', 'amount': 50, 'unit': 'mg'}, {'name': 'Potassium, K', 'amount': 2, 'unit': 'mg'}, {'name': 'Zinc, Zn', 'amount': 0, 'unit': 'mg'}, {'name': 'Iodine, I', 'amount': 5080, 'unit': 'µg'}]}, 'Water': 0.42, 'other_nutrients': []}
# On item: 746777
# On item: 746780
# On item: 746782
# On item: 747444
# On item: 747447
# On item: 748608
# 'macronutrients'
# {'fdcId': 748608, 'description': 'Oil, olive, extra virgin', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 844, 'micronutrients': {'vitamins': [], 'minerals': []}, 'other_nutrients': [], 'lipids': {'saturated_fat': 15.4, 'monounsaturated_fat': 69.2, 'polyunsaturated_fat': 9.07}}
# 'macronutrients'
# {'fdcId': 748608, 'description': 'Oil, olive, extra virgin', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 844, 'micronutrients': {'vitamins': [], 'minerals': []}, 'other_nutrients': [], 'lipids': {'saturated_fat': 15.4, 'monounsaturated_fat': 69.2, 'polyunsaturated_fat': 9.07}}
# 'macronutrients'
# {'fdcId': 748608, 'description': 'Oil, olive, extra virgin', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 844, 'micronutrients': {'vitamins': [], 'minerals': []}, 'other_nutrients': [], 'lipids': {'saturated_fat': 15.4, 'monounsaturated_fat': 69.2, 'polyunsaturated_fat': 9.07}}
# 'macronutrients'
# {'fdcId': 748608, 'description': 'Oil, olive, extra virgin', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 844, 'micronutrients': {'vitamins': [], 'minerals': []}, 'other_nutrients': [], 'lipids': {'saturated_fat': 15.4, 'monounsaturated_fat': 69.2, 'polyunsaturated_fat': 9.07}}
# On item: 748967
# On item: 749420
# On item: 790508
# On item: 790577
# On item: 790646
# On item: 1104647
# On item: 1104962
# On item: 1105314
# On item: 1750339
# On item: 1750342
# On item: 1999627
# On item: 1999628
# On item: 1999629
# On item: 1999633
# On item: 1999634
# On item: 2003597
# On item: 2003598
# On item: 2003599
# On item: 2003600
# On item: 2003601
# On item: 2003603
# On item: 2258586
# On item: 2258588
# On item: 2258589
# On item: 2258590
# On item: 2258591
# On item: 2259793
# Could not get amount for vitamin: Vitamin A
# On item: 2262072
# On item: 2262074
# On item: 2346386
# Could not get amount for vitamin: Vitamin A
# On item: 2346388
# On item: 2346390
# On item: 2346391
# On item: 2346393
# On item: 2346394
# On item: 2346395
# On item: 2346398
# On item: 2346399
# On item: 2346400
# On item: 2346401
# On item: 2346402
# On item: 2346404
# On item: 2346405
# On item: 2346406
# On item: 2346407
# On item: 2346408
# On item: 2346409
# On item: 2346410
# On item: 2346411
# On item: 2346412
# On item: 2346413
# On item: 167754
# On item: 168163
# On item: 168175
# On item: 168176
# On item: 168238
# On item: 168314
# On item: 168389
# On item: 168412
# On item: 168415
# On item: 168448
# On item: 168572
# On item: 169074
# On item: 169089
# On item: 169092
# On item: 169105
# On item: 169205
# On item: 169231
# On item: 169236
# On item: 169291
# On item: 169296
# On item: 169704
# On item: 169711
# On item: 169992
# On item: 170028
# On item: 170276
# On item: 170400
# On item: 170499
# On item: 170917
# On item: 170935
# On item: 170937
# On item: 171318
# On item: 171328
# On item: 171697
# On item: 171705
# On item: 171714
# On item: 172231
# On item: 172232
# On item: 172233
# On item: 172421
# On item: 172476
# On item: 172687
# On item: 173032
# On item: 173470
# On item: 173473
# On item: 173474
# On item: 174523
# On item: 175180
# On item: 2340854
# On item: 2340906
# On item: 2340989
# On item: 2341033
# On item: 2341252
# On item: 2341259
# On item: 2341260
# On item: 2341284
# On item: 2341287
# On item: 2341300
# On item: 2341307
# On item: 2341312
# On item: 2341343
# On item: 2341441
# On item: 2341474
# On item: 2341608
# On item: 2341699
# On item: 2341708
# On item: 2341749
# On item: 2341766
# On item: 2341807
# On item: 2341861
# On item: 2341891
# On item: 2341894
# On item: 2342187
# On item: 2342325
# On item: 2342337
# On item: 2342418
# On item: 2342464
# On item: 2342673
# On item: 2342676
# On item: 2342911
# On item: 2342917
# On item: 2342931
# On item: 2342974
# On item: 2342976
# On item: 2342977
# On item: 2342979
# On item: 2342980
# On item: 2342981
# On item: 2342991
# On item: 2343006
# On item: 2343090
# On item: 2343096
# On item: 2343103
# On item: 2343158
# On item: 2343160
# On item: 2343212
# On item: 2343347
# On item: 2343371
# On item: 2343384
# On item: 2343389
# On item: 2343477
# On item: 2343527
# On item: 2343546
# On item: 2343645
# On item: 2343679
# On item: 2343699
# On item: 2343787
# On item: 2343808
# On item: 2343818
# On item: 2343835
# On item: 2343841
# On item: 2343945
# On item: 2343973
# On item: 2343992
# On item: 2344031
# On item: 2344106
# On item: 2344450
# On item: 2344649
# On item: 2344659
# On item: 2344662
# On item: 2344664
# On item: 2344698
# On item: 2344723
# On item: 2344729
# On item: 2344733
# On item: 2344735
# On item: 2344736
# On item: 2344737
# On item: 2344741
# On item: 2344743
# On item: 2344750
# On item: 2344754
# On item: 2344760
# On item: 2344762
# On item: 2344763
# On item: 2344765
# On item: 2344767
# On item: 2344782
# On item: 2344801
# On item: 2344833
# On item: 2344896
# On item: 2344916
# On item: 2344955
# On item: 2344986
# On item: 2345068
# On item: 2345073
# On item: 2345075
# On item: 2345119
# On item: 2345147
# On item: 2345165
# On item: 2345288
# On item: 2345290
# On item: 2345292
# On item: 2345294
# On item: 2345297
# On item: 2345299
# On item: 2345301
# On item: 2345302
# On item: 2345303
# On item: 2345305
# On item: 2345311
# On item: 2345312
# On item: 2345314
# On item: 2345316
# On item: 2345317
# On item: 2345318
# On item: 2345323
# On item: 2345324
# On item: 2345326
# On item: 2345327
# On item: 2345329
# On item: 2345335
# On item: 2345401
# On item: 2345417
# On item: 2345431
# On item: 2345458
# On item: 2345469
# On item: 2345478
# On item: 2345503
# On item: 2345512
# On item: 2345528
# On item: 2345604
# On item: 2345617
# On item: 2345623
# On item: 2345761
# On item: 2345841
# On item: 2345888
# On item: 2345920
# On item: 2345935
# On item: 2345988
# On item: 2346058
# On item: 2346111
# On item: 2346138
# On item: 2346192
# On item: 2346263
# On item: 2346264
# On item: 2346283
# On item: 2346348

# %%
for item in nutrify_food_items_nutrients:
    if "olive," in item["description"].lower():
        print(item)
# Out:
# {'fdcId': 748608, 'description': 'Oil, olive, extra virgin', 'default_size': 100, 'unit': 'g', 'total_energy_calories': 844, 'micronutrients': {'vitamins': [], 'minerals': []}, 'other_nutrients': [], 'lipids': {'saturated_fat': 15.4, 'monounsaturated_fat': 69.2, 'polyunsaturated_fat': 9.07}, 'fdc_source_url': 'https://fdc.nal.usda.gov/fdc-app.html#/food-details/748608/nutrients'}

# %%
nutrify_food_items_nutrients[0]
# Out:
# {'fdcId': 321360,
#  'description': 'Tomatoes, grape, raw',
#  'default_size': 100,
#  'unit': 'g',
#  'total_energy_calories': 31,
#  'micronutrients': {'vitamins': [{'name': 'Vitamin C, total ascorbic acid',
#     'amount': 27.2,
#     'unit': 'mg'},
#    {'name': 'Choline, total', 'amount': 9.8, 'unit': 'mg'},
#    {'name': 'Vitamin E (alpha-tocopherol)', 'amount': 0.98, 'unit': 'mg'},
#    {'name': 'Vitamin K (phylloquinone)', 'amount': 4.2, 'unit': 'µg'},
#    {'name': 'Riboflavin', 'amount': 0.065, 'unit': 'mg'},
#    {'name': 'Thiamin', 'amount': 0.075, 'unit': 'mg'},
#    {'name': 'Vitamin B-6', 'amount': 0.06, 'unit': 'mg'},
#    {'name': 'Folate, total', 'amount': 10, 'unit': 'µg'},
#    {'name': 'Niacin', 'amount': 0.805, 'unit': 'mg'}],
#   'minerals': [{'name': 'Calcium, Ca', 'amount': 11, 'unit': 'mg'},
#    {'name': 'Copper, Cu', 'amount': 0.058, 'unit': 'mg'},
#    {'name': 'Iron, Fe', 'amount': 0.33, 'unit': 'mg'},
#    {'name': 'Magnesium, Mg', 'amount': 11.9, 'unit': 'mg'},
#    {'name': 'Manganese, Mn', 'amount': 0.121, 'unit': 'mg'},
#    {'name': 'Phosphorus, P', 'amount': 28, 'unit': 'mg'},
#    {'name': 'Potassium, K', 'amount': 260, 'unit': 'mg'},
#    {'name': 'Sodium, Na', 'amount': 6, 'unit': 'mg'},
#    {'name': 'Zinc, Zn', 'amount': 0.2, 'unit': 'mg'}]},
#  'Water': 92.5,
#  'macronutrients': {'fat': 0.63, 'protein': 0.83, 'carbohydrate': 5.51},
#  'other_nutrients': [],
#  'fdc_source_url': 'https://fdc.nal.usda.gov/fdc-app.html#/food-details/321360/nutrients'}

# %%
len(nutrify_food_items_nutrients)
# Out:
# 274

# %%
# Save to JSON
with open("nutrify_foodvision_items_nutrients.json", "w") as f:
    json.dump(nutrify_food_items_nutrients, f)

# %%
# Upload to Google Storage
# !gsutil cp nutrify_foodvision_items_nutrients.json gs://food_vision_bucket_with_object_versioning/nutrition_information/nutrify_foodvision_items_nutrients.json
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Copying file://nutrify_foodvision_items_nutrients.json [Content-Type=application/json]...
# - [1 files][399.4 KiB/399.4 KiB]
# Operation completed over 1 objects/399.4 KiB.

# %%
# TODO: 
# back the nutrition information up to Google Storage - could also track this as an Artifact in Weights & Biases? 
# Merge the Nutrition information with the Nutrify Food Item names
# Perhaps it's time to start getting a code to match all of the Nutrify food item names?
# Match the metadata of the Nutrify food items with the nutrition information
# For foods without an FDC ID - could match the closest food item based on the name and then use the nutrition information from that food item
# Could do the same with every other food, e.g. encode the text and show links to the closest food items (e.g. apple_red -> red delicious apple + more, apple_green -> granny smith apple + more, etc.)
# This would be the same with text-based foods as well, just include the most similar foods based on the text lookup (e.g. canola oil -> canola oil + more, olive oil -> olive oil + more, etc.)

# %%
# TODO: end goal

"""
{
    "nutrify_name": "Cheese, blue",
    "nutrition_information": 
    {"fdcId": 1000001,
     "description": "Cheese, blue",
     "size": 100,
     "unit": "g",
     "Macronutrients": {"Protein": 21.4,
                        "Total lipid (fat)": 28.74,
                        "Carbohydrate, by difference": 3.06},
     "Total energy (calories)": 376,
     "Micronutrients": {"Minerals": {"name": "Calcium, Ca",
                                     "unitName": "mg",
                                     "amount": 673.0},
                        "Vitamins": {"name": "Vitamin A, IU",
                                     "unitName": "mg",
                                     "amount": 2499.0}},
    "source_url": "https://fdc.nal.usda.gov/fdc-app.html#/food-details/1000001/nutrients"}
} 
"""
# Out:
# '\n{\n    "nutrify_name": "Cheese, blue",\n    "nutrition_information": \n    {"fdcId": 1000001,\n     "description": "Cheese, blue",\n     "size": 100,\n     "unit": "g",\n     "Macronutrients": {"Protein": 21.4,\n                        "Total lipid (fat)": 28.74,\n                        "Carbohydrate, by difference": 3.06},\n     "Total energy (calories)": 376,\n     "Micronutrients": {"Minerals": {"name": "Calcium, Ca",\n                                     "unit": "mg",\n                                     "amount": 673.0},\n                        "Vitamins": {"name"Vitamin A, IU": 2499.0}},\n    "source_url": "https://fdc.nal.usda.gov/fdc-app.html#/food-details/1000001/nutrients"}\n} \n'

# %% [markdown]
# ## Find a match for foods with no exact match

# %%
## TODO: 
# UPTOHERE
# Find classes which don't have nutrients
# Display options for the *most* similar items
    # E.g. if someone types in "Cheese, blue" and there is no exact match, display the closest matches
    # Could also just do this for the existing foods (find the most similar foods via name)

# %%
# Which rows don't have FDC IDs?
nutrify_to_fdcid[nutrify_to_fdcid["fdc_id"].isna()]
# Out:
#      number            class_name fdc_id
# 0         0               achacha   None
# 11       11  bacon_and_egg_burger   None
# 15       15          banana_bread   None
# 22       22            beef_diced   None
# 23       23            beef_kebab   None
# 30       30               biltong   None
# 31       31          black_pepper   None
# 48       48     cape_gooseberries   None
# 54       54         carrot_purple   None
# 68       68      chicken_stir_fry   None
# 73       73           chimichurri   None
# 78       78              choy_sum   None
# 89       89       crumbed_chicken   None
# 93       93          curry_leaves   None
# 102     102          endive_curly   None
# 106     106           finger_lime   None
# 116     116         garlic_chives   None
# 121     121          grapes_black   None
# 127     127                 gyoza   None
# 134     134                   ice   None
# 139     139                jujube   None
# 141     141       karaage_chicken   None
# 143     143            kiwi_berry   None
# 148     148            lemongrass   None
# 155     155           lime_leaves   None
# 162     162            mangosteen   None
# 164     164              marjoram   None
# 168     168           melon_candy   None
# 169     169            melon_dino   None
# 170     170            melon_long   None
# 171     171         melon_spanish   None
# 179     179         mushroom_flat   None
# 186     186   mushroom_white_cups   None
# 204     204                papple   None
# 209     209                pawpaw   None
# 215     215          pear_prickly   None
# 234     234           potato_bake   None
# 237     237        potato_kipfler   None
# 239     239   potato_purple_sweet   None
# 242     242     potato_royal_blue   None
# 243     243        potato_scallop   None
# 246     246    potato_white_sweet   None
# 255     255              rambutan   None
# 266     266              rosellas   None
# 278     278          sausage_roll   None
# 298     298             tamarillo   None
# 307     307        tomato_chutney   None

# %%
# Create a function to similarity match the class names (e.g. code which string is most like another string)
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import dot_score
model = SentenceTransformer("all-MiniLM-L6-v2")

def embed_list_of_classes(class_names: list, model: SentenceTransformer):
    """
    Embeds a list of class names.
    """

    # Map the class_name to the embedding
    class_name_to_embedding = {class_name: embedding for class_name, embedding in zip(class_names, model.encode(class_names))}

    return class_name_to_embedding

# Create a function to similarity match the class names (e.g. code which string is most like another string)
def find_most_similar_class_name(target_class_name, class_name_embedding_dict, num_similar=3):
    """
    Finds the most similar class name to the class_name provided.
    """
    # Get the embedding of the target_class_name
    target_class_name_embedding = model.encode([target_class_name])[0]

    # Create a dictionary of the class_name and the dot score between the target_class_name and the class_name
    class_name_embedding_dict = {class_name: dot_score(embedding, target_class_name_embedding) for class_name, embedding in class_name_embedding_dict.items()}

    # Sort the dictionary by the dot score
    most_similar_class_names = {k: v[0].item() for k, v in sorted(class_name_embedding_dict.items(), key=lambda item: item[1], reverse=True)}

    # Only return the top num_similar
    # most_similar_class_names = list(most_similar_class_names.items())[:num_similar]

    return most_similar_class_names

# %%
# Get a list of the unique descriptions
unique_descriptions = fdcid_to_description_df["description"].unique().tolist()
len(unique_descriptions)
# Out:
# 13475

# %%
# Create an embedding of all the unique descriptions
class_name_embedding_dict_unique_descriptions = embed_list_of_classes(unique_descriptions, model)

# %%
food_item_without_fdcid = rows_without_fdcid.class_name.to_list()
food_item_without_fdcid[:5]
# Out:
# ['achacha', 'bacon_and_egg_burger', 'banana_bread', 'beef_diced', 'beef_kebab']

# %%
# target_food_item = random.choice(food_item_without_fdcid)
target_food_item = "breadfruit"
print(f"Showing the most similar class names to: {target_food_item}")
most_similar_class_names = find_most_similar_class_name(target_food_item, class_name_embedding_dict_unique_descriptions, num_similar=10)
most_similar_class_names
# Out:
# Showing the most similar class names to: breadfruit
# {'Breadfruit, cooked': 0.8408920168876648,
#  'Breadfruit, raw': 0.7962300181388855,
#  'Bread, pumpkin': 0.7196508049964905,
#  'Bread, fruit': 0.7077605724334717,
#  'Bread, vegetable': 0.7036866545677185,
#  'Bread, Italian': 0.6614352464675903,
#  'Bread, cheese': 0.6606635451316833,
#  'Bread, wheat': 0.6581324338912964,
#  'Bread, vegetable, toasted': 0.6531142592430115,
#  'Bread, dough, fried': 0.649786114692688,
#  'Bread, sour dough, toasted': 0.6474003791809082,
#  'Bread, potato': 0.6473690271377563,
#  'Bread, white': 0.6419284343719482,
#  'Bread, rye': 0.6404439210891724,
#  'Bread stuffing': 0.6403353214263916,
#  'Bread, cheese, toasted': 0.6380453109741211,
#  'Bread, pumpernickel, toasted': 0.6380175352096558,
#  'Bread, Irish soda': 0.6379777789115906,
#  'Bread, pumpernickel': 0.6369190216064453,
#  'Bread, barley': 0.633845865726471,
#  'Bread, zucchini': 0.6325340270996094,
#  'Bread, naan': 0.6309512853622437,
#  'Bread, soy': 0.6300880312919617,
#  'Bread, sour dough': 0.6282667517662048,
#  'Bread, wheat, toasted': 0.6268751621246338,
#  'Casabe, cassava bread': 0.626651406288147,
#  'Bread, Cuban': 0.6258007287979126,
#  'Bread, white wheat': 0.6255069971084595,
#  'Bread, nut': 0.6252327561378479,
#  'Bread, whole wheat': 0.6251974701881409,
#  'Bread, oatmeal': 0.6251062154769897,
#  'Bread, egg': 0.6222550868988037,
#  'Bread, sprouted wheat': 0.6201033592224121,
#  'Bread, soy, toasted': 0.619598388671875,
#  'Bread, sprouted wheat, toasted': 0.6193941831588745,
#  'Bread, pita': 0.617633581161499,
#  'Bread, white, toasted': 0.6165446043014526,
#  'Bread, whole wheat, toasted': 0.6153135299682617,
#  'Bread, gluten free, toasted': 0.6148947477340698,
#  'Bread, rye, toasted': 0.6145893931388855,
#  'Bread, sweet potato': 0.6140116453170776,
#  'Bread, multigrain, toasted': 0.6135376691818237,
#  'Bread, black': 0.6132357716560364,
#  'Bread, sticks, plain': 0.6114659309387207,
#  'Bread, high protein, toasted': 0.6088485717773438,
#  'Bread, gluten free': 0.6077978014945984,
#  'Bread, barley, toasted': 0.6077713370323181,
#  'Tuna loaf': 0.60750812292099,
#  'Bread, high protein': 0.605101466178894,
#  'Bread, cinnamon': 0.6040151119232178,
#  'Seeds, breadfruit seeds, roasted': 0.6033520698547363,
#  'Bread, potato, toasted': 0.6028780341148376,
#  'Chicken patty, breaded': 0.6001709699630737,
#  'Bread, whole-wheat, commercially prepared, toasted': 0.6001011729240417,
#  'Bread, cracked-wheat': 0.5998914241790771,
#  'Bread, pan dulce, sweet yeast bread': 0.5998600721359253,
#  'Bread, oatmeal, toasted': 0.5993586778640747,
#  'Jelly sandwich, on wheat bread': 0.5983338356018066,
#  'Bread, white, commercially prepared, toasted': 0.5980876088142395,
#  'Bread, egg, toasted': 0.5970678329467773,
#  'Bread, wheat, sprouted, toasted': 0.596989631652832,
#  'Bread, white with whole wheat swirl, toasted': 0.59629887342453,
#  'Bread, Boston Brown': 0.5960354208946228,
#  'Bread, sunflower meal, toasted': 0.5949838757514954,
#  'Pudding, bread': 0.5949123501777649,
#  'Bread, white, commercially prepared': 0.5946334600448608,
#  'Bread, egg, Challah, toasted': 0.5941752791404724,
#  'Corned beef loaf, jellied': 0.5940395593643188,
#  'Bread, Cuban, toasted': 0.5939335227012634,
#  'Bread, black, toasted': 0.5938522219657898,
#  'Bread, cinnamon, toasted': 0.5936936140060425,
#  'Bread, pita with fruit': 0.592975378036499,
#  'Bread, onion': 0.5925966501235962,
#  'Bread, boston brown, canned': 0.5882575511932373,
#  'Bread, sweet potato, toasted': 0.5878143310546875,
#  'Bread, multigrain': 0.5871411561965942,
#  'Bread, oat bran, toasted': 0.5866045355796814,
#  'Bread, marble rye and pumpernickel, toasted': 0.5842975378036499,
#  'Bread, whole wheat, made from home recipe or purchased at bakery, toasted': 0.5836028456687927,
#  'Bread, oat bran': 0.5835278034210205,
#  'Seeds, breadfruit seeds, raw': 0.5834307670593262,
#  'Bread, cornmeal and molasses, toasted': 0.5831270217895508,
#  'Peppered loaf, pork, beef': 0.58292555809021,
#  'Bread, egg, Challah': 0.5824210047721863,
#  'Bread, wheat, sprouted': 0.5823383331298828,
#  'Bread, whole-wheat, commercially prepared': 0.5821377038955688,
#  'Pillsbury, Crusty French Loaf, refrigerated dough': 0.5816576480865479,
#  'Bread, raisin, toasted': 0.5812342166900635,
#  'Restaurant, Latino, bunuelos (fried yeast bread)': 0.5803471803665161,
#  'Bread, wheat or cracked wheat, toasted': 0.5788914561271667,
#  'Bread, chappatti or roti': 0.5772647857666016,
#  'Bread, rice': 0.5772207379341125,
#  'Bread, sunflower meal': 0.5748828649520874,
#  'Bread, white, made from home recipe or purchased at a bakery, toasted': 0.5734115839004517,
#  'Jelly sandwich, on white bread': 0.5723716616630554,
#  'Bread, raisin': 0.5723303556442261,
#  'Bread, wheat or cracked wheat, made from home recipe or purchased at bakery, toasted': 0.5718125104904175,
#  'Bread, whole-wheat, prepared from recipe, toasted': 0.571434736251831,
#  'Bread, whole grain white, toasted': 0.570448100566864,
#  'Bread, rice, toasted': 0.5693649649620056,
#  'Bread, protein, (includes gluten), toasted': 0.5689418315887451,
#  'Fish sandwich, fried, on wheat bun': 0.5681459903717041,
#  'Fish sandwich, fried, on wheat bun, with cheese': 0.5679432153701782,
#  'Bread, onion, toasted': 0.566455602645874,
#  'Bread, Spanish coffee': 0.566156804561615,
#  'Chicken cornbread': 0.5627782344818115,
#  'Bread, puri': 0.5623680353164673,
#  'Bread, rice bran, toasted': 0.5621345043182373,
#  'Chili hot dog sandwich, on wheat bread': 0.5615307092666626,
#  'Bread, reduced calorie and/or high fiber, white or NFS, with fruit and/or nuts, toasted': 0.5613934993743896,
#  'Doughnut, yeast type': 0.5604877471923828,
#  'Bread, French or Vienna, toasted': 0.559423565864563,
#  'Bread, NS as to major flour, toasted': 0.5593653917312622,
#  'Bread, rice bran': 0.5589267015457153,
#  'Bread, cornmeal and molasses': 0.558214545249939,
#  'Bread, protein (includes gluten)': 0.558041512966156,
#  'Bread, paratha': 0.5576506853103638,
#  'Bread, multigrain, with raisins, toasted': 0.5572830438613892,
#  'Bread, white with whole wheat swirl': 0.5572478175163269,
#  'Bread, French or Vienna, whole wheat, toasted': 0.556875467300415,
#  'Bread, naan, plain, commercially prepared, refrigerated': 0.5566625595092773,
#  'Bread, marble rye and pumpernickel': 0.5565595030784607,
#  'Green bean casserole': 0.5557224154472351,
#  'Bread, pita, white, unenriched': 0.5549329519271851,
#  'Injera, Ethiopian bread': 0.5547922849655151,
#  'Soybean curd, breaded, fried': 0.5542569160461426,
#  'Bread, white, commercially prepared (includes soft bread crumbs)': 0.55357825756073,
#  'Bread, pita, whole-wheat': 0.5523239970207214,
#  'Bread, multigrain, reduced calorie and/or high fiber, toasted': 0.5522184371948242,
#  'Chili hot dog sandwich, on white bread': 0.5522124767303467,
#  'Bread, reduced-calorie, oat bran, toasted': 0.5514172911643982,
#  'Bread, wheat or cracked wheat': 0.551357090473175,
#  'Seeds, breadfruit seeds, boiled': 0.5513076782226562,
#  'Bread, French or Vienna': 0.5507640838623047,
#  'Olive loaf, pork': 0.5503488779067993,
#  'Bread, whole grain white': 0.5493170619010925,
#  'Bread, pita, whole wheat': 0.5490707159042358,
#  'Hot dog sandwich, NFS, on white bread': 0.5482227206230164,
#  'Chicken fillet, breaded': 0.5480533838272095,
#  'Luncheon meat, loaf type': 0.5479450225830078,
#  'Bread, crumbs, dry, grated, plain': 0.547676682472229,
#  'Hot dog sandwich, NFS, on wheat bread': 0.5474447011947632,
#  'Bread, reduced-calorie, white': 0.5470722913742065,
#  'Breading or batter as ingredient in food': 0.5467652678489685,
#  'Bread, white, made from home recipe or purchased at a bakery': 0.5465276837348938,
#  'Bread, french or vienna, toasted (includes sourdough)': 0.5462095737457275,
#  'Sloppy joe sandwich, on wheat bun': 0.5459598302841187,
#  'Bread, raisin, unenriched': 0.5450243949890137,
#  'Bread, whole wheat, made from home recipe or purchased at bakery': 0.5445505380630493,
#  'Cheese sandwich, cheddar cheese, on wheat bread': 0.5443143248558044,
#  'Bread, whole wheat, with raisins, toasted': 0.5437245965003967,
#  'Bread, banana, prepared from recipe, made with margarine': 0.5435089468955994,
#  'Bread, roll, Mexican, bollilo': 0.5431702136993408,
#  'Biscuit, wheat': 0.5428171157836914,
#  'Ham and cheese loaf or roll': 0.5423943996429443,
#  'Garlic bread, NFS': 0.5423401594161987,
#  'Bread, raisin, enriched, toasted': 0.5404648184776306,
#  'Bread, made from home recipe or purchased at a bakery, toasted, NS as to major flour': 0.5401514172554016,
#  'Fish sandwich, fried, on white bun, with cheese': 0.5400809049606323,
#  'Jackfruit, raw': 0.5388729572296143,
#  'Bread, naan, whole wheat, commercially prepared, refrigerated': 0.5388320684432983,
#  'Bread, irish soda, prepared from recipe': 0.5386934876441956,
#  'Bread, reduced calorie and/or high fiber, white or NFS, toasted': 0.5382340550422668,
#  'French toast, whole grain': 0.5373337864875793,
#  'Fried eggplant': 0.5373044013977051,
#  'Fish sandwich, fried, from fast food': 0.5362545251846313,
#  'Breakfast pastry, NFS': 0.5358921885490417,
#  'Bread, reduced-calorie, rye': 0.5357332825660706,
#  'Bread, white, low sodium or no salt, toasted': 0.5355304479598999,
#  'Breadsticks, NFS': 0.5353782176971436,
#  'Jackfruit, canned, syrup pack': 0.5353624820709229,
#  'Bread, white, commercially prepared, low sodium, no salt': 0.5345941781997681,
#  'Bread, reduced-calorie, wheat': 0.5345492959022522,
#  'Bread, crumbs, dry, grated, seasoned': 0.5344948768615723,
#  'Italian sandwich on wheat': 0.5343738794326782,
#  'Bread, white, commercially prepared, toasted, low sodium no salt': 0.534011960029602,
#  'Bread, pita, white, enriched': 0.5338996052742004,
#  'Hot dog sandwich, vegetarian, on bread': 0.5329189300537109,
#  'Fast food, biscuit': 0.5323435664176941,
#  'Bread, whole-wheat, prepared from recipe': 0.5323299169540405,
#  'Cereal, cinnamon toast': 0.5322448015213013,
#  'Roll, egg bread': 0.5319464206695557,
#  'Grilled cheese sandwich, cheddar cheese, on wheat bread': 0.531691312789917,
#  'Spoonbread': 0.5310096740722656,
#  'Club sandwich on wheat': 0.5303617119789124,
#  'Doughnut, jelly': 0.52994704246521,
#  'Garlic bread, from fast food / restaurant': 0.5292514562606812,
#  'Bread, multi-grain, toasted (includes whole-grain)': 0.5288252234458923,
#  'Wheat flours, bread, unenriched': 0.5285760760307312,
#  'Ham biscuit sandwich': 0.5283491611480713,
#  'Fish sandwich, fried, on white bun': 0.5282544493675232,
#  'Breadsticks, soft, frozen': 0.5277632474899292,
#  'Bread, wheat or cracked wheat, made from home recipe or purchased at bakery': 0.5274450778961182,
#  'Bread, pita, wheat or cracked wheat': 0.5273204445838928,
#  'Meat loaf, Puerto Rican style': 0.5268577337265015,
#  'Bread, white, special formula, added fiber, toasted': 0.5266401767730713,
#  'Bread, blue corn, somiviki (Hopi)': 0.5257880687713623,
#  'Wheat flour, white, bread, enriched': 0.5257449150085449,
#  'Candied fruit': 0.5254935026168823,
#  'Doughnut, chocolate': 0.5252928733825684,
#  'SUBWAY, SUBWAY CLUB sub on white bread with lettuce and tomato': 0.5249177813529968,
#  'Bread, french or vienna, whole wheat': 0.5246423482894897,
#  'Bread, French or Vienna, whole wheat': 0.5246423482894897,
#  'Hot dog sandwich, beef, on wheat bread': 0.5246150493621826,
#  'Breakfast bar, corn flake crust with fruit': 0.5243934392929077,
#  'Pickle and pimiento loaf, pork': 0.5240931510925293,
#  'Bread, wheat or cracked wheat, with raisins, toasted': 0.5233403444290161,
#  'Biscuit with fruit': 0.5222898125648499,
#  'Fish sandwich, fried, from fast food, with cheese': 0.5221019387245178,
#  'Garlic bread, from frozen': 0.5216668844223022,
#  'Bread, wheat or cracked wheat, reduced calorie and/or high fiber, toasted': 0.5213274955749512,
#  'SUBWAY, cold cut sub on white bread with lettuce and tomato': 0.5211222171783447,
#  'Cheese sandwich, reduced fat cheese, on wheat bread': 0.5207366943359375,
#  'Flour, bread, white, enriched, unbleached': 0.5206475853919983,
#  'Cheese sandwich, American cheese, on wheat bread': 0.5201544761657715,
#  'Bread, reduced-calorie, oatmeal': 0.5200052261352539,
#  'Bread, chapati or roti, plain, commercially prepared': 0.5199785828590393,
#  'Bread, french or vienna (includes sourdough)': 0.5195519924163818,
#  'Almond butter sandwich, on wheat bread': 0.5194523930549622,
#  'Meat loaf dinner, NFS, frozen meal': 0.5193851590156555,
#  'SUBWAY, black forest ham sub on white bread with lettuce and tomato': 0.5185970067977905,
#  'Club sandwich on wheat, with cheese': 0.5184532999992371,
#  'Bread, stuffing, cornbread, dry mix': 0.5184244513511658,
#  'Cuban sandwich': 0.5183612108230591,
#  'Picnic loaf, pork, beef': 0.5182248950004578,
#  'Cheesecake, fruit': 0.5180922746658325,
#  'French toast, plain': 0.5179516077041626,
#  'Hot dog sandwich, beef, on white bread': 0.5179195404052734,
#  'Breadsticks, hard, whole wheat': 0.5178216695785522,
#  'Wheat bread as ingredient in sandwiches': 0.5177699327468872,
#  'Bread, raisin, enriched': 0.5173946619033813,
#  'Doughnut, NFS': 0.5171043872833252,
#  'Bread, stuffing, dry mix': 0.5169332027435303,
#  'Breadsticks, hard, gluten free': 0.5169103741645813,
#  'Biscuit, from fast food / restaurant': 0.5168330073356628,
#  'Biscuit, from refrigerated dough': 0.5160106420516968,
#  'Bread, paratha, whole wheat, commercially prepared, frozen': 0.5158838629722595,
#  'Coffee cake, crumb or quick-bread type, with fruit': 0.5152254104614258,
#  'Biscuit, cheese': 0.5152197480201721,
#  'Bologna sandwich on wheat': 0.5147822499275208,
#  'Cheese sandwich, cheddar cheese, on white bread': 0.5147575736045837,
#  'Macaroni and cheese loaf, chicken, pork and beef': 0.5144692659378052,
#  'Chili hot dog sandwich, on wheat bun': 0.5142987370491028,
#  'Garlic bread, frozen': 0.5141842365264893,
#  'Bread, lard, Puerto Rican style': 0.5135600566864014,
#  'Vegetable sandwich on wheat': 0.51337730884552,
#  'French toast, fast food / restaurant': 0.5132918953895569,
#  'French dip sandwich': 0.513163685798645,
#  'Bread, chapati or roti, whole wheat, commercially prepared, frozen': 0.513161301612854,
#  'Bologna sandwich on wheat, with cheese': 0.5131393671035767,
#  'Breadsticks, soft, fast food / restaurant': 0.5130218863487244,
#  'Bread, cornbread, dry mix, unenriched (includes corn muffin mix)': 0.5129780769348145,
#  'Egg sandwich on wheat bread, with meat and cheese': 0.5128512382507324,
#  'Bread, made from home recipe or purchased at a bakery, NS as to major flour': 0.5126303434371948,
#  'Hot dog sandwich, meat and poultry, on wheat bread': 0.5120251178741455,
#  'Babyfood, GERBER, GRADUATES Lil Biscuits Vanilla Wheat': 0.5118492841720581,
#  'Egg casserole with bread, cheese, milk and meat': 0.5110130310058594,
#  'Hot dog sandwich, turkey, on wheat bread': 0.5108691453933716,
#  'Fast foods, submarine sandwich, cold cut on white bread with lettuce and tomato': 0.5108211040496826,
#  'JIMMY DEAN, Sausage, Egg, and Cheese Breakfast Biscuit, frozen, unprepared': 0.5106563568115234,
#  'Pan Dulce, with fruit, no frosting': 0.5095518827438354,
#  'KFC, biscuit': 0.5094670653343201,
#  'Meat loaf with potatoes, vegetable, frozen meal': 0.5092206597328186,
#  'Cereal, shredded wheat, flavored': 0.5091003775596619,
#  'Bread, lard, toasted, Puerto Rican style': 0.5090975761413574,
#  'Restaurant, Latino, arepa (unleavened cornmeal bread)': 0.5089406371116638,
#  'Hot dog sandwich, meat and poultry, on white bread': 0.5087176561355591,
#  'Cheese, cottage, creamed, with fruit': 0.5086753368377686,
#  'Egg sandwich on wheat bread, with cheese': 0.5082569122314453,
#  'Barbecue loaf, pork, beef': 0.5077168941497803,
#  'Chicken fillet sandwich, fried, on wheat bun, with cheese': 0.5075563788414001,
#  'Fast foods, submarine sandwich, ham on white bread with lettuce and tomato': 0.507554292678833,
#  'Focaccia, Italian flatbread, plain': 0.5073943734169006,
#  'Bread, Italian, Grecian, Armenian, toasted': 0.5071931481361389,
#  'Squash, summer, casserole, with cheese sauce': 0.5066419839859009,
#  'School Lunch, chicken patty, whole grain breaded': 0.5063959360122681,
#  'Sloppy joe sandwich, on white bun': 0.5059199929237366,
#  'Grilled cheese sandwich, reduced fat cheese, on wheat bread': 0.505813717842102,
#  'Bread, gluten-free, white, made with potato extract, rice starch, and rice flour': 0.5058027505874634,
#  'Fast foods, submarine sandwich, meatball marinara on white bread': 0.5056591629981995,
#  'Snack mix': 0.5056386590003967,
#  'Peanut butter sandwich, with reduced fat peanut butter, on wheat bread': 0.5054820775985718,
#  'Bread, caressed, toasted, Puerto Rican style': 0.5045972466468811,
#  'Bread, reduced-calorie, oat bran': 0.5043776035308838,
#  'Ice cream sandwich': 0.5043691396713257,
#  'Cereal, fruit crispy': 0.5040969848632812,
#  'Bread, caressed, Puerto Rican style': 0.5033144950866699,
#  'Bread, whole wheat, with raisins': 0.5028544068336487,
#  'Falafel sandwich': 0.5028390288352966,
#  'Ham luncheon meat, loaf type': 0.5028259754180908,
#  'Hot dog sandwich, turkey, on white bread': 0.5026003122329712,
#  'Grilled cheese sandwich, American cheese, on wheat bread': 0.5025060772895813,
#  'Dutch brand loaf, chicken, pork and beef': 0.5022680759429932,
#  'KFC, Fried Chicken, EXTRA CRISPY, Breast, meat and skin with breading': 0.5021069645881653,
#  'Vegetable sandwich on wheat, with cheese': 0.5020586848258972,
#  'Egg sandwich on white bread': 0.501912534236908,
#  'Pan Dulce, with sugar topping': 0.5016530752182007,
#  'Egg sandwich on wheat bread': 0.5012568235397339,
#  'Cheese, cottage, with fruit': 0.5005456209182739,
#  'Hot dog sandwich, reduced fat, on wheat bread': 0.50029057264328,
#  'Hot dog sandwich, NFS, on wheat bun': 0.49986565113067627,
#  'Luxury loaf, pork': 0.49927669763565063,
#  'Schar, Gluten-Free, Wheat-Free, Classic White Bread': 0.4991301894187927,
#  'Candies, NESTLE, CRUNCH Bar and Dessert Topping': 0.49898141622543335,
#  'Corn pone, baked': 0.498778373003006,
#  'Breadsticks, hard, NFS': 0.4987142086029053,
#  'Lamb or mutton loaf': 0.4986182451248169,
#  'Fast foods, submarine sandwich, bacon, lettuce, and tomato on white bread': 0.498538076877594,
#  'Babyfood, fruit supreme dessert': 0.49843573570251465,
#  'Hot dog sandwich, beef, on wheat bun': 0.498426616191864,
#  'Chicken fillet sandwich, fried, on wheat bun': 0.498354434967041,
#  'Bread, white, low sodium or no salt': 0.4982406795024872,
#  'Sausage biscuit sandwich, with cheese': 0.4980713725090027,
#  'Cornstarch': 0.49783340096473694,
#  'Bread, cornbread, dry mix, enriched (includes corn muffin mix)': 0.49764084815979004,
#  'Sweetbreads': 0.49755406379699707,
#  'Ham sandwich on wheat': 0.4974808096885681,
#  'Cheese sandwich, reduced fat cheese, on white bread': 0.4973497986793518,
#  'Sausage biscuit sandwich': 0.49672096967697144,
#  'Egg sandwich on white bread, with meat and cheese': 0.49659615755081177,
#  'Almond butter sandwich, on white bread': 0.49641355872154236,
#  'Garlic bread, with melted cheese, from fast food / restaurant': 0.49605482816696167,
#  'Hot dog sandwich, reduced fat, on white bread': 0.49602770805358887,
#  'Babyfood, cookie, baby, fruit': 0.49589627981185913,
#  'Cornbread stuffing': 0.49585723876953125,
#  'Meatloaf sandwich': 0.4956262707710266,
#  'Crackers, melba toast, wheat': 0.4955996572971344,
#  'Coffee cake, crumb or quick-bread type, cheese-filled': 0.49550196528434753,
#  'Cereals, QUAKER, Instant Oatmeal, Banana Bread, dry': 0.4954010546207428,
#  'French toast, NFS': 0.495376855134964,
#  'Doughnut, yeast type, with chocolate icing': 0.49506473541259766,
#  'KFC, Fried Chicken, EXTRA CRISPY, Thigh, meat and skin with breading': 0.4949813485145569,
#  'Breakfast bar, cereal crust with fruit filling, lowfat': 0.49496105313301086,
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Breast, meat and skin with breading': 0.49481111764907837,
#  'Lobster with bread stuffing, baked': 0.49448928236961365,
#  'Grilled cheese sandwich, cheddar cheese, on white bread': 0.4944869875907898,
#  "Mother's loaf, pork": 0.4943787455558777,
#  'Fast Foods, Fried Chicken, Drumstick, meat and skin with breading': 0.4943782389163971,
#  'Bread, reduced calorie and/or high fiber, white or NFS': 0.49433526396751404,
#  'Corn flour patty or tart, fried': 0.4943113327026367,
#  'French toast, gluten free': 0.49415892362594604,
#  'Fast Foods, Fried Chicken, Skin and breading from all pieces': 0.4937662184238434,
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Thigh, meat and skin with breading': 0.493744820356369,
#  'Meat loaf made with beef': 0.4934311807155609,
#  'Bread, multigrain, with raisins': 0.4932049512863159,
#  'Peanut butter and jelly sandwich, with reduced fat peanut butter, on wheat bread': 0.4930332899093628,
#  "McDONALD'S, Sausage Biscuit with Egg": 0.49291348457336426,
#  'Bread, reduced calorie and/or high fiber, white or NFS, with fruit and/or nuts': 0.4928963780403137,
#  'Egg sandwich on wheat bread, with meat': 0.49289026856422424,
#  'French toast, frozen, ready-to-heat': 0.4927314221858978,
#  'Ham sandwich on wheat, with cheese': 0.49245333671569824,
#  'Eggplant and meat casserole': 0.49234044551849365,
#  'Bread, multi-grain (includes whole-grain)': 0.4921955466270447,
#  'Fast foods, fish sandwich, with tartar sauce and cheese': 0.4918237328529358,
#  'French toast, frozen': 0.49176475405693054,
#  'Dessert pizza': 0.4912571310997009,
#  'Cereal beverage': 0.4906887114048004,
#  'Pastry, mainly flour and water, fried': 0.49061694741249084,
#  'Fast foods, fish sandwich, with tartar sauce': 0.4905817210674286,
#  'Egg sandwich on white bread, with cheese': 0.4904218912124634,
#  'Phyllo dough': 0.49010807275772095,
#  'Almond butter and jelly sandwich, on wheat bread': 0.4900958836078644,
#  'Peanut butter sandwich, with regular peanut butter, on wheat bread': 0.4899965226650238,
#  'Cereals ready-to-eat, POST, Shredded Wheat, original big biscuit': 0.4899526536464691,
#  'Babyfood, dessert, fruit pudding, pineapple, strained': 0.4897981882095337,
#  'Frozen novelties, KLONDIKE, SLIM-A-BEAR Vanilla Sandwich': 0.48976269364356995,
#  "McDONALD'S, Deluxe Breakfast, with syrup and margarine": 0.48957252502441406,
#  'Baked beans': 0.48929476737976074,
#  'Bread, native, water, toasted, Puerto Rican style': 0.4891901910305023,
#  'Starfruit, raw': 0.48843222856521606,
#  'Bread, Italian, Grecian, Armenian': 0.4882039427757263,
#  'Sausage, egg and cheese breakfast biscuit': 0.488044410943985,
#  'Breakfast tart': 0.4879419207572937,
#  'KFC, Fried Chicken, EXTRA CRISPY, Skin and Breading': 0.4876419007778168,
#  'Fast foods, french toast sticks': 0.48760321736335754,
#  'Roll, wheat or cracked wheat, hamburger bun': 0.48755353689193726,
#  'Cookie, sandwich, sugar free': 0.4875083267688751,
#  'School Lunch, chicken nuggets, whole grain breaded': 0.4871620535850525,
#  'Fast foods, biscuit, with ham': 0.48710793256759644,
#  'Cheese sandwich, American cheese, on white bread': 0.48641836643218994,
#  'Doughnut, custard-filled': 0.4857763946056366,
#  'Peanut butter': 0.4854138195514679,
#  'Doughnuts, yeast-leavened, glazed, unenriched (includes honey buns)': 0.48535796999931335,
#  'Bread, NS as to major flour': 0.4853098392486572,
#  'Bread, white, special formula, added fiber': 0.48522841930389404,
#  'Meat loaf made with ham': 0.48515987396240234,
#  'Cereals ready-to-eat, SUN COUNTRY, KRETSCHMER Toasted Wheat Bran': 0.48486754298210144,
#  'Crackers, breakfast biscuit': 0.48475533723831177,
#  'Hot dog sandwich, vegetarian, on bun': 0.48470014333724976,
#  'Breadsticks, soft, NFS': 0.48453640937805176,
#  'Cereal, shredded wheat, plain': 0.4844871759414673,
#  'Fast foods, submarine sandwich, oven roasted chicken on white bread with lettuce and tomato': 0.4840986132621765,
#  'Roll, whole wheat, hamburger bun': 0.484062135219574,
#  'POPEYES, Fried Chicken, Mild, Breast, meat and skin with breading': 0.483944833278656,
#  'Cereal, other, fruit flavored': 0.483939528465271,
#  'Eggplant, pickled': 0.4838867485523224,
#  'Peanut butter sandwich, with reduced fat peanut butter, on white bread': 0.48382145166397095,
#  'Cereals ready-to-eat, wheat germ, toasted, plain': 0.48381584882736206,
#  'Egg sandwich on white bread, with meat': 0.48358893394470215,
#  "Rudi's, Gluten-Free Bakery, Original Sandwich Bread": 0.4835485816001892,
#  'Bread, native, water, Puerto Rican style': 0.48354846239089966,
#  'Crackers, melba toast, rye (includes pumpernickel)': 0.48341476917266846,
#  'Hamburger wrap sandwich, from fast food': 0.48330527544021606,
#  'Lasagna, Vegetable, frozen, baked': 0.4832538664340973,
#  'Muffin, wheat': 0.482920378446579,
#  'Babyfood, dessert, tropical fruit, junior': 0.4822957217693329,
#  "McDONALD'S, Sausage Biscuit": 0.48223888874053955,
#  'Cheese, cottage, lowfat, with fruit': 0.4820632338523865,
#  'Coffee cake, crumb or quick-bread type': 0.4820306897163391,
#  'Yeast': 0.4817022383213043,
#  'BURGER KING, french toast sticks': 0.4816681444644928,
#  'Bagel, whole wheat': 0.48165813088417053,
#  'POPEYES, Fried Chicken, Mild, Skin and Breading': 0.48160338401794434,
#  'Fast foods, submarine sandwich, turkey breast on white bread with lettuce and tomato': 0.48120346665382385,
#  'Corn bran, crude': 0.4809255599975586,
#  'Egg sandwich on biscuit': 0.4806738495826721,
#  'Crackers, crispbread, rye': 0.480605810880661,
#  "McDONALD'S, Sausage McMUFFIN with Egg": 0.4805810749530792,
#  'Breadsticks, soft, with parmesan cheese, fast food / restaurant': 0.4805184602737427,
#  'Babyfood, baked product, finger snacks cereal fortified': 0.4803699851036072,
#  'Cheese, cottage cheese, with gelatin dessert and fruit': 0.48028939962387085,
#  'Bread, stuffing, cornbread, dry mix, prepared': 0.4799724817276001,
#  'Ice cream cookie sandwich': 0.4798969626426697,
#  'Cereal, crunch': 0.4798063635826111,
#  'Nutella sandwich on white bread': 0.47977131605148315,
#  'Crackers, flatbread': 0.47976255416870117,
#  'Meat loaf made with chicken or turkey, with tomato-based sauce': 0.4796340763568878,
#  'Bean cake': 0.47927048802375793,
#  'Fried seafood sandwich': 0.4788171350955963,
#  'SUBWAY, B.L.T. sub on white bread with bacon, lettuce and tomato': 0.47874757647514343,
#  'KFC, Fried Chicken, EXTRA CRISPY, Wing, meat and skin with breading': 0.47865402698516846,
#  'Pancakes, fruit': 0.4783455431461334,
#  'Topping, butterscotch or caramel': 0.47828778624534607,
#  'Bread, wheat or cracked wheat, with raisins': 0.47823265194892883,
#  'Peanut butter and jelly sandwich, with regular peanut butter, regular jelly, on wheat bread': 0.47819897532463074,
#  'Egg white sandwich': 0.47809702157974243,
#  'POPEYES, Fried Chicken, Mild, Thigh, meat and skin with breading': 0.4780609607696533,
#  'Candies, peanut bar': 0.47796690464019775,
#  'Cream of wheat, instant, made with water, fat added': 0.4779658317565918,
#  'Chicken fillet sandwich, grilled, on wheat bun, with cheese': 0.4779090881347656,
#  'Chicken, thighs, frozen, breaded, reheated': 0.4778992235660553,
#  'Barbecue beef sandwich, on wheat bun': 0.47743672132492065,
#  'Bread, cornbread, dry mix, prepared with 2% milk, 80% margarine, and eggs': 0.4774293899536133,
#  'Bread, multigrain, reduced calorie and/or high fiber': 0.4772260785102844,
#  'Crackers, crispbread': 0.4772094488143921,
#  'Meat loaf made with chicken or turkey': 0.4771479070186615,
#  'Grilled cheese sandwich, NFS': 0.4771438241004944,
#  'Sandwich spread': 0.47707465291023254,
#  'French toast, prepared from recipe, made with low fat (2%) milk': 0.4766393303871155,
#  'Fast foods, submarine sandwich, roast beef on white bread with lettuce and tomato': 0.4764096438884735,
#  'Bratwurst, with cheese': 0.4763428568840027,
#  'Bagel, wheat': 0.4762122333049774,
#  'Cheese sandwich, NFS': 0.4760672152042389,
#  'Grilled cheese sandwich, reduced fat cheese, on white bread': 0.4759256839752197,
#  'Cheese, cottage, low fat': 0.47590765357017517,
#  'Bread, cornbread, prepared from recipe, made with low fat (2%) milk': 0.47586527466773987,
#  'Bread, white, prepared from recipe, made with low fat (2%) milk': 0.47571414709091187,
#  'Peanut butter and jelly sandwich, NFS': 0.4756428003311157,
#  'Vegetable sandwich on white': 0.4755500555038452,
#  'Chili hot dog sandwich, on white bun': 0.47550731897354126,
#  'Cereal or Granola bar, NFS': 0.4754868149757385,
#  'Biscuit, home recipe': 0.4753991961479187,
#  'Ham, sliced, restaurant': 0.475366473197937,
#  'Bread, stuffing, dry mix, prepared': 0.47536322474479675,
#  'Tomato sandwich on wheat': 0.47530049085617065,
#  'Fish sandwich, grilled': 0.4750761389732361,
#  'Fish sandwich, from school cafeteria': 0.4748647212982178,
#  'Pepperidge Farm, Goldfish, Baked Snack Crackers, Cheddar': 0.47470229864120483,
#  'Doughnuts, yeast-leavened, glazed, enriched (includes honey buns)': 0.47433972358703613,
#  'Wheat, sprouted': 0.47401517629623413,
#  'POPEYES, Fried Chicken, Mild, Wing, meat and skin with breading': 0.4739592671394348,
#  'Egg, whole, fried with margarine': 0.4738442301750183,
#  'Egg sandwich on bagel': 0.47383183240890503,
#  'Fast foods, submarine sandwich, turkey, roast beef and ham on white bread with lettuce and tomato': 0.47374871373176575,
#  'Peanut butter and jelly sandwich, with reduced fat peanut butter, on white bread': 0.4736350178718567,
#  'French toast sticks': 0.4735957980155945,
#  'Cereal, other, plain': 0.47354763746261597,
#  "McDONALD'S, BIG BREAKFAST": 0.4733417332172394,
#  'Babyfood, dessert, peach cobbler, junior': 0.4733353555202484,
#  'Toppings, butterscotch or caramel': 0.47328996658325195,
#  'Hamburger, on wheat bun, 1 small patty': 0.47318291664123535,
#  'Potato pancake': 0.4731621742248535,
#  'Candies, butterscotch': 0.4731025993824005,
#  "DENNY'S, fish fillet, battered or breaded, fried": 0.4729064702987671,
#  'Fast foods, biscuit, with sausage': 0.4728845953941345,
#  'Cereal, ready-to-eat, NFS': 0.472748726606369,
#  'Cornbread, prepared from mix': 0.4727083444595337,
#  'Bread stuffing made with egg': 0.47269880771636963,
#  'Cookie, chocolate sandwich': 0.472698450088501,
#  'Hamburger, on wheat bun, 1 medium patty': 0.47269749641418457,
#  'Fast Foods, Fried Chicken, Breast, meat and skin and breading': 0.47265684604644775,
#  'Ice cream sandwich, chocolate': 0.47254782915115356,
#  'Meat loaf made with beef, with tomato-based sauce': 0.4721909761428833,
#  'Bacon biscuit sandwich': 0.4721660017967224,
#  'Rye flour, dark': 0.4717644453048706,
#  'Fast foods, biscuit, with egg and ham': 0.47165387868881226,
#  'Melba toast': 0.471557080745697,
#  'SUBWAY, turkey breast sub on white bread with lettuce and tomato': 0.47150665521621704,
#  'Peanut sauce': 0.47137805819511414,
#  'Apple, baked': 0.47134459018707275,
#  'Muffins, corn, toaster-type': 0.47129887342453003,
#  "Cereal or granola bar (Kellogg's Nutri-Grain Fruit and Nut Bar)": 0.47076570987701416,
#  'Flour, almond': 0.4707169532775879,
#  'Peanut butter and jelly sandwich, with regular peanut butter, reduced sugar jelly, on wheat bread': 0.4705965518951416,
#  'Fast Foods, biscuit, with egg and sausage': 0.47058525681495667,
#  'Hot dog sandwich, turkey, on wheat bun': 0.47042912244796753,
#  'Biscuit with gravy': 0.46965354681015015,
#  'French toast sticks, fast food / restaurant': 0.469481885433197,
#  'Egg sandwich on biscuit, with sausage and cheese': 0.46935606002807617,
#  'Breadsticks, hard, reduced sodium': 0.4693300127983093,
#  'Egg white sandwich, with cheese': 0.46932387351989746,
#  'Cream of wheat, NFS': 0.46925318241119385,
#  'Candies, sesame crunch': 0.46923208236694336,
#  'Almond butter and jelly sandwich, on white bread': 0.46922388672828674,
#  'Cereal, cooked, NFS': 0.4692174792289734,
#  'Meat loaf made with beef and pork, with tomato-based sauce': 0.4692113697528839,
#  'Wheat bran, crude': 0.469059556722641,
#  'Ketchup': 0.4689899682998657,
#  'Cookie, shortbread': 0.4688701331615448,
#  'Pepper, for use on a sandwich': 0.46885693073272705,
#  'SUBWAY, tuna sub on white bread with lettuce and tomato': 0.46880918741226196,
#  'Cheese, cottage cheese, with gelatin dessert and vegetables': 0.4685937166213989,
#  'Piki bread, made from blue cornmeal (Hopi)': 0.46856871247291565,
#  'Pastry, made with bean paste and salted egg yolk filling, baked': 0.4684900939464569,
#  'Fast foods, submarine sandwich, tuna on white bread with lettuce and tomato': 0.4684605896472931,
#  'Cream of wheat, instant, made with water, no added fat': 0.46842414140701294,
#  'Chicken, meatless, breaded, fried': 0.4683564305305481,
#  'Pancakes, pumpkin': 0.4682786464691162,
#  'Cookie, peanut butter sandwich': 0.4682377278804779,
#  'Bagels, wheat': 0.4680778682231903,
#  'McDouble (McDonalds)': 0.4680153727531433,
#  'Beans, baked, canned, with franks': 0.46788403391838074,
#  'Cereals ready-to-eat, MALT-O-MEAL, CINNAMON TOASTERS': 0.4677205979824066,
#  'Hot dog sandwich, reduced fat, on wheat bun': 0.46769803762435913,
#  "McDONALD'S, McCHICKEN Sandwich": 0.46763497591018677,
#  'POPEYES, biscuit': 0.467204749584198,
#  'Hot dog sandwich, beef, on white bun': 0.4671017527580261,
#  'Veggie burger, on bun, with cheese': 0.4668958783149719,
#  'Babyfood, dessert, banana yogurt, strained': 0.46661898493766785,
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Skin and Breading': 0.46661603450775146,
#  'Pizza, with meat, whole wheat thin crust': 0.46627146005630493,
#  'Cheese, cottage, salted, dry curd': 0.4662117660045624,
#  'Fast foods, roast beef sandwich, plain': 0.4661980867385864,
#  'Cornbread muffin, stick, round': 0.46599769592285156,
#  'Bread, gluten-free, white, made with rice flour, corn starch, and/or tapioca': 0.46590179204940796,
#  'Gnocchi, cheese': 0.4657341241836548,
#  'Hamburger, on wheat bun, 1 large patty': 0.4657180905342102,
#  "Cereal or granola bar (Kellogg's Nutri-Grain Cereal Bar)": 0.4656648337841034,
#  'Toaster pastries, brown-sugar-cinnamon': 0.46554678678512573,
#  'Breadsticks, soft, stuffed or topped with melted cheese': 0.46552497148513794,
#  'Bread, gluten-free, white, made with tapioca starch and brown rice flour': 0.46542322635650635,
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Wing, meat and skin with breading': 0.4654195308685303,
#  'Roll, sour dough': 0.46540606021881104,
#  'Chicken fillet sandwich, fried, on white bun; with cheese': 0.46538957953453064,
#  'Cereal, reduced sugar': 0.4653702974319458,
#  'Crackers, melba toast, plain': 0.46535444259643555,
#  'Pillsbury, Buttermilk Biscuits, Artificial Flavor, refrigerated dough': 0.46533799171447754,
#  'Pastry, cookie type, fried': 0.4653186500072479,
#  'Cornbread, made from home recipe': 0.4652201533317566,
#  'Wheat germ, crude': 0.46501240134239197,
#  'Bread, salvadoran sweet cheese (quesadilla salvadorena)': 0.4649471640586853,
#  'Hot dog sandwich, NFS, on white bun': 0.4649468958377838,
#  'Fast Foods, Fried Chicken, Thigh, meat and skin and breading': 0.46493035554885864,
#  'Bread, kneel down (Navajo)': 0.46447962522506714,
#  'Cake or cupcake, gingerbread': 0.4644656181335449,
#  'Tortilla, whole wheat': 0.46415114402770996,
#  'Dessert sauce': 0.4640581011772156,
#  'Babyfood, pretzels': 0.46403998136520386,
#  'Muffin, whole wheat': 0.4639129638671875,
#  'Egg sandwich on biscuit, with bacon and cheese': 0.4638279676437378,
#  'Babyfood, dessert, fruit pudding, orange, strained': 0.4637625515460968,
#  'Meat loaf, NS as to type of meat': 0.4637145698070526,
#  "Cereal or granola bar (Kellogg's Nutri-Grain Yogurt Bar)": 0.4636024236679077,
#  'Hot dog sandwich, meat and poultry, on wheat bun': 0.4636012613773346,
#  'Babyfood, cherry cobbler, junior': 0.46320945024490356,
#  'Bagel, wheat bran': 0.4631580114364624,
#  'Babyfood, tropical fruit medley': 0.4629637897014618,
#  'Cheesecake, chocolate': 0.4629408121109009,
#  'Doughnuts, yeast-leavened, with creme filling': 0.4628598093986511,
#  'Babyfood, dessert, peach cobbler, strained': 0.46282947063446045,
#  'Frozen yogurt sandwich': 0.4626396596431732,
#  'Cheese sauce': 0.4624376595020294,
#  'Babyfood, meat, ham, junior': 0.4623286724090576,
#  'Peanut butter sandwich, with regular peanut butter, on white bread': 0.4622320532798767,
#  'Tortillas, ready-to-bake or -fry, whole wheat': 0.4620695114135742,
#  'Peanut butter sandwich, NFS': 0.46205976605415344,
#  'Babyfood, dessert, banana pudding, strained': 0.46198174357414246,
#  'Muffin, fruit': 0.4618249833583832,
#  'Pizza, with meat, whole wheat thick crust': 0.46136564016342163,
#  'Chicken fillet sandwich, fried, on white bun': 0.4611954689025879,
#  'Cereal, chocolate crispy': 0.46096357703208923,
#  'KFC, Fried Chicken, EXTRA CRISPY, Drumstick, meat and skin with breading': 0.46074432134628296,
#  'Flour, potato': 0.4606260061264038,
#  'Pie, pineapple cream': 0.46048760414123535,
#  'Muffin, wheat bran': 0.46042582392692566,
#  'POPEYES, Fried Chicken, Mild, Drumstick, meat and skin with breading': 0.46034184098243713,
#  'Babyfood, fortified cereal bar, fruit filling': 0.4602036476135254,
#  'Gelato, chocolate': 0.46015244722366333,
#  'Cereal or granola bar, with coconut, chocolate coated': 0.46003034710884094,
#  'Cheese, cottage, dry curd': 0.4599679112434387,
#  'Chiliburger, with or without cheese, on bun': 0.4599379897117615,
#  'Veggie burger, on bun': 0.4598294198513031,
#  'Crackers, melba toast, plain, without salt': 0.4597627818584442,
#  'Bread, white, prepared from recipe, made with nonfat dry milk': 0.4596705734729767,
#  'Meat loaf made with beef and pork': 0.4596444368362427,
#  'Pan Dulce, with raisins and icing': 0.45931559801101685,
#  'Cheese puffs and twists, corn based, baked, low fat': 0.45927169919013977,
#  'Tortilla, flour': 0.45922791957855225,
#  'Cereal, bran flakes, flavored': 0.459226131439209,
#  'Candies, NESTLE, BUTTERFINGER Crisp': 0.45912837982177734,
#  'KFC, Fried Chicken, ORIGINAL RECIPE, Drumstick, meat and skin with breading': 0.4591062068939209,
#  'Candies, KIT KAT Wafer Bar': 0.45909762382507324,
#  'Cream of wheat, regular or quick, made with water, fat added': 0.4590741693973541,
#  'Cheesecake, plain': 0.4589668810367584,
#  'Seeds, breadnut tree seeds, dried': 0.45895910263061523,
#  'Cake, coffeecake, cheese': 0.45895081758499146,
#  'Cereals, QUAKER, Weight Control Instant Oatmeal, banana bread': 0.45890480279922485,
#  'Egg sandwich on bagel, with ham': 0.45889830589294434,
#  'Garlic bread, with melted cheese, from frozen': 0.45871099829673767,
#  'Grapefruit, canned': 0.45862671732902527,
#  'Pizza, cheese, whole wheat thin crust': 0.4585460126399994,
#  'Pumpkin seeds, salted': 0.45854097604751587,
#  'Chicken fillet sandwich, grilled, on wheat bun': 0.4585344195365906,
#  "WENDY'S, Frosty Dairy Dessert": 0.45849519968032837,
#  'Cereal, other, peanut butter': 0.45846498012542725,
#  'Cassava, cooked': 0.45845454931259155,
#  'Cereals, farina, enriched, assorted brands including CREAM OF WHEAT, quick (1-3 minutes), cooked with water, without salt': 0.4583384096622467,
#  'Pizza, cheese, with fruit, thin crust': 0.45829129219055176,
#  'Grilled cheese sandwich, American cheese, on white bread': 0.4582260251045227,
#  'Pickles, cucumber, sweet (includes bread and butter pickles)': 0.4581996202468872,
#  'Cereals, farina, enriched, assorted brands including CREAM OF WHEAT, quick (1-3 minutes), dry': 0.4581666588783264,
#  'Fast foods, submarine sandwich, steak and cheese on white bread with cheese, lettuce and tomato': 0.4581618905067444,
#  'Breakfast link, pattie, or slice, meatless': 0.45810675621032715,
#  'Chili con carne with beans and cheese': 0.45775747299194336,
#  'Fruit butter': 0.4572852849960327,
#  'Cereal or granola bar (KIND Fruit and Nut Bar)': 0.4571934938430786,
#  'Vegetable sandwich wrap': 0.45717543363571167,
#  'Cake, coffeecake, fruit': 0.4568255543708801,
#  'Bagel, wheat, with fruit and nuts': 0.4567757844924927,
#  'Peanut butter and jelly sandwich, with regular peanut butter, regular jelly, on white bread': 0.456257700920105,
#  'Chicken fillet sandwich, fried, from fast food': 0.4562394618988037,
#  'Ice cream sandwich, vanilla': 0.45621928572654724,
#  'Cheese, cottage, with vegetables': 0.4561437964439392,
#  'Crab cake sandwich': 0.45612481236457825,
#  'Cereal, wheat flakes': 0.4560065269470215,
#  'Corned beef sandwich on wheat, with cheese': 0.4559311270713806,
#  'Candies, NESTLE, CHUNKY Bar': 0.4558291733264923,
#  'Vegetable sandwich on white, with cheese': 0.4558197259902954,
#  "McDONALD'S, Egg McMUFFIN": 0.4556734561920166,
#  'Crackers, wheat, sandwich, with peanut butter filling': 0.4555988907814026,
#  'Sloppy joe, no bun': 0.4555945098400116,
#  'Cheese, cottage cheese, with gelatin dessert': 0.45549091696739197,
#  'Ice cream, fried': 0.45546138286590576,
#  'Babyfood, Snack, GERBER, GRADUATES, LIL CRUNCHIES, baked whole grain corn snack': 0.45546114444732666,
#  'Milk and cereal bar': 0.4553380310535431,
#  'Turkey sandwich on wheat, with cheese': 0.45497649908065796,
#  'Egg white sandwich, with meat': 0.45496630668640137,
#  'Pastry, fruit-filled': 0.45495206117630005,
#  'Ham, canned': 0.4549182057380676,
#  'Bread, gluten-free, whole grain, made with tapioca starch and brown rice flour': 0.4548240900039673,
#  'Egg burrito, with ham': 0.4547181725502014,
#  'Fast foods, chicken, breaded and fried, boneless pieces, plain': 0.4546958804130554,
#  'Turkey and ham sandwich on wheat, with cheese': 0.4545873999595642,
#  'Bread, wheat or cracked wheat, reduced calorie and/or high fiber': 0.4545510709285736,
#  'Candies, MARS SNACKFOOD US, SNICKERS CRUNCHER': 0.45426109433174133,
#  'Fast Food, Pizza Chain, 14" pizza, cheese topping, stuffed crust': 0.45422786474227905,
#  'Wheat cereal, chocolate flavored, cooked': 0.454148530960083,
#  'Babyfood, cereal, with egg yolks, junior': 0.4541374146938324,
#  'Squash, summer, casserole, with rice and tomato sauce': 0.4541357457637787,
#  'Sardine sandwich': 0.4541105329990387,
#  'Muffin, fruit, low fat': 0.45409587025642395,
#  'Rye flour, light': 0.4540574550628662,
#  'Gyro sandwich': 0.4540153741836548,
#  'Doughnut, chocolate, with chocolate icing': 0.45384955406188965,
#  'Cereal, multigrain': 0.45366713404655457,
#  'Mozzarella sticks, breaded, baked, or fried': 0.45364290475845337,
#  'Barbecue chicken sandwich, on wheat bun': 0.4536186456680298,
#  'Bulgur, cooked': 0.4533866345882416,
#  'Muffin, pumpkin': 0.45332005620002747,
#  'Bagels, cinnamon-raisin, toasted': 0.4532439708709717,
#  'Cereal or granola bar, reduced sugar, NFS': 0.45303553342819214,
#  'Millet flour': 0.45302775502204895,
#  'Babyfood, dessert, fruit dessert, without ascorbic acid, junior': 0.45302385091781616,
#  'Peanut butter and jelly sandwich, with regular peanut butter, reduced sugar jelly, on white bread': 0.4529796838760376,
#  'Pillsbury Grands, Buttermilk Biscuits, refrigerated dough': 0.4529518187046051,
#  'Pizza, cheese, whole wheat thick crust': 0.452862948179245,
#  'Pizza, with meat other than pepperoni, stuffed crust': 0.45283859968185425,
#  'Fast foods, biscuit, with egg, cheese, and bacon': 0.45272374153137207,
#  'Cereal or granola bar, chocolate coated, NFS': 0.4525335133075714,
#  'Doughnut, cake type, powdered sugar': 0.4524186849594116,
#  'Fruit, chocolate covered': 0.452289342880249,
#  'Fast foods, hamburger; single, regular patty; double decker bun with condiments and special sauce': 0.4522526264190674,
#  'Restaurant, family style, fish fillet, battered or breaded, fried': 0.452178418636322,
#  'Pumpkin, canned, with salt': 0.4521411657333374,
#  'Nutritional powder mix, sugar free (Carnation Instant Breakfast)': 0.4521203935146332,
#  'Doughnut, custard-filled, with icing': 0.45211175084114075,
#  'Topping, fruit': 0.4519982933998108,
#  'Muffin, oatmeal': 0.45199090242385864,
#  'Babyfood, dessert, peach yogurt': 0.4519728124141693,
#  'Rye flour, medium': 0.451679527759552,
#  'Fast Foods, Fried Chicken, Wing, meat and skin and breading': 0.45167747139930725,
#  'Cake, coffeecake, cinnamon with crumb topping, commercially prepared, unenriched': 0.45148998498916626,
#  "McDONALD'S, Sausage McMUFFIN": 0.45143747329711914,
#  'Squash, summer, casserole with tomato and cheese': 0.45140472054481506,
#  'Babyfood, crackers, vegetable': 0.45134198665618896,
#  'Eggplant parmesan casserole, regular': 0.45128488540649414,
#  'Ham, prosciutto': 0.45118072628974915,
#  "HOT POCKETS Ham 'N Cheese Stuffed Sandwich, frozen": 0.4511738717556,
#  'Peanut butter and jelly': 0.45114967226982117,
#  'Cereals, WHEATENA, dry': 0.4511130154132843,
#  'Biscuits, plain or buttermilk, refrigerated dough, lower fat, baked': 0.4510877728462219,
#  'PIZZA HUT, breadstick, parmesan garlic': 0.45105624198913574,
#  'Beef stroganoff': 0.4510546326637268,
#  'SUBWAY, roast beef sub on white bread with lettuce and tomato': 0.45096564292907715,
#  'Tart, breakfast, low fat': 0.45093703269958496,
#  'Cream of wheat, regular or quick, made with water, no added fat': 0.4508378803730011,
#  "Cereal, K's, flavored": 0.4507468044757843,
#  'Muffins, wheat bran, toaster-type with raisins, toasted': 0.4507007300853729,
#  'Fast foods, griddle cake sandwich, sausage': 0.4507002830505371,
#  'Puff pastry, frozen, ready-to-bake, baked': 0.4506475329399109,
#  'SUBWAY, meatball marinara sub on white bread (no toppings)': 0.45025476813316345,
#  "Milk 'n Cereal bar": 0.45014825463294983,
#  'Cereals ready-to-eat, MALT-O-MEAL, BERRY COLOSSAL CRUNCH': 0.45014387369155884,
#  'Chicken fillet sandwich, fried, from fast food, with cheese': 0.44967925548553467,
#  'Babyfood, snack, GERBER, GRADUATES, YOGURT MELTS': 0.4496432840824127,
#  'Fast foods, shrimp, breaded and fried': 0.44963452219963074,
#  'Pizza, cheese, with fruit, thick crust': 0.44961056113243103,
#  'Ice cream sandwich, made with light ice cream, vanilla': 0.449590802192688,
#  'Fast foods, cheeseburger; double, regular patty; double decker bun with condiments and special sauce': 0.4495181441307068,
#  "Candies, confectioner's coating, butterscotch": 0.44936704635620117,
#  'Biscuits, plain or buttermilk, refrigerated dough, higher fat, baked': 0.4493548274040222,
#  'Cake, gingerbread, dry mix': 0.44933420419692993,
#  'Wheat bran': 0.449280321598053,
#  'Potato flour': 0.44924452900886536,
#  'Frozen novelties, KLONDIKE, SLIM-A-BEAR Fudge Bar, 98% fat free, no sugar added': 0.44923877716064453,
#  'Doughnuts, french crullers, glazed': 0.44921019673347473,
#  'Babyfood, dinner, macaroni and cheese, junior': 0.449196457862854,
#  'Egg sandwich on biscuit, with sausage': 0.4491525888442993,
#  'Breakfast bar, NFS': 0.4491506516933441,
#  'Flour, whole wheat, unenriched': 0.4491426348686218,
#  'Waffle, fruit': 0.44914108514785767,
#  'Candies, NESTLE, BUTTERFINGER Bar': 0.4491228759288788,
#  'Babyfood, cereal, mixed, prepared with whole milk': 0.4490654170513153,
#  'Spam sandwich': 0.4490440785884857,
#  'Nutella sandwich on wheat bread': 0.44895246624946594,
#  'Seeds, breadnut tree seeds, raw': 0.44889700412750244,
#  'Corn pone, fried': 0.4488707482814789,
#  "Cereal, O's, flavored": 0.44868791103363037,
#  'Cereal, bran flakes, plain': 0.4486645460128784,
#  'Babyfood, vegetables, corn, creamed, junior': 0.44865256547927856,
#  'Peanut butter and jelly sandwich, frozen commercial product without crusts': 0.4484967589378357,
#  'Pastry, puff': 0.4484444856643677,
#  'LEAN POCKETS, Ham N Cheddar': 0.4483892321586609,
#  'Snack bar, oatmeal': 0.4483889639377594,
#  'Pork sandwich, with cheese': 0.4483562111854553,
#  'Egg sandwich on bagel, with bacon': 0.4481769800186157,
#  'Pizza, cheese, stuffed crust': 0.4479498267173767,
#  'Apricot, canned': 0.44788822531700134,
#  'Mushrooms, for use on a sandwich': 0.4477747082710266,
#  'Pizza, no cheese, thin crust': 0.44776540994644165,
#  'Bologna sandwich on white, with cheese': 0.44770634174346924,
#  'Snacks, NUTRI-GRAIN FRUIT AND NUT BAR': 0.4476853609085083,
#  'Crackers, wheat, sandwich, with cheese filling': 0.44762516021728516,
#  'Crackers, sandwich, reduced fat, peanut butter filled': 0.4475640654563904,
#  'Fast foods, biscuit, with egg and bacon': 0.4474973678588867,
#  'Lasagna, cheese, frozen, unprepared': 0.4474104940891266,
#  'Babyfood, dessert, dutch apple, junior': 0.4470948874950409,
#  'PIZZA HUT 14" Pepperoni Pizza, Pan Crust': 0.4469507932662964,
#  'Muffins, blueberry, toaster-type, toasted': 0.4469476044178009,
#  'Chili con carne, NS as to beans, with cheese': 0.4469197690486908,
#  'Cereal, other, NFS': 0.44655507802963257,
#  'Rolls, hamburger or hot dog, wheat/cracked wheat': 0.4465477168560028,
#  'Ketchup, restaurant': 0.4465031325817108,
#  'Black bean sauce': 0.44649508595466614,
#  'Beans and franks': 0.44642484188079834,
#  'Babyfood, cereal, with eggs, strained': 0.44639208912849426,
#  'Cereal, flavored puffs': 0.44639095664024353,
#  'Peanut flour, low fat': 0.44630271196365356,
#  'Babyfood, GERBER, Banana with orange medley': 0.44616392254829407,
#  'Chili, no beans, canned entree': 0.44615668058395386,
#  'Pancakes, fruit, fast food / restaurant': 0.44613856077194214,
#  'Pork sandwich': 0.4461081922054291,
#  'Babyfood, fruit, pears and pineapple, junior': 0.44610679149627686,
#  'Cheese, cream': 0.44599103927612305,
#  'French toast, school': 0.44598621129989624,
#  'Turkey sticks, breaded, battered, fried': 0.4456877112388611,
#  'Cookie, raisin sandwich, cream-filled': 0.4455881118774414,
#  'Rhubarb, frozen, cooked, with sugar': 0.44558343291282654,
#  'Garlic bread, with parmesan cheese, from fast food / restaurant': 0.44554954767227173,
#  'Babyfood, dessert, custard pudding, vanilla, strained': 0.445392906665802,
#  'Cookie, vanilla sandwich': 0.44538402557373047,
#  'Fast foods, griddle cake sandwich, egg, cheese, and bacon': 0.4453774094581604,
#  'Italian sandwich on white': 0.4452756643295288,
#  'Papaya, canned': 0.44520437717437744,
#  'Flour, pastry, unenriched, unbleached': 0.44515401124954224,
#  'Shrimp toast': 0.4451274871826172,
#  'Wheat bun as ingredient in sandwiches': 0.44511961936950684,
#  'Fast foods, griddle cake sandwich, egg, cheese, and sausage': 0.4450802803039551,
#  'Babyfood, dessert, cherry vanilla pudding, junior': 0.4449828863143921,
#  'Roll, whole wheat, hot dog bun': 0.4446209669113159,
#  'Bagel, with fruit other than raisins': 0.44455042481422424,
#  'Peanut butter, creamy': 0.4445299208164215,
#  "Cottage cheese, farmer's": 0.4445227086544037,
#  'Babyfood, Baby MUM MUM Rice Biscuits': 0.4444810748100281,
#  'Chipotle dip, yogurt based': 0.44445493817329407,
#  "McDONALD'S, BIG MAC (without Big Mac Sauce)": 0.44439196586608887,
#  'Eggnog': 0.44435498118400574,
#  'Babyfood, cereal, mixed, with applesauce and bananas, strained': 0.44428837299346924,
#  'Crunchmaster, Multi-Grain Crisps, Snack Crackers, Gluten-Free': 0.444219172000885,
#  'Cereal or granola bar (Kashi Crunchy)': 0.4442105293273926,
#  'Oil, sheanut': 0.44417691230773926,
#  'Salmon cake sandwich': 0.44415971636772156,
#  'Cereal, corn flakes, flavored': 0.44411879777908325,
#  'Pan Dulce, no topping': 0.4441075026988983,
#  'Formulated bar, MARS SNACKFOOD US, SNICKERS MARATHON Protein Performance Bar, Caramel Nut Rush': 0.44407474994659424,
#  'Cereals ready-to-eat, MALT-O-MEAL, Frosted Flakes': 0.44406425952911377,
#  'Spices, cardamom': 0.4439987540245056,
#  'Cookie, pumpkin': 0.4438819885253906,
#  'Cheeseburger, on wheat bun, 1 small patty': 0.4438077509403229,
#  'Cereals ready-to-eat, MALT-O-MEAL, COLOSSAL CRUNCH': 0.44368210434913635,
#  'Muffin, zucchini': 0.4436549246311188,
#  'Cookie, chocolate chip sandwich': 0.4436366558074951,
#  "WENDY'S, Homestyle Chicken Fillet Sandwich": 0.4435594975948334,
#  'Biscuits, plain or buttermilk, frozen, baked': 0.4435279965400696,
#  'Cookie, chocolate sandwich, reduced fat': 0.4434886872768402,
#  'Babyfood, beverage, GERBER, GRADUATES, FRUIT SPLASHERS': 0.4433571398258209,
#  'Pizza, cheese, with fruit, medium crust': 0.44328492879867554,
#  'Cereals, WHEATENA, cooked with water': 0.44322624802589417,
#  'Pumpkin, canned, without salt': 0.44317173957824707,
#  'Fast foods, onion rings, breaded and fried': 0.4431599974632263,
#  'Spinach and cheese casserole': 0.443115234375,
#  'Biscuits, plain or buttermilk, refrigerated dough, lower fat': 0.4430697560310364,
#  'Pancake syrup': 0.4430622458457947,
#  'Pizza, with pepperoni, from school lunch, medium crust': 0.4430529773235321,
#  'Bologna sandwich on white': 0.4430118501186371,
#  'Bacon, lettuce, tomato sandwich on wheat': 0.44292470812797546,
#  'Hot dog sandwich, meat and poultry, on white bun': 0.4429231286048889,
#  'Babyfood, meat, ham, strained': 0.44288936257362366,
#  'Turkey or chicken burger, on wheat bun': 0.4428257346153259,
#  'Pepperidge Farm, Goldfish, Baked Snack Crackers, Pizza': 0.442817747592926,
#  'Fish, cod, baked or broiled': 0.44275954365730286,
#  'Cereal, granola': 0.4426371455192566,
#  'PIZZA HUT 12" Pepperoni Pizza, Pan Crust': 0.44255927205085754,
#  'Cereal, other, chocolate': 0.4425234794616699,
#  'Corn, creamed': 0.4423920810222626,
#  'Cheese, cottage, creamed, large or small curd': 0.44236889481544495,
#  'Cereal, fruit rings': 0.442335844039917,
#  'Babyfood, cereal, with egg yolks, strained': 0.4423017203807831,
#  'Pizza, with meat other than pepperoni, from school lunch, thin crust': 0.4422042667865753,
#  'Cookies, gluten-free, chocolate sandwich, with creme filling': 0.44214028120040894,
#  'Pizza, no cheese, thick crust': 0.442058265209198,
#  'Cake or cupcake, spice': 0.441958487033844,
#  'Babyfood, dessert, custard pudding, vanilla, junior': 0.4418773651123047,
#  'Pancakes, fruit, frozen': 0.4418576955795288,
#  "Cereal, O's, NFS": 0.4418044090270996,
#  'Pumpkin, canned, cooked': 0.44166818261146545,
#  'Cereal or granola bar (Quaker Chewy Dipps Granola Bar)': 0.4416657090187073,
#  'Cheese steak sandwich or sub on wheat': 0.4416629672050476,
#  "Candies, confectioner's coating, peanut butter": 0.44148722290992737,
#  'Reuben sandwich': 0.44148531556129456,
#  'Salami sandwich on wheat, with cheese': 0.4414745569229126,
#  'Babyfood, meat, beef, junior': 0.4414184093475342,
#  "McDONALD'S, Fruit 'n Yogurt Parfait": 0.4413982331752777,
#  'Turkey sandwich on wheat': 0.44139766693115234,
#  'Cookie, chocolate, sandwich, with extra filling': 0.44136887788772583,
#  "Cereal, K's, plain": 0.44112735986709595,
#  'Roll, wheat or cracked wheat, hot dog bun': 0.4410666227340698,
#  'Salami sandwich on wheat': 0.4409594237804413,
#  'Beef, ground, 90% lean meat / 10% fat, loaf, cooked, baked': 0.44092893600463867,
#  'Babyfood, fruit, tutti frutti, junior': 0.4409206807613373,
#  'Muffin, cheese': 0.4408741593360901,
#  'Egg sandwich on biscuit, with bacon': 0.440865159034729,
#  'Candies, MARS SNACKFOOD US, SNICKERS MUNCH bar': 0.4408487379550934,
#  'Creamy dressing, made with sour cream and/or buttermilk and oil, reduced calorie, fat-free': 0.44081351161003113,
#  'Eggplant dip': 0.44077399373054504,
#  'Cookie, peanut butter': 0.44073760509490967,
#  'Pastry, Italian, with cheese': 0.44068431854248047,
#  'Cookie, marshmallow, with rice cereal, no bake': 0.44056275486946106,
#  'Banana, fried': 0.44056007266044617,
#  'Cream, sour, full fat': 0.4404536485671997,
#  "McDONALD'S, FILET-O-FISH (without tartar sauce)": 0.44044628739356995,
#  'Doughnuts, yeast-leavened, with jelly filling': 0.44043654203414917,
#  'Sweet potato, candied': 0.44038939476013184,
#  'Roll, whole grain white, hamburger bun': 0.4403870105743408,
#  'Beef, ground, 70% lean meat / 30% fat, loaf, cooked, baked': 0.4402586817741394,
#  'Barley flour or meal': 0.44022873044013977,
#  "WENDY'S, Jr. Hamburger, with cheese": 0.44019901752471924,
#  'Fast foods, biscuit, with crispy chicken fillet': 0.4401470422744751,
#  'Cookie, chocolate, made with oatmeal and coconut, no bake': 0.44010022282600403,
#  'Rolls, hamburger or hot dog, whole wheat': 0.4400492310523987,
#  'Baked beans, vegetarian': 0.4397786259651184,
#  'Toaster pastries, fruit (includes apple, blueberry, cherry, strawberry)': 0.43968650698661804,
#  'Hot dog sandwich, turkey, on white bun': 0.4396437704563141,
#  'Babyfood, dinner, macaroni and cheese, strained': 0.4396248459815979,
#  'Biscuits, plain or buttermilk, refrigerated dough, higher fat': 0.4396233856678009,
#  'Hamburger, from school cafeteria': 0.43955403566360474,
#  'Coleslaw, with fruit': 0.43948131799697876,
#  'Mckee Baking, Little Debbie Nutty Bars, Wafers with Peanut Butter, Chocolate Covered': 0.4393913149833679,
#  'Candies, MARS SNACKFOOD US, SNICKERS Bar': 0.43936866521835327,
#  'Hot dog sandwich, reduced fat, on white bun': 0.43935906887054443,
#  'KFC, Fried Chicken, EXTRA CRISPY, Breast, meat only, skin and breading removed': 0.43921929597854614,
#  "McDONALD'S, QUARTER POUNDER with Cheese": 0.43919703364372253,
#  'Wheat, hard red spring': 0.4391442835330963,
#  'Cereal or granola bar with nuts, chocolate coated': 0.43895554542541504,
#  'Sandwich spread, meatless': 0.4388503432273865,
#  'Peanut butter, chunk style, without salt': 0.4387975335121155,
#  'SUBWAY, oven roasted chicken sub on white bread with lettuce and tomato': 0.438784658908844,
#  'Beef, ground, 95% lean meat / 5% fat, loaf, cooked, baked': 0.43877696990966797,
#  'Cereals, WHEATENA, cooked with water, with salt': 0.438728928565979,
#  'Chicken fillet sandwich, grilled, on white bun, with cheese': 0.43866056203842163,
#  'Pizza, cheese and vegetables, whole wheat thin crust': 0.4386219382286072,
#  'Beverage, instant breakfast powder, chocolate, sugar-free, not reconstituted': 0.4386011064052582,
#  'Pineapple, canned, NFS': 0.4384486675262451,
#  'Babyfood, fruit, tutti frutti, strained': 0.43844279646873474,
#  'Snowpea, frozen, cooked, fat added': 0.43838247656822205,
#  'Nuts, acorn flour, full fat': 0.4381854832172394,
#  'Snacks, corn cakes': 0.4381297826766968,
#  'KFC, Fried Chicken, EXTRA CRISPY, Thigh, meat only, skin and breading removed': 0.4380682706832886,
#  'Fast Food, Pizza Chain, 14" pizza, cheese topping, thin crust': 0.4379405379295349,
#  'Pizza, with meat other than pepperoni, from school lunch, thick crust': 0.4377608895301819,
#  'Spices, fenugreek seed': 0.43763649463653564,
#  'Cucumber, for use on a sandwich': 0.43761157989501953,
#  'Mexican pizza': 0.43749773502349854,
#  'Soybean, curd cheese': 0.43746352195739746,
#  'Cheeseburger, on wheat bun, 1 medium patty': 0.4372684359550476,
#  'Candies, MOUNDS Candy Bar': 0.43710947036743164,
#  'Pizza, cheese, from school lunch, thin crust': 0.4370519816875458,
#  'Cereals, MALT-O-MEAL, original, plain, dry': 0.4370332360267639,
#  'Jelly sandwich, NFS': 0.4370321035385132,
#  'Rice and Wheat cereal bar': 0.436847984790802,
#  'Fried broccoli': 0.43678539991378784,
#  'Pimento, canned': 0.43675103783607483,
#  "Cereal, O's, plain": 0.43667900562286377,
#  'Eggplant, cooked, fat added': 0.43665218353271484,
#  'Cheeseburger (McDonalds)': 0.43652135133743286,
#  'Fast Food, Pizza Chain, 14" pizza, pepperoni topping, thin crust': 0.4364944398403168,
#  'Egg sandwich on croissant, with ham': 0.4364676773548126,
#  'Cereal or granola bar, peanuts , oats, sugar, wheat germ': 0.4364592432975769,
#  'Cheeseburger, on wheat bun, 1 large patty': 0.4363735616207123,
#  'Shortening bread, soybean (hydrogenated) and cottonseed': 0.43625369668006897,
#  'Babyfood, dinner, macaroni and tomato and beef, junior': 0.4361737370491028,
#  'Fish, mackerel, baked or broiled': 0.43616151809692383,
#  'Cereals ready-to-eat, MALT-O-MEAL, COCO-ROOS': 0.43614253401756287,
#  'Pizza, cheese, from restaurant or fast food, thin crust': 0.435939759016037,
#  "Dip, FRITO'S, bean, original flavor": 0.435894250869751,
#  'SUBWAY, steak & cheese sub on white bread with American cheese, lettuce and tomato': 0.4358854293823242,
#  'Waffle, fruit, frozen': 0.4358471632003784,
#  'Beef, ground, 97% lean meat / 3% fat, loaf, cooked, baked': 0.43575406074523926,
#  'Cheeseburger, from school cafeteria': 0.4357268214225769,
#  'Garlic bread, with parmesan cheese, from frozen': 0.43569278717041016,
#  'Bread, pound cake type, pan de torta salvadoran': 0.435691237449646,
#  'Cereals ready-to-eat, RALSTON Corn Biscuits': 0.4356810450553894,
#  'Cake, yellow, commercially prepared, with chocolate frosting, in-store bakery': 0.43550920486450195,
#  'Bagels, oat bran': 0.43547523021698,
#  'Babyfood, cereal, mixed, with bananas, dry': 0.4354011118412018,
#  'Waffle, whole grain, fruit, frozen': 0.4353962242603302,
#  'French toast sticks, school': 0.43524932861328125,
#  "Cereals ready-to-eat, POST, Shredded Wheat n' Bran, spoon-size": 0.43519020080566406,
#  'Babyfood, macaroni and cheese, toddler': 0.43513306975364685,
#  'Cake, chocolate, flourless': 0.4351259768009186,
#  'Beef, ground, 80% lean meat / 20% fat, loaf, cooked, baked': 0.4350701570510864,
#  "McDONALD'S, Hotcakes (plain)": 0.4350172281265259,
#  'Dessert topping, powdered': 0.43496203422546387,
#  'Toaster Pastries, fruit, frosted (include apples, blueberry, cherry, strawberry)': 0.43491485714912415,
#  'Babyfood, dinner, mixed vegetable, junior': 0.43487560749053955,
#  'Cereal or granola bar (Quaker Chewy Granola Bar)': 0.4348663091659546,
#  'Bratwurst': 0.43484893441200256,
#  'Muffins, blueberry, toaster-type': 0.43484801054000854,
#  'Veal, leg (top round), separable lean and fat, cooked, pan-fried, not breaded': 0.43473297357559204,
#  'Beef, ground, 75% lean meat / 25% fat, loaf, cooked, baked': 0.43472176790237427,
#  'Cereal or granola bar, fruit and nut': 0.43470287322998047,
#  'Ranch dip, yogurt based': 0.4346839189529419,
#  'Babyfood, fruit, applesauce and pineapple, junior': 0.43465936183929443,
#  'Cake or cupcake, chocolate with white icing, bakery': 0.4346070885658264,
#  'Seeds, sesame seeds, whole, roasted and toasted': 0.434536874294281,
#  'Ham sandwich or sub, with cheese, restaurant': 0.4345182180404663,
#  'Pie shell, chocolate': 0.43439510464668274,
#  'Snowpea, fresh, cooked, fat added': 0.43429455161094666,
#  'Ham sandwich or sub, restaurant': 0.4342697262763977,
#  'Babyfood, Multigrain whole grain cereal, dry fortified': 0.4341563582420349,
#  'Gravy, mushroom, canned': 0.43407076597213745,
#  'Beef, ground, 93% lean meat / 7% fat, loaf, cooked, baked': 0.43406349420547485,
#  'Cereals, MALT-O-MEAL, Farina Hot Wheat Cereal, dry': 0.4338463842868805,
#  'Salmon nuggets, breaded, frozen, heated': 0.4337214231491089,
#  'Dip, bean, original flavor': 0.43366822600364685,
#  'Gelatin dessert': 0.43349432945251465,
#  'Bean chips': 0.43346425890922546,
#  'Quarter Pounder with cheese (McDonalds)': 0.43338543176651,
#  'Tennis Bread, plain (Apache)': 0.4332769513130188,
#  'Manicotti, vegetable- and cheese-filled, with tomato sauce, meatless': 0.43326109647750854,
#  'Cookie, butterscotch, brownie': 0.4331144392490387,
#  'Cookies, peanut butter, refrigerated dough, baked': 0.43311282992362976,
#  'Gelatin dessert, sugar free, with fruit': 0.43307313323020935,
#  'Sour cream, fat free': 0.43306687474250793,
#  'Peanut butter, chunk style, with salt': 0.43305325508117676,
#  'Babyfood, vegetable, butternut squash and corn': 0.43304330110549927,
#  'Cake or cupcake, chocolate with chocolate icing, bakery': 0.43300488591194153,
#  'Roll, rye': 0.43300455808639526,
#  'Rolls, dinner, rye': 0.4329751431941986,
#  'Frostings, coconut-nut, ready-to-eat': 0.4329500198364258,
#  ...}

# %%
import openai

openai.api_key_path = "../foodvision/utils/openai_api_key.txt"

def chat_complete(prompt: str, **openai_kwargs) -> str:
    """Generate completion from OpenAI ChatGPT API"""
    default_kwargs = {"model": "gpt-3.5-turbo", "max_tokens": 256, "temperature": 0.2, "top_p": 1}
    openai_kwargs = {**default_kwargs, **openai_kwargs}
    response = openai.ChatCompletion.create(
        **openai_kwargs,
        messages=[
                {"role": "system", "content": "You are a helpful assistant who is very good at designing apps and making them look good."},
                {"role": "user", "content": prompt},
            ]
        )
    return response

base_prompt_for_sorting_food_names = """You are a food scientist and nutritionist very knowledgable on all different kinds of foods.\n
Given the following list of foods and the target text, please sort the list of foods into which ones relate most to the target text.\n
For example, the list ['apples, red delicious, with skin, raw',
 'apples, gala, with skin, raw',
 'apples, honeycrisp, with skin, raw',
 'apples, granny smith, with skin, raw',
 'applesauce, unsweetened, with added vitamin c',
 ...]
and the target text 'apple_red' would be sorted as a JSON dictionary,
 '1': 'apples, red delicious, with skin, raw', 
 '2': 'apples, gala, with skin, raw', 
 '3': 'apples, honeycrisp, with skin, raw', 
 '4': 'apples, granny smith, with skin, raw', 
 '5': 'applesauce, unsweetened, with added vitamin c', 
 ....\n
Please do not include any extra foods or text, only return the list of foods in the target food list.\n
Put a favour on similar types of foods, e.g. if the target text contains "capsicum_green" then "pepper, red" should be higher than "cabbage, green".\n
If the target list of foods to sort has N items, you should return a list of N items.\n
For example, if the target list of foods to sort has 10 items, you should return a list of 10 items.\n
Target text: {target_text}\n
List of foods to sort: {target_food_list}\n
Sorted list of food as properly formatted JSON dictionary:\n
"""

def sort_list_of_foods(base_prompt: str, target_text: str, target_food_list: list) -> list:
    # print(base_prompt)
    target_text_dict = {"target_text": target_text, "target_food_list": target_food_list}
    target_text_prompt = base_prompt.format(**target_text_dict)
    # target_text_prompt = base_prompt.format(target_text, target_food_list)
    # print(target_text_prompt)
    answer = chat_complete(target_text_prompt)
    answer_formatted = str(answer.choices[0].message.content)
    # Remove "\n"
    # print(f"Display name generated: {target_text} -> {answer_formatted}")
    return answer_formatted

# target_text = "capsicum_red"
target_text = random.choice(food_item_without_fdcid)
print(f"Predicting the most similar class names to: {target_text}")

most_similar_class_names = find_most_similar_class_name(target_text, class_name_embedding_dict_unique_descriptions)

# Get the top 10 most similar class names
target_food_list = list(most_similar_class_names.keys())[:10]
print(len(target_food_list))

# Turn target_food_list into a dictionary with keys in order of 1, 2, 3...
target_food_list = {i+1: food_name for i, food_name in enumerate(target_food_list)}
print(target_food_list)
# print(target_food_list)

sorted_list_of_foods = sort_list_of_foods(base_prompt=base_prompt_for_sorting_food_names, target_text=target_text, target_food_list=target_food_list)
sorted_list_of_foods
# Out:
# Predicting the most similar class names to: melon_spanish
# 10
# {1: 'Melon, banana (Navajo)', 2: 'Honeydew melon, raw', 3: 'Melons, honeydew, raw', 4: 'Winter melon, cooked', 5: 'Melons, casaba, raw', 6: 'Bitter melon, cooked', 7: 'Melons, cantaloupe, raw', 8: 'Horned melon (Kiwano)', 9: 'Waxgourd, (chinese preserving melon), raw', 10: 'Waxgourd, (chinese preserving melon), cooked, boiled, drained, with salt'}
# '{\n    "1": "Melons, honeydew, raw",\n    "2": "Honeydew melon, raw",\n    "3": "Melons, cantaloupe, raw",\n    "4": "Melons, casaba, raw",\n    "5": "Horned melon (Kiwano)",\n    "6": "Waxgourd, (chinese preserving melon), raw",\n    "7": "Waxgourd, (chinese preserving melon), cooked, boiled, drained, with salt",\n    "8": "Winter melon, cooked",\n    "9": "Bitter melon, cooked",\n    "10": "Melon, banana (Navajo)"\n}'

# %%
import json
sorted_list_of_foods = json.loads(sorted_list_of_foods)
sorted_list_of_foods
# Out:
# {'1': 'peppers, bell, red, raw',
#  '2': 'cabbage, red, raw',
#  '3': 'cherries, sweet, dark red, raw',
#  '4': 'lettuce, leaf, red, raw',
#  '5': 'onions, red, raw',
#  '6': 'peppers, bell, orange, raw',
#  '7': 'peppers, bell, yellow, raw',
#  '8': 'peppers, bell, green, raw',
#  '9': 'mustard, prepared, yellow',
#  '10': 'beans, dry, medium red (0% moisture)'}

# %%
unique_categories = food["food_category_id"].unique()
len(unique_categories)
# Out:
# 19

# %% [markdown]
# 19 different food categories... I wonder what these are?

# %%
food["food_category_id"].value_counts()
# Out:
# 11.0    10819
# 1.0      9057
# 9.0      8558
# 16.0     4575
# 4.0      2892
# 14.0     2889
# 12.0     2769
# 20.0     1949
# 5.0      1503
# 15.0      913
# 7.0       795
# 10.0      613
# 6.0       568
# 18.0      488
# 25.0      474
# 13.0      454
# 2.0       386
# 19.0       54
# Name: food_category_id, dtype: int64

# %%
# Get food categories
food_cats = pd.read_csv("data/2022/FoodData_Central_Supporting_Data_csv_2022-10-28/food_category.csv")
food_cats
# Out:
#     id  code                          description
# 0    1   100               Dairy and Egg Products
# 1    2   200                     Spices and Herbs
# 2    3   300                           Baby Foods
# 3    4   400                        Fats and Oils
# 4    5   500                     Poultry Products
# 5    6   600           Soups, Sauces, and Gravies
# 6    7   700          Sausages and Luncheon Meats
# 7    8   800                    Breakfast Cereals
# 8    9   900              Fruits and Fruit Juices
# 9   10  1000                        Pork Products
# 10  11  1100    Vegetables and Vegetable Products
# 11  12  1200                Nut and Seed Products
# 12  13  1300                        Beef Products
# 13  14  1400                            Beverages
# 14  15  1500       Finfish and Shellfish Products
# 15  16  1600          Legumes and Legume Products
# 16  17  1700        Lamb, Veal, and Game Products
# 17  18  1800                       Baked Products
# 18  19  1900                               Sweets
# 19  20  2000              Cereal Grains and Pasta
# 20  21  2100                           Fast Foods
# 21  22  2200      Meals, Entrees, and Side Dishes
# 22  23  2500                               Snacks
# 23  24  3500  American Indian/Alaska Native Foods
# 24  25  3600                     Restaurant Foods
# 25  26  4500       Branded Food Products Database
# 26  27  2600            Quality Control Materials
# 27  28  1410                  Alcoholic Beverages

# %% [markdown]
# ## 10 foods we want
#
# To keep things simple, we will reduce the databases from FoodData Central to 10 different foods.
#
# Why these foods?
#
# Because we have images for those foods ready to go.
#
# ```python
# # These aren't whole foods so we don't want them yet, let's get another list and get those
# ten_foods = ["chicken_curry",
# "chicken_wings",
# "fried_rice",
# "grilled_salmon",
# "humburger",
# "ice_cream",
# "pizza",
# "ramen",
# "steak",
# "sushi"]
#
# # We want these... (they're whole foods)
# ten_whole_foods = ["chicken_wings",
#     "apple",
#     "banana",
#     "beef", # steak, etc
#     "carrots",
#     "egg", # whole egg
#     "strawberries",
#     "blueberries",
#     "mushrooms",
#     "honey"
# ]
# ```

# %%
ten_whole_foods = ['apple',
 'banana',
 'beef', # steak etc
 'blueberries',
 'carrots',
 'chicken_wings',
 'egg', # whole egg
 'honey',
 'mushrooms',
 'strawberries']
ten_whole_foods
# Out:
# ['apple',
#  'banana',
#  'beef',
#  'blueberries',
#  'carrots',
#  'chicken_wings',
#  'egg',
#  'honey',
#  'mushrooms',
#  'strawberries']

# %%
food.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/daniel/code/nutrify/data_exploration/usda_food_data_exploration.ipynb Cell 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22544954414e2d525458227d/home/daniel/code/nutrify/data_exploration/usda_food_data_exploration.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> food.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
food.data_type.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/daniel/code/nutrify/data_exploration/usda_food_data_exploration.ipynb Cell 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22544954414e2d525458227d/home/daniel/code/nutrify/data_exploration/usda_food_data_exploration.ipynb#Y121sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> food.data_type.value_counts()
#
# AttributeError: 'str' object has no attribute 'data_type'

# %%
# Foundation food is the ground truth for a certain type of food, excludes some details about the food
# E.g. the data_type foundation_food for Chicken will the the original unique ID for chicken
foundation_food = food[(food["data_type"] == "foundation_food") | (food["data_type"] == "survey_fndds_food")]
len(foundation_food)
# Out:
# 5905

# %%
# Out:
# survey_fndds_food    5624
# foundation_food       281
# Name: data_type, dtype: int64

# %%
foundation_food[foundation_food["description"].str.contains("blue")]
# Out:
#         fdc_id          data_type  \
# 42186  2263889    foundation_food
# 43441  2346411    foundation_food
# 348    2341108  survey_fndds_food
# 2720   2343480  survey_fndds_food
# 3933   2344693  survey_fndds_food
# 4009   2344769  survey_fndds_food
# 4011   2344771  survey_fndds_food
# 4012   2344772  survey_fndds_food
# 4057   2344817  survey_fndds_food
# 4994   2345754  survey_fndds_food
# 5013   2345773  survey_fndds_food
# 5028   2345788  survey_fndds_food
# 5075   2345835  survey_fndds_food
#
#                                        description  food_category_id  \
# 42186                             blueberries, raw               9.0
# 43441                             blueberries, raw               9.0
# 348                      cheese, blue or roquefort               NaN
# 2720                                pie, blueberry               NaN
# 3933                            blueberries, dried               NaN
# 4009                              blueberries, raw               NaN
# 4011                           blueberries, frozen               NaN
# 4012                         blueberry pie filling               NaN
# 4057                               blueberry juice               NaN
# 4994             blue or roquefort cheese dressing               NaN
# 5013      blue or roquefort cheese dressing, light               NaN
# 5028   blue or roquefort cheese dressing, fat free               NaN
# 5075                               blueberry syrup               NaN
#
#       publication_date
# 42186       2022-04-28
# 43441       2022-10-28
# 348         2022-10-28
# 2720        2022-10-28
# 3933        2022-10-28
# 4009        2022-10-28
# 4011        2022-10-28
# 4012        2022-10-28
# 4057        2022-10-28
# 4994        2022-10-28
# 5013        2022-10-28
# 5028        2022-10-28
# 5075        2022-10-28

# %%
foundation_foods = foundation_food["description"]
foundation_foods.iloc[20:40]
# Out:
# 4153               peanut butter, smooth style, with salt
# 4329                             cheese, parmesan, grated
# 4491    cheese, pasteurized process, american, vitamin...
# 4580    grapefruit juice, white, canned or bottled, un...
# 4723                                 peaches, yellow, raw
# 4817    seeds, sunflower seed kernels, dry roasted, wi...
# 4951      sausage, italian, pork, mild, cooked, pan-fried
# 5164                  bread, white, commercially prepared
# 5285          sausage, turkey, breakfast links, mild, raw
# 5428                                        cheese, swiss
# 5489    kale, frozen, cooked, boiled, drained, without...
# 5751    carrots, frozen, unprepared (includes foods fo...
# 5991                            mustard, prepared, yellow
# 6198                                figs, dried, uncooked
# 6339                                kiwifruit, green, raw
# 6491                              melons, cantaloupe, raw
# 6650                                      nectarines, raw
# 6794    oranges, raw, navels (includes foods for usda'...
# 6992                                    strawberries, raw
# 7216                         lettuce, cos or romaine, raw
# Name: description, dtype: object

# %%
# Found a list of the foundation foods we're going to start with!
foundation_foods_list = list(foundation_foods)
for food in foundation_foods_list:
    if "blue" in food:
        print(food)
# Out:
# blueberries, raw
# blueberries, raw
# cheese, blue or roquefort
# pie, blueberry
# blueberries, dried
# blueberries, raw
# blueberries, frozen
# blueberry pie filling
# blueberry juice
# blue or roquefort cheese dressing
# blue or roquefort cheese dressing, light
# blue or roquefort cheese dressing, fat free
# blueberry syrup

# %%
# food.loc[(food["description"].str.contains("chicken", case=False)) & (food["description"].str.contains("drumstick", case=False))][-10:]
# Find chicken in foundation food
for food in foundation_foods:
    if "chicken" in food.lower():
        print(food)
# Out:
# chicken, broilers or fryers, drumstick, meat only, cooked, braised
# chicken, broiler or fryers, breast, skinless, boneless, meat only, cooked, braised
# mock chicken legs
# chicken, ns as to part and cooking method, ns as to skin eaten
# chicken, ns as to part and cooking method, skin eaten
# chicken, ns as to part and cooking method, skin not eaten
# chicken, ns as to part, baked, broiled, or roasted, ns as to skin eaten
# chicken, ns as to part, baked, broiled, or roasted, skin eaten
# chicken, ns as to part, baked, broiled, or roasted, skin not eaten
# chicken, ns as to part, rotisserie, ns as to skin eaten
# chicken, ns as to part, rotisserie, skin eaten
# chicken, ns as to part, rotisserie, skin not eaten
# chicken, ns as to part, stewed, ns as to skin eaten
# chicken, ns as to part, stewed, skin eaten
# chicken, ns as to part, stewed, skin not eaten
# chicken, ns as to part, grilled without sauce, ns as to skin eaten
# chicken, ns as to part, grilled without sauce, skin eaten
# chicken, ns as to part, grilled without sauce, skin not eaten
# chicken, ns as to part, grilled with sauce, ns as to skin eaten
# chicken, ns as to part, grilled with sauce, skin eaten
# chicken, ns as to part, grilled with sauce, skin not eaten
# chicken, ns as to part, sauteed, skin eaten
# chicken, ns as to part, sauteed, skin not eaten
# chicken, ns as to part, fried, coated, skin / coating eaten
# chicken, ns as to part, fried, coated, skin / coating not eaten
# chicken, ns as to part, baked, coated, skin / coating eaten
# chicken, ns as to part, baked, coated, skin / coating not eaten
# chicken breast, ns as to cooking method, skin eaten
# chicken breast, ns as to cooking method, skin not eaten
# chicken breast, baked, broiled, or roasted, skin eaten, from raw
# chicken breast, baked, broiled, or roasted, skin not eaten, from raw
# chicken breast, baked or broiled, skin eaten, from pre-cooked
# chicken breast, baked or broiled, skin not eaten, from pre-cooked
# chicken breast, baked or broiled, skin eaten, from fast food / restaurant
# chicken breast, baked or broiled, skin not eaten, from fast food / restaurant
# chicken breast, baked, broiled, or roasted with marinade, skin eaten, from raw
# chicken breast, baked, broiled, or roasted with marinade, skin not eaten, from raw
# chicken breast, rotisserie, skin eaten
# chicken breast, rotisserie, skin not eaten
# chicken breast, stewed, skin eaten
# chicken breast, stewed, skin not eaten
# chicken breast, grilled without sauce, skin eaten
# chicken breast, grilled without sauce, skin not eaten
# chicken breast, grilled with sauce, skin eaten
# chicken breast, grilled with sauce, skin not eaten
# chicken breast, sauteed, skin eaten
# chicken breast, sauteed, skin not eaten
# chicken breast, fried, coated, skin / coating eaten, from raw
# chicken breast, fried, coated, skin / coating not eaten, from raw
# chicken breast, fried, coated, prepared skinless, coating eaten, from raw
# chicken breast, fried, coated, skin / coating eaten, from pre-cooked
# chicken breast, fried, coated, skin / coating not eaten, from pre-cooked
# chicken breast, fried, coated, skin / coating eaten, from fast food / restaurant
# chicken breast, fried, coated, skin / coating not eaten, from fast food / restaurant
# chicken breast, baked, coated, skin / coating eaten
# chicken breast, baked, coated, skin / coating not eaten
# chicken leg, drumstick and thigh, ns as to cooking method, skin eaten
# chicken leg, drumstick and thigh, ns as to cooking method, skin not eaten
# chicken leg, drumstick and thigh, baked or broiled, skin eaten
# chicken leg, drumstick and thigh, baked or broiled, skin not eaten
# chicken leg, drumstick and thigh, rotisserie, skin eaten
# chicken leg, drumstick and thigh, rotisserie, skin not eaten
# chicken leg, drumstick and thigh, stewed, skin eaten
# chicken leg, drumstick and thigh, stewed, skin not eaten
# chicken leg, drumstick and thigh, grilled without sauce, skin eaten
# chicken leg, drumstick and thigh, grilled without sauce, skin not eaten
# chicken leg, drumstick and thigh, grilled with sauce, skin eaten
# chicken leg, drumstick and thigh, grilled with sauce, skin not eaten
# chicken leg, drumstick and thigh, sauteed, skin eaten
# chicken leg, drumstick and thigh, sauteed, skin not eaten
# chicken leg, drumstick and thigh, fried, coated, skin / coating eaten
# chicken leg, drumstick and thigh, fried, coated, skin / coating not eaten
# chicken leg, drumstick and thigh, baked, coated, skin / coating eaten
# chicken leg, drumstick and thigh, baked, coated, skin / coating not eaten
# chicken drumstick, ns as to cooking method, skin eaten
# chicken drumstick, ns as to cooking method, skin not eaten
# chicken drumstick, baked, broiled, or roasted, skin eaten, from raw
# chicken drumstick, baked, broiled, or roasted, skin not eaten, from raw
# chicken drumstick, baked or broiled, skin eaten, from pre-cooked
# chicken drumstick, baked or broiled, skin not eaten, from pre-cooked
# chicken drumstick, baked or broiled, skin eaten, from fast food / restaurant
# chicken drumstick, baked or broiled, skin not eaten, from fast food / restaurant
# chicken drumstick, rotisserie, skin eaten
# chicken drumstick, rotisserie, skin not eaten
# chicken drumstick, grilled without sauce, skin eaten
# chicken drumstick, grilled without sauce, skin not eaten
# chicken drumstick, grilled with sauce, skin eaten
# chicken drumstick, grilled with sauce, skin not eaten
# chicken drumstick, stewed, skin eaten
# chicken drumstick, stewed, skin not eaten
# chicken drumstick, sauteed, skin eaten
# chicken drumstick, sauteed, skin not eaten
# chicken drumstick, fried, coated, skin / coating eaten, from raw
# chicken drumstick, fried, coated, skin / coating not eaten, from raw
# chicken drumstick, fried, coated, prepared skinless, coating eaten, from raw
# chicken drumstick, fried, coated, skin / coating eaten, from pre-cooked
# chicken drumstick, fried, coated, skin / coating not eaten, from pre-cooked
# chicken drumstick, fried, coated, skin / coating eaten, from fast food / restaurant
# chicken drumstick, fried, coated, skin / coating not eaten, from fast food / restaurant
# chicken drumstick, baked, coated, skin / coating eaten
# chicken drumstick, baked, coated, skin / coating not eaten
# chicken thigh, ns as to cooking method, skin eaten
# chicken thigh, ns as to cooking method, skin not eaten
# chicken thigh, baked, broiled, or roasted, skin eaten, from raw
# chicken thigh, baked, broiled, or roasted, skin not eaten, from raw
# chicken thigh, baked or broiled, skin eaten, from pre-cooked
# chicken thigh, baked or broiled, skin not eaten, from pre-cooked
# chicken thigh, baked or broiled, skin eaten, from fast food / restaurant
# chicken thigh, baked or broiled, skin not eaten, from fast food / restaurant
# chicken thigh, rotisserie, skin eaten
# chicken thigh, rotisserie, skin not eaten
# chicken thigh, stewed, skin eaten
# chicken thigh, stewed, skin not eaten
# chicken thigh, grilled without sauce, skin eaten
# chicken thigh, grilled without sauce, skin not eaten
# chicken thigh, grilled with sauce, skin eaten
# chicken thigh, grilled with sauce, skin not eaten
# chicken thigh, sauteed, skin eaten
# chicken thigh, sauteed, skin not eaten
# chicken thigh, fried, coated, skin / coating eaten, from raw
# chicken thigh, fried, coated, skin / coating not eaten, from raw
# chicken thigh, fried, coated, prepared skinless, coating eaten, from raw
# chicken thigh, fried, coated, skin / coating eaten, from pre-cooked
# chicken thigh, fried, coated, skin / coating not eaten, from pre-cooked
# chicken thigh, fried, coated, skin / coating eaten, from fast food
# chicken thigh, fried, coated, skin / coating not eaten, from fast food
# chicken thigh, fried, coated, skin / coating eaten, from restaurant
# chicken thigh, fried, coated, skin / coating not eaten, from restaurant
# chicken thigh, baked, coated, skin / coating eaten
# chicken thigh, baked, coated, skin / coating not eaten
# chicken wing, ns as to cooking method
# chicken wing, baked, broiled, or roasted, from raw
# chicken wing, baked or broiled, from pre-cooked
# chicken wing, baked or broiled, from fast food / restaurant
# chicken wing, rotisserie
# chicken wing, stewed
# chicken wing, grilled without sauce
# chicken wing, grilled with sauce
# chicken wing, sauteed
# chicken wing, fried, coated, from raw
# chicken wing, fried, coated, from pre-cooked
# chicken wing, fried, coated, from fast food
# chicken wing, fried, coated, from restaurant
# chicken wing, baked, coated
# chicken "wings" with hot sauce, from fast food / restaurant
# chicken "wings" with other sauces or seasoning, from fast food / restaurant
# chicken "wings", plain, from fast food / restaurant
# chicken "wings" with hot sauce, from precooked
# chicken "wings" with other sauces or seasoning, from precooked
# chicken "wings", plain, from precooked
# chicken "wings" with hot sauce, from other sources
# chicken "wings" with other sauces or seasoning, from other sources
# chicken "wings", plain, from other sources
# chicken "wings", boneless, with hot sauce, from fast food / restaurant
# chicken "wings", boneless, with hot sauce, from other sources
# chicken, back
# chicken, neck or ribs
# chicken, tail
# chicken skin
# chicken feet
# chicken, canned, meat only
# chicken, chicken roll, roasted
# chicken patty, breaded
# chicken fillet, breaded
# chicken fillet, grilled
# chicken, ground
# chicken nuggets, nfs
# chicken nuggets, from fast food
# chicken nuggets, from restaurant
# chicken nuggets, from school lunch
# chicken nuggets, from frozen
# chicken nuggets, from other sources
# chicken tenders or strips, nfs
# chicken tenders or strips, breaded, from fast food
# chicken tenders or strips, breaded, from restaurant
# chicken tenders or strips, breaded, from school lunch
# chicken tenders or strips, breaded, from frozen
# chicken tenders or strips, breaded, from other sources
# fried chicken chunks, puerto rican style
# baby toddler chicken
# liver, chicken
# turkey or chicken and beef sausage
# turkey or chicken sausage
# turkey or chicken sausage, reduced sodium
# turkey or chicken sausage, reduced fat
# turkey or chicken and pork sausage
# turkey or chicken, pork, and beef sausage, reduced sodium
# chicken, prepackaged or deli, luncheon meat
# chicken, prepackaged or deli, luncheon meat, reduced sodium
# chicken salad spread
# chicken or turkey cacciatore
# stewed chicken with tomato-based sauce, mexican style
# chili con carne with chicken or turkey and beans
# chicken with gravy
# chicken or turkey fricassee
# chicken or turkey with cream sauce
# chicken or turkey with mushroom sauce
# chicken or turkey with teriyaki
# barbecue chicken
# sweet and sour chicken or turkey
# sweet and sour chicken or turkey, without vegetables
# chicken curry
# chicken curry with rice
# chicken with mole sauce
# chicken or turkey with cheese sauce
# chicken or turkey cordon bleu
# chicken or turkey parmigiana
# orange chicken
# sesame chicken
# chicken kiev
# stuffed chicken, drumstick or breast, puerto rican style
# chicken or turkey hash
# chicken or turkey and potatoes with gravy
# chicken or turkey and noodles, no sauce
# chicken or turkey and noodles with gravy
# chicken or turkey and noodles with mushroom sauce
# chicken or turkey and noodles with cream or white sauce
# chicken or turkey and noodles with cheese sauce
# chicken or turkey tetrazzini
# chicken or turkey and noodles with tomato-based sauce
# chicken or turkey and noodles with soy-based sauce
# chicken or turkey and rice, no sauce
# biryani with chicken
# chicken or turkey and rice with cream sauce
# chicken or turkey and rice with mushroom sauce
# chicken or turkey and rice with tomato-based sauce
# chicken or turkey and rice with soy-based sauce
# chicken or turkey with dumplings
# chicken or turkey with stuffing
# chicken or turkey cake, patty, or croquette
# chicken or turkey souffle
# meat loaf made with chicken or turkey
# meat loaf made with chicken or turkey, with tomato-based sauce
# chicken or turkey, potatoes, corn, and cheese, with gravy
# chicken or turkey, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; no sauce
# chicken or turkey, potatoes, and vegetables excluding carrots, broccoli, and dark-green leafy; no sauce
# chicken or turkey, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; gravy
# chicken or turkey, potatoes, and vegetables excluding carrots, broccoli, and dark-green leafy; gravy
# chicken or turkey, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; cream sauce, white sauce, or mushroom sauce
# chicken or turkey, potatoes, and vegetables excluding carrots, broccoli, and dark-green leafy; cream sauce, white sauce, or mushroom sauce
# chicken or turkey, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; cheese sauce
# chicken or turkey, potatoes, and vegetables excluding carrots, broccoli, and dark-green leafy; cheese sauce
# chicken or turkey, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; tomato-based sauce
# chicken or turkey, potatoes, and vegetables excluding carrots, broccoli, and dark-green leafy; tomato-based sauce
# chicken or turkey stew with potatoes and vegetables including carrots, broccoli, and/or dark-green leafy; gravy
# chicken or turkey stew with potatoes and vegetables excluding carrots, broccoli, and dark-green leafy; tomato- based sauce
# chicken or turkey, noodles, and vegetables including carrots, broccoli, and/or dark-green leafy; no sauce
# chicken or turkey, noodles, and vegetables excluding carrots, broccoli, and dark-green leafy; no sauce
# chicken or turkey, noodles, and vegetables including carrots, broccoli, and/or dark-green leafy; gravy
# chicken or turkey, noodles, and vegetables excluding carrots, broccoli, and dark-green leafy; gravy
# chicken or turkey, noodles, and vegetables including carrots, broccoli, and/or dark-green leafy; cream sauce, white sauce, or mushroom sauce
# chicken or turkey, noodles, and vegetables excluding carrots, broccoli, and/or dark-green leafy; cream sauce, white sauce, or mushroom sauce
# chicken or turkey, noodles, and vegetables including carrots, broccoli, and/or dark-green leafy; tomato-based sauce
# chicken or turkey, noodles, and vegetables excluding carrots, broccoli, and dark-green leafy; tomato-based sauce
# chicken or turkey chow mein or chop suey with noodles
# chicken or turkey, noodles, and vegetables including carrots, broccoli, and/or dark-green leafy; cheese sauce
# chicken or turkey, noodles, and vegetables excluding carrots, broccoli, and dark-green leafy; cheese sauce
# chicken or turkey, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; no sauce
# chicken or turkey, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; no sauce
# chicken or turkey, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; gravy
# chicken or turkey, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; gravy
# chicken or turkey, rice, corn, and cheese, with gravy
# chicken or turkey, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; soy-based sauce
# chicken or turkey, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; soy-based sauce
# chicken or turkey, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; cream sauce, white sauce, or mushroom sauce
# chicken or turkey, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; cream sauce, white sauce, or mushroom sauce
# chicken or turkey, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; cheese sauce
# chicken or turkey, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; cheese sauce
# chicken or turkey, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; tomato-based sauce
# chicken or turkey, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; tomato-based sauce
# pot pie, chicken
# chicken or turkey, stuffing, and vegetables including carrots, broccoli, and/or dark-green leafy; no sauce
# chicken or turkey,stuffing, and vegetables excluding carrots, broccoli, and dark green leafy; no sauce
# chicken or turkey, stuffing, and vegetables including carrots, broccoli, and/or dark-green leafy; gravy
# chicken or turkey, stuffing, and vegetables excluding carrots, broccoli, and dark-green leafy; gravy
# chicken or turkey, dumplings, and vegetables including carrots, broccoli, and/or dark green leafy; gravy
# chicken or turkey, dumplings, and vegetables excluding carrots, broccoli, and dark green leafy; gravy
# chicken fricassee, puerto rican style
# chicken or turkey and vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, no sauce
# chicken or turkey and vegetables excluding carrots, broccoli, and dark-green leafy; no potatoes, no sauce
# chicken or turkey shish kabob with vegetables, excluding potatoes
# chicken or turkey creole, without rice
# chicken or turkey and vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, gravy
# chicken or turkey and vegetables excluding carrots, broccoli, and dark-green leafy; no potatoes, gravy
# chicken or turkey a la king with vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, cream, white, or soup-based sauce
# chicken or turkey a la king with vegetables excluding carrorts, broccoli, and dark-green leafy; no potatoes, cream, white, or soup-based sauce
# chicken or turkey divan
# chicken or turkey and vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, soy-based sauce
# chicken or turkey and vegetables excluding carrots, broccoli, and dark-green leafy; no potatoes, soy-based sauce
# chicken or turkey and vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, tomato-based sauce
# chicken or turkey and vegetables excluding carrots, broccoli, and dark-green leafy; no potatoes, tomato-based sauce
# general tso chicken
# kung pao chicken
# almond chicken
# chicken or turkey chow mein or chop suey, no noodles
# chicken or turkey salad, made with mayonnaise
# chicken or turkey salad with nuts and/or fruits
# chicken or turkey salad with egg
# chicken or turkey salad, made with light mayonnaise
# chicken or turkey salad, made with mayonnaise-type salad dressing
# chicken or turkey salad, made with light mayonnaise-type salad dressing
# chicken or turkey salad, made with creamy dressing
# chicken or turkey salad, made with light creamy dressing
# chicken or turkey salad, made with italian dressing
# chicken or turkey salad, made with light italian dressing
# chicken or turkey salad, made with any type of fat free dressing
# chicken or turkey garden salad, chicken and/or turkey, tomato and/or carrots, other vegetables, no dressing
# chicken or turkey garden salad, chicken and/or turkey, other vegetables excluding tomato and carrots, no dressing
# chicken or turkey garden salad with bacon and cheese, chicken and/or turkey, bacon, cheese, lettuce and/or greens, tomato and/or carrots, other vegetables, no dressing
# chicken or turkey, breaded, fried, garden salad with bacon and cheese, chicken and/or turkey, bacon, cheese, lettuce and/or greens, tomato and/or carrots, other vegetables, no dressing
# chicken or turkey garden salad with cheese, chicken and/or turkey, cheese, lettuce and/or greens, tomato and/or carrots, other vegetables, no dressing
# chicken or turkey, breaded, fried, garden salad with cheese, chicken and/or turkey, cheese, lettuce and/or greens, tomato and/or carrots, other vegetables, no dressing
# asian chicken or turkey garden salad, chicken and/or turkey, lettuce, fruit, nuts, no dressing
# asian chicken or turkey garden salad with crispy noodles, chicken and/or turkey, lettuce, fruit, nuts, crispy noodles, no dressing
# chicken or turkey caesar garden salad, chicken and/or turkey, lettuce, tomato, cheese, no dressing
# chicken or turkey, breaded, fried, caesar garden salad, chicken and/or turkey, lettuce, tomatoes, cheese, no dressing
# chicken or turkey and vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, cheese sauce
# chicken or turkey and vegetables excluding carrots, broccoli, and dark-green leafy; no potatoes, cheese sauce
# chicken or turkey fricassee, with sauce, no potatoes, potatoes reported separately, puerto rican style
# chicken or turkey fricassee, no sauce, no potatoes, puerto rican style
# livers, chicken, chopped, with eggs and onion
# chicken deli sandwich or sub, restaurant
# chicken deli sandwich or sub, with cheese, restaurant
# chicken salad sandwich on white
# chicken salad sandwich on wheat
# chicken salad sandwich wrap
# barbecue chicken sandwich, on white bun
# barbecue chicken sandwich, on wheat bun
# chicken fillet sandwich, nfs
# chicken fillet sandwich, from school cafeteria
# chicken fillet biscuit, from fast food
# chicken fillet sandwich, fried, from fast food
# chicken fillet sandwich, fried, from fast food, with cheese
# chicken fillet sandwich, grilled, from fast food
# chicken fillet sandwich, grilled, from fast food, with cheese
# chicken fillet sandwich, ns as to fried or grilled, from fast food
# chicken fillet sandwich, fried, on white bun
# chicken fillet sandwich, fried, on white bun; with cheese
# chicken fillet sandwich, fried, on wheat bun
# chicken fillet sandwich, fried, on wheat bun, with cheese
# chicken fillet sandwich, grilled, on white bun
# chicken fillet sandwich, grilled, on white bun, with cheese
# chicken fillet sandwich, grilled, on wheat bun
# chicken fillet sandwich, grilled, on wheat bun, with cheese
# chicken fillet wrap sandwich, fried, from fast food
# chicken fillet wrap sandwich, grilled, from fast food
# turkey or chicken burger, on white bun
# turkey or chicken burger, on wheat bun
# chicken dinner, nfs, frozen meal
# chicken, fried, with potatoes, vegetable, frozen meal
# chicken patty, or nuggets, boneless, breaded, potatoes, vegetable, frozen meal
# chicken, fried, with potatoes, vegetable, dessert, frozen meal, large meat portion
# teriyaki chicken with rice and vegetable, diet frozen meal
# chicken with rice and vegetable, diet frozen meal
# chicken and vegetables au gratin with rice, diet frozen entree
# chicken and vegetable entree with rice, diet frozen meal
# chicken with noodles and cheese sauce, diet frozen meal
# chicken and vegetable entree with noodles, diet frozen meal
# chicken in soy-based sauce, rice and vegetables, frozen meal
# chicken and vegetable entree with noodles and cream sauce, frozen meal
# chicken or turkey broth, bouillon, or consomme
# chicken or turkey broth, without tomato, home recipe
# chicken or turkey broth, less or reduced sodium, canned or ready-to-serve
# chicken or turkey gumbo soup, home recipe, canned or ready-to-serve
# chicken or turkey noodle soup, chunky style, canned or ready-to-serve
# chicken or turkey soup with vegetables, broccoli, carrots, celery, potatoes and onions, asian style
# chicken or turkey corn soup with noodles, home recipe
# chicken or turkey vegetable soup, canned, prepared with water or ready-to-serve
# chicken or turkey vegetable soup, stew type
# chicken or turkey vegetable soup with rice, stew type, chunky style
# chicken or turkey vegetable soup with noodles, stew type, chunky style, canned or ready-to-serve
# chicken or turkey vegetable soup, home recipe
# chicken or turkey vegetable soup with rice, home recipe, mexican style
# chicken or turkey and corn hominy soup,  home recipe, mexican style
# chicken or turkey soup with vegetables and fruit, asian style
# chicken or turkey soup, cream of, ns as to prepared with milk or water
# chicken or turkey soup, cream of, prepared with milk
# chicken egg foo yung
# chicken, meatless, nfs
# chicken, meatless, breaded, fried
# luncheon slice, meatless-beef, chicken, salami or turkey
# taco or tostada salad with chicken
# taco or tostada salad with chicken and sour cream
# taco, corn tortilla, chicken, cheese
# taco, corn tortilla, chicken, with beans, cheese
# taco, flour tortilla, chicken, cheese
# taco, flour tortilla, chicken, with beans, cheese
# burrito, chicken, cheese
# burrito, chicken, with rice, cheese
# burrito, chicken, with beans, cheese
# burrito, chicken, with beans and rice, cheese
# burrito bowl, chicken
# burrito bowl, chicken, with rice
# burrito bowl, chicken, with beans
# burrito bowl, chicken, with beans and rice
# enchilada, chicken
# tamale, chicken
# nachos, chicken
# nachos, chicken, with beans
# chimichanga, chicken
# quesadilla, chicken
# quesadilla, chicken, with vegetables
# taquito, chicken
# fajita, chicken
# egg roll, with chicken or turkey
# empanada, chicken
# empanada, chicken, with vegetables
# turnover or hot pocket, chicken
# chicken cornbread
# cornmeal dressing with chicken or turkey and vegetables
# dressing with chicken or turkey and vegetables
# lasagna with chicken or turkey
# lasagna, with chicken or turkey, and spinach
# stuffed shells, with chicken, with tomato sauce
# lo mein, with chicken
# pad thai with chicken
# macaroni or noodles with cheese and chicken or turkey
# macaroni or pasta salad with chicken
# rice, fried, with chicken
# rice with chicken, puerto rican style
# soupy rice with chicken, puerto rican style
# soupy rice mixture with chicken and potatoes, puerto rican style
# chicken or turkey noodle soup, canned or ready-to-serve
# chicken or turkey noodle soup, home recipe
# chicken or turkey noodle soup, cream of, home recipe, canned, or ready-to-serve
# chicken or turkey noodle soup, reduced sodium, canned or ready-to-serve
# chicken or turkey rice soup, canned, or ready-to-serve
# chicken or turkey rice soup, home recipe
# chicken or turkey rice soup, reduced sodium, canned, prepared with water or ready-to-serve
# chicken or turkey soup with dumplings and potatoes, home recipe, canned, or ready-to-serve
# chicken or turkey soup with dumplings, home recipe, canned or ready-to-serve
# potato from puerto rican chicken fricassee, with sauce
# chicken, for use with vegetables
# chicken as ingredient in recipes

# %%
chicken_wing_id = int(foundation_food.loc[foundation_food["description"].str.contains("Chicken", case=False)].iloc[0]["fdc_id"])
chicken_wing_id
# Out:
# 331897

# %%
food_nutrient[food_nutrient["fdc_id"] == chicken_wing_id]
# Out:
#             id  fdc_id  nutrient_id  amount  data_points  derivation_id  \
# 41650  2259068  331897         1303   0.003          5.0            1.0
# 41651  2259065  331897         1280   0.008          5.0            1.0
# 41652  2259076  331897         1404   0.045          5.0            1.0
# 41653  2259059  331897         1261   0.002          5.0            1.0
# 41654  2259106  331897         1109   0.170          1.0            1.0
# ...        ...     ...          ...     ...          ...            ...
# 41740  2259066  331897         1300   0.006          5.0            1.0
# 41741  2259121  331897         1271   0.088          5.0            1.0
# 41742  2259112  331897         1167   5.050          5.0            1.0
# 41743  2259074  331897         1329   0.021          NaN            4.0
# 41744  2259138  331897         1330   0.008          NaN            4.0
#
#          min    max  median footnote  min_year_acqured  min_year_acquired  \
# 41650  0.002  0.004   0.003      NaN            2010.0                NaN
# 41651  0.008  0.009   0.008      NaN            2010.0                NaN
# 41652  0.035  0.059   0.042      NaN            2010.0                NaN
# 41653  0.001  0.003   0.002      NaN            2010.0                NaN
# 41654    NaN    NaN   0.170      NaN            2010.0                NaN
# ...      ...    ...     ...      ...               ...                ...
# 41740  0.005  0.007   0.006      NaN            2010.0                NaN
# 41741  0.083  0.094   0.087      NaN            2010.0                NaN
# 41742  4.890  5.240   5.050      NaN            2010.0                NaN
# 41743    NaN    NaN     NaN      NaN               NaN                NaN
# 41744    NaN    NaN     NaN      NaN               NaN                NaN
#
#                             nutrient_name
# 41650                          tfa 16:1 t
# 41651                 pufa 22:5 n-3 (dpa)
# 41652           pufa 18:3 n-3 c,c,c (ala)
# 41653                             sfa 8:0
# 41654        vitamin e (alpha-tocopherol)
# ...                                   ...
# 41740                            sfa 17:0
# 41741                           pufa 20:4
# 41742                              niacin
# 41743  fatty acids, total trans-monoenoic
# 41744    fatty acids, total trans-dienoic
#
# [95 rows x 13 columns]

# %% [markdown]
# ## Get protein, carb, fat IDs
#
# See this document for info on foundation foods and their nutrients - https://fdc.nal.usda.gov/docs/Foundation_Foods_Documentation_Apr2021.pdf
#
# * Carbohydrate, by difference = total carbohydrates

# %%
nutrient[(nutrient["name"].str.contains("protein", case=False)) | \
         (nutrient["name"].str.contains("carbohydrate", case=False)) | \
         (nutrient["name"].str.contains("fat", case=False))]
# Out:
#        id                                               name unit_name  \
# 4    1003                                            Protein         G
# 5    1004                                  Total lipid (fat)         G
# 6    1005                        Carbohydrate, by difference         G
# 50   1049                                    Solids, non-fat         G
# 51   1050                         Carbohydrate, by summation         G
# 54   1053                                   Adjusted Protein         G
# 73   1072                                Carbohydrate, other         G
# 86   1085                                   Total fat (NLEA)         G
# 258  1257                           Fatty acids, total trans         G
# 259  1258                       Fatty acids, total saturated         G
# 291  1291  Fatty acids, other than 607-615, 617-621, 624-...         G
# 292  1292                 Fatty acids, total monounsaturated         G
# 293  1293                 Fatty acids, total polyunsaturated         G
# 318  1318                      Fatty acids, saturated, other         G
# 319  1319                     Fatty acids, monounsat., other         G
# 320  1320                     Fatty acids, polyunsat., other         G
# 326  1326                      Fatty acids, total sat., NLEA         G
# 327  1327                Fatty acids, total monounsat., NLEA         G
# 328  1328                Fatty acids, total polyunsat., NLEA         G
# 329  1329                 Fatty acids, total trans-monoenoic         G
# 330  1330                   Fatty acids, total trans-dienoic         G
# 331  1331                 Fatty acids, total trans-polyenoic         G
# 450  2039                                      Carbohydrates         G
#
#      nutrient_nbr      rank
# 4           203.0     600.0
# 5           204.0     800.0
# 6           205.0    1110.0
# 50          253.0  999999.0
# 51          205.2    1120.0
# 54          257.0     700.0
# 73          284.0       NaN
# 86          298.0     900.0
# 258         605.0   15400.0
# 259         606.0    9700.0
# 291         644.0  999999.0
# 292         645.0   11400.0
# 293         646.0   12900.0
# 318         677.0  999999.0
# 319         678.0  999999.0
# 320         679.0  999999.0
# 326         690.0  999999.0
# 327         691.0  999999.0
# 328         692.0  999999.0
# 329         693.0   15500.0
# 330         694.0   15601.0
# 331         695.0   15619.0
# 450         956.0    1100.0

# %%
target_nutrients = nutrient[nutrient["name"].isin(["Protein", "Total lipid (fat)", "Carbohydrate, by difference"])]
target_nutrients
# Out:
#      id                         name unit_name  nutrient_nbr    rank
# 4  1003                      Protein         G         203.0   600.0
# 5  1004            Total lipid (fat)         G         204.0   800.0
# 6  1005  Carbohydrate, by difference         G         205.0  1110.0

# %%
target_nutrient_dict = {1003: "protein",
    1004: "fat",
    1005: "carbohydrate"
}

# %% [markdown]
# ## Get target food protein, fat, carbohydrates
#
# We want to now index on the target foods and the target nutrients and retrieve their values for each food/nutrient.
#
# E.g.
#
# ```python
# {"food_1": {"protein": 100,
#             "carbohydrate": 50,
#             "fat": 20},
#  "food_2": ...
#
# ...}
# ```

# %%
list(target_nutrient_dict.keys())
# Out:
# [1003, 1004, 1005]

# %%
food_nutrient
# Out:
#               id   fdc_id  nutrient_id   amount  data_points  derivation_id  \
# 0        2201847   319877         1051   56.300          1.0            1.0
# 1        2201845   319877         1002    1.280          1.0            1.0
# 2        2201846   319877         1004   19.000          1.0            1.0
# 3        2201844   319877         1007    1.980          1.0            1.0
# 4        2201852   319878         1091  188.000          1.0            1.0
# ...          ...      ...          ...      ...          ...            ...
# 365555  28906044  2346383          334    0.000          NaN            NaN
# 365556  28906068  2346383          612    0.048          NaN            NaN
# 365557  28906042  2346383          323   10.500          NaN            NaN
# 365558  28906052  2346383          417    0.000          NaN            NaN
# 365559  28906070  2346383          614   23.263          NaN            NaN
#
#         min  max  median footnote  min_year_acqured  min_year_acquired  \
# 0       NaN  NaN     NaN      NaN               NaN                NaN
# 1       NaN  NaN     NaN      NaN               NaN                NaN
# 2       NaN  NaN     NaN      NaN               NaN                NaN
# 3       NaN  NaN     NaN      NaN               NaN                NaN
# 4       NaN  NaN     NaN      NaN               NaN                NaN
# ...     ...  ...     ...      ...               ...                ...
# 365555  NaN  NaN     NaN      NaN               NaN                NaN
# 365556  NaN  NaN     NaN      NaN               NaN                NaN
# 365557  NaN  NaN     NaN      NaN               NaN                NaN
# 365558  NaN  NaN     NaN      NaN               NaN                NaN
# 365559  NaN  NaN     NaN      NaN               NaN                NaN
#
#             nutrient_name
# 0                   water
# 1                nitrogen
# 2       total lipid (fat)
# 3                     ash
# 4           phosphorus, p
# ...                   ...
# 365555                NaN
# 365556                NaN
# 365557                NaN
# 365558                NaN
# 365559                NaN
#
# [495894 rows x 13 columns]

# %%
food_nutrient[(food_nutrient["nutrient_id"].isin(list(target_nutrient_dict.keys())))]
# Out:
#               id   fdc_id  nutrient_id  amount  data_points  derivation_id  \
# 2        2201846   319877         1004   19.00          1.0            1.0
# 16       2201859   319882         1004   18.70          1.0            1.0
# 28       2201873   319892         1004   16.60          1.0            1.0
# 43       2201886   319899         1004   19.10          1.0            1.0
# 97       2201942   319908         1004   18.20          1.0            1.0
# ...          ...      ...          ...     ...          ...            ...
# 129408  28911795  2352627         1004    0.12          1.0            1.0
# 129433  28911820  2352652         1004    0.19          1.0            1.0
# 129458  28911845  2352677         1004    0.17          1.0            1.0
# 129485  28911872  2352704         1004    0.18          1.0            1.0
# 129517  28911904  2352736         1004    0.00          1.0            1.0
#
#         min  max  median footnote  min_year_acqured  min_year_acquired  \
# 2       NaN  NaN     NaN      NaN               NaN                NaN
# 16      NaN  NaN     NaN      NaN               NaN                NaN
# 28      NaN  NaN     NaN      NaN               NaN                NaN
# 43      NaN  NaN     NaN      NaN               NaN                NaN
# 97      NaN  NaN     NaN      NaN               NaN                NaN
# ...     ...  ...     ...      ...               ...                ...
# 129408  NaN  NaN     NaN      NaN               NaN                NaN
# 129433  NaN  NaN     NaN      NaN               NaN                NaN
# 129458  NaN  NaN     NaN      NaN               NaN                NaN
# 129485  NaN  NaN     NaN      NaN               NaN                NaN
# 129517  NaN  NaN     NaN      NaN               NaN                NaN
#
#             nutrient_name
# 2       total lipid (fat)
# 16      total lipid (fat)
# 28      total lipid (fat)
# 43      total lipid (fat)
# 97      total lipid (fat)
# ...                   ...
# 129408  total lipid (fat)
# 129433  total lipid (fat)
# 129458  total lipid (fat)
# 129485  total lipid (fat)
# 129517  total lipid (fat)
#
# [5007 rows x 13 columns]

# %%
food_nutrient.dtypes
# Out:
# id                     int64
# fdc_id                 int64
# nutrient_id            int64
# amount               float64
# data_points          float64
# derivation_id        float64
# min                  float64
# max                  float64
# median               float64
# footnote              object
# min_year_acqured     float64
# min_year_acquired    float64
# nutrient_name         object
# dtype: object

# %%
# Find nutrition for chicken_wing_id (protein, fat, carb)
food_nutrient[(food_nutrient["fdc_id"] == chicken_wing_id) & (food_nutrient["nutrient_id"].isin(list(target_nutrient_dict.keys())))]
# Out:
#             id  fdc_id  nutrient_id  amount  data_points  derivation_id  \
# 41686  2259098  331897         1004    5.95          6.0            1.0
# 41718  2259079  331897         1003   23.90          NaN           49.0
# 41729  2259099  331897         1005    0.00          NaN           49.0
#
#          min    max  median footnote  min_year_acqured  min_year_acquired  \
# 41686   5.54   6.33    5.93      NaN            2010.0                NaN
# 41718  23.00  24.60   24.10      NaN               NaN                NaN
# 41729    NaN    NaN     NaN      NaN               NaN                NaN
#
#                      nutrient_name
# 41686            total lipid (fat)
# 41718                      protein
# 41729  carbohydrate, by difference

# %%
sorted(list(foundation_foods))
# Out:
# ['abalone',
#  'adobo, with noodles',
#  'adobo, with rice',
#  'agave liquid sweetener',
#  'alcoholic malt beverage',
#  'alcoholic malt beverage, sweetened',
#  'alexander',
#  'alfalfa sprouts, raw',
#  'alfredo sauce',
#  'alfredo sauce with added vegetables',
#  'alfredo sauce with meat',
#  'alfredo sauce with meat and added vegetables',
#  'alfredo sauce with poultry',
#  'alfredo sauce with poultry and added vegetables',
#  'alfredo sauce with seafood',
#  'alfredo sauce with seafood and added vegetables',
#  'almond butter',
#  'almond butter and jelly sandwich, on wheat bread',
#  'almond butter and jelly sandwich, on white bread',
#  'almond butter sandwich, on wheat bread',
#  'almond butter sandwich, on white bread',
#  'almond butter, creamy',
#  'almond butter, lower sodium',
#  'almond chicken',
#  'almond milk, sweetened',
#  'almond milk, sweetened, chocolate',
#  'almond milk, unsweetened',
#  'almond milk, unsweetened, chocolate',
#  'almond milk, unsweetened, plain, refrigerated',
#  'almond milk, unsweetened, plain, shelf stable',
#  'almond milk, unsweetened, plain, shelf stable',
#  'almond oil',
#  'almond paste',
#  'almonds, chocolate covered candy',
#  'almonds, flavored',
#  'almonds, honey roasted',
#  'almonds, lightly salted',
#  'almonds, nfs',
#  'almonds, salted',
#  'almonds, unroasted',
#  'almonds, unsalted',
#  'aloe vera juice drink',
#  'ambrosia',
#  'animal fat or drippings',
#  'anisette toast',
#  'antipasto with ham, fish, cheese, vegetables',
#  'apple cider',
#  'apple juice beverage, 40-50% juice, light',
#  'apple juice, 100%',
#  'apple juice, 100%, with calcium added',
#  'apple juice, with added vitamin c, from concentrate, shelf stable',
#  'apple pie filling',
#  'apple salad with dressing',
#  'apple, baked',
#  'apple, candied',
#  'apple, dried',
#  'apple, raw',
#  'apples, fuji, with skin, raw',
#  'apples, fuji, with skin, raw',
#  'apples, gala, with skin, raw',
#  'apples, gala, with skin, raw',
#  'apples, granny smith, with skin, raw',
#  'apples, granny smith, with skin, raw',
#  'apples, honeycrisp, with skin, raw',
#  'apples, honeycrisp, with skin, raw',
#  'apples, red delicious, with skin, raw',
#  'apples, red delicious, with skin, raw',
#  'applesauce, flavored',
#  'applesauce, regular',
#  'applesauce, unsweetened',
#  'applesauce, unsweetened, with added vitamin c',
#  'applesauce, unsweetened, with added vitamin c',
#  'apricot nectar',
#  'apricot, canned',
#  'apricot, dried',
#  'apricot, raw',
#  'arepa dominicana',
#  'armadillo',
#  'artichoke dip',
#  'artichoke, canned, cooked, no added fat',
#  'artichoke, fresh, cooked, no added fat',
#  'artichoke, raw',
#  'artichokes, ns as to form, cooked',
#  'artichokes, stuffed',
#  'asian chicken or turkey garden salad with crispy noodles, chicken and/or turkey, lettuce, fruit, nuts, crispy noodles, no dressing',
#  'asian chicken or turkey garden salad, chicken and/or turkey, lettuce, fruit, nuts, no dressing',
#  'asian stir fry vegetables, cooked, fat added',
#  'asian stir fry vegetables, cooked, no added fat',
#  'asparagus soup, cream of, ns as to made with milk or water',
#  'asparagus soup, cream of, prepared with milk',
#  'asparagus, canned, cooked with butter or margarine',
#  'asparagus, canned, cooked with oil',
#  'asparagus, canned, cooked, fat added, ns as to fat type',
#  'asparagus, canned, cooked, no added fat',
#  'asparagus, fresh, cooked with butter or margarine',
#  'asparagus, fresh, cooked with oil',
#  'asparagus, fresh, cooked, fat added, ns as to fat type',
#  'asparagus, fresh, cooked, no added fat',
#  'asparagus, frozen, cooked with butter or margarine',
#  'asparagus, frozen, cooked with oil',
#  'asparagus, frozen, cooked, fat added, ns as to fat type',
#  'asparagus, frozen, cooked, no added fat',
#  'asparagus, ns as to form, cooked',
#  'asparagus, raw',
#  'avocado dressing',
#  'avocado, for use on a sandwich',
#  'avocado, raw',
#  'baby toddler apples, stage 1',
#  'baby toddler apples, stage 2',
#  'baby toddler bananas, stage 1',
#  'baby toddler bananas, stage 2',
#  'baby toddler bar',
#  'baby toddler beef',
#  'baby toddler beets',
#  'baby toddler biscuit',
#  'baby toddler carrots, stage 1',
#  'baby toddler carrots, stage 2',
#  'baby toddler cereal, barley, dry',
#  'baby toddler cereal, multigrain with fruit, dry',
#  'baby toddler cereal, multigrain with fruit, ready-to-eat',
#  'baby toddler cereal, multigrain, dry',
#  'baby toddler cereal, multigrain, ready-to-eat',
#  'baby toddler cereal, nfs',
#  'baby toddler cereal, oatmeal with fruit, dry',
#  'baby toddler cereal, oatmeal with fruit, ready-to-eat',
#  'baby toddler cereal, oatmeal, dry',
#  'baby toddler cereal, oatmeal, ready-to-eat',
#  'baby toddler cereal, rice with fruit, dry',
#  'baby toddler cereal, rice with fruit, ready-to-eat',
#  'baby toddler cereal, rice, dry',
#  'baby toddler cereal, rice, ready-to-eat',
#  'baby toddler chicken',
#  'baby toddler cookie',
#  'baby toddler crackers',
#  'baby toddler crunchies',
#  'baby toddler food, nfs',
#  'baby toddler fruit and meat',
#  'baby toddler fruit and vegetables, stage 2',
#  'baby toddler fruit and vegetables, stage 3',
#  'baby toddler fruit and vegetables, with grain',
#  'baby toddler fruit and vegetables, with yogurt',
#  'baby toddler fruit, nfs',
#  'baby toddler fruit, vegetables, and meat',
#  'baby toddler fruit, with grain',
#  'baby toddler fruit, with yogurt',
#  'baby toddler green beans, stage 1',
#  'baby toddler green beans, stage 2',
#  'baby toddler ham',
#  'baby toddler juice, apple',
#  'baby toddler juice, fruit and vegetable',
#  'baby toddler juice, fruit and yogurt blend',
#  'baby toddler juice, grape',
#  'baby toddler juice, mixed fruit',
#  'baby toddler juice, nfs',
#  'baby toddler juice, pear',
#  'baby toddler mangoes',
#  'baby toddler meat stick',
#  'baby toddler meat, nfs',
#  'baby toddler multiple fruit, stage 2',
#  'baby toddler multiple fruit, stage 3',
#  'baby toddler multiple vegetables, stage 2',
#  'baby toddler multiple vegetables, stage 3',
#  'baby toddler peaches, stage 1',
#  'baby toddler peaches, stage 2',
#  'baby toddler pears, stage 1',
#  'baby toddler pears, stage 2',
#  'baby toddler peas, stage 1',
#  'baby toddler peas, stage 2',
#  'baby toddler prunes',
#  'baby toddler pudding',
#  'baby toddler puffs, fruit',
#  'baby toddler puffs, vegetable',
#  'baby toddler snack, nfs',
#  'baby toddler squash, stage 1',
#  'baby toddler squash, stage 2',
#  'baby toddler sweet potatoes, stage 1',
#  'baby toddler sweet potatoes, stage 2',
#  'baby toddler turkey',
#  'baby toddler vegetable, nfs',
#  'baby toddler vegetables and meat',
#  'baby toddler vegetables, with grain',
#  'baby toddler wheels',
#  'baby toddler yogurt melts',
#  'baby toddler yogurt, plain',
#  'baby toddler yogurt, with fruit',
#  'bacalaitos fritos',
#  'bacalao guisado',
#  'bacon and tomato dressing',
#  'bacon biscuit sandwich',
#  'bacon bits',
#  'bacon or side pork, fresh, cooked',
#  'bacon strip, meatless',
#  'bacon, for use on a sandwich',
#  'bacon, for use with vegetables',
#  'bacon, lettuce, tomato sandwich on wheat',
#  'bacon, lettuce, tomato sandwich on white',
#  'bacon, ns as to type of meat, cooked',
#  'bacon, ns as to type of meat, reduced sodium, cooked',
#  'bagel',
#  'bagel chips',
#  'bagel, multigrain',
#  'bagel, multigrain, with raisins',
#  'bagel, oat bran',
#  'bagel, pumpernickel',
#  'bagel, wheat',
#  'bagel, wheat bran',
#  'bagel, wheat, with fruit and nuts',
#  'bagel, wheat, with raisins',
#  'bagel, whole grain white',
#  'bagel, whole wheat',
#  'bagel, whole wheat, with raisins',
#  'bagel, with fruit other than raisins',
#  'bagel, with raisins',
#  'baked beans',
#  'baked beans from fast food / restaurant',
#  'baked beans, reduced sodium',
#  'baked beans, vegetarian',
#  'baklava',
#  'bamboo shoots, cooked',
#  'banana chips',
#  'banana nectar',
#  'banana pudding',
#  'banana split',
#  'banana, fried',
#  'banana, raw',
#  'bananas, overripe, raw',
#  'bananas, overripe, raw',
#  'bananas, ripe and slightly ripe, raw',
#  'bananas, ripe and slightly ripe, raw',
#  'bao bun',
#  'bao bun, no meat',
#  'barbecue beef sandwich, on wheat bun',
#  'barbecue beef sandwich, on white bun',
#  'barbecue beef, no sauce',
#  'barbecue beef, with sauce',
#  'barbecue chicken',
#  'barbecue chicken sandwich, on wheat bun',
#  'barbecue chicken sandwich, on white bun',
#  'barbecue meat, nfs',
#  'barbecue pork sandwich, on wheat bun',
#  'barbecue pork sandwich, on white bun',
#  'barbecue pork, no sauce',
#  'barbecue pork, with sauce',
#  'barbecue rib sandwich',
#  'barbecue sandwich, nfs',
#  'barbecue sauce',
#  'barfi or burfi, indian dessert',
#  'barley',
#  'barley soup, home recipe, canned, or ready-to-serve',
#  'basbousa',
#  'basil, raw',
#  'bean and ham soup, canned, reduced sodium, prepared with water or ready-to-serve',
#  'bean and ham soup, home recipe',
#  'bean cake',
#  'bean chips',
#  'bean dip, made with refried beans',
#  'bean paste, sweetened',
#  'bean salad, yellow and/or green string beans',
#  'bean soup, home recipe',
#  'bean soup, nfs',
#  'bean sprouts, cooked',
#  'bean sprouts, raw',
#  'bean with bacon or ham soup, canned or ready-to-serve',
#  'beans and brown rice',
#  'beans and franks',
#  'beans and rice, from fast food / restaurant',
#  'beans and rice, with meat',
#  'beans and rice, with tomatoes',
#  'beans and tomatoes, fat added',
#  'beans and tomatoes, no added fat',
#  'beans and white rice',
#  'beans with meat, ns as to type',
#  'beans, dry, black (0% moisture)',
#  'beans, dry, black (0% moisture)',
#  'beans, dry, brown (0% moisture)',
#  'beans, dry, brown (0% moisture)',
#  'beans, dry, carioca (0% moisture)',
#  'beans, dry, carioca (0% moisture)',
#  'beans, dry, cranberry (0% moisture)',
#  'beans, dry, cranberry (0% moisture)',
#  'beans, dry, dark red kidney (0% moisture)',
#  'beans, dry, dark red kidney (0% moisture)',
#  'beans, dry, flor de mayo (0% moisture)',
#  'beans, dry, flor de mayo (0% moisture)',
#  'beans, dry, great northern (0% moisture)',
#  'beans, dry, great northern (0% moisture)',
#  'beans, dry, light red kidney (0% moisture)',
#  'beans, dry, light red kidney (0% moisture)',
#  'beans, dry, light tan (0% moisture)',
#  'beans, dry, light tan (0% moisture)',
#  'beans, dry, medium red (0% moisture)',
#  'beans, dry, medium red (0% moisture)',
#  'beans, dry, navy (0% moisture)',
#  'beans, dry, navy (0% moisture)',
#  'beans, dry, pink (0% moisture)',
#  'beans, dry, pink (0% moisture)',
#  'beans, dry, pinto (0% moisture)',
#  'beans, dry, pinto (0% moisture)',
#  'beans, dry, red (0% moisture)',
#  'beans, dry, red (0% moisture)',
#  'beans, dry, small red (0% moisture)',
#  'beans, dry, small red (0% moisture)',
#  'beans, dry, small white (0% moisture)',
#  'beans, dry, small white (0% moisture)',
#  'beans, dry, tan (0% moisture)',
#  'beans, dry, tan (0% moisture)',
#  'beans, from canned, ns as to type, fat added',
#  'beans, from canned, ns as to type, no added fat',
#  'beans, from dried, ns as to type, fat added',
#  'beans, from dried, ns as to type, no added fat',
#  'beans, from fast food / restaurant, ns as to type',
#  'beans, nfs',
#  'beans, snap, green, canned, regular pack, drained solids',
#  'beans, snap, green, raw',
#  'bear',
#  'beaver',
#  'beef and broccoli',
#  'beef and macaroni with cheese sauce',
#  'beef and noodles with cream or white sauce',
#  'beef and noodles with gravy',
#  'beef and noodles with mushroom sauce',
#  'beef and noodles with soy-based sauce',
#  'beef and noodles with tomato-based sauce',
#  'beef and noodles, no sauce',
#  'beef and potatoes with cheese sauce',
#  'beef and potatoes with cream sauce, white sauce or mushroom sauce',
#  'beef and potatoes, no sauce',
#  'beef and rice with cheese sauce',
#  'beef and rice with cream sauce',
#  'beef and rice with gravy',
#  'beef and rice with mushroom sauce',
#  'beef and rice with soy-based sauce',
#  'beef and rice with tomato-based sauce',
#  'beef and rice, no sauce',
#  'beef and vegetables excluding carrots, broccoli, and dark-green leafy; no potatoes, gravy',
#  'beef and vegetables excluding carrots, broccoli, and dark-green leafy; no potatoes, no sauce',
#  'beef and vegetables excluding carrots, broccoli, and dark-green leafy; no potatoes, soy-based sauce',
#  'beef and vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, gravy',
#  'beef and vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, no sauce',
#  'beef and vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, soy-based sauce',
#  'beef and vegetables, hawaiian style',
#  'beef as ingredient in recipes',
#  'beef broth, without tomato, home recipe',
#  'beef burgundy',
#  'beef chow mein or chop suey with noodles',
#  'beef chow mein or chop suey, no noodles',
#  'beef curry',
#  'beef curry with rice',
#  'beef dinner, nfs, frozen meal',
#  'beef egg foo yung',
#  'beef goulash',
#  'beef goulash with noodles',
#  'beef jerky',
#  'beef noodle soup, canned or ready-to-serve',
#  'beef noodle soup, home recipe',
#  'beef rolls, stuffed with vegetables or meat mixture, tomato-based sauce',
#  'beef salad',
#  'beef sausage',
#  'beef sausage with cheese',
#  'beef sausage, reduced fat',
#  'beef sausage, reduced sodium',
#  'beef shish kabob with vegetables, excluding potatoes',
#  'beef steak with onions, puerto rican style',
#  'beef stew with potatoes and vegetables excluding carrots, broccoli, and dark-green leafy; gravy',
#  'beef stew with potatoes and vegetables excluding carrots, broccoli, and dark-green leafy; tomato-based sauce',
#  'beef stew with potatoes and vegetables including carrots, broccoli, and/or dark-green leafy; gravy',
#  'beef stew with potatoes and vegetables including carrots, broccoli, and/or dark-green leafy; tomato-based sauce',
#  'beef stew with potatoes, puerto rican style',
#  'beef stew with potatoes, tomato-based sauce, mexican style',
#  'beef stew with vegetables excluding potatoes, puerto rican style',
#  'beef stew, meat with gravy, no potatoes, puerto rican style',
#  'beef stew, no potatoes, tomato-based sauce, mexican style',
#  'beef stroganoff',
#  'beef stroganoff with noodles',
#  'beef taco filling: beef, cheese, tomato, taco sauce',
#  'beef vegetable soup with potato, pasta, or rice, chunky style, canned, or ready-to-serve',
#  'beef vegetable soup, home recipe, mexican style',
#  'beef wellington',
#  'beef with cream or white sauce',
#  'beef with gravy',
#  'beef with mushroom sauce',
#  'beef with soy-based sauce',
#  'beef with spaetzle or rice, vegetable, frozen meal',
#  'beef with sweet and sour sauce',
#  'beef with tomato-based sauce',
#  'beef with vegetable, diet frozen meal',
#  'beef with vegetables excluding carrots, broccoli, and dark-green leafy; no potatoes, mushroom sauce',
#  'beef with vegetables excluding carrots, broccoli, and dark-green leafy; no potatoes, tomato-based sauce',
#  'beef with vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, mushroom sauce',
#  'beef with vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, tomato-based sauce',
#  'beef, bacon, cooked',
#  'beef, bacon, reduced sodium, cooked',
#  'beef, brisket',
#  'beef, broth, bouillon, or consomme',
#  'beef, corned',
#  'beef, cow head',
#  'beef, dried, chipped, cooked in fat',
#  'beef, dried, chipped, uncooked',
#  'beef, dumplings, and vegetables excluding carrots, broccoli, and dark-green leafy; gravy',
#  'beef, dumplings, and vegetables including carrots, broccoli, and/or dark-green leafy; gravy',
#  'beef, for use with vegetables',
#  'beef, ground',
#  'beef, ground, patty',
#  'beef, ground, raw',
#  'beef, ground, with egg and onion',
#  'beef, loin, tenderloin roast, separable lean only, boneless, trimmed to 0" fat, select, cooked, roasted',
#  'beef, loin, tenderloin roast, separable lean only, boneless, trimmed to 0" fat, select, cooked, roasted',
#  'beef, loin, top loin steak, boneless, lip-on, separable lean only, trimmed to 1/8" fat, choice, raw',
#  'beef, loin, top loin steak, boneless, lip-on, separable lean only, trimmed to 1/8" fat, choice, raw',
#  'beef, neck bones',
#  'beef, nfs',
#  'beef, noodles, and vegetables excluding carrots, broccoli, and dark-green leafy; gravy',
#  'beef, noodles, and vegetables excluding carrots, broccoli, and dark-green leafy; mushroom sauce',
#  'beef, noodles, and vegetables excluding carrots, broccoli, and dark-green leafy; no sauce',
#  'beef, noodles, and vegetables excluding carrots, broccoli, and dark-green leafy; soy-based sauce',
#  'beef, noodles, and vegetables excluding carrots, broccoli, and dark-green leafy; tomato-based sauce',
#  'beef, noodles, and vegetables including carrots, broccoli, and/or dark-green leafy; gravy',
#  'beef, noodles, and vegetables including carrots, broccoli, and/or dark-green leafy; mushroom sauce',
#  'beef, noodles, and vegetables including carrots, broccoli, and/or dark-green leafy; no sauce',
#  'beef, noodles, and vegetables including carrots, broccoli, and/or dark-green leafy; soy-based sauce',
#  'beef, noodles, and vegetables including carrots, broccoli, and/or dark-green leafy; tomato-based sauce',
#  'beef, oxtails',
#  'beef, pot roast',
#  'beef, potatoes, and vegetables excluding carrots, broccoli, and dark-green leafy; cheese sauce',
#  'beef, potatoes, and vegetables excluding carrots, broccoli, and dark-green leafy; cream sauce, white sauce, or mushroom sauce',
#  'beef, potatoes, and vegetables excluding carrots, broccoli, and dark-green leafy; gravy',
#  'beef, potatoes, and vegetables excluding carrots, broccoli, and dark-green leafy; soy-based sauce',
#  'beef, potatoes, and vegetables excluding carrots, broccoli, and dark-green leafy; tomato-based sauce',
#  'beef, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; cheese sauce',
#  'beef, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; cream sauce, white sauce, or mushroom sauce',
#  'beef, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; gravy',
#  'beef, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; no sauce',
#  'beef, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; soy-based sauce',
#  'beef, potatoes, and vegetables including carrots, broccoli, and/or dark-green leafy; tomato-based sauce',
#  'beef, potatoes, and vegetables, excluding carrots, broccoli, and dark-green leafy; no sauce',
#  'beef, prepackaged or deli, luncheon meat',
#  'beef, prepackaged or deli, luncheon meat, reduced sodium',
#  'beef, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; cheese sauce',
#  'beef, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; gravy',
#  'beef, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; mushroom sauce',
#  'beef, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; no sauce',
#  'beef, rice, and vegetables excluding carrots, broccoli, and dark-green leafy; soy-based sauce',
#  'beef, rice, and vegetables excluding carrots, broccoli, and/or dark-green leafy; tomato-based sauce',
#  'beef, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; cheese sauce',
#  'beef, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; gravy',
#  'beef, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; mushroom sauce',
#  'beef, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; no sauce',
#  'beef, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; soy-based sauce',
#  'beef, rice, and vegetables including carrots, broccoli, and/or dark-green leafy; tomato-based sauce',
#  'beef, roast',
#  'beef, roast, hash',
#  'beef, round, eye of round roast, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  'beef, round, eye of round roast, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  'beef, round, top round roast, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  'beef, round, top round roast, boneless, separable lean only, trimmed to 0" fat, select, raw',
#  'beef, sandwich steak',
#  'beef, short loin, porterhouse steak, separable lean only, trimmed to 1/8" fat, select, raw',
#  'beef, short loin, porterhouse steak, separable lean only, trimmed to 1/8" fat, select, raw',
#  'beef, short loin, t-bone steak, bone-in, separable lean only, trimmed to 1/8" fat, choice, cooked, grilled',
#  'beef, short loin, t-bone steak, bone-in, separable lean only, trimmed to 1/8" fat, choice, cooked, grilled',
#  'beef, shortribs',
#  'beef, sliced, with gravy, potatoes, vegetable, frozen meal',
#  'beef, steak, chuck',
#  'beef, steak, country fried',
#  'beef, steak, cube',
#  'beef, steak, flank',
#  'beef, steak, nfs',
#  'beef, steak, ribeye, lean and fat eaten',
#  'beef, steak, ribeye, lean only eaten',
#  'beef, steak, ribeye, ns as to fat eaten',
#  'beef, steak, round',
#  'beef, steak, sirloin, lean and fat eaten',
#  'beef, steak, sirloin, lean only eaten',
#  'beef, steak, sirloin, ns as to fat eaten',
#  'beef, steak, strip, lean and fat eaten',
#  'beef, steak, strip, lean only eaten',
#  'beef, steak, strip, ns as to fat eaten',
#  'beef, steak, t-bone,  lean and fat eaten',
#  'beef, steak, t-bone, lean only eaten',
#  'beef, steak, t-bone, ns as to fat eaten',
#  'beef, steak, tenderloin',
#  'beef, stew meat',
#  'beef, tofu, and vegetables excluding carrots, broccoli,  and dark-green leafy; no potatoes, soy-based sauce',
#  'beef, tofu, and vegetables including carrots, broccoli, and/or dark-green leafy; no potatoes, soy-based sauce',
#  'beer',
#  'beer, higher alcohol',
#  'beer, light',
#  'beer, low carb',
#  'beet greens, cooked',
#  'beet greens, raw',
#  'beet juice',
#  'beets, canned, cooked, fat added',
#  'beets, canned, cooked, no added fat',
#  'beets, canned, reduced sodium, cooked',
#  'beets, fresh, cooked, fat added',
#  'beets, fresh, cooked, no added fat',
#  'beets, ns as to form, cooked',
#  'beets, pickled',
#  'beets, raw',
#  'beignet',
#  'berries, nfs',
#  'bibimbap, korean',
#  'big mac (mcdonalds)',
#  'biryani with chicken',
#  'biryani with meat',
#  'biryani with vegetables',
#  'biscayne codfish, puerto rican style',
#  'biscuit with fruit',
#  'biscuit with gravy',
#  'biscuit, cheese',
#  'biscuit, from fast food / restaurant',
#  'biscuit, from refrigerated dough',
#  'biscuit, home recipe',
#  'biscuit, nfs',
#  'biscuit, wheat',
#  'bison',
#  'bitter melon, cooked',
#  'bitter melon, horseradish, jute, or radish leaves, cooked',
#  'black bean salad',
#  'black bean sauce',
#  'black bean soup, home recipe, canned or ready-to-serve',
#  'black beans and brown rice',
#  'black beans and rice, from fast food / restaurant',
#  'black beans and white rice',
#  'black beans with meat',
#  'black beans, from canned, fat added',
#  'black beans, from canned, no added fat',
#  'black beans, from canned, reduced sodium',
#  'black beans, from dried, fat added',
#  'black beans, from dried, no added fat',
#  'black beans, from fast food / restaurant',
#  'black beans, nfs',
#  'black russian',
#  'blackberries, frozen',
#  'blackberries, raw',
#  'blackberry juice, 100%',
#  'blackeyed peas, from canned',
#  'blackeyed peas, from dried',
#  'blackeyed peas, from frozen',
#  'blackeyed peas, nfs',
#  'blood sausage',
#  'bloody mary',
#  'bluberries, canned',
#  'blue or roquefort cheese dressing',
#  'blue or roquefort cheese dressing, fat free',
#  'blue or roquefort cheese dressing, light',
#  'blueberries, dried',
#  'blueberries, frozen',
#  'blueberries, raw',
#  'blueberries, raw',
#  'blueberries, raw',
#  'blueberry juice',
#  'blueberry pie filling',
#  'blueberry syrup',
#  'bologna',
#  'bologna sandwich on wheat',
#  'bologna sandwich on wheat, with cheese',
#  'bologna sandwich on white',
#  'bologna sandwich on white, with cheese',
#  'bologna, reduced fat',
#  'bologna, reduced sodium',
#  'borscht',
#  'bouillabaisse',
#  'brains',
#  'brandy',
#  'brandy and cola',
#  'bratwurst',
#  'bratwurst, with cheese',
#  'brazil nuts',
#  'bread stuffing',
#  'bread stuffing made with egg',
#  'bread, barley',
#  'bread, barley, toasted',
#  'bread, black',
#  'bread, black, toasted',
#  'bread, boston brown',
#  'bread, caressed, puerto rican style',
#  'bread, caressed, toasted, puerto rican style',
#  'bread, chappatti or roti',
#  'bread, cheese',
#  'bread, cheese, toasted',
#  'bread, cinnamon',
#  'bread, cinnamon, toasted',
#  'bread, cornmeal and molasses',
#  'bread, cornmeal and molasses, toasted',
#  'bread, cuban',
#  'bread, cuban, toasted',
#  'bread, dough, fried',
#  'bread, egg, challah',
#  'bread, egg, challah, toasted',
#  'bread, french or vienna',
#  'bread, french or vienna, toasted',
#  'bread, french or vienna, whole wheat',
#  'bread, french or vienna, whole wheat, toasted',
#  'bread, fruit',
#  'bread, gluten free',
#  'bread, gluten free, toasted',
#  'bread, high protein',
#  'bread, high protein, toasted',
#  'bread, irish soda',
#  'bread, italian, grecian, armenian',
#  'bread, italian, grecian, armenian, toasted',
#  'bread, lard, puerto rican style',
#  'bread, lard, toasted, puerto rican style',
#  'bread, made from home recipe or purchased at a bakery, ns as to major flour',
#  'bread, made from home recipe or purchased at a bakery, toasted, ns as to major flour',
#  'bread, marble rye and pumpernickel',
#  'bread, marble rye and pumpernickel, toasted',
#  'bread, multigrain',
#  'bread, multigrain, reduced calorie and/or high fiber',
#  'bread, multigrain, reduced calorie and/or high fiber, toasted',
#  'bread, multigrain, toasted',
#  'bread, multigrain, with raisins',
#  'bread, multigrain, with raisins, toasted',
#  'bread, naan',
#  'bread, native, water, puerto rican style',
#  'bread, native, water, toasted, puerto rican style',
#  'bread, ns as to major flour',
#  'bread, ns as to major flour, toasted',
#  'bread, nut',
#  'bread, oat bran',
#  'bread, oat bran, toasted',
#  'bread, oatmeal',
#  'bread, oatmeal, toasted',
#  'bread, onion',
#  'bread, onion, toasted',
#  'bread, paratha',
#  'bread, pita',
#  'bread, pita with fruit',
#  'bread, pita, wheat or cracked wheat',
#  'bread, pita, whole wheat',
#  'bread, potato',
#  'bread, potato, toasted',
#  'bread, pumpernickel',
#  'bread, pumpernickel, toasted',
#  'bread, pumpkin',
#  'bread, puri',
#  'bread, raisin',
#  'bread, raisin, toasted',
#  'bread, reduced calorie and/or high fiber, white or nfs',
#  'bread, reduced calorie and/or high fiber, white or nfs, toasted',
#  'bread, reduced calorie and/or high fiber, white or nfs, with fruit and/or nuts',
#  'bread, reduced calorie and/or high fiber, white or nfs, with fruit and/or nuts, toasted',
#  'bread, rice',
#  'bread, rice, toasted',
#  'bread, rye',
#  'bread, rye, toasted',
#  'bread, sour dough',
#  'bread, sour dough, toasted',
#  'bread, soy',
#  'bread, soy, toasted',
#  'bread, spanish coffee',
#  'bread, sprouted wheat',
#  'bread, sprouted wheat, toasted',
#  'bread, sunflower meal',
#  'bread, sunflower meal, toasted',
#  'bread, sweet potato',
#  'bread, sweet potato, toasted',
#  'bread, vegetable',
#  'bread, vegetable, toasted',
#  'bread, wheat or cracked wheat',
#  'bread, wheat or cracked wheat, made from home recipe or purchased at bakery',
#  'bread, wheat or cracked wheat, made from home recipe or purchased at bakery, toasted',
#  'bread, wheat or cracked wheat, reduced calorie and/or high fiber',
#  'bread, wheat or cracked wheat, reduced calorie and/or high fiber, toasted',
#  'bread, wheat or cracked wheat, toasted',
#  'bread, wheat or cracked wheat, with raisins',
#  'bread, wheat or cracked wheat, with raisins, toasted',
#  'bread, white',
#  'bread, white with whole wheat swirl',
#  'bread, white with whole wheat swirl, toasted',
#  'bread, white, commercially prepared',
#  'bread, white, low sodium or no salt',
#  'bread, white, low sodium or no salt, toasted',
#  'bread, white, made from home recipe or purchased at a bakery',
#  'bread, white, made from home recipe or purchased at a bakery, toasted',
#  'bread, white, special formula, added fiber',
#  'bread, white, special formula, added fiber, toasted',
#  'bread, white, toasted',
#  'bread, whole grain white',
#  'bread, whole grain white, toasted',
#  'bread, whole wheat',
#  'bread, whole wheat, made from home recipe or purchased at bakery',
#  'bread, whole wheat, made from home recipe or purchased at bakery, toasted',
#  'bread, whole wheat, toasted',
#  'bread, whole wheat, with raisins',
#  'bread, whole wheat, with raisins, toasted',
#  'bread, whole-wheat, commercially prepared',
#  'bread, zucchini',
#  'breadfruit, cooked',
#  'breading or batter as ingredient in food',
#  'breadsticks, hard, gluten free',
#  'breadsticks, hard, nfs',
#  'breadsticks, hard, reduced sodium',
#  'breadsticks, hard, whole wheat',
#  'breadsticks, nfs',
#  'breadsticks, soft, fast food / restaurant',
#  'breadsticks, soft, frozen',
#  'breadsticks, soft, nfs',
#  'breadsticks, soft, stuffed or topped with melted cheese',
#  'breadsticks, soft, with parmesan cheese, fast food / restaurant',
#  'breakfast bar, cereal crust with fruit filling, lowfat',
#  'breakfast bar, date, with yogurt coating',
#  'breakfast bar, nfs',
#  'breakfast link, pattie, or slice, meatless',
#  'breakfast meat as ingredient in omelet',
#  'breakfast pastry, nfs',
#  'breakfast pizza with egg',
#  'breakfast tart',
#  'breakfast tart, lowfat',
#  'brioche',
#  'broccoflower, cooked',
#  'broccoflower, raw',
#  'broccoli and cauliflower, cooked, fat added',
#  'broccoli and cauliflower, cooked, no added fat',
#  'broccoli casserole with noodles',
#  'broccoli casserole with rice',
#  'broccoli cheese soup, prepared with milk, home recipe, canned, or ready-to-serve',
#  'broccoli raab, cooked',
#  'broccoli raab, raw',
#  'broccoli salad with cauliflower, cheese, bacon bits, and dressing',
#  'broccoli slaw salad',
#  'broccoli soup, prepared with milk, home recipe, canned or ready-to-serve',
#  'broccoli soup, prepared with water, home recipe, canned, or ready-to-serve',
#  'broccoli, cauliflower and carrots, cooked, fat added',
#  'broccoli, cauliflower and carrots, cooked, no added fat',
#  'broccoli, chinese, cooked',
#  'broccoli, chinese, raw',
#  'broccoli, cooked, as ingredient',
#  'broccoli, cooked, from restaurant',
#  'broccoli, fresh, cooked with butter or margarine',
#  'broccoli, fresh, cooked with oil',
#  'broccoli, fresh, cooked, fat added, ns as to fat type',
#  'broccoli, fresh, cooked, no added fat',
#  'broccoli, frozen, cooked with butter or margarine',
#  'broccoli, frozen, cooked with oil',
#  'broccoli, frozen, cooked, fat added, ns as to fat type',
#  'broccoli, frozen, cooked, no added fat',
#  'broccoli, ns as to form, cooked',
#  'broccoli, raw',
#  'broccoli, raw',
#  'broccoli, raw',
#  'bruschetta',
#  'brussels sprouts, fresh, cooked, fat added',
#  'brussels sprouts, fresh, cooked, no added fat',
#  'brussels sprouts, frozen, cooked, fat added',
#  'brussels sprouts, frozen, cooked, no added fat',
#  'brussels sprouts, ns as to form, cooked',
#  'brussels sprouts, raw',
#  'buckwheat groats',
#  'buffalo sauce',
#  'bulgur, fat added',
#  'bulgur, no added fat',
#  'bulgur, ns as to fat',
#  'burdock, cooked',
#  'burrito bowl, beef or pork',
#  'burrito bowl, beef or pork, with beans',
#  'burrito bowl, beef or pork, with beans and rice',
#  'burrito bowl, beef or pork, with rice',
#  'burrito bowl, chicken',
#  'burrito bowl, chicken, with beans',
#  'burrito bowl, chicken, with beans and rice',
#  'burrito bowl, chicken, with rice',
#  'burrito bowl, nfs',
#  'burrito bowl, with beans',
#  'burrito, beef, cheese',
#  'burrito, beef, with beans and rice, cheese',
#  'burrito, beef, with beans, cheese',
#  'burrito, beef, with rice, cheese',
#  'burrito, cheese only',
#  'burrito, chicken, cheese',
#  'burrito, chicken, with beans and rice, cheese',
#  'burrito, chicken, with beans, cheese',
#  'burrito, chicken, with rice, cheese',
#  'burrito, meat, no cheese',
#  'burrito, meat, with beans and rice, no cheese',
#  'burrito, meat, with beans, no cheese',
#  'burrito, meat, with rice, no cheese',
#  'burrito, nfs',
#  'burrito, pork, cheese',
#  'burrito, pork, with beans and rice, cheese',
#  'burrito, pork, with beans, cheese',
#  'burrito, pork, with rice, cheese',
#  'burrito, with beans and rice, cheese',
#  'burrito, with beans, cheese',
#  'burrito, with beans, no cheese',
#  'butter replacement, liquid',
#  'butter replacement, powder',
#  'butter, light',
#  'butter, nfs',
#  'butter, stick',
#  'butter, stick, salted',
#  'butter, stick, unsalted',
#  'butter, tub',
#  'butter-oil blend, light',
#  'butter-oil blend, nfs',
#  'butter-oil blend, stick',
#  'butter-oil blend, tub',
#  'buttermilk, fat free (skim)',
#  'buttermilk, low fat',
#  'buttermilk, whole',
#  'cabbage salad, nfs',
#  'cabbage soup, home recipe, canned or ready-to-serve',
#  'cabbage with ham hocks',
#  'cabbage with meat soup, home recipe, canned or ready-to-serve',
#  'cabbage, chinese, cooked, fat added',
#  'cabbage, chinese, cooked, no added fat',
#  'cabbage, chinese, raw',
#  'cabbage, cooked, as ingredient',
#  'cabbage, fresh, pickled, japanese style',
#  'cabbage, green, cooked with butter or margarine',
#  'cabbage, green, cooked with oil',
#  'cabbage, green, cooked, fat added, ns as to fat type',
#  'cabbage, green, cooked, no added fat',
#  'cabbage, green, raw',
#  'cabbage, green, raw',
#  'cabbage, red, cooked',
#  'cabbage, red, pickled',
#  'cabbage, red, raw',
#  'cabbage, red, raw',
#  'cabbage, savoy, cooked',
#  'cactus, cooked, fat added',
#  'cactus, cooked, no added fat',
#  'cactus, raw',
#  'caesar dressing',
#  'caesar dressing, fat free',
#  'caesar dressing, light',
#  'caesar salad, with romaine, no dressing',
#  'cake made with glutinous rice',
#  'cake made with glutinous rice and dried beans',
#  'cake or cupcake, apple',
#  'cake or cupcake, banana',
#  'cake or cupcake, black forest',
#  'cake or cupcake, carrot',
#  'cake or cupcake, chocolate with chocolate icing, bakery',
#  'cake or cupcake, chocolate with chocolate icing, from mix',
#  'cake or cupcake, chocolate with white icing, bakery',
#  'cake or cupcake, chocolate with white icing, from mix',
#  'cake or cupcake, chocolate, no icing',
#  'cake or cupcake, coconut',
#  'cake or cupcake, german chocolate',
#  'cake or cupcake, gingerbread',
#  'cake or cupcake, gluten free',
#  'cake or cupcake, lemon',
#  'cake or cupcake, marble',
#  'cake or cupcake, nfs',
#  'cake or cupcake, peanut butter',
#  'cake or cupcake, pumpkin',
#  'cake or cupcake, red velvet',
#  'cake or cupcake, spice',
#  'cake or cupcake, strawberry',
#  'cake or cupcake, white with chocolate icing, bakery',
#  'cake or cupcake, white with chocolate icing, from mix',
#  'cake or cupcake, white with white icing, bakery',
#  'cake or cupcake, white with white icing, from mix',
#  'cake or cupcake, white, no icing',
#  'cake or cupcake, zucchini',
#  'cake, angel food',
#  'cake, boston cream pie',
#  'cake, chocolate, flourless',
#  'cake, cream',
#  'cake, fruit cake',
#  'cake, jelly roll',
#  'cake, pineapple, upside down',
#  'cake, pound',
#  'cake, sponge',
#  'cake, strawberry shortcake',
#  'cake, torte',
#  'cake, tres leche',
#  'calamari, cooked',
#  'calamari, fried',
#  'calzone, with cheese, meatless',
#  'calzone, with meat and cheese',
#  'canadian bacon, cooked',
#  'canadian club and soda',
#  'candy, caramel',
#  'candy, cotton',
#  'candy, fruit flavored pieces',
#  'candy, fruit leather',
#  'candy, fruit snacks',
#  'candy, gummy',
#  'candy, hard',
#  'candy, licorice',
#  'candy, lollipop',
#  'candy, marshmallow',
#  'candy, mint',
#  'candy, nfs',
#  'candy, non chocolate, other, nfs',
#  'candy, non chocolate, sugar free',
#  'candy, nougat with nuts',
#  'candy, peanut brittle',
#  'candy, sprinkles',
#  'candy, taffy',
#  'cannelloni, cheese- and spinach-filled, no sauce',
#  'canola oil',
#  'cantaloupe nectar',
#  'cantaloupe, raw',
#  'cape cod',
#  'caramel dip, light',
#  'caramel dip, regular',
#  'caribou',
#  'carrot juice, 100%',
#  'carrots, baby, raw',
#  'carrots, canned, cooked with butter or margarine',
#  'carrots, canned, cooked with oil',
#  'carrots, canned, cooked, fat added, ns as to fat type',
#  'carrots, canned, cooked, no added fat',
#  'carrots, canned, reduced sodium, cooked with butter or margarine',
#  'carrots, canned, reduced sodium, cooked with oil',
#  'carrots, canned, reduced sodium, cooked, fat added, ns as to fat type',
#  'carrots, canned, reduced sodium, cooked, no added fat',
#  'carrots, cooked, as ingredient',
#  'carrots, cooked, from restaurant',
#  'carrots, fresh, cooked with butter or margarine',
#  'carrots, fresh, cooked with oil',
#  'carrots, fresh, cooked, fat added, ns as to fat type',
#  'carrots, fresh, cooked, no added fat',
#  'carrots, frozen, cooked with butter or margarine',
#  'carrots, frozen, cooked with oil',
#  'carrots, frozen, cooked, fat added, ns as to fat type',
#  'carrots, frozen, cooked, no added fat',
#  'carrots, frozen, unprepared',
#  "carrots, frozen, unprepared (includes foods for usda's food distribution program)",
#  'carrots, glazed, cooked',
#  'carrots, mature, raw',
#  'carrots, ns as to form, cooked',
#  'carrots, raw',
#  'carrots, raw, salad',
#  'carrots, raw, salad with apples',
#  'casabe, cassava bread',
#  'cashew butter',
#  'cashews, honey roasted',
#  'cashews, lightly salted',
#  'cashews, nfs',
#  'cashews, salted',
#  'cashews, unroasted',
#  'cashews, unsalted',
#  'cassava pasteles, puerto rican style',
#  'cassava, cooked',
#  'cauliflower, cooked, as ingredient',
#  'cauliflower, fresh, cooked with butter or margarine',
#  'cauliflower, fresh, cooked with oil',
#  'cauliflower, fresh, cooked, fat added, ns as to fat type',
#  'cauliflower, fresh, cooked, no added fat',
#  'cauliflower, frozen, cooked with butter or margarine',
#  'cauliflower, frozen, cooked with oil',
#  'cauliflower, frozen, cooked, fat added, ns as to fat type',
#  'cauliflower, frozen, cooked, no added fat',
#  'cauliflower, ns as to form, cooked',
#  'cauliflower, pickled',
#  'cauliflower, raw',
#  'caviar',
#  'celery juice',
#  'celery soup, cream of, prepared with water, home recipe, canned or ready-to-serve',
#  'celery, cooked',
#  'celery, pickled',
#  'celery, raw',
#  'celery, raw',
#  'cereal beverage',
#  'cereal beverage with beet roots, from powdered instant',
#  'cereal or granola bar (general mills fiber one chewy bar)',
#  'cereal or granola bar (general mills nature valley chewy trail mix)',
#  'cereal or granola bar (general mills nature valley crunchy granola bar)',
#  'cereal or granola bar (general mills nature valley sweet and salty granola bar)',
#  'cereal or granola bar (kashi chewy)',
#  'cereal or granola bar (kashi crunchy)',
#  "cereal or granola bar (kellogg's nutri-grain cereal bar)",
#  "cereal or granola bar (kellogg's nutri-grain fruit and nut bar)",
#  "cereal or granola bar (kellogg's nutri-grain yogurt bar)",
#  "cereal or granola bar (kellogg's special k bar)",
#  'cereal or granola bar (kind fruit and nut bar)',
#  'cereal or granola bar (quaker chewy 25% less sugar granola bar)',
#  'cereal or granola bar (quaker chewy 90 calorie granola bar)',
#  'cereal or granola bar (quaker chewy dipps granola bar)',
#  'cereal or granola bar (quaker chewy granola bar)',
#  'cereal or granola bar (quaker granola bites)',
#  'cereal or granola bar with nuts, chocolate coated',
#  'cereal or granola bar, chocolate coated, nfs',
#  'cereal or granola bar, coated with non-chocolate coating',
#  'cereal or granola bar, fruit and nut',
#  'cereal or granola bar, high fiber, coated with non-chocolate yogurt coating',
#  'cereal or granola bar, lowfat, nfs',
#  'cereal or granola bar, nfs',
#  'cereal or granola bar, nonfat',
#  'cereal or granola bar, oats, nuts, coated with non-chocolate coating',
#  'cereal or granola bar, peanuts , oats, sugar, wheat germ',
#  'cereal or granola bar, reduced sugar, nfs',
#  'cereal or granola bar, with coconut, chocolate coated',
#  'cereal or granola bar, with rice cereal',
#  'cereal or granola bar, with yogurt coating (general mills nature valley chewy granola bar)',
#  'cereal, bran flakes, flavored',
#  'cereal, bran flakes, plain',
#  'cereal, chocolate crispy',
#  'cereal, chocolate puffs',
#  'cereal, cinnamon toast',
#  'cereal, cooked, nfs',
#  'cereal, corn flakes, flavored',
#  'cereal, corn flakes, plain',
#  'cereal, corn puffs',
#  'cereal, corn squares',
#  ...]

# %%
ten_whole_foods = ["chicken_wings",
    "apple",
    "banana",
    "beef", # steak, etc
    "carrots",
    "egg", # whole egg
    "strawberries",
    "blueberries",
    "mushrooms",
    "honey"
]

# %%
ten_whole_foods
# Out:
# ['chicken_wings',
#  'apple',
#  'banana',
#  'beef',
#  'carrots',
#  'egg',
#  'strawberries',
#  'blueberries',
#  'mushrooms',
#  'honey']

# %% [markdown]
# ## Get ten whole foods `food_id`
#
# Everything except blueberries and honey are available in `foundation_food`.
#
# For blueberries and honey, we'll have to dig into the survery data: `data_exploration/data/FoodData_Central_survey_food_csv_2020-10-30`

# %%
# Get all food ids from foundation_food (honey and blueberries in another dataset)
target_whole_foods = ['apple', # removed chicken wings... can come back later...
 'banana',
 'beef',
 'blueberries',
 'carrots',
 'chicken',
 'egg',
 'honey',
 'strawberries',
 'mushrooms']

# %%
# str.contains can search on regex - https://stackoverflow.com/a/17973255/7900723
pattern = "|".join([f"(?i){food}" for food in target_whole_foods])
pattern
# Out:
# '(?i)apple|(?i)banana|(?i)beef|(?i)blueberries|(?i)carrots|(?i)chicken|(?i)egg|(?i)honey|(?i)strawberries|(?i)mushrooms'

# %%
foundation_food[foundation_food["description"].str.contains(pattern, case=False)].sort_values(by=["description"])
# Out:
#        fdc_id          data_type  \
# 1481  2342241  survey_fndds_food
# 2208  2342968  survey_fndds_food
# 4053  2344813  survey_fndds_food
# 5405  2346165  survey_fndds_food
# 4054  2344814  survey_fndds_food
# ...       ...                ...
# 1338  2342098  survey_fndds_food
# 1337  2342097  survey_fndds_food
# 1336  2342096  survey_fndds_food
# 2248  2343008  survey_fndds_food
# 2249  2343009  survey_fndds_food
#
#                                             description  food_category_id  \
# 1481                                     almond chicken               NaN
# 2208                             almonds, honey roasted               NaN
# 4053                                        apple cider               NaN
# 5405          apple juice beverage, 40-50% juice, light               NaN
# 4054                                  apple juice, 100%               NaN
# ...                                                 ...               ...
# 1338  venison or deer, noodles, and vegetables inclu...               NaN
# 1337  venison or deer, potatoes, and vegetables excl...               NaN
# 1336  venison or deer, potatoes, and vegetables incl...               NaN
# 2248                   walnuts, excluding honey roasted               NaN
# 2249                             walnuts, honey roasted               NaN
#
#      publication_date
# 1481       2022-10-28
# 2208       2022-10-28
# 4053       2022-10-28
# 5405       2022-10-28
# 4054       2022-10-28
# ...               ...
# 1338       2022-10-28
# 1337       2022-10-28
# 1336       2022-10-28
# 2248       2022-10-28
# 2249       2022-10-28
#
# [1185 rows x 5 columns]

# %%
foundation_food[foundation_food["description"].str.contains("honey")]
# Out:
#         fdc_id          data_type                         description  \
# 20191  1105547    foundation_food  apples, honeycrisp, with skin, raw
# 20547  1750343    foundation_food  apples, honeycrisp, with skin, raw
# 2208   2342968  survey_fndds_food              almonds, honey roasted
# 2215   2342975  survey_fndds_food              cashews, honey roasted
# 2228   2342988  survey_fndds_food           mixed nuts, honey roasted
# 2237   2342997  survey_fndds_food              peanuts, honey roasted
# 2242   2343002  survey_fndds_food               pecans, honey roasted
# 2248   2343008  survey_fndds_food    walnuts, excluding honey roasted
# 2249   2343009  survey_fndds_food              walnuts, honey roasted
# 2757   2343517  survey_fndds_food  sopaipilla, without syrup or honey
# 2758   2343518  survey_fndds_food      sopaipilla with syrup or honey
# 3141   2343901  survey_fndds_food      rice, sweet, cooked with honey
# 3188   2343948  survey_fndds_food              cereal, o's, honey nut
# 3210   2343970  survey_fndds_food                cereal, other, honey
# 3976   2344736  survey_fndds_food                 honeydew melon, raw
# 4853   2345613  survey_fndds_food                   honey mustard dip
# 4976   2345736  survey_fndds_food                        honey butter
# 4999   2345759  survey_fndds_food              honey mustard dressing
# 5021   2345781  survey_fndds_food       honey mustard dressing, light
# 5032   2345792  survey_fndds_food    honey mustard dressing, fat free
# 5081   2345841  survey_fndds_food                               honey
#
#        food_category_id publication_date
# 20191               9.0       2020-10-30
# 20547               9.0       2020-10-30
# 2208                NaN       2022-10-28
# 2215                NaN       2022-10-28
# 2228                NaN       2022-10-28
# 2237                NaN       2022-10-28
# 2242                NaN       2022-10-28
# 2248                NaN       2022-10-28
# 2249                NaN       2022-10-28
# 2757                NaN       2022-10-28
# 2758                NaN       2022-10-28
# 3141                NaN       2022-10-28
# 3188                NaN       2022-10-28
# 3210                NaN       2022-10-28
# 3976                NaN       2022-10-28
# 4853                NaN       2022-10-28
# 4976                NaN       2022-10-28
# 4999                NaN       2022-10-28
# 5021                NaN       2022-10-28
# 5032                NaN       2022-10-28
# 5081                NaN       2022-10-28

# %%
# Found this earlier
chicken_wing_id
# Out:
# 331897

# %%
# Map foods to food_id (these have been filtered from larger quantities to smaller quantities)
# For example, if there were 5 kinds of apple, only one was chosen
whole_foods_id_map = {1750339: "apple", # red delicious
    1105314: "banana", # Bananas, ripe and slightly ripe, raw
    1102702: "blueberries", # blueberries, raw	
    746763: "beef", # t-bone steak 
    746764: "carrots", # frozen unprepared
    331897: "chicken_wings", # Chicken, broilers or fryers, drumstick, meat o...	
    329490: "egg", # Egg, whole, dried	
    1103956: "honey", # Honey
    1750347: "mushrooms", # Mushrooms, white button
    747448: "strawberries" # strawberries, raw
}

# %%
list(whole_foods_id_map.keys())
# Out:
# [1750339,
#  1105314,
#  1102702,
#  746763,
#  746764,
#  331897,
#  329490,
#  1103956,
#  1750347,
#  747448]

# %%
# Find nutrition for eight whole foods
target_whole_foods_df = food_nutrient[(food_nutrient["fdc_id"].isin(list(whole_foods_id_map.keys()))) & \
    (food_nutrient["nutrient_id"].isin(list(target_nutrient_dict.keys())))][["fdc_id", "nutrient_id", "amount"]]
target_whole_foods_df
# Out:
#         fdc_id  nutrient_id     amount
# 34265   329490         1004  39.800000
# 34266   329490         1005   1.870000
# 34270   329490         1003  48.100000
# 41686   331897         1004   5.950000
# 41718   331897         1003  23.900000
# 41729   331897         1005   0.000000
# 71052   746763         1003  27.300000
# 71079   746763         1005   0.000000
# 71097   746763         1004  11.400000
# 71175   746764         1004   0.470000
# 71197   746764         1005   7.920000
# 71198   746764         1003   0.810000
# 81087   747448         1004   0.220000
# 81165   747448         1005   7.630000
# 81175   747448         1003   0.640000
# 96994  1105314         1005  23.000000
# 97023  1105314         1004   0.290000
# 97028  1105314         1003   0.740000
# 98266  1750339         1005  14.781700
# 98267  1750339         1003   0.187500
# 98285  1750339         1004   0.212500
# 98488  1750347         1005   4.079375
# 98500  1750347         1004   0.370800
# 98508  1750347         1003   2.890625

# %%
# Pivot the table to how we want it
target_whole_foods_df = target_whole_foods_df.pivot_table("amount", "fdc_id", "nutrient_id")
target_whole_foods_df
# Out:
# nutrient_id       1003     1004       1005
# fdc_id
# 329490       48.100000  39.8000   1.870000
# 331897       23.900000   5.9500   0.000000
# 746763       27.300000  11.4000   0.000000
# 746764        0.810000   0.4700   7.920000
# 747448        0.640000   0.2200   7.630000
# 1105314       0.740000   0.2900  23.000000
# 1750339       0.187500   0.2125  14.781700
# 1750347       2.890625   0.3708   4.079375

# %%
len(whole_foods_id_map)
# Out:
# 10

# %%
target_whole_foods_df = target_whole_foods_df.reset_index(drop=False).rename_axis(None, axis=1)
target_whole_foods_df
# Out:
#     fdc_id       1003     1004       1005
# 0   329490  48.100000  39.8000   1.870000
# 1   331897  23.900000   5.9500   0.000000
# 2   746763  27.300000  11.4000   0.000000
# 3   746764   0.810000   0.4700   7.920000
# 4   747448   0.640000   0.2200   7.630000
# 5  1105314   0.740000   0.2900  23.000000
# 6  1750339   0.187500   0.2125  14.781700
# 7  1750347   2.890625   0.3708   4.079375

# %%
target_nutrient_dict
# Out:
# {1003: 'protein', 1004: 'fat', 1005: 'carbohydrate'}

# %%
# Rename columns
target_whole_foods_df.rename(columns=target_nutrient_dict, inplace=True)
target_whole_foods_df
# Out:
#     fdc_id    protein      fat  carbohydrate
# 0   329490  48.100000  39.8000      1.870000
# 1   331897  23.900000   5.9500      0.000000
# 2   746763  27.300000  11.4000      0.000000
# 3   746764   0.810000   0.4700      7.920000
# 4   747448   0.640000   0.2200      7.630000
# 5  1105314   0.740000   0.2900     23.000000
# 6  1750339   0.187500   0.2125     14.781700
# 7  1750347   2.890625   0.3708      4.079375

# %%
# Add food names
target_whole_foods_df["food_name"] = target_whole_foods_df["fdc_id"].map(whole_foods_id_map)
target_whole_foods_df
# Out:
#     fdc_id    protein      fat  carbohydrate      food_name
# 0   329490  48.100000  39.8000      1.870000            egg
# 1   331897  23.900000   5.9500      0.000000  chicken_wings
# 2   746763  27.300000  11.4000      0.000000           beef
# 3   746764   0.810000   0.4700      7.920000        carrots
# 4   747448   0.640000   0.2200      7.630000   strawberries
# 5  1105314   0.740000   0.2900     23.000000         banana
# 6  1750339   0.187500   0.2125     14.781700          apple
# 7  1750347   2.890625   0.3708      4.079375      mushrooms

# %% [markdown]
# All amounts are per 100g.

# %% [markdown]
# ## Export first 10 target food nutrition information

# %%
target_whole_foods_df.to_csv("target_ten_whole_food_nutrition_info.csv", index=False)

# %%
ten_whole_foods
# Out:
# ['apple',
#  'banana',
#  'beef',
#  'blueberries',
#  'carrots',
#  'chicken_wings',
#  'egg',
#  'honey',
#  'mushrooms',
#  'strawberries']
