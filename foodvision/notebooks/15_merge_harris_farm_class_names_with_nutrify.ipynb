# %% [markdown]
# # Notebook to explore the naming of the class names for FoodVision
#
# * **Goal:** Get the class names for FoodVision and see which ones can be broken down into something more specific.

# %%
# Append the upper level directory to sys
import sys
sys.path.append("..")

import pandas as pd
import numpy as np

from pathlib import Path

import torch

from utils.misc import sort_dict_by_values

from zero_shot_classification import open_clip_compute_image_features_of_list, open_clip_compute_text_features, open_clip_zero_shot_classification
# Out:
# /home/daniel/.local/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/daniel/.local/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZN3c106detail19maybe_wrap_dim_slowIlEET_S2_S2_b
#   warn(f"Failed to load image Python extension: {e}")

# %%
# Get original labels to label new data from
# Get config
from configs.default_config import config

args = config

# Connect to GCP
from utils.gcp_utils import set_gcp_credentials, test_gcp_connection
set_gcp_credentials(path_to_key="../utils/google-storage-key.json")
test_gcp_connection()

import wandb

# Initialize a new run
from utils.wandb_utils import wandb_load_artifact, wandb_download_and_load_labels

notes = f"autolabel new images"

run = wandb.init(project=args.wandb_project, 
                 job_type=args.wandb_job_type,
                 tags=['auto_label_new_images'],
                 notes=notes)

annotations, class_names, class_dict, reverse_class_dict, labels_path = wandb_download_and_load_labels(wandb_run=run,
wandb_labels_artifact_name=args.wandb_labels_artifact)

len(annotations.label.unique())
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# [INFO] GCP credentials set!
# [INFO] GCP connection successful! Access to GCP for saving/loading data and models available.
# wandb: Currently logged in as: mrdbourke. Use `wandb login --relogin` to force relogin
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/home/daniel/code/nutrify/foodvision/notebooks/wandb/run-20230313_103053-2dg5ukt2</code>
# Syncing run <strong><a href="https://wandb.ai/mrdbourke/test_wandb_artifacts_by_reference/runs/2dg5ukt2" target="_blank">upbeat-morning-488</a></strong> to <a href="https://wandb.ai/mrdbourke/test_wandb_artifacts_by_reference" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# [INFO] Labels directory: ./artifacts/food_vision_labels:v45
# [INFO] Labels path: artifacts/food_vision_labels:v45/annotations.csv
# [INFO] Working with: 269 classes
# 269

# %%
annotations, class_names, class_dict, reverse_class_dict, labels_path = wandb_download_and_load_labels(wandb_run=run,
wandb_labels_artifact_name=args.wandb_labels_artifact)
# Out:
# [INFO] Labels directory: ./artifacts/food_vision_labels:v45
# [INFO] Labels path: artifacts/food_vision_labels:v45/annotations.csv
# [INFO] Working with: 269 classes

# %%
len(class_dict), len(class_names), len(reverse_class_dict)
# Out:
# (269, 269, 269)

# %%
# Find the class_names with "lettuce" in them
[class_name for class_name in class_names if "lettuce" in class_name]
# Out:
# ['lettuce_cos',
#  'lettuce_iceberg',
#  'lettuce_oakleaf_green',
#  'lettuce_oakleaf_red']

# %% [markdown]
# ## Import class names

# %%
harris_farm = pd.read_csv("nutrify_food_icons_to_create.csv")
print(f"Num rows: {len(harris_farm)}")
harris_farm.head()
# Out:
# Num rows: 157
#      icon_name        category  done notes  \
# 0         eggs  animal_product   1.0   NaN
# 1  apple_green           fruit   1.0   NaN
# 2    apple_red           fruit   1.0   NaN
# 3      apricot           fruit   1.0   NaN
# 4      avocado           fruit   1.0   NaN
#
#                                          folder_link  \
# 0  https://drive.google.com/drive/folders/1S_Jx6C...
# 1  https://drive.google.com/drive/folders/1kR3etD...
# 2  https://drive.google.com/drive/folders/1EtnwDJ...
# 3  https://drive.google.com/drive/folders/1QLw9dl...
# 4  https://drive.google.com/drive/folders/1ZEMBcW...
#
#                      image_link last_edited  \
# 0          nutrify_icon_egg.png   2/18/2023
# 1  nutrify_icon_apple_green.png   2/18/2023
# 2    nutrify_icon_apple_red.png   2/18/2023
# 3    nutrify_icon_apricot02.png   2/18/2023
# 4    nutrify_icon_avocado02.png   2/18/2023
#
#                                    revisions  \
# 0            nutrify_icon_egg_revision01.png
# 1  nutrify_icon_apple_green02_revision01.png
# 2    nutrify_icon_apple_red02_revision01.svg
# 3      nutrify_icon_apricot02_revision01.png
# 4      nutrify_icon_avocado02_revision01.png
#
#                                             comments
# 0                                                NaN
# 1  Could we please get slices of Apple/green appl...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# Drop rows if the nutrify_class_name is nan
harris_farm = harris_farm.dropna(subset=['icon_name'])
print(f"Num rows: {len(harris_farm)}")
# Out:
# Num rows: 154

# %%
# Only keep columns "icon_name"
harris_farm = harris_farm[["icon_name"]]
harris_farm.head()
# Out:
#      icon_name
# 0         eggs
# 1  apple_green
# 2    apple_red
# 3      apricot
# 4      avocado

# %%
# Find the class_names with "lettuce" in them
[class_name for class_name in class_names if "lettuce" in class_name]
# Out:
# ['lettuce_cos',
#  'lettuce_iceberg',
#  'lettuce_oakleaf_green',
#  'lettuce_oakleaf_red']

# %%
harris_farm_classes = harris_farm.icon_name.unique()

# Remove item that contains "example"
harris_farm_classes = sorted([x for x in harris_farm_classes if "example" not in x])

# Remove seasons
seasons = ["spring", "summer", "autumn", "winter"]
harris_farm_classes = sorted([x for x in harris_farm_classes if x not in seasons])

# Remove egg variants
egg_variants = ['egg_fried',
 'egg_hard_boiled',
 'egg_raw',
 'egg_soft_boiled',]
harris_farm_classes = sorted([x for x in harris_farm_classes if x not in egg_variants])

# Rename brussel_sprout -> brussel_sprouts
harris_farm_classes = sorted([x.replace("brussel_sprout", "brussel_sprouts") for x in harris_farm_classes])

# Rename enoki_mushroom -> enoki_mushrooms
harris_farm_classes = sorted([x.replace("enoki_mushrooms", "mushroom_enoki") for x in harris_farm_classes])

# Rename parsnip -> parsnips
harris_farm_classes = sorted([x.replace("parsnip", "parsnips") for x in harris_farm_classes])

# Rename kiwi_fruit -> kiwifruit
harris_farm_classes = sorted([x.replace("kiwifruit", "kiwi_fruit") for x in harris_farm_classes])

# Rename taroroot -> taro
harris_farm_classes = sorted([x.replace("taroroot", "taro") for x in harris_farm_classes])

# Rename star_fruit -> starfruit
harris_farm_classes = sorted([x.replace("star_fruit", "starfruit") for x in harris_farm_classes])

# Rename snowpeas -> snow_peas
harris_farm_classes = sorted([x.replace("snowpeas", "snow_peas") for x in harris_farm_classes])

# Rename lettuce_cos -> cos_lettuce
# harris_farm_classes = sorted([x.replace("lettuce_cos", "cos_lettuce") for x in harris_farm_classes])

# Rename lettuce_iceberg -> iceberg_lettuce
# harris_farm_classes = sorted([x.replace("lettuce_iceberg", "iceberg_lettuce") for x in harris_farm_classes])

# Rename hazelnut -> hazelnuts
harris_farm_classes = sorted([x.replace("hazelnut", "hazelnuts") for x in harris_farm_classes])

# Rename cherry_tomato -> tomato_cherry
harris_farm_classes = sorted([x.replace("cherry_tomato", "tomato_cherry") for x in harris_farm_classes])

# Rename sweet_potato -> potato_sweet
harris_farm_classes = sorted([x.replace("sweet_potato", "potato_sweet") for x in harris_farm_classes])

# Rename squash -> squash_butternut
harris_farm_classes = sorted([x.replace("squash", "squash_butternut") for x in harris_farm_classes])

# Remove "mushrooms" from harris_farm_classes
harris_farm_classes = [food for food in harris_farm_classes if food != "mushrooms"]
# harris_farm_classes = sorted([x.replace("mushrooms", "") for x in harris_farm_classes])

# Compare the unique class names to the class names in the annotations
harris_farm_class_names_not_in_nutrify = sorted([class_name for class_name in harris_farm_classes if class_name not in class_names])
len(harris_farm_class_names_not_in_nutrify), harris_farm_class_names_not_in_nutrify
# Out:
# (9,
#  ['bay_leaves',
#   'chervil',
#   'choy_sum',
#   'curry_leaves',
#   'lemongrass',
#   'lime_leaves',
#   'quince',
#   'swede',
#   'witlof'])

# %%
# Multi names:
# onion_green -> spring_onion, bunching_onion
# shallots -> shallot, eschalot (also called eschallot), french shallot, scallion
# soda -> soft drink

# For VegFru
# "globe_artichoke" in VegFru is the same as "artichoke" in Harris Farm
# "chicory" in VegFru is the same as "chicory" in Harris Farm
# "black_bean_sprouts" & "soybean_sprouts" & "mung_bean_sprouts" in VegFru is the same as "bean_sprouts" in Harris Farm

# %%
# Combine the class names
combined_class_names = sorted(list(set(class_names + harris_farm_class_names_not_in_nutrify)))
len(combined_class_names), combined_class_names
# Out:
# (279,
#  ['almond_butter',
#   'almonds',
#   'apple_green',
#   'apple_red',
#   'apricot',
#   'artichoke',
#   'asparagus',
#   'avocado',
#   'bacon',
#   'bacon_and_egg_burger',
#   'bagel',
#   'baklava',
#   'banana',
#   'banana_bread',
#   'barbecue_sauce',
#   'basil',
#   'bay_leaves',
#   'bean_sprouts',
#   'beans',
#   'beef_curry',
#   'beef_diced',
#   'beef_kebab',
#   'beef_mince',
#   'beef_patty',
#   'beef_roast',
#   'beef_stir_fry',
#   'beer',
#   'beetroot',
#   'biltong',
#   'blackberries',
#   'blueberries',
#   'bok_choy',
#   'bread',
#   'bread_naan',
#   'broccoli',
#   'broccolini',
#   'brownie',
#   'brussel_sprouts',
#   'burrito',
#   'butter',
#   'cabbage_green',
#   'cabbage_red',
#   'calamari',
#   'candy',
#   'capsicum_green',
#   'capsicum_orange',
#   'capsicum_red',
#   'capsicum_yellow',
#   'carrot',
#   'carrot_purple',
#   'cashews',
#   'cauliflower',
#   'celery',
#   'cheese',
#   'cheeseburger',
#   'cherries',
#   'chervil',
#   'chicken_breast',
#   'chicken_thighs',
#   'chicken_wings',
#   'chicory',
#   'chilli',
#   'chimichurri',
#   'chives',
#   'chocolate',
#   'chocolate_cake',
#   'choko',
#   'choy_sum',
#   'coconut',
#   'coffee',
#   'coleslaw',
#   'cookies',
#   'coriander',
#   'corn',
#   'corn_chips',
#   'cream',
#   'croissant',
#   'crumbed_chicken',
#   'cucumber',
#   'cupcake',
#   'curry_chicken',
#   'curry_leaves',
#   'dates',
#   'dill',
#   'donuts',
#   'dragonfruit',
#   'edamame',
#   'eggplant',
#   'eggs',
#   'endive',
#   'fennel',
#   'figs',
#   'french_toast',
#   'fries',
#   'fruit_juice',
#   'fruit_salad',
#   'fruit_smoothie',
#   'garlic',
#   'garlic_bread',
#   'garlic_chives',
#   'ginger',
#   'goji_berries',
#   'granola',
#   'grapefruit',
#   'grapes_black',
#   'grapes_red',
#   'grapes_white',
#   'green_beans',
#   'guacamole',
#   'guava',
#   'gyoza',
#   'ham',
#   'hazelnuts',
#   'honey',
#   'honeydew_melon',
#   'hot_chocolate',
#   'ice_coffee',
#   'ice_cream',
#   'jalapeno',
#   'jerusalem_artichoke',
#   'kale',
#   'karaage_chicken',
#   'kimchi',
#   'kiwi_fruit',
#   'lamb_chops',
#   'leek',
#   'lemon',
#   'lemongrass',
#   'lentils',
#   'lettuce_cos',
#   'lettuce_iceberg',
#   'lettuce_oakleaf_green',
#   'lettuce_oakleaf_red',
#   'lime',
#   'lime_leaves',
#   'longan',
#   'lychee',
#   'macadamia',
#   'mandarin',
#   'mango',
#   'mangosteen',
#   'maple_syrup',
#   'marjoram',
#   'mayonnaise',
#   'melon_candy',
#   'melon_dino',
#   'melon_spanish',
#   'milk',
#   'mint',
#   'miso_soup',
#   'mixed_nuts',
#   'mushroom_enoki',
#   'mushroom_oyster',
#   'mushroom_portobello',
#   'mushroom_swiss_brown',
#   'mushroom_white_cups',
#   'nectarine',
#   'noodles',
#   'okra',
#   'olive_oil',
#   'olives',
#   'omelette',
#   'onion_brown',
#   'onion_green',
#   'onion_red',
#   'onion_white',
#   'orange',
#   'orange_juice',
#   'oregano',
#   'oysters',
#   'pain_au_chocolat',
#   'pancakes',
#   'papaya',
#   'parsley',
#   'parsnips',
#   'passionfruit',
#   'pasta',
#   'pawpaw',
#   'peach',
#   'peanuts',
#   'pear',
#   'pear_nashi',
#   'peas',
#   'pecans',
#   'persimmon',
#   'pickles',
#   'pineapple',
#   'pistachio',
#   'pizza',
#   'plum',
#   'plum_sugar',
#   'pomegranate',
#   'pomello',
#   'popcorn',
#   'pork_belly',
#   'pork_chop',
#   'pork_loins',
#   'pork_roast',
#   'porridge',
#   'potato_bake',
#   'potato_brown',
#   'potato_chips',
#   'potato_kipfler',
#   'potato_mashed',
#   'potato_purple_sweet',
#   'potato_red',
#   'potato_roast',
#   'potato_scallop',
#   'potato_sweet',
#   'potato_white',
#   'prawns',
#   'prosciutto',
#   'pumpkin',
#   'pumpkin_butternut',
#   'quince',
#   'radish_red',
#   'radish_white',
#   'ramen',
#   'raspberries',
#   'rhubarb',
#   'rice_brown',
#   'rice_fried',
#   'rice_white',
#   'rocket',
#   'rockmelon',
#   'rosemary',
#   'sage',
#   'salad',
#   'salami',
#   'salmon',
#   'salsa',
#   'salt',
#   'sandwich',
#   'sandwich_toasted',
#   'sardines',
#   'sausage_roll',
#   'sausages',
#   'scrambled_eggs',
#   'seaweed',
#   'shallots',
#   'silverbeet',
#   'snow_peas',
#   'soda',
#   'soy_sauce',
#   'spaghetti_bolognese',
#   'spinach',
#   'sports_drink',
#   'squash',
#   'squash_butternut',
#   'squash_pattypan',
#   'starfruit',
#   'steak',
#   'strawberries',
#   'sushi',
#   'swede',
#   'swiss_chard',
#   'tacos',
#   'tamarillo',
#   'taro',
#   'tarragon',
#   'tea',
#   'thyme',
#   'toast',
#   'tofu',
#   'tomato',
#   'tomato_cherry',
#   'tomato_chutney',
#   'tomato_sauce',
#   'turmeric',
#   'turnip',
#   'walnuts',
#   'watercress',
#   'watermelon',
#   'wine_red',
#   'wine_white',
#   'witlof',
#   'wombok',
#   'yoghurt',
#   'zucchini'])

# %% [markdown]
# ## Update annotations

# %%
original_annotations = annotations.copy()
updated_annotations = original_annotations.copy()

# %%
# radish -> radish_red/radish_white (also called daikon_radish)
radish_options = ["radish_red", "radish_white"]

radish_rows = updated_annotations[updated_annotations['class_name'] == "radish"]
radish_indices = radish_rows.index

updated_annotations.loc[radish_indices, 'class_name'] = np.random.choice(radish_options, size=len(radish_indices))

# How many rows contain "radish"?
len(updated_annotations[updated_annotations['class_name'].str.contains("radish")])
updated_annotations[updated_annotations['class_name'].str.contains("radish")]
# Out:
#                                                  filename  \
# 2097    test/daikon_radish/ff48d84c-d20f-4166-a12f-cb1...
# 2098    test/daikon_radish/fbe10a12-5171-4f91-8789-8d8...
# 2099    test/daikon_radish/aebe0abd-fe6f-41db-b83d-d26...
# 2100    test/daikon_radish/29c636b5-9bfd-4299-8e25-c09...
# 2101    test/daikon_radish/2e27848e-858e-45d7-8495-5c8...
# ...                                                   ...
# 109807  2023-03-03-food_photos/radish_red/9ec8fd03-296...
# 115043  2023-03-08-food_photos/radish_white/c7be9e02-d...
# 115044  2023-03-08-food_photos/radish_white/3eef7d0d-6...
# 115243  2023-03-08-food_photos/radish_red/2dd815ca-38e...
# 115244  2023-03-08-food_photos/radish_red/530f4df7-75a...
#
#                                        image_name    class_name  label  split  \
# 2097     ff48d84c-d20f-4166-a12f-cb1158bac3cd.jpg  radish_white    209   test
# 2098     fbe10a12-5171-4f91-8789-8d8790a4ad07.jpg  radish_white    209   test
# 2099     aebe0abd-fe6f-41db-b83d-d26fc327a724.jpg  radish_white    209   test
# 2100     29c636b5-9bfd-4299-8e25-c09728ee7edf.jpg  radish_white    209   test
# 2101     2e27848e-858e-45d7-8495-5c8fc91d8e89.jpg    radish_red    208   test
# ...                                           ...           ...    ...    ...
# 109807  9ec8fd03-2965-4cae-a61e-8ecb36ba791c.jpeg    radish_red    208  train
# 115043  c7be9e02-d3b5-4122-84f3-13b7eb2b91c1.jpeg  radish_white    209  train
# 115044  3eef7d0d-60f0-4494-b8d7-fcb79123aa23.jpeg  radish_white    209   test
# 115243  2dd815ca-38e1-4aaf-a8d2-418808c6d3ec.jpeg    radish_red    208  train
# 115244  530f4df7-75ad-4499-b0e3-2f2785502dd6.jpeg    radish_red    208  train
#
#        clear_or_confusing whole_food_or_dish one_food_or_multiple  \
# 2097                  NaN                NaN                  NaN
# 2098                  NaN                NaN                  NaN
# 2099                  NaN                NaN                  NaN
# 2100                  NaN                NaN                  NaN
# 2101                  NaN                NaN                  NaN
# ...                   ...                ...                  ...
# 109807              clear         whole_food             one_food
# 115043              clear         whole_food             one_food
# 115044              clear         whole_food             one_food
# 115243              clear         whole_food             one_food
# 115244              clear         whole_food             one_food
#
#        label_last_updated_at            label_source       image_source
# 2097     2023-03-06_11-28-55  open_clip_auto_relabel  internet_download
# 2098     2023-03-06_11-28-55  open_clip_auto_relabel  internet_download
# 2099     2023-03-06_11-28-55  open_clip_auto_relabel  internet_download
# 2100     2023-03-06_11-28-55  open_clip_auto_relabel  internet_download
# 2101     2023-03-06_11-28-55  open_clip_auto_relabel  internet_download
# ...                      ...                     ...                ...
# 109807   2023-03-06_11-28-55  open_clip_auto_relabel      manual_upload
# 115043   2023-03-09_08-24-32           manual_upload      manual_upload
# 115044   2023-03-09_08-24-32           manual_upload      manual_upload
# 115243   2023-03-09_08-24-32           manual_upload      manual_upload
# 115244   2023-03-09_08-24-32           manual_upload      manual_upload
#
# [1238 rows x 11 columns]

# %%
# daikon_radish -> radish_white (also called daikon_radish)
daikon_radish_options = ["radish_white"]

daikon_radish_rows = updated_annotations[updated_annotations['class_name'] == "daikon_radish"]
daikon_radish_indices = daikon_radish_rows.index

updated_annotations.loc[daikon_radish_indices, 'class_name'] = np.random.choice(daikon_radish_options, size=len(daikon_radish_indices))

# How many rows contain "radish"?
len(updated_annotations[updated_annotations['class_name'].str.contains("radish")])
updated_annotations[updated_annotations['class_name'].str.contains("radish")]
# Out:
#                                                 filename  \
# 2097   test/daikon_radish/ff48d84c-d20f-4166-a12f-cb1...
# 2098   test/daikon_radish/fbe10a12-5171-4f91-8789-8d8...
# 2099   test/daikon_radish/aebe0abd-fe6f-41db-b83d-d26...
# 2100   test/daikon_radish/29c636b5-9bfd-4299-8e25-c09...
# 2101   test/daikon_radish/2e27848e-858e-45d7-8495-5c8...
# ...                                                  ...
# 96543  all_nutrify_vegfru/radish_red/9ef1a88c-2282-43...
# 96544  all_nutrify_vegfru/radish_red/39777b14-fc09-48...
# 96545  all_nutrify_vegfru/radish_red/ca1a4aa5-4924-49...
# 96546  all_nutrify_vegfru/radish_red/9954879b-6392-41...
# 96547  all_nutrify_vegfru/radish_red/eebb89d4-3c1a-42...
#
#                                       image_name    class_name  label  split  \
# 2097    ff48d84c-d20f-4166-a12f-cb1158bac3cd.jpg  radish_white     64   test
# 2098    fbe10a12-5171-4f91-8789-8d8790a4ad07.jpg  radish_white     64   test
# 2099    aebe0abd-fe6f-41db-b83d-d26fc327a724.jpg  radish_white     64   test
# 2100    29c636b5-9bfd-4299-8e25-c09728ee7edf.jpg  radish_white     64   test
# 2101    2e27848e-858e-45d7-8495-5c8fc91d8e89.jpg  radish_white     64   test
# ...                                          ...           ...    ...    ...
# 96543  9ef1a88c-2282-430c-a785-4b53fb2f79bc.jpeg    radish_red    215  train
# 96544  39777b14-fc09-485f-916d-037270d45586.jpeg    radish_red    215  train
# 96545  ca1a4aa5-4924-4991-bfb9-90c35cbfc9d5.jpeg    radish_red    215  train
# 96546  9954879b-6392-41f2-bfb7-8883fcb4e6b1.jpeg    radish_red    215  train
# 96547  eebb89d4-3c1a-4238-b8d8-57a0f03827de.jpeg    radish_red    215  train
#
#       clear_or_confusing whole_food_or_dish one_food_or_multiple  \
# 2097                 NaN                NaN                  NaN
# 2098                 NaN                NaN                  NaN
# 2099                 NaN                NaN                  NaN
# 2100                 NaN                NaN                  NaN
# 2101                 NaN                NaN                  NaN
# ...                  ...                ...                  ...
# 96543                NaN                NaN                  NaN
# 96544                NaN                NaN                  NaN
# 96545                NaN                NaN                  NaN
# 96546                NaN                NaN                  NaN
# 96547                NaN                NaN                  NaN
#
#       label_last_updated_at                          label_source  \
# 2097                    NaN                                   NaN
# 2098                    NaN                                   NaN
# 2099                    NaN                                   NaN
# 2100                    NaN                                   NaN
# 2101                    NaN                                   NaN
# ...                     ...                                   ...
# 96543   2023-02-27_14-38-31  vegfru_dataset_with_manual_filtering
# 96544   2023-02-27_14-38-31  vegfru_dataset_with_manual_filtering
# 96545   2023-02-27_14-38-31  vegfru_dataset_with_manual_filtering
# 96546   2023-02-27_14-38-31  vegfru_dataset_with_manual_filtering
# 96547   2023-02-27_14-38-31  vegfru_dataset_with_manual_filtering
#
#             image_source
# 2097   internet_download
# 2098   internet_download
# 2099   internet_download
# 2100   internet_download
# 2101   internet_download
# ...                  ...
# 96543     vegfru_dataset
# 96544     vegfru_dataset
# 96545     vegfru_dataset
# 96546     vegfru_dataset
# 96547     vegfru_dataset
#
# [1231 rows x 11 columns]

# %%
# How many class_names contain "radish"?
for class_name in updated_class_names:
    if "radish" in class_name:
        print(class_name)
# Out:
# radish_white
# radish_red

# %%
# Combine nectarine and nectarines -> nectarine
updated_annotations.loc[updated_annotations['class_name'] == "nectarines", 'class_name'] = "nectarine"

# %%
# Combine steak + beef -> steak (steak = cut of meat, beef = whole animal)
updated_annotations.loc[updated_annotations['class_name'] == "beef", 'class_name'] = "steak"

# %%
# Rename the following classes:
# white_wine -> wine_white
# red_wine -> wine_red
# cherry_tomato -> tomato_cherry
# mashed_potato -> potato_mashed
# sweet_potato -> potato_sweet
# purple_sweet_potato -> potato_purple_sweet
# nuts -> mixed_nuts
# roast_beef -> beef_roast
# roast_pork -> pork_roast
# roast_potatoes -> potato_roast
# enoki_mushroom -> mushroom_enoki

updated_annotations.loc[updated_annotations['class_name'] == "white_wine", 'class_name'] = "wine_white"
updated_annotations.loc[updated_annotations['class_name'] == "red_wine", 'class_name'] = "wine_red"
updated_annotations.loc[updated_annotations['class_name'] == "cherry_tomato", 'class_name'] = "tomato_cherry"
updated_annotations.loc[updated_annotations['class_name'] == "mashed_potato", 'class_name'] = "potato_mashed"
updated_annotations.loc[updated_annotations['class_name'] == "sweet_potato", 'class_name'] = "potato_sweet"
updated_annotations.loc[updated_annotations['class_name'] == "purple_sweet_potato", 'class_name'] = "potato_purple_sweet"
updated_annotations.loc[updated_annotations['class_name'] == "nuts", 'class_name'] = "mixed_nuts"
updated_annotations.loc[updated_annotations['class_name'] == "roast_beef", 'class_name'] = "beef_roast"
updated_annotations.loc[updated_annotations['class_name'] == "roast_pork", 'class_name'] = "pork_roast"
updated_annotations.loc[updated_annotations['class_name'] == "roast_potatoes", 'class_name'] = "potato_roast"
updated_annotations.loc[updated_annotations['class_name'] == "enoki_mushroom", 'class_name'] = "mushroom_enoki"

# %%
# Get unique class_names
def get_unique_class_names():
    updated_class_names = sorted(updated_annotations.class_name.unique())
    print(len(updated_class_names), updated_class_names)
    return sorted(updated_class_names)

updated_class_names = get_unique_class_names()
# Out:
# 233 ['almond_butter', 'almonds', 'apple_green', 'apple_red', 'apricot', 'asparagus', 'avocado', 'bacon', 'bacon_and_egg_burger', 'bagel', 'baklava', 'banana', 'banana_bread', 'barbecue_sauce', 'basil', 'beans', 'beef_curry', 'beef_mince', 'beef_roast', 'beef_stir_fry', 'beer', 'beetroot', 'biltong', 'blackberries', 'blueberries', 'bok_choy', 'bread', 'bread_naan', 'broccoli', 'broccolini', 'brownie', 'brussel_sprouts', 'burrito', 'butter', 'cabbage_green', 'cabbage_red', 'calamari', 'candy', 'capsicum_green', 'capsicum_orange', 'capsicum_red', 'capsicum_yellow', 'carrot', 'cashews', 'cauliflower', 'celery', 'cheese', 'cheeseburger', 'cherries', 'chicken_breast', 'chicken_thighs', 'chicken_wings', 'chilli', 'chimichurri', 'chives', 'chocolate', 'chocolate_cake', 'coconut', 'coffee', 'coleslaw', 'cookies', 'coriander', 'corn', 'corn_chips', 'cream', 'croissant', 'crumbed_chicken', 'cucumber', 'cupcake', 'curry_chicken', 'dates', 'donuts', 'dragonfruit', 'edamame', 'eggplant', 'eggs', 'endive', 'fennel', 'figs', 'french_toast', 'fried_rice', 'fries', 'fruit_juice', 'fruit_smoothie', 'garlic', 'garlic_bread', 'ginger', 'goji_berries', 'granola', 'grapefruit', 'grapes_black', 'grapes_red', 'grapes_white', 'green_beans', 'guacamole', 'guava', 'gyoza', 'ham', 'hazelnuts', 'honey', 'honeydew_melon', 'hot_chocolate', 'ice_coffee', 'ice_cream', 'jerusalem_artichoke', 'kale', 'karaage_chicken', 'kimchi', 'kiwi_fruit', 'lamb_chops', 'leek', 'lemon', 'lentils', 'lettuce_cos', 'lettuce_iceberg', 'lettuce_oakleaf', 'lime', 'longan', 'lychee', 'macadamia', 'mandarin', 'mango', 'maple_syrup', 'mayonnaise', 'milk', 'mint', 'miso_soup', 'mixed_nuts', 'mushroom_enoki', 'mushroom_oyster', 'mushrooms', 'nectarine', 'noodles', 'okra', 'olive_oil', 'olives', 'omelette', 'onion_brown', 'onion_green', 'onion_red', 'onion_white', 'orange', 'orange_juice', 'oysters', 'pain_au_chocolat', 'pancakes', 'papaya', 'parsley', 'parsnips', 'passionfruit', 'pasta', 'pawpaw', 'peach', 'pear', 'pear_nashi', 'peas', 'pecans', 'persimmon', 'pickles', 'pineapple', 'pistachio', 'pizza', 'plum', 'pomegranate', 'popcorn', 'pork_belly', 'pork_chop', 'pork_loins', 'pork_roast', 'porridge', 'potato_bake', 'potato_brown', 'potato_chips', 'potato_mashed', 'potato_purple_sweet', 'potato_red', 'potato_roast', 'potato_scallop', 'potato_sweet', 'potato_white', 'prawns', 'prosciutto', 'pumpkin', 'radish_red', 'radish_white', 'ramen', 'raspberries', 'rhubarb', 'rice', 'rockmelon', 'rosemary', 'salad', 'salami', 'salmon', 'salsa', 'salt', 'sandwich', 'sardines', 'sausage_roll', 'sausages', 'scrambled_eggs', 'seaweed', 'shallots', 'snow_peas', 'soda', 'soy_sauce', 'spaghetti_bolognese', 'spinach', 'sports_drink', 'squash', 'starfruit', 'steak', 'strawberries', 'sushi', 'swiss_chard', 'tacos', 'tamarillo', 'taro', 'tea', 'toast', 'tofu', 'tomato', 'tomato_cherry', 'tomato_chutney', 'tomato_sauce', 'turnip', 'walnuts', 'watercress', 'watermelon', 'wine_red', 'wine_white', 'yoghurt', 'zucchini']

# %%
updated_class_names_and_harris_farm = sorted(list(set(updated_class_names + harris_farm_class_names_not_in_nutrify)))
len(updated_class_names_and_harris_farm), updated_class_names_and_harris_farm
# Out:
# (256,
#  ['almond_butter',
#   'almonds',
#   'apple_green',
#   'apple_red',
#   'apricot',
#   'artichoke',
#   'asparagus',
#   'avocado',
#   'bacon',
#   'bacon_and_egg_burger',
#   'bagel',
#   'baklava',
#   'banana',
#   'banana_bread',
#   'barbecue_sauce',
#   'basil',
#   'bay_leaves',
#   'bean_sprouts',
#   'beans',
#   'beef_curry',
#   'beef_mince',
#   'beef_roast',
#   'beef_stir_fry',
#   'beer',
#   'beetroot',
#   'biltong',
#   'blackberries',
#   'blueberries',
#   'bok_choy',
#   'bread',
#   'bread_naan',
#   'broccoli',
#   'broccolini',
#   'brownie',
#   'brussel_sprouts',
#   'burrito',
#   'butter',
#   'cabbage_green',
#   'cabbage_red',
#   'calamari',
#   'candy',
#   'capsicum_green',
#   'capsicum_orange',
#   'capsicum_red',
#   'capsicum_yellow',
#   'carrot',
#   'cashews',
#   'cauliflower',
#   'celery',
#   'cheese',
#   'cheeseburger',
#   'cherries',
#   'chervil',
#   'chicken_breast',
#   'chicken_thighs',
#   'chicken_wings',
#   'chicory',
#   'chilli',
#   'chimichurri',
#   'chives',
#   'chocolate',
#   'chocolate_cake',
#   'choy_sum',
#   'coconut',
#   'coffee',
#   'coleslaw',
#   'cookies',
#   'coriander',
#   'corn',
#   'corn_chips',
#   'cream',
#   'croissant',
#   'crumbed_chicken',
#   'cucumber',
#   'cupcake',
#   'curry_chicken',
#   'curry_leaves',
#   'dates',
#   'dill',
#   'donuts',
#   'dragonfruit',
#   'edamame',
#   'eggplant',
#   'eggs',
#   'endive',
#   'fennel',
#   'figs',
#   'french_toast',
#   'fried_rice',
#   'fries',
#   'fruit_juice',
#   'fruit_smoothie',
#   'garlic',
#   'garlic_bread',
#   'ginger',
#   'goji_berries',
#   'granola',
#   'grapefruit',
#   'grapes_black',
#   'grapes_red',
#   'grapes_white',
#   'green_beans',
#   'guacamole',
#   'guava',
#   'gyoza',
#   'ham',
#   'hazelnuts',
#   'honey',
#   'honeydew_melon',
#   'hot_chocolate',
#   'ice_coffee',
#   'ice_cream',
#   'jalapeno',
#   'jerusalem_artichoke',
#   'kale',
#   'karaage_chicken',
#   'kimchi',
#   'kiwi_fruit',
#   'lamb_chops',
#   'leek',
#   'lemon',
#   'lemongrass',
#   'lentils',
#   'lettuce_cos',
#   'lettuce_iceberg',
#   'lettuce_oakleaf',
#   'lime',
#   'lime_leaves',
#   'longan',
#   'lychee',
#   'macadamia',
#   'mandarin',
#   'mango',
#   'maple_syrup',
#   'marjoram',
#   'mayonnaise',
#   'milk',
#   'mint',
#   'miso_soup',
#   'mixed_nuts',
#   'mushroom_enoki',
#   'mushroom_oyster',
#   'mushrooms',
#   'nectarine',
#   'noodles',
#   'okra',
#   'olive_oil',
#   'olives',
#   'omelette',
#   'onion_brown',
#   'onion_green',
#   'onion_red',
#   'onion_white',
#   'orange',
#   'orange_juice',
#   'oregano',
#   'oysters',
#   'pain_au_chocolat',
#   'pancakes',
#   'papaya',
#   'parsley',
#   'parsnips',
#   'passionfruit',
#   'pasta',
#   'pawpaw',
#   'peach',
#   'peanuts',
#   'pear',
#   'pear_nashi',
#   'peas',
#   'pecans',
#   'persimmon',
#   'pickles',
#   'pineapple',
#   'pistachio',
#   'pizza',
#   'plum',
#   'pomegranate',
#   'popcorn',
#   'pork_belly',
#   'pork_chop',
#   'pork_loins',
#   'pork_roast',
#   'porridge',
#   'potato_bake',
#   'potato_brown',
#   'potato_chips',
#   'potato_mashed',
#   'potato_purple_sweet',
#   'potato_red',
#   'potato_roast',
#   'potato_scallop',
#   'potato_sweet',
#   'potato_white',
#   'prawns',
#   'prosciutto',
#   'pumpkin',
#   'quince',
#   'radish_red',
#   'radish_white',
#   'ramen',
#   'raspberries',
#   'rhubarb',
#   'rice',
#   'rockmelon',
#   'rosemary',
#   'sage',
#   'salad',
#   'salami',
#   'salmon',
#   'salsa',
#   'salt',
#   'sandwich',
#   'sardines',
#   'sausage_roll',
#   'sausages',
#   'scrambled_eggs',
#   'seaweed',
#   'shallots',
#   'silverbeet',
#   'snow_peas',
#   'soda',
#   'soy_sauce',
#   'spaghetti_bolognese',
#   'spinach',
#   'sports_drink',
#   'squash',
#   'starfruit',
#   'steak',
#   'strawberries',
#   'sushi',
#   'swede',
#   'swiss_chard',
#   'tacos',
#   'tamarillo',
#   'taro',
#   'tarragon',
#   'tea',
#   'thyme',
#   'toast',
#   'tofu',
#   'tomato',
#   'tomato_cherry',
#   'tomato_chutney',
#   'tomato_sauce',
#   'turmeric',
#   'turnip',
#   'walnuts',
#   'watercress',
#   'watermelon',
#   'wine_red',
#   'wine_white',
#   'witlof',
#   'wombok',
#   'yoghurt',
#   'zucchini'])

# %%
# Create a list of classes to add
classes_to_add = ["hash_brown", "rice_white", "rice_brown", "rice_fried"]

# Remove "rice" (because it's being expanded)
updated_class_names_and_harris_farm = [class_name for class_name in updated_class_names_and_harris_farm if class_name != "rice"]

# Add classes to updated list
updated_class_names_and_harris_farm = sorted(list(set(updated_class_names_and_harris_farm + classes_to_add)))

len(updated_class_names_and_harris_farm), updated_class_names_and_harris_farm
# Out:
# (259,
#  ['almond_butter',
#   'almonds',
#   'apple_green',
#   'apple_red',
#   'apricot',
#   'artichoke',
#   'asparagus',
#   'avocado',
#   'bacon',
#   'bacon_and_egg_burger',
#   'bagel',
#   'baklava',
#   'banana',
#   'banana_bread',
#   'barbecue_sauce',
#   'basil',
#   'bay_leaves',
#   'bean_sprouts',
#   'beans',
#   'beef_curry',
#   'beef_mince',
#   'beef_roast',
#   'beef_stir_fry',
#   'beer',
#   'beetroot',
#   'biltong',
#   'blackberries',
#   'blueberries',
#   'bok_choy',
#   'bread',
#   'bread_naan',
#   'broccoli',
#   'broccolini',
#   'brownie',
#   'brussel_sprouts',
#   'burrito',
#   'butter',
#   'cabbage_green',
#   'cabbage_red',
#   'calamari',
#   'candy',
#   'capsicum_green',
#   'capsicum_orange',
#   'capsicum_red',
#   'capsicum_yellow',
#   'carrot',
#   'cashews',
#   'cauliflower',
#   'celery',
#   'cheese',
#   'cheeseburger',
#   'cherries',
#   'chervil',
#   'chicken_breast',
#   'chicken_thighs',
#   'chicken_wings',
#   'chicory',
#   'chilli',
#   'chimichurri',
#   'chives',
#   'chocolate',
#   'chocolate_cake',
#   'choy_sum',
#   'coconut',
#   'coffee',
#   'coleslaw',
#   'cookies',
#   'coriander',
#   'corn',
#   'corn_chips',
#   'cream',
#   'croissant',
#   'crumbed_chicken',
#   'cucumber',
#   'cupcake',
#   'curry_chicken',
#   'curry_leaves',
#   'dates',
#   'dill',
#   'donuts',
#   'dragonfruit',
#   'edamame',
#   'eggplant',
#   'eggs',
#   'endive',
#   'fennel',
#   'figs',
#   'french_toast',
#   'fried_rice',
#   'fries',
#   'fruit_juice',
#   'fruit_smoothie',
#   'garlic',
#   'garlic_bread',
#   'ginger',
#   'goji_berries',
#   'granola',
#   'grapefruit',
#   'grapes_black',
#   'grapes_red',
#   'grapes_white',
#   'green_beans',
#   'guacamole',
#   'guava',
#   'gyoza',
#   'ham',
#   'hash_brown',
#   'hazelnuts',
#   'honey',
#   'honeydew_melon',
#   'hot_chocolate',
#   'ice_coffee',
#   'ice_cream',
#   'jalapeno',
#   'jerusalem_artichoke',
#   'kale',
#   'karaage_chicken',
#   'kimchi',
#   'kiwi_fruit',
#   'lamb_chops',
#   'leek',
#   'lemon',
#   'lemongrass',
#   'lentils',
#   'lettuce_cos',
#   'lettuce_iceberg',
#   'lettuce_oakleaf',
#   'lime',
#   'lime_leaves',
#   'longan',
#   'lychee',
#   'macadamia',
#   'mandarin',
#   'mango',
#   'maple_syrup',
#   'marjoram',
#   'mayonnaise',
#   'milk',
#   'mint',
#   'miso_soup',
#   'mixed_nuts',
#   'mushroom_enoki',
#   'mushroom_oyster',
#   'mushrooms',
#   'nectarine',
#   'noodles',
#   'okra',
#   'olive_oil',
#   'olives',
#   'omelette',
#   'onion_brown',
#   'onion_green',
#   'onion_red',
#   'onion_white',
#   'orange',
#   'orange_juice',
#   'oregano',
#   'oysters',
#   'pain_au_chocolat',
#   'pancakes',
#   'papaya',
#   'parsley',
#   'parsnips',
#   'passionfruit',
#   'pasta',
#   'pawpaw',
#   'peach',
#   'peanuts',
#   'pear',
#   'pear_nashi',
#   'peas',
#   'pecans',
#   'persimmon',
#   'pickles',
#   'pineapple',
#   'pistachio',
#   'pizza',
#   'plum',
#   'pomegranate',
#   'popcorn',
#   'pork_belly',
#   'pork_chop',
#   'pork_loins',
#   'pork_roast',
#   'porridge',
#   'potato_bake',
#   'potato_brown',
#   'potato_chips',
#   'potato_mashed',
#   'potato_purple_sweet',
#   'potato_red',
#   'potato_roast',
#   'potato_scallop',
#   'potato_sweet',
#   'potato_white',
#   'prawns',
#   'prosciutto',
#   'pumpkin',
#   'quince',
#   'radish_red',
#   'radish_white',
#   'ramen',
#   'raspberries',
#   'rhubarb',
#   'rice_brown',
#   'rice_fried',
#   'rice_white',
#   'rockmelon',
#   'rosemary',
#   'sage',
#   'salad',
#   'salami',
#   'salmon',
#   'salsa',
#   'salt',
#   'sandwich',
#   'sardines',
#   'sausage_roll',
#   'sausages',
#   'scrambled_eggs',
#   'seaweed',
#   'shallots',
#   'silverbeet',
#   'snow_peas',
#   'soda',
#   'soy_sauce',
#   'spaghetti_bolognese',
#   'spinach',
#   'sports_drink',
#   'squash',
#   'starfruit',
#   'steak',
#   'strawberries',
#   'sushi',
#   'swede',
#   'swiss_chard',
#   'tacos',
#   'tamarillo',
#   'taro',
#   'tarragon',
#   'tea',
#   'thyme',
#   'toast',
#   'tofu',
#   'tomato',
#   'tomato_cherry',
#   'tomato_chutney',
#   'tomato_sauce',
#   'turmeric',
#   'turnip',
#   'walnuts',
#   'watercress',
#   'watermelon',
#   'wine_red',
#   'wine_white',
#   'witlof',
#   'wombok',
#   'yoghurt',
#   'zucchini'])

# %%
# New
# hash_brown 
# rice -> rice_white, rice_brown, rice_fried
# beef_patty -> beef_pattie

# Next
# Merge updated class_names with Nutrify original class names (replace and rename and train another model)
# Get images for new Harris Farm class names and upload to model
# Combine all class names into largest model yet
# Start creating a dictionary/JSON of class names and their synonyms

# %%
from typing import List, Dict, Tuple

def get_updated_class_names_class_dict_and_reverse_class_dict(df: pd.DataFrame) -> Tuple[List[str], Dict[int, str], Dict[str, int]]:
    """Get an updated class names list, class dict and reverse class dict from a dataframe."""
    updated_class_names = sorted(df.class_name.unique())
    updated_class_dict = {i: class_name for i, class_name in enumerate(updated_class_names)}
    updated_reverse_class_dict = {class_name: i for i, class_name in enumerate(updated_class_names)}
    assert len(updated_class_dict) == len(updated_reverse_class_dict), "Class dict and reverse class dict are not the same length"
    return updated_class_names, updated_class_dict, updated_reverse_class_dict

def map_updated_class_dict_to_updated_annotations(df: pd.DataFrame, updated_reverse_class_dict: Dict[str, int]) -> pd.DataFrame:
    """Map updated class dict to updated annotations dataframe.
    
    For example, go from {"apple_red": 1} -> df["label"] = 1
    """
    updated_annotations = df.copy()
    updated_annotations.loc[:, 'label'] = updated_annotations['class_name'].map(updated_reverse_class_dict)
    assert len(updated_annotations.label.unique()) == len(updated_reverse_class_dict), "Number of unique labels in updated annotations does not match number of unique class names in updated reverse class dict"
    return updated_annotations

# %%
updated_class_names, updated_class_dict, updated_reverse_class_dict = get_updated_class_names_class_dict_and_reverse_class_dict(updated_annotations)

updated_annotations = map_updated_class_dict_to_updated_annotations(updated_annotations, updated_reverse_class_dict)

len(updated_class_names), updated_class_names[:10]
# Out:
# (233,
#  ['almond_butter',
#   'almonds',
#   'apple_green',
#   'apple_red',
#   'apricot',
#   'asparagus',
#   'avocado',
#   'bacon',
#   'bacon_and_egg_burger',
#   'bagel'])

# %%
updated_annotations
# Out:
#                                                  filename  \
# 0       test/pain_au_chocolat/4fd7cb42-bd7f-48f1-bfdc-...
# 1       test/pain_au_chocolat/2062f52a-781c-4e4f-b8a7-...
# 2       test/pain_au_chocolat/8003e0f6-37e8-460d-9c14-...
# 3       test/pain_au_chocolat/839437c8-c643-408f-9f04-...
# 4       test/pain_au_chocolat/ca5c13ff-a535-4b69-9144-...
# ...                                                   ...
# 108734  all_nutrify_vegfru/onion_brown/dcfb12aa-529a-4...
# 108735  all_nutrify_vegfru/onion_brown/56092377-8538-4...
# 108736  all_nutrify_vegfru/onion_brown/2abe0c8a-d934-4...
# 108737  all_nutrify_vegfru/onion_brown/dc0cccea-9c94-4...
# 108738  all_nutrify_vegfru/onion_brown/9e216cc8-65d9-4...
#
#                                        image_name        class_name  label  \
# 0        4fd7cb42-bd7f-48f1-bfdc-607c2f54b788.jpg  pain_au_chocolat    144
# 1        2062f52a-781c-4e4f-b8a7-0a108934f453.jpg  pain_au_chocolat    144
# 2        8003e0f6-37e8-460d-9c14-e7c6fe44a37f.jpg  pain_au_chocolat    144
# 3        839437c8-c643-408f-9f04-d0d3bec238c3.jpg  pain_au_chocolat    144
# 4        ca5c13ff-a535-4b69-9144-e06275e01e35.jpg  pain_au_chocolat    144
# ...                                           ...               ...    ...
# 108734  dcfb12aa-529a-4981-bd04-bb89b1fec91e.jpeg       onion_brown    137
# 108735  56092377-8538-46db-a270-930b11cd0798.jpeg       onion_brown    137
# 108736  2abe0c8a-d934-4a13-8105-13d5b69ab95f.jpeg       onion_brown    137
# 108737  dc0cccea-9c94-41c9-9664-02be13017ae0.jpeg       onion_brown    137
# 108738  9e216cc8-65d9-41ef-bf6f-46a97a15f897.jpeg       onion_brown    137
#
#         split clear_or_confusing whole_food_or_dish one_food_or_multiple  \
# 0        test                NaN                NaN                  NaN
# 1        test                NaN                NaN                  NaN
# 2        test                NaN                NaN                  NaN
# 3        test                NaN                NaN                  NaN
# 4        test                NaN                NaN                  NaN
# ...       ...                ...                ...                  ...
# 108734  train                NaN                NaN                  NaN
# 108735  train                NaN                NaN                  NaN
# 108736   test                NaN                NaN                  NaN
# 108737  train                NaN                NaN                  NaN
# 108738  train                NaN                NaN                  NaN
#
#        label_last_updated_at                          label_source  \
# 0                        NaN                                   NaN
# 1                        NaN                                   NaN
# 2                        NaN                                   NaN
# 3                        NaN                                   NaN
# 4                        NaN                                   NaN
# ...                      ...                                   ...
# 108734   2023-02-27_14-38-31  vegfru_dataset_with_manual_filtering
# 108735   2023-02-27_14-38-31  vegfru_dataset_with_manual_filtering
# 108736   2023-02-27_14-38-31  vegfru_dataset_with_manual_filtering
# 108737   2023-02-27_14-38-31  vegfru_dataset_with_manual_filtering
# 108738   2023-02-27_14-38-31  vegfru_dataset_with_manual_filtering
#
#              image_source
# 0       internet_download
# 1       internet_download
# 2       internet_download
# 3       internet_download
# 4       internet_download
# ...                   ...
# 108734     vegfru_dataset
# 108735     vegfru_dataset
# 108736     vegfru_dataset
# 108737     vegfru_dataset
# 108738     vegfru_dataset
#
# [108739 rows x 11 columns]

# %%
updated_annotations.label.value_counts()
# Out:
# 91     1828
# 146    1815
# 74     1812
# 84     1697
# 121    1633
#        ...
# 39       50
# 38       50
# 41       45
# 40       43
# 174       1
# Name: label, Length: 233, dtype: int64

# %%
# Find the class names with under 1000 images (sorted descending)
updated_annotations.class_name.value_counts()[updated_annotations.class_name.value_counts() < 1000].sort_values(ascending=True).to_dict()
# Out:
# {'potato_purple_sweet': 1,
#  'capsicum_red': 43,
#  'capsicum_yellow': 45,
#  'capsicum_green': 50,
#  'capsicum_orange': 50,
#  'fruit_smoothie': 60,
#  'prosciutto': 62,
#  'curry_chicken': 64,
#  'bread_naan': 67,
#  'cabbage_green': 80,
#  'potato_red': 93,
#  'guacamole': 100,
#  'beans': 101,
#  'cream': 104,
#  'lettuce_oakleaf': 112,
#  'chocolate': 123,
#  'butter': 124,
#  'kimchi': 125,
#  'bagel': 131,
#  'pawpaw': 133,
#  'turnip': 136,
#  'bacon': 140,
#  'toast': 142,
#  'popcorn': 142,
#  'corn_chips': 146,
#  'olive_oil': 147,
#  'starfruit': 148,
#  'tofu': 152,
#  'cheese': 153,
#  'sushi': 154,
#  'honey': 156,
#  'yoghurt': 164,
#  'salt': 165,
#  'mushroom_oyster': 166,
#  'fries': 167,
#  'salami': 169,
#  'salmon': 171,
#  'rice': 171,
#  'soy_sauce': 172,
#  'baklava': 172,
#  'soda': 173,
#  'pork_loins': 173,
#  'burrito': 174,
#  'ham': 175,
#  'squash': 175,
#  'maple_syrup': 175,
#  'sports_drink': 176,
#  'pork_chop': 177,
#  'rockmelon': 177,
#  'chocolate_cake': 178,
#  'sandwich': 179,
#  'wine_white': 179,
#  'croissant': 180,
#  'seaweed': 180,
#  'salsa': 181,
#  'pork_roast': 182,
#  'candy': 182,
#  'beef_mince': 182,
#  'granola': 183,
#  'mushrooms': 183,
#  'brownie': 184,
#  'mixed_nuts': 185,
#  'pickles': 185,
#  'almond_butter': 185,
#  'orange_juice': 185,
#  'donuts': 185,
#  'cupcake': 186,
#  'sausages': 187,
#  'porridge': 188,
#  'pizza': 188,
#  'cheeseburger': 188,
#  'sardines': 188,
#  'oysters': 189,
#  'lamb_chops': 189,
#  'beer': 190,
#  'tacos': 191,
#  'biltong': 191,
#  'wine_red': 192,
#  'garlic_bread': 192,
#  'coffee': 193,
#  'lentils': 193,
#  'beef_roast': 194,
#  'calamari': 194,
#  'potato_scallop': 194,
#  'rosemary': 194,
#  'tomato_sauce': 195,
#  'potato_chips': 195,
#  'pancakes': 196,
#  'tomato_chutney': 196,
#  'dragonfruit': 197,
#  'fried_rice': 198,
#  'barbecue_sauce': 198,
#  'pain_au_chocolat': 199,
#  'mayonnaise': 199,
#  'blackberries': 200,
#  'kale': 201,
#  'watercress': 202,
#  'prawns': 202,
#  'bacon_and_egg_burger': 202,
#  'potato_roast': 202,
#  'dates': 202,
#  'milk': 203,
#  'omelette': 203,
#  'pasta': 203,
#  'tea': 203,
#  'beef_curry': 205,
#  'hot_chocolate': 205,
#  'tamarillo': 206,
#  'fruit_juice': 207,
#  'chicken_thighs': 208,
#  'noodles': 209,
#  'potato_mashed': 209,
#  'ice_cream': 209,
#  'gyoza': 210,
#  'beef_stir_fry': 210,
#  'french_toast': 211,
#  'miso_soup': 213,
#  'chimichurri': 215,
#  'banana_bread': 216,
#  'pork_belly': 216,
#  'chicken_wings': 216,
#  'crumbed_chicken': 217,
#  'karaage_chicken': 217,
#  'potato_bake': 218,
#  'chicken_breast': 219,
#  'scrambled_eggs': 219,
#  'sausage_roll': 220,
#  'spaghetti_bolognese': 222,
#  'cookies': 227,
#  'snow_peas': 227,
#  'ramen': 229,
#  'eggs': 232,
#  'chives': 237,
#  'bread': 248,
#  'salad': 253,
#  'coleslaw': 260,
#  'pear': 305,
#  'ice_coffee': 319,
#  'lettuce_cos': 331,
#  'broccolini': 344,
#  'potato_white': 369,
#  'honeydew_melon': 373,
#  'steak': 378,
#  'potato_brown': 384,
#  'endive': 399,
#  'onion_white': 402,
#  'parsnips': 413,
#  'hazelnuts': 449,
#  'lettuce_iceberg': 455,
#  'pear_nashi': 482,
#  'cabbage_red': 490,
#  'okra': 495,
#  'green_beans': 503,
#  'spinach': 509,
#  'shallots': 536,
#  'mandarin': 544,
#  'radish_red': 553,
#  'zucchini': 555,
#  'beetroot': 557,
#  'onion_green': 560,
#  'goji_berries': 573,
#  'broccoli': 574,
#  'mint': 575,
#  'mushroom_enoki': 578,
#  'coconut': 599,
#  'onion_red': 622,
#  'olives': 630,
#  'taro': 631,
#  'swiss_chard': 636,
#  'lime': 646,
#  'apple_green': 657,
#  'basil': 670,
#  'radish_white': 678,
#  'parsley': 686,
#  'cauliflower': 712,
#  'grapefruit': 742,
#  'fennel': 757,
#  'macadamia': 762,
#  'coriander': 769,
#  'blueberries': 777,
#  'onion_brown': 778,
#  'celery': 796,
#  'edamame': 800,
#  'brussel_sprouts': 802,
#  'pistachio': 814,
#  'lemon': 816,
#  'cashews': 824,
#  'apricot': 847,
#  'almonds': 856,
#  'rhubarb': 859,
#  'raspberries': 867,
#  'leek': 891,
#  'jerusalem_artichoke': 931,
#  'persimmon': 937,
#  'longan': 940,
#  'pumpkin': 942,
#  'ginger': 974,
#  'orange': 975,
#  'chilli': 985,
#  'avocado': 998}

# %%
# Calculate the class weights for each class
import numpy as np
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class_counts = np.bincount(updated_annotations.label)
class_weights = {i: 1. / count for i, count in enumerate(class_counts)}
class_weights_tensor = torch.Tensor(list(class_weights.values())).to(device)
class_weights_tensor
# Out:
# tensor([5.4054e-03, 1.1682e-03, 1.5221e-03, 7.5930e-04, 1.1806e-03, 1.0000e-03,
#         1.0020e-03, 7.1429e-03, 4.9505e-03, 7.6336e-03, 5.8140e-03, 6.4392e-04,
#         4.6296e-03, 5.0505e-03, 1.4925e-03, 9.9010e-03, 4.8780e-03, 5.4945e-03,
#         5.1546e-03, 4.7619e-03, 5.2632e-03, 1.7953e-03, 5.2356e-03, 5.0000e-03,
#         1.2870e-03, 9.8619e-04, 4.0323e-03, 1.4925e-02, 1.7422e-03, 2.9070e-03,
#         5.4348e-03, 1.2469e-03, 5.7471e-03, 8.0645e-03, 1.2500e-02, 2.0408e-03,
#         5.1546e-03, 5.4945e-03, 2.0000e-02, 2.0000e-02, 2.3256e-02, 2.2222e-02,
#         9.1827e-04, 1.2136e-03, 1.4045e-03, 1.2563e-03, 6.5359e-03, 5.3191e-03,
#         6.6845e-04, 4.5662e-03, 4.8077e-03, 4.6296e-03, 1.0152e-03, 4.6512e-03,
#         4.2194e-03, 8.1301e-03, 5.6180e-03, 1.6694e-03, 5.1813e-03, 3.8462e-03,
#         4.4053e-03, 1.3004e-03, 8.2919e-04, 6.8493e-03, 9.6154e-03, 5.5556e-03,
#         4.6083e-03, 8.9286e-04, 5.3763e-03, 1.5625e-02, 4.9505e-03, 5.4054e-03,
#         5.0761e-03, 1.2500e-03, 5.5188e-04, 4.3103e-03, 2.5063e-03, 1.3210e-03,
#         7.7399e-04, 4.7393e-03, 5.0505e-03, 5.9880e-03, 4.8309e-03, 1.6667e-02,
#         5.8928e-04, 5.2083e-03, 1.0267e-03, 1.7452e-03, 5.4645e-03, 1.3477e-03,
#         8.2102e-04, 5.4705e-04, 7.4184e-04, 1.9881e-03, 1.0000e-02, 7.9428e-04,
#         4.7619e-03, 5.7143e-03, 2.2272e-03, 6.4103e-03, 2.6810e-03, 4.8780e-03,
#         3.1348e-03, 4.7847e-03, 1.0741e-03, 4.9751e-03, 4.6083e-03, 8.0000e-03,
#         7.7821e-04, 5.2910e-03, 1.1223e-03, 1.2255e-03, 5.1813e-03, 3.0211e-03,
#         2.1978e-03, 8.9286e-03, 1.5480e-03, 1.0638e-03, 8.1037e-04, 1.3123e-03,
#         1.8382e-03, 6.1237e-04, 5.7143e-03, 5.0251e-03, 4.9261e-03, 1.7391e-03,
#         4.6948e-03, 5.4054e-03, 1.7301e-03, 6.0241e-03, 5.4645e-03, 8.0386e-04,
#         4.7847e-03, 2.0202e-03, 6.8027e-03, 1.5873e-03, 4.9261e-03, 1.2853e-03,
#         1.7857e-03, 1.6077e-03, 2.4876e-03, 1.0256e-03, 5.4054e-03, 5.2910e-03,
#         5.0251e-03, 5.1020e-03, 5.5096e-04, 1.4577e-03, 2.4213e-03, 8.1967e-04,
#         4.9261e-03, 7.5188e-03, 8.5179e-04, 3.2787e-03, 2.0747e-03, 8.0580e-04,
#         8.4531e-04, 1.0672e-03, 5.4054e-03, 8.7719e-04, 1.2285e-03, 5.3191e-03,
#         9.1158e-04, 7.5131e-04, 7.0423e-03, 4.6296e-03, 5.6497e-03, 5.7803e-03,
#         5.4945e-03, 5.3191e-03, 4.5872e-03, 2.6042e-03, 5.1282e-03, 4.7847e-03,
#         1.0000e+00, 1.0753e-02, 4.9505e-03, 5.1546e-03, 8.1699e-04, 2.7100e-03,
#         4.9505e-03, 1.6129e-02, 1.0616e-03, 1.8083e-03, 1.4749e-03, 4.3668e-03,
#         1.1534e-03, 1.1641e-03, 5.8480e-03, 5.6497e-03, 5.1546e-03, 3.9526e-03,
#         5.9172e-03, 5.8480e-03, 5.5249e-03, 6.0606e-03, 5.5866e-03, 5.3191e-03,
#         4.5455e-03, 5.3476e-03, 4.5662e-03, 5.5556e-03, 1.8657e-03, 4.4053e-03,
#         5.7803e-03, 5.8140e-03, 4.5045e-03, 1.9646e-03, 5.6818e-03, 5.7143e-03,
#         6.7568e-03, 2.6455e-03, 6.4392e-04, 6.4935e-03, 1.5723e-03, 5.2356e-03,
#         4.8544e-03, 1.5848e-03, 4.9261e-03, 7.0423e-03, 6.5789e-03, 8.8028e-04,
#         8.4531e-04, 5.1020e-03, 5.1282e-03, 7.3529e-03, 9.8425e-04, 4.9505e-03,
#         7.8802e-04, 5.2083e-03, 5.5866e-03, 6.0976e-03, 1.8018e-03],
#        device='cuda:0')

# %%
# How many unique labels are there?
len(updated_annotations.label.unique())
# Out:
# 233

# %%
from utils.misc import check_for_differences_between_df

num_differences = check_for_differences_between_df(updated_annotations, original_annotations)
num_differences
# Out:
# 99880

# %%
config.annotations_columns_to_export
# Out:
# ['filename',
#  'image_name',
#  'class_name',
#  'label',
#  'split',
#  'clear_or_confusing',
#  'whole_food_or_dish',
#  'one_food_or_multiple',
#  'label_last_updated_at',
#  'label_source',
#  'image_source']

# %%
updated_annotations["class_name"].value_counts()
# Out:
# grapes_red             1828
# papaya                 1815
# eggplant               1812
# garlic                 1697
# mango                  1633
#                        ...
# capsicum_orange          50
# capsicum_green           50
# capsicum_yellow          45
# capsicum_red             43
# potato_purple_sweet       1
# Name: class_name, Length: 233, dtype: int64

# %%
# Upload the updated annotations to Google Storage and track the changes
import os
from utils.gcp_utils import upload_to_gs, rename_blob, delete_blob
from utils.wandb_utils import wandb_add_artifact_with_reference
from utils.misc import get_now_time

UPDATED_ANNOTATIONS_TARGET_FILENAME = "updated_annotations.csv"
ORIGINAL_ANNOTATIONS_TARGET_FILENAME = "annotations.csv"
GS_BUCKET_NAME = config.gs_bucket_name

# Export the updated annotations to a CSV
columns_to_export = config.annotations_columns_to_export
print(f"[INFO] Exporting the following columns to {UPDATED_ANNOTATIONS_TARGET_FILENAME}: {columns_to_export}")

# TODO: Check if the updated_annotations_reset_index and the original_annotations actually differ, if so save them and upload them, else exit
if num_differences > 0:
    print(f"[INFO] {num_differences} changes to annotations.csv, updated label files and original annotations are different, saving the updated annotations.csv")

    # Export the updated_annotations_reset_index to a csv
    updated_annotations[columns_to_export].to_csv(UPDATED_ANNOTATIONS_TARGET_FILENAME, index=False)

    # Upload the updated CSV to Google Storage
    upload_to_gs(bucket_name=GS_BUCKET_NAME, 
                 source_file_name=UPDATED_ANNOTATIONS_TARGET_FILENAME, 
                 destination_blob_name=UPDATED_ANNOTATIONS_TARGET_FILENAME)

    # Rename the old CSV on Google Storage
    bucket_to_move_old_annotations_to = "old_annotations"
    name_to_rename_old_annotations = os.path.join(bucket_to_move_old_annotations_to, f"{get_now_time()}_old_annotations.csv")

    rename_blob(bucket_name=GS_BUCKET_NAME,
                blob_name=ORIGINAL_ANNOTATIONS_TARGET_FILENAME,
                new_name=name_to_rename_old_annotations)

    # Rename the "updated_annotations.csv" on Google Storage to "annotations.csv" 
    rename_blob(bucket_name=GS_BUCKET_NAME,
                blob_name=UPDATED_ANNOTATIONS_TARGET_FILENAME,
                new_name=ORIGINAL_ANNOTATIONS_TARGET_FILENAME)

    # Track the changes in the annotations with Weights & Biases
    annotations_path_on_gcs = f"gs://{GS_BUCKET_NAME}/{ORIGINAL_ANNOTATIONS_TARGET_FILENAME}"
    wandb_add_artifact_with_reference(wandb_run=run,
                                      artifact_name="food_vision_labels",
                                      artifact_type="labels",
                                      description="Labels for FoodVision project",
                                      reference_path=annotations_path_on_gcs)
else:
    print("[INFO] No changes to annotations.csv, updated label files and original annotations are the same, try fixing/updating the label files and try again")
# Out:
# [INFO] Exporting the following columns to updated_annotations.csv: ['filename', 'image_name', 'class_name', 'label', 'split', 'clear_or_confusing', 'whole_food_or_dish', 'one_food_or_multiple', 'label_last_updated_at', 'label_source', 'image_source']
# [INFO] 99880 changes to annotations.csv, updated label files and original annotations are different, saving the updated annotations.csv
# [INFO] Uploading updated_annotations.csv to updated_annotations.csv...
# [INFO] Connected to Google Storage bucket: food_vision_bucket_with_object_versioning
# [INFO] File updated_annotations.csv uploaded to food_vision_bucket_with_object_versioning/updated_annotations.csv.
# [INFO] File size: 20812605 bytes
# [INFO] Blob annotations.csv has been renamed to old_annotations/2023-02-28_13-21-51_old_annotations.csv
# [INFO] Blob updated_annotations.csv has been renamed to annotations.csv
# [INFO] Logging 'food_vision_labels' from 'gs://food_vision_bucket_with_object_versioning/annotations.csv' to Weights & Biases...
